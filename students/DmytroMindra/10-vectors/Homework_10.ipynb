# %% [markdown]
# # Infrastructure setup

# %% [markdown]
# ## Initilizing the runtime (runtime)

# %%
# %env local_data_path = /Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/
# !echo "data path: ${local_data_path}"

# Google collab restarts the VMs after some time and drops all the files stored on VM,
# so some files would be persisted on mounted Google Drive to persist the progress
# between the sessions

GDRIVE_PATH = '/Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/'

# 1551 Dataset has lots of small files. Reading them from mounted Google Drive
# sometimes takes significant time, so I have decided to checkout it to VM
# DATA_1551_PATH = '/content/drive/My  Drive/Colab/homework-10/1551.gov.ua/raw/'
DATA_1551_PATH = '/Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/1551.gov.ua/raw/'


#
# Working with word2vec models
#

models_path = '/Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/vec_models/'

# news.cased.tokenized.word2vec.300d
news_cased_tokenized_word2vec_300d_path = models_path +'news.cased.tokenized.word2vec.300d' 
# news.lowercased.tokenized.word2vec.300d
news_lowercased_tokenized_word2vec_300d_path = models_path +'news.lowercased.tokenized.word2vec.300d' 
# news.cased.lemmatized.word2vec.300d
news_cased_lemmatized_word2vec_300d_path = models_path +'news.cased.lemmatized.word2vec.300d' 
# news.lowercased.lemmatized.word2vec.300d
news_lowercased_lemmatized_word2vec_300d_path = models_path +'news.lowercased.lemmatized.word2vec.300d' 

# ubercorpus.cased.tokenized.word2vec.300d
ubercorpus_cased_tokenized_word2vec_300d_path = models_path + 'ubercorpus.cased.tokenized.word2vec.300d'

# ubercorpus.lowercased.tokenized.word2vec.300d
ubercorpus_lowercased_tokenized_word2vec_300d_path = models_path + 'ubercorpus.lowercased.tokenized.word2vec.300d'

# ubercorpus.cased.lemmatized.word2vec.300d
ubercorpus_cased_lemmatized_word2vec_300d_path = models_path + 'ubercorpus.cased.lemmatized.word2vec.300d'

# ubercorpus.lowercased.lemmatized.word2vec.300d
ubercorpus_lowercased_lemmatized_word2vec_300d_path = models_path + 'ubercorpus.lowercased.lemmatized.word2vec.300d'


#
# An amazing progress bar function
#

def printProgressBar (iteration, total, prefix = '', suffix = '', decimals = 1, length = 100, fill = '█', printEnd = "\r"):
    """
    Call in a loop to create terminal progress bar
    @params:
        iteration   - Required  : current iteration (Int)
        total       - Required  : total iterations (Int)
        prefix      - Optional  : prefix string (Str)
        suffix      - Optional  : suffix string (Str)
        decimals    - Optional  : positive number of decimals in percent complete (Int)
        length      - Optional  : character length of bar (Int)
        fill        - Optional  : bar fill character (Str)
        printEnd    - Optional  : end character (e.g. "\r", "\r\n") (Str)
    """
    percent = ("{0:." + str(decimals) + "f}").format(100 * (iteration / float(total)))
    filledLength = int(length * iteration // total)
    bar = fill * filledLength + '-' * (length - filledLength)

    print('\r%s |%s| %s%% %s' % (prefix, bar, percent, suffix), end = '')
    # Print New Line on Complete
    if iteration == total: 
        print()

printProgressBar(1, 10, prefix = 'Progress:', suffix = 'Complete', length = 50)        
printProgressBar(1, 100, prefix = 'Progress:', suffix = 'Complete', length = 50)
# Out:
# env: local_data_path=/Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/
# data path: /Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/
# Progress: |--------------------------------------------------| 1.0% Completee

# %% [markdown]
# ## Downloading the data (once)

# %% [markdown]
# ### Donwloading 1551 data to VMs drive (runtime)

# %%
# !git clone https://github.com/lang-uk/1551.gov.ua ${local_data_path}1551.gov.ua
# Out:
# Cloning into '/Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/1551.gov.ua'...
# remote: Enumerating objects: 127370, done.
# remote: Total 127370 (delta 0), reused 0 (delta 0), pack-reused 127370
# Receiving objects: 100% (127370/127370), 108.40 MiB | 5.76 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# Updating files: 100% (127332/127332), done.

# %% [markdown]
# ### Downloading 1551 data to Google Drive (once)

# %%
# !git clone https://github.com/lang-uk/1551.gov.ua '/content/drive/My Drive/Colab/homework-10/1551.gov.ua'
# Out:
# Cloning into '/content/drive/My Drive/Colab/homework-10/1551.gov.ua'...
# remote: Enumerating objects: 127370, done.
# remote: Total 127370 (delta 0), reused 0 (delta 0), pack-reused 127370
# Receiving objects: 100% (127370/127370), 108.40 MiB | 3.41 MiB/s, done.
# Resolving deltas: 100% (43/43), done.
# Checking out files: 100% (127332/127332), done.

# %% [markdown]
# ### Downloading **news** corpus to GDrive (once)

# %% [markdown]
# https://lang.org.ua/static/downloads/models/news.cased.tokenized.word2vec.300d.bz2
#
# https://lang.org.ua/static/downloads/models/news.lowercased.tokenized.word2vec.300d.bz2
#
# https://lang.org.ua/static/downloads/models/news.cased.lemmatized.word2vec.300d.bz2
#
# https://lang.org.ua/static/downloads/models/news.lowercased.lemmatized.word2vec.300d.bz2

# %%
# !wget -P ${local_data_path} https://lang.org.ua/static/downloads/models/news.cased.tokenized.word2vec.300d.bz2
# !wget -P ${local_data_path} https://lang.org.ua/static/downloads/models/news.lowercased.tokenized.word2vec.300d.bz2
# !wget -P ${local_data_path} https://lang.org.ua/static/downloads/models/news.cased.lemmatized.word2vec.300d.bz2
# !wget -P ${local_data_path} https://lang.org.ua/static/downloads/models/news.lowercased.lemmatized.word2vec.300d.bz2

# !bzip2 -d ${local_data_path}news.cased.tokenized.word2vec.300d.bz2
# !bzip2 -d ${local_data_path}news.lowercased.tokenized.word2vec.300d.bz2
# !bzip2 -d ${local_data_path}news.cased.lemmatized.word2vec.300d.bz2
# !bzip2 -d ${local_data_path}news.lowercased.lemmatized.word2vec.300d.bz2
# Out:
# --2020-05-18 15:59:15--  https://lang.org.ua/static/downloads/models/news.cased.tokenized.word2vec.300d.bz2
# Resolving lang.org.ua (lang.org.ua)... 95.216.74.77
# Connecting to lang.org.ua (lang.org.ua)|95.216.74.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 343843428 (328M) [application/octet-stream]
# Saving to: ‘/Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/news.cased.tokenized.word2vec.300d.bz2’
#
# news.cased.tokenize 100%[===================>] 327,91M  8,59MB/s    in 46s
#
# 2020-05-18 16:00:02 (7,07 MB/s) - ‘/Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/news.cased.tokenized.word2vec.300d.bz2’ saved [343843428/343843428]
#
# --2020-05-18 16:00:02--  https://lang.org.ua/static/downloads/models/news.lowercased.tokenized.word2vec.300d.bz2
# Resolving lang.org.ua (lang.org.ua)... 95.216.74.77
# Connecting to lang.org.ua (lang.org.ua)|95.216.74.77|:443... connected.
# ...

# %% [markdown]
# ### Downloading **ubercorpus** to GDrive (once)

# %% [markdown]
# ```
# https://lang.org.ua/static/downloads/models/ubercorpus.cased.tokenized.word2vec.300d.bz2
#
# https://lang.org.ua/static/downloads/models/ubercorpus.lowercased.tokenized.word2vec.300d.bz2
#
# https://lang.org.ua/static/downloads/models/ubercorpus.cased.lemmatized.word2vec.300d.bz2
#
# https://lang.org.ua/static/downloads/models/ubercorpus.lowercased.lemmatized.word2vec.300d.bz2
#
# ```

# %%
# !wget -P ${local_data_path} https://lang.org.ua/static/downloads/models/ubercorpus.cased.tokenized.word2vec.300d.bz2
# !wget -P ${local_data_path} https://lang.org.ua/static/downloads/models/ubercorpus.lowercased.tokenized.word2vec.300d.bz2
# !wget -P ${local_data_path} https://lang.org.ua/static/downloads/models/ubercorpus.cased.lemmatized.word2vec.300d.bz2
# !wget -P ${local_data_path} https://lang.org.ua/static/downloads/models/ubercorpus.lowercased.lemmatized.word2vec.300d.bz2

# !bzip2 -d ${local_data_path}ubercorpus.cased.tokenized.word2vec.300d.bz2
# !bzip2 -d ${local_data_path}ubercorpus.lowercased.tokenized.word2vec.300d.bz2
# !bzip2 -d ${local_data_path}ubercorpus.cased.lemmatized.word2vec.300d.bz2
# !bzip2 -d ${local_data_path}ubercorpus.lowercased.lemmatized.word2vec.300d.bz2
# Out:
# --2020-05-18 16:22:43--  https://lang.org.ua/static/downloads/models/ubercorpus.cased.tokenized.word2vec.300d.bz2
# Resolving lang.org.ua (lang.org.ua)... 95.216.74.77
# Connecting to lang.org.ua (lang.org.ua)|95.216.74.77|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 555203899 (529M) [application/octet-stream]
# Saving to: ‘/Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/ubercorpus.cased.tokenized.word2vec.300d.bz2’
#
# ubercorpus.cased.to 100%[===================>] 529,48M  10,1MB/s    in 53s
#
# 2020-05-18 16:23:36 (9,97 MB/s) - ‘/Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/ubercorpus.cased.tokenized.word2vec.300d.bz2’ saved [555203899/555203899]
#
# --2020-05-18 16:23:36--  https://lang.org.ua/static/downloads/models/ubercorpus.lowercased.tokenized.word2vec.300d.bz2
# Resolving lang.org.ua (lang.org.ua)... 95.216.74.77
# ...

# %% [markdown]
# ## Initializing models on GDrive (once)

# %%
# !rm -r ${local_data_path}vec_models
# !mkdir ${local_data_path}vec_models

# news.cased.tokenized.word2vec.300d
# !python -m spacy init-model uk ${local_data_path}vec_models/news.cased.tokenized.word2vec.300d --vectors-loc ${local_data_path}news.cased.tokenized.word2vec.300d
# news.lowercased.tokenized.word2vec.300d
# !python -m spacy init-model uk ${local_data_path}vec_models/news.lowercased.tokenized.word2vec.300d --vectors-loc ${local_data_path}news.lowercased.tokenized.word2vec.300d
# news.cased.lemmatized.word2vec.300d
# !python -m spacy init-model uk ${local_data_path}vec_models/news.cased.lemmatized.word2vec.300d --vectors-loc ${local_data_path}news.cased.lemmatized.word2vec.300d
# news.lowercased.lemmatized.word2vec.300d
# !python -m spacy init-model uk ${local_data_path}vec_models/news.lowercased.lemmatized.word2vec.300d --vectors-loc ${local_data_path}news.lowercased.lemmatized.word2vec.300d

# ubercorpus.cased.tokenized.word2vec.300d
# !python -m spacy init-model uk ${local_data_path}vec_models/ubercorpus.cased.tokenized.word2vec.300d --vectors-loc ${local_data_path}ubercorpus.cased.tokenized.word2vec.300d
# ubercorpus.lowercased.tokenized.word2vec.300d
# !python -m spacy init-model uk ${local_data_path}vec_models/ubercorpus.lowercased.tokenized.word2vec.300d --vectors-loc ${local_data_path}ubercorpus.lowercased.tokenized.word2vec.300d
# ubercorpus.cased.lemmatized.word2vec.300d
# !python -m spacy init-model uk ${local_data_path}vec_models/ubercorpus.cased.lemmatized.word2vec.300d --vectors-loc ${local_data_path}ubercorpus.cased.lemmatized.word2vec.300d
# ubercorpus.lowercased.lemmatized.word2vec.300d
# !python -m spacy init-model uk ${local_data_path}vec_models/ubercorpus.lowercased.lemmatized.word2vec.300d --vectors-loc ${local_data_path}ubercorpus.lowercased.lemmatized.word2vec.300d
# Out:
# ✔ Successfully created model
# 365319it [00:36, 9998.13it/s] dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/news.cased.tokenized.word2vec.300d
# ✔ Loaded vectors from
# /Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/news.cased.tokenized.word2vec.300d
# ✔ Sucessfully compiled vocab
# 365495 entries, 365319 vectors
# ✔ Successfully created model
# 328958it [00:32, 10009.27it/s]dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/news.lowercased.tokenized.word2vec.300d
# ✔ Loaded vectors from
# /Users/dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/news.lowercased.tokenized.word2vec.300d
# ✔ Sucessfully compiled vocab
# 329134 entries, 328958 vectors
# ✔ Successfully created model
# 178460it [00:17, 9934.54it/s] dmytromindra/Projects/prj-nlp-2020/students/DmytroMindra/10-vectors/data/news.cased.lemmatized.word2vec.300d
# ✔ Loaded vectors from
# ...

# %% [markdown]
# ## Installing pymorphy (runtime)

# %%
# !pip uninstall pymorphy2-dicts-uk -y
# !pip uninstall pymorphy2 -y
# !pip install git+https://github.com/kmike/pymorphy2.git pymorphy2-dicts-uk
# Out:
# Found existing installation: pymorphy2-dicts-uk 2.4.1.1.1460299261
# Uninstalling pymorphy2-dicts-uk-2.4.1.1.1460299261:
#   Successfully uninstalled pymorphy2-dicts-uk-2.4.1.1.1460299261
# Found existing installation: pymorphy2 0.8
# Uninstalling pymorphy2-0.8:
#   Successfully uninstalled pymorphy2-0.8
# ...
#   Cloning https://github.com/kmike/pymorphy2.git to /private/var/folders/9s/pv07x6217fldw0yk1sy3m2x40000gn/T/pip-req-build-b042tkjf
#   Running command git clone -q https://github.com/kmike/pymorphy2.git /private/var/folders/9s/pv07x6217fldw0yk1sy3m2x40000gn/T/pip-req-build-b042tkjf
# ...
#   Using cached pymorphy2_dicts_uk-2.4.1.1.1460299261-py2.py3-none-any.whl (5.0 MB)
# ...
# Could not build wheels for pymorphy2, since package 'wheel' is not installed.
# Could not build wheels for dawg-python, since package 'wheel' is not installed.
# Could not build wheels for pymorphy2-dicts-ru, since package 'wheel' is not installed.
# ...

# %% [markdown]
# ### Testing if pymorphy models work

# %%
import spacy
news_cased_tokenized_model = spacy.load(news_cased_tokenized_word2vec_300d_path)

# %%
w1 = news_cased_tokenized_model('кіт')
w2 = news_cased_tokenized_model('собака')
print(w1.similarity(w2))
# Out:
# 0.7224378959711921

# %% [markdown]
# ## Language detector (runtime)

# %%
# !python -m pip install -U pycld2

import pycld2 as cld2

isReliable, textBytesFound, details = cld2.detect(
    "Відкриття спортивних залів не підлягає нинішнім карантинним пом'якшенням."
)

print (details[0][1])
# Out:
# Requirement already up-to-date: pycld2 in ./venv/lib/python3.8/site-packages (0.41)
# Could not build wheels for pycld2, since package 'wheel' is not installed.
# uk

# %% [markdown]
# # Data

# %% [markdown]
# ## Doc2Vec (runtime)

# %%
def vectorize_without_stopwords(text, model):
    words = model(text)
    filtered_words = []

    for w in words:
      if w not in spacy.lang.uk.stop_words.STOP_WORDS:
        filtered_words.append(w.text)

    words = model(' '.join(filtered_words))
    return words.vector

def vectorize_with_stopwords(text, model):
    words = model(text)
    return words.vector

# %% [markdown]
# ## Loading the data in memory (runtime)

# %%
import gzip
import json
import glob

import time

def read_file(f):
    with gzip.open(f, 'rt', encoding='utf-8') as inf:
        j = json.load(inf)
        return j[0]

start = time.time()

data = []
files = []

for f in glob.glob(DATA_1551_PATH+'*/*'):
  files.append(f)

print('Files count', len(files))
counter = 0
for file in files:
  data.append(read_file(file))
  counter+=1
  if counter%100 ==0:
    #print (len(files) - counter,'/',len(files))
    printProgressBar(counter, len(files), prefix = 'Progress:', suffix = 'Complete', length = 50)

printProgressBar(counter, len(files), prefix = 'Progress:', suffix = 'Complete', length = 50)
print()
print ('Data loaded:',len(data))

end = time.time()
print('Time elapsed:', end - start, 'seconds')
# Out:
# Files count 127329
# Progress: |██████████████████████████████████████████████████| 100.0% Complete
#
# Data loaded: 127329
# Time elapsed: 82.60631895065308 seconds

# %% [markdown]
# ## Selecting a subset of data for fast processing (runtime)

# %%
import pycld2 as cld2
category_id = {}

def get_top_categories (n_categories, filter_ukrainian = False):
  categories_count = {}
  counter = 0

  for data_item in data:
    if data_item['CallZType'] not in categories_count:
      categories_count[data_item['CallZType']] = 0
      category_id[data_item['CallZType']] = counter
      counter+=1
    categories_count[data_item['CallZType']]+=1


  def takeSecond(elem):
      return elem[1]


  category_statistics = []

  for category in categories_count:
    category_statistics.append((category, categories_count[category]))

  category_statistics.sort(key=takeSecond, reverse=True)

  selected_categories = {}

  for category in category_statistics[:n_categories]:
      selected_categories[category[0]] = []

  for data_item in data:

      if filter_ukrainian:
        printable_str = ''.join(x for x in data_item['CallZText'] if x.isprintable())
        isReliable, textBytesFound, details = cld2.detect(printable_str)
        if details[0][1]=='uk' and data_item['CallZType'] in selected_categories:
          selected_categories[data_item['CallZType']].append(data_item['CallZText'])

      elif data_item['CallZType'] in selected_categories:
        selected_categories[data_item['CallZType']].append(data_item['CallZText'])
  
  return selected_categories


def get_vectorized_data(source_data, vectorizer, model):

  features = []
  labels = []

  for category in source_data:
    for data_item in source_data[category]:
      vectorized_data = vectorizer(data_item, model)
      if vectorized_data is not None:
        features.append(vectorized_data)
        labels.append(category_id[category])

  return features, labels

# %% [markdown]
# # Iterations

# %% [markdown]
# ## Baseline

# %% [markdown]
# This is a prettified version of our classroom baseline KNeighborsClassifier is rather slow and it does not provide any verbose output. It is not quite fun to play with.

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.neighbors import KNeighborsClassifier
from sklearn import metrics
from sklearn.metrics import classification_report

filtered_data = get_top_categories(10)

X, y = get_vectorized_data(filtered_data, vectorizer = vectorize_with_stopwords, model = news_cased_tokenized_model)

print (len(X), len(y))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

neighbors = KNeighborsClassifier(n_neighbors=3, n_jobs = -1)
neighbors.fit(np.array(X_train), np.array(y_train))

y_pred = neighbors.predict(X_test)


print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# 44895 44895
# Accuracy: 0.562702483801296
#
#               precision    recall  f1-score   support
#
#            1       0.58      0.82      0.68      4450
#            3       0.48      0.49      0.49      1071
#            4       0.43      0.43      0.43       761
#            7       0.57      0.47      0.52      1946
#           15       0.37      0.32      0.34       714
#           16       0.58      0.48      0.53      2155
#           18       0.63      0.58      0.60      1190
#           23       0.43      0.26      0.33       820
#           46       0.71      0.42      0.53       857
#           57       0.69      0.43      0.53       852
#
#     accuracy                           0.56     14816
#    macro avg       0.55      0.47      0.50     14816
# weighted avg       0.56      0.56      0.55     14816

# %% [markdown]
# ## Iteration 1: MLPClassifier + GridSearchCV

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.neural_network import MLPClassifier
from sklearn.model_selection import GridSearchCV
from sklearn import metrics
from sklearn.metrics import classification_report

filtered_data = get_top_categories(10)

X, y = get_vectorized_data(filtered_data, vectorizer = vectorize_with_stopwords, model = news_cased_tokenized_model)

print (len(X), len(y))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

parameters = {'solver': ['lbfgs'], 'max_iter': [300,400,500], 'alpha': 10.0 ** -np.arange(1, 5), 'hidden_layer_sizes':np.arange(10, 15)}
clf = GridSearchCV(MLPClassifier(), parameters, n_jobs=-1, verbose = 100)
clf.fit(np.array(X_train), np.array(y_train))

print(clf.score(X_train, y_train))
print(clf.best_params_)

y_pred = clf.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# 44895 44895
# Fitting 5 folds for each of 60 candidates, totalling 300 fits
# [Parallel(n_jobs=-1)]: Using backend LokyBackend with 2 concurrent workers.
# Memmapping (shape=(30079, 300), dtype=float32) to new file /dev/shm/joblib_memmapping_folder_390_1568765816/390-139852888724144-a0cdaac5b8e84678b01201776a4044f5.pkl
# Pickling array (shape=(30079,), dtype=int64).
# Pickling array (shape=(24063,), dtype=int64).
# Pickling array (shape=(6016,), dtype=int64).
# Memmapping (shape=(30079, 300), dtype=float32) to old file /dev/shm/joblib_memmapping_folder_390_1568765816/390-139852888724144-a0cdaac5b8e84678b01201776a4044f5.pkl
# Pickling array (shape=(30079,), dtype=int64).
# Pickling array (shape=(24063,), dtype=int64).
# Pickling array (shape=(6016,), dtype=int64).
# Memmapping (shape=(30079, 300), dtype=float32) to old file /dev/shm/joblib_memmapping_folder_390_1568765816/390-139852888724144-a0cdaac5b8e84678b01201776a4044f5.pkl
# Pickling array (shape=(30079,), dtype=int64).
# ...

# %% [markdown]
# ## Iteration 2: No stop words

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from sklearn.metrics import classification_report

filtered_data = get_top_categories(10)

X, y = get_vectorized_data(filtered_data, vectorizer = vectorize_without_stopwords, model = news_cased_tokenized_model)

print (len(X), len(y))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# {'alpha': 0.1, 'hidden_layer_sizes': 14, 'max_iter': 400, 'solver': 'lbfgs'}
clf = MLPClassifier(alpha = 0.1, hidden_layer_sizes = 14, max_iter = 400, solver = 'lbfgs', n_jobs=-1, verbose = 100)
clf.fit(np.array(X_train), np.array(y_train))

y_pred = clf.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# 44895 44895
# Accuracy: 0.759651727861771
#
#               precision    recall  f1-score   support
#
#            1       0.83      0.89      0.86      4450
#            3       0.77      0.67      0.71      1071
#            4       0.73      0.61      0.66       761
#            7       0.78      0.75      0.76      1946
#           15       0.60      0.37      0.46       714
#           16       0.65      0.75      0.70      2155
#           18       0.80      0.85      0.82      1190
#           23       0.58      0.50      0.54       820
#           46       0.80      0.79      0.79       857
#           57       0.80      0.82      0.81       852
#
#     accuracy                           0.76     14816
#    macro avg       0.73      0.70      0.71     14816
# weighted avg       0.76      0.76      0.75     14816
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...

# %% [markdown]
# **Summary:** After adding stop word filtering, the accuracy dropped a bit, but the distribution changed a bit as well. So I will keep filtering for next iterations.

# %% [markdown]
# ## Iteration 3: Language Detector

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from sklearn.metrics import classification_report

filtered_data = get_top_categories(10, filter_ukrainian=True)

X, y = get_vectorized_data(filtered_data, vectorizer = vectorize_without_stopwords, model = news_cased_tokenized_model)

print (len(X), len(y))

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

# {'alpha': 0.1, 'hidden_layer_sizes': 14, 'max_iter': 400, 'solver': 'lbfgs'}
clf = MLPClassifier(alpha = 0.1, hidden_layer_sizes = 14, max_iter = 400, solver = 'lbfgs', verbose=100)
clf.fit(np.array(X_train), np.array(y_train))

y_pred = clf.predict(X_test)

print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

print()

print(classification_report(y_test, y_pred))
# Out:
# 23789 23789
# Accuracy: 0.8081773022544899
#
#               precision    recall  f1-score   support
#
#            1       0.87      0.88      0.87      2159
#            3       0.80      0.83      0.82       651
#            4       0.69      0.72      0.71       362
#            7       0.86      0.83      0.84      1048
#           15       0.61      0.55      0.58       444
#           16       0.72      0.75      0.73      1200
#           18       0.89      0.86      0.88       731
#           23       0.64      0.61      0.62       441
#           46       0.89      0.89      0.89       411
#           57       0.90      0.91      0.91       404
#
#     accuracy                           0.81      7851
#    macro avg       0.79      0.78      0.78      7851
# weighted avg       0.81      0.81      0.81      7851
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning: lbfgs failed to converge (status=1):
# ...

# %% [markdown]
# **Summary:** Accuracy is much higher, but the amount of data now is 23789 instead of 44895 in previous experiment.

# %% [markdown]
# ## Iteration 4: We need more vectors

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from sklearn.metrics import classification_report

available_models = [
  ('news_cased_tokenized',news_cased_tokenized_word2vec_300d_path),
  ('news_lowercased_tokenized',news_lowercased_tokenized_word2vec_300d_path),
  ('news_cased_lemmatized',news_cased_lemmatized_word2vec_300d_path),
  ('news_lowercased_lemmatized',news_lowercased_lemmatized_word2vec_300d_path),
  ('ubercorpus_cased_tokenized',ubercorpus_cased_tokenized_word2vec_300d_path),
  ('ubercorpus_lowercased_tokenized',ubercorpus_lowercased_tokenized_word2vec_300d_path),
  ('ubercorpus_cased_lemmatized',ubercorpus_cased_lemmatized_word2vec_300d_path),
  ('ubercorpus_lowercased_lemmatized',ubercorpus_lowercased_lemmatized_word2vec_300d_path)
]

def evaluate (language_model, language_model_name):
  filtered_data = get_top_categories(10, filter_ukrainian=True)

  X, y = get_vectorized_data(filtered_data, vectorizer = vectorize_without_stopwords, model = language_model)

  print (len(X), len(y))

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

  # {'alpha': 0.1, 'hidden_layer_sizes': 14, 'max_iter': 400, 'solver': 'lbfgs'}
  clf = MLPClassifier(alpha = 0.1, hidden_layer_sizes = 14, max_iter = 400, solver = 'lbfgs', verbose=100, random_state=42)
  clf.fit(np.array(X_train), np.array(y_train))

  y_pred = clf.predict(X_test)

  print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

  print()

  print(classification_report(y_test, y_pred))

for lg_model in available_models:
  print ('Evaluating:', lg_model[0])
  model = spacy.load(lg_model[1])
  evaluate(model, lg_model[0])
# Out:
# Evaluating: news_cased_tokenized
# 23789 23789
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Accuracy: 0.8094510253470896
#
#               precision    recall  f1-score   support
#
#            1       0.87      0.90      0.88      2159
#            3       0.79      0.83      0.81       651
#            4       0.75      0.65      0.69       362
#            7       0.87      0.85      0.86      1048
#           15       0.65      0.56      0.60       444
#           16       0.72      0.76      0.74      1200
#           18       0.88      0.84      0.86       731
# ...

# %% [markdown]
# **Summary:** I have achieved the best result with **ubercorpus_cased_tokenized**
#
#
# ```
# Accuracy: 0.8127627053878487
#
#               precision    recall  f1-score   support
#
#            1       0.88      0.88      0.88      2159
#            3       0.81      0.81      0.81       651
#            4       0.72      0.73      0.73       362
#            7       0.86      0.85      0.85      1048
#           15       0.63      0.56      0.59       444
#           16       0.72      0.77      0.75      1200
#           18       0.91      0.88      0.89       731
#           23       0.63      0.56      0.59       441
#           46       0.87      0.89      0.88       411
#           57       0.87      0.90      0.89       404
#
#     accuracy                           0.81      7851
#    macro avg       0.79      0.78      0.79      7851
# weighted avg       0.81      0.81      0.81      7851
# ```

# %% [markdown]
# ## Iteration 5: All Categories

# %%
import numpy as np
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle
from sklearn.neural_network import MLPClassifier
from sklearn import metrics
from sklearn.metrics import classification_report

def evaluate (language_model):
  filtered_data = get_top_categories(1000, filter_ukrainian=True)

  X, y = get_vectorized_data(filtered_data, vectorizer = vectorize_without_stopwords, model = language_model)

  print (len(X), len(y))

  X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=42)

  # {'alpha': 0.1, 'hidden_layer_sizes': 14, 'max_iter': 400, 'solver': 'lbfgs'}
  clf = MLPClassifier(alpha = 0.1, hidden_layer_sizes = 14, max_iter = 400, solver = 'lbfgs', verbose=100, random_state=42)
  clf.fit(np.array(X_train), np.array(y_train))

  y_pred = clf.predict(X_test)

  print("Accuracy:",metrics.accuracy_score(y_test, y_pred))

  print()

  print(classification_report(y_test, y_pred))


model = spacy.load(ubercorpus_cased_tokenized_word2vec_300d_path)
evaluate(model)
# Out:
# /usr/lib/python3.6/runpy.py:193: UserWarning: [W019] Changing vectors name from uk_model.vectors to uk_model.vectors_595119, to avoid clash with previously loaded vectors. See Issue #3853.
#   "__main__", mod_spec)
# 69407 69407
# /usr/local/lib/python3.6/dist-packages/sklearn/neural_network/_multilayer_perceptron.py:470: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
#   self.n_iter_ = _check_optimize_result("lbfgs", opt_res, self.max_iter)
# Accuracy: 0.45156079458633486
#
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00        13
#            1       0.64      0.87      0.73      2132
#            2       0.50      0.04      0.07        28
#            3       0.48      0.66      0.55       663
# ...

# %% [markdown]
# # Visualization

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import numpy as np
# We import seaborn to make nice plots.
import seaborn as sns


# We'll use matplotlib for graphics.
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
import matplotlib
# %matplotlib inline

from sklearn.utils import shuffle


available_models = [
  ('news_cased_tokenized',news_cased_tokenized_word2vec_300d_path),
  ('news_lowercased_tokenized',news_lowercased_tokenized_word2vec_300d_path),
  ('news_cased_lemmatized',news_cased_lemmatized_word2vec_300d_path),
  ('news_lowercased_lemmatized',news_lowercased_lemmatized_word2vec_300d_path),
  ('ubercorpus_cased_tokenized',ubercorpus_cased_tokenized_word2vec_300d_path),
  ('ubercorpus_lowercased_tokenized',ubercorpus_lowercased_tokenized_word2vec_300d_path),
  ('ubercorpus_cased_lemmatized',ubercorpus_cased_lemmatized_word2vec_300d_path),
  ('ubercorpus_lowercased_lemmatized',ubercorpus_lowercased_lemmatized_word2vec_300d_path)
]

tsne_data = []

def prepare_visuzliation_model(language_model, language_model_name, sample_size, categories = 10):

    tsne = TSNE(n_components=2, random_state=0, n_iter = 250, verbose = 100, n_jobs = -1, perplexity=50)
    filtered_data = get_top_categories(10, filter_ukrainian=True)
    X, y = get_vectorized_data(filtered_data, vectorizer = vectorize_without_stopwords, model = language_model)
    print (len(X), len(y))

    X, y = shuffle (X, y, random_state=0)

    X = X[:sample_size]
    y = y[:sample_size]

    X_embedded = tsne.fit_transform(X)

    tsne_data.append((language_model_name, X_embedded, y))

for lg_model in available_models:
  model_name = lg_model[0]
  print ('Preparing visualization data for ', model_name)
  model = spacy.load(lg_model[1])
  prepare_visuzliation_model(model,model_name, 100000, 30)


import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
import matplotlib
# %matplotlib inline


def visualize(X_embedded,y, model_name):
  sns.set_style('white')

  sns.set_palette('bright')
  sns.set_context("notebook", font_scale=1.5,
                  rc={"lines.linewidth": 2.5})

  f = plt.figure(figsize=(12, 12))
  ax = plt.subplot(aspect='equal')

  ax = sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y, legend='brief', palette="Set2" )
  ax.set_title(model_name)

  # 5. Place legend to the right
  plt.legend(bbox_to_anchor=(1, 1), loc=2)

for data_item in tsne_data:
  visualize(data_item[1],data_item[2],data_item[0])
# Out:
# Preparing visualization data for  news_cased_tokenized
# 23789 23789
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 23789 samples in 0.543s...
# [t-SNE] Computed neighbors for 23789 samples in 90.242s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 23789
# [t-SNE] Computed conditional probabilities for sample 2000 / 23789
# [t-SNE] Computed conditional probabilities for sample 3000 / 23789
# [t-SNE] Computed conditional probabilities for sample 4000 / 23789
# [t-SNE] Computed conditional probabilities for sample 5000 / 23789
# [t-SNE] Computed conditional probabilities for sample 6000 / 23789
# [t-SNE] Computed conditional probabilities for sample 7000 / 23789
# [t-SNE] Computed conditional probabilities for sample 8000 / 23789
# [t-SNE] Computed conditional probabilities for sample 9000 / 23789
# [t-SNE] Computed conditional probabilities for sample 10000 / 23789
# [t-SNE] Computed conditional probabilities for sample 11000 / 23789
# ...

# %%
from sklearn.manifold import TSNE
import matplotlib.pyplot as plt
import numpy as np
import seaborn as sns

import matplotlib.pyplot as plt
import matplotlib.patheffects as PathEffects
import matplotlib
# %matplotlib inline

from sklearn.utils import shuffle

def visualize(X_embedded,y, model_name):
  sns.set_style('white')

  sns.set_palette('bright')
  sns.set_context("notebook", font_scale=1.5,
                  rc={"lines.linewidth": 2.5})

  f = plt.figure(figsize=(12, 12))
  ax = plt.subplot(aspect='equal')

  ax = sns.scatterplot(X_embedded[:,0], X_embedded[:,1], hue=y, legend=False, palette="Set2" )
  ax.set_title(model_name)

  # 5. Place legend to the right
  plt.legend(bbox_to_anchor=(1, 1), loc=2)

language_model = spacy.load(ubercorpus_cased_tokenized_word2vec_300d_path)
tsne = TSNE(n_components=2, random_state=0, n_iter = 250, verbose = 100, n_jobs = -1, perplexity=50)
filtered_data = get_top_categories(30, filter_ukrainian=True)
X, y = get_vectorized_data(filtered_data, vectorizer = vectorize_without_stopwords, model = language_model)
print (len(X), len(y))

X, y = shuffle (X, y, random_state=0)
X = X
y = y


X_embedded = tsne.fit_transform(X)

visualize (X_embedded, y, '')
# Out:
# /Library/Frameworks/Python.framework/Versions/3.8/lib/python3.8/runpy.py:194: UserWarning: [W019] Changing vectors name from uk_model.vectors to uk_model.vectors_595119, to avoid clash with previously loaded vectors. See Issue #3853.
#   return _run_code(code, main_globals, None,
# 38077 38077
# [t-SNE] Computing 151 nearest neighbors...
# [t-SNE] Indexed 38077 samples in 1.002s...
# [t-SNE] Computed neighbors for 38077 samples in 245.598s...
# [t-SNE] Computed conditional probabilities for sample 1000 / 38077
# [t-SNE] Computed conditional probabilities for sample 2000 / 38077
# [t-SNE] Computed conditional probabilities for sample 3000 / 38077
# [t-SNE] Computed conditional probabilities for sample 4000 / 38077
# [t-SNE] Computed conditional probabilities for sample 5000 / 38077
# [t-SNE] Computed conditional probabilities for sample 6000 / 38077
# [t-SNE] Computed conditional probabilities for sample 7000 / 38077
# ...

# %% [markdown]
# # Summary

# %% [markdown]
# 1. I've learned how to use MLPClassifier, GridSearchCV, and KNeighborsClassifier
# 2. I've used various pre-trained Word2Vec models
# 3. I've learned how to use TSNE ans Seaborn for data visualization
# 4. Doing this project in Google Colab was painful as the machine can be recycled at any time and I had to start over and over again.
# 5. Google Colab utilizes the table of contents that makes notebook navigation easy
