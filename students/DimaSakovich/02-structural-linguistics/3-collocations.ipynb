# %%
import os

from IPython.display import display, Markdown, Image

# %%
REPO_PATH = os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))
TASK_PATH = os.path.join(REPO_PATH, "tasks", "02-structural-linguistics")
DATA_PATH = os.path.join(TASK_PATH, "data")

# %%
def show_markdown(path):
    with open(path, 'r') as fh:
        content = fh.read()
    display(Markdown(content))

# %%
show_markdown(os.path.join(TASK_PATH, "3-collocations.md"))
# Out:
# ## Колокації
#
# Одним із важливих аспектів будь-якої природної мови є сполучуваність слів. В англійській мові поняття сполучуваності дуже відчутне і присутнє у всіх мовних структурах: ми кажемо _"make a mistake",_ але _"do a favour";_ ми кажемо _"big surprise",_ але _"great anger";_ ми кажемо _"highly unlikely",_ але _"seriously wrong"._
#
# ### 1. Англійська мова
#
# У цьому завданні вам потрібно дослідити сполучуваність дієслів одного синонімного ряду з прислівниками. Наприклад, ми частіше кажемо _"love somebody dearly", "honor somebody highly",_ але _"admire somebody greatly"._
#
# **Завдання:**
# 1. продовжте синонімний ряд дієслів: _"say", "tell", "speak", "claim", "communicate"_
# 2. напишіть функцію, яка знаходить у реченні дієслово (за складеним раніше синонімним рядом) і витягає усі можливі прислівники на "-ly", якими це дієслово керує
# 3. напишіть програму, яка знайде усі можливі прислівники для ваших дієслів у [корпусі блогів](data/blog2008.txt)
# 4. на виході програма повинна видати десять найчастотніших прислівників для кожного дієслова (разом із частотою). Приклад виводу:
# 	```
# 	say: (loudly, 51), (silently, 45), (quietly, 10)
# 	tell: (quietly, 100), (loudly, 61), (seriously, 5)
# 	```
# 5. збережіть програму та результати аналізу на корпусі (вивід) у директорії з вашим іменем
#
# Синоніми можна знайти у тезаурусах (http://www.thesaurus.com/, https://www.merriam-webster.com/thesaurus) чи [WordNet](http://wordnetweb.princeton.edu/perl/webwn).
#
# Підказка: зверніть увагу на те, що у природній мові дієслова можуть мати різні форми, а прислівників може бути по декілька.
#
# ### 2. Українська мова
#
# У цьому завданні вам потрібно дослідити сполучуваність іменників-істот з прикметниками.
#
# **Завдання:**
# 1. напишіть функцію, яка знаходить у реченні іменник, що позначає істоту, і витягає усі прикметники, якими цей іменник керує
# 2. напишіть програму, яка знайде усі можливі словосполучення прикметників та іменників-істот у [романі "Тигролови"](data/tyhrolovy.txt)
# 3. на виході програма повинна видати усі знайдені словосполучення та їх частоти. Приклад виводу:
# 	```
# 	84: старий сірко
# 	5: великий начальник
# 	```
# 4. збережіть програму та результати виводу в директорії з вашим іменем
#
# Підказка: можна шукати послідовність прикметника та іменника і визначати словосполучення через pymorphy2. Також можна попрацювати з деревами залежностей через StanfordNLP, але можливо доведеться запускати код десь на Google Colab, бо там дуже великі моделі для української мови.
#
# ### Джерела
#
# Ви можете використати будь-яку мову програмування та будь-яку NLP-бібліотеку.
#
# Корпус блогів взятий з [Political Blog Corpora](http://www.cs.cmu.edu/~ark/blog-data/).

# %% [markdown]
# ### Part 1

# %%
import re
import gc
import json
import spacy
import pandas as pd

from collections import Counter, OrderedDict
from functools import reduce
from multiprocessing import cpu_count
from tqdm import tqdm
from tqdm.contrib.concurrent import process_map

# %%
nlp_en = spacy.load('en_core_web_md')

# %%
synonyms = ["say", 
            "add", "announce", "answer", "assert", "claim", "convey", "declare", "deliver",
            "disclose", "do", "estimate", "express", "maintain", "mention", "read", "repeat", "reply",
            "report", "respond", "reveal", "speak", "state", "suggest", "tell", "voice", "affirm", "communicate"]

# %%
def count_adv(sentence, verbs=synonyms):
    tokens = nlp_en(sentence)
    cnt = Counter()
    
    for token in tokens:
        if token.pos_ == 'ADV' and token.text[-2:] == 'ly' and token.dep_ == 'advmod':
            first_ancestor = next(token.ancestors, "")
            if first_ancestor:
                if first_ancestor.lemma_ in verbs and first_ancestor.pos_ == 'VERB':
                    cnt.update({(first_ancestor.lemma_, token.lower_):1})
    return cnt

# %%
corpus_df = pd.read_table(os.path.join(DATA_PATH, 'blog2008.txt'), names=["text"])

# %%
# %%time

try:
    with open('collocations_en.json', 'r') as file_:
        collocations = json.load(file_)
except FileNotFoundError:
    lst = process_map(count_adv, corpus_df.text.values, max_workers=cpu_count())
    total_cntr = reduce((lambda x, y: x + y), lst)

    collocations = {}
    for (verb, adv), count in total_cntr.items():
        collocations[verb] = collocations.get(verb, []) + [(adv, count)]
        
    collocations = {verb: sorted(cnt, key=lambda x: x[1], reverse=True)[:10] for verb, cnt in collocations.items()}
    
    with open('collocations_en.json', 'w') as file_:
        json.dump(collocations, file_, sort_keys=True, indent=4)
    
    del lst, total_cntr
    gc.collect()
# Out:
# HBox(children=(FloatProgress(value=0.0, max=300894.0), HTML(value='')))
# CPU times: user 3min 19s, sys: 14.1 s, total: 3min 33s
# Wall time: 9min 27s

# %% [markdown]
# ### Part 2

# %%
import stanfordnlp
import warnings

warnings.filterwarnings("ignore")

# %%
nlp_uk = stanfordnlp.Pipeline(lang='uk')
# Out:
# Use device: gpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/dima/stanfordnlp_resources/uk_iu_models/uk_iu_tokenizer.pt', 'lang': 'uk', 'shorthand': 'uk_iu', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/dima/stanfordnlp_resources/uk_iu_models/uk_iu_tagger.pt', 'pretrain_path': '/home/dima/stanfordnlp_resources/uk_iu_models/uk_iu.pretrain.pt', 'lang': 'uk', 'shorthand': 'uk_iu', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/home/dima/stanfordnlp_resources/uk_iu_models/uk_iu_lemmatizer.pt', 'lang': 'uk', 'shorthand': 'uk_iu', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/home/dima/stanfordnlp_resources/uk_iu_models/uk_iu_parser.pt', 'pretrain_path': '/home/dima/stanfordnlp_resources/uk_iu_models/uk_iu.pretrain.pt', 'lang': 'uk', 'shorthand': 'uk_iu', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
corpus_df = pd.read_table(os.path.join(DATA_PATH, 'tyhrolovy.txt'), names=["text"])

# %%
corpus_df
# Out:
#                                                    text
# 0                                             Тигролови
# 1                                         Іван Багряний
# 2                                         ЧАСТИНА ПЕРША
# 3                                         Розділ перший
# 4                                                ДРАКОН
# ...                                                 ...
# 2653  Гриць прип'яв Заливая, щоб не втік. Так звеліл...
# 2654  Але Заливай скучав. Скучав смертельно. Вірний ...
# 2655                Подався доганяти без надії догнати.
# 2656                  Але — сміливі завжди мають щастя.
# 2657                                               1943
#
# [2658 rows x 1 columns]

# %%
def count_adj_uk(string):
    sentences = nlp_uk(string).sentences
    cnt = Counter()
    
    for sentence in sentences:
        for token in sentence.words:
            if token.upos in {'NOUN', 'PROPN'} and re.findall(r"Animacy=(.*?)\|", token.feats)[0] == 'Anim':
                res = [tkn.lemma.lower() for tkn in sentence.words 
                                         if tkn.upos == 'ADJ' and tkn.governor == int(token.index)]
                for _ in res:
                    cnt.update({(token.lemma.lower(), _):1})
    return cnt

# %%
# from torch.multiprocessing import Pool, Process, set_start_method
# try:
#      set_start_method('spawn', force=True)
# except RuntimeError:
#     pass

# %%
count_adj_uk("""Кожен чистив свою. Наталка вінчестера. Старий Сірко теж вінчестера. Гриць свою "японку". А Григорій — трилінійку. Гвинтівка була новесенька, але Григорій розібрав її до шрубика. Хотів перевірити, чи все в ній в порядку та й для вправи — чи не забув, як те все робиться.""")
# Out:
# Counter({('сірко', 'старий'): 1})

# %%
corpus_df.loc[corpus_df.text.str.contains('Сірко')]
# Out:
#                                                    text
# 590   — Сірківна, — вимовила дівчина з гордістю. — М...
# 716   — А так. Я сама, синку, довго не могла звикнут...
# 717   Перевелись люди, і звелось життя нінащо... Вже...
# 762   Обоє забачили Григорія, посміхаються. — Ого, с...
# 769   А вже як розв'ючували коней гуртом, старий Сір...
# ...                                                 ...
# 2620  Ідучи додому, старий Сірко всю дорогу тільки т...
# 2627  Приїхавши, старий Сірко розіклав газети на сто...
# 2629  Другого дня після приїзду Сірка з Хабаровська,...
# 2636  То був радісний день у Сірків. Старий розправи...
# 2650  Цікавішого чогось в своєму житті Сірко ще не ч...
#
# [132 rows x 1 columns]

# %%
# %%time

try:
    with open('collocations_uk.json', 'r') as file_:
        collocations = json.load(file_)
except FileNotFoundError:
#     lst = list(map(count_adj_uk, corpus_df.text.values))
    lst = []
    for item in tqdm(corpus_df.text.values):
        lst.append(count_adj_uk(item))
    total_cntr = reduce((lambda x, y: x + y), lst)

    collocations = {}
    for (verb, adv), count in total_cntr.items():
        collocations[verb] = collocations.get(verb, []) + [(adv, count)]
        
    collocations = {verb: sorted(cnt, key=lambda x: x[1], reverse=True)[:10] for verb, cnt in collocations.items()}
    
    with open('collocations_uk.json', 'w') as file_:
        json.dump(collocations, file_, sort_keys=True, indent=4, ensure_ascii=False)
    
    del lst, total_cntr
    gc.collect()
# Out:
# 100%|██████████| 2658/2658 [03:45<00:00, 11.78it/s]
# CPU times: user 3min 45s, sys: 322 ms, total: 3min 46s
# Wall time: 3min 45s

# %%
OrderedDict(sorted(collocations.items()))
# Out:
# OrderedDict([('авантюрник', [('індустріальний', 1)]),
#              ('аввакума', [('вільнодумний', 1)]),
#              ('аматор', [('новітний', 1), ('пржевальський', 1)]),
#              ('амба', [('всемогутній', 1), ('славніший', 1)]),
#              ('амурець', [('другий', 1), ('здоровенний', 1)]),
#              ('арештант', [('виснажений', 1)]),
#              ('арсеньев', [('екзотичніший', 1)]),
#              ('баб', [('голоспинний', 1)]),
#              ('байда', [('перевернутий', 1)]),
#              ('байкал', [('священний', 1)]),
#              ('банда', [('великий', 1), ('озброєний', 1)]),
#              ('батьки', [('розкуркулений', 1), ('розкиданий', 1)]),
#              ('батько',
#               [('давніш', 1),
#                ('хрещений', 1),
#                ('задоволений', 1),
#                ('старий', 1)]),
#              ('безвірник', [('правовірний', 1)]),
#              ('бик', [('розпалений', 1), ('другий', 1)]),
#              ('бог',
#               [('дивний', 2),
#                ('волохатий', 2),
#                ('могутній', 2),
#                ('тутешній', 1),
#                ('лютий', 1),
#                ('безжалісний', 1),
#                ('гірський', 1)]),
#              ('брат', [('щасливий', 1)]),
#              ('бурундук', [('занепокоєний', 1)]),
#              ('бурят', [('червоношкірий', 1)]),
#              ('бюрократи', [('радгоспний', 1)]),
#              ('ведмідь',
#               [('гімалайський', 1),
#                ('волохатий', 1),
#                ('величезний', 1),
#                ('чорний', 1),
#                ('припертий', 1),
#                ('другий', 1)]),
#              ('ветеран', [('старий', 1)]),
#              ('винуватиця', [('головний', 1)]),
#              ('витребеньки', [('різдвяний', 1)]),
#              ('вовк', [('старий', 1)]),
#              ('вовчур', [('гостровухий', 1)]),
#              ('воднораз', [('простий', 1)]),
#              ('вождя', [('виголошений', 1)]),
#              ('волохата', [('чорний', 1)]),
#              ('ворог', [('новий', 1), ('вчений', 1), ('лихий', 1)]),
#              ('вояк', [('досвідчений', 1)]),
#              ('вчитель', [('скрипник', 1)]),
#              ('вівця', [('оточений', 1)]),
#              ('відкриватель', [('експансивний', 1)]),
#              ('відрядженець', [('різний', 1), ('відповідальний', 1)]),
#              ('він-бо', [('старший', 1)]),
#              ('віршовник', [('виряджений', 1)]),
#              ('віслюк', [('чортовий', 1)]),
#              ('гадюка', [('страшний', 1), ('отруйний', 1)]),
#              ('гадючин', [('останній', 1)]),
#              ('гайдамака', [('диявольський', 1)]),
#              ('генерал', [('найбільший', 1)]),
#              ('геній', [('творчий', 1)]),
#              ('герой', [('національний', 1), ('бравий', 1)]),
#              ('гетьман', [('малоросійський', 1)]),
#              ('гнус', [('клятий', 1)]),
#              ('голова',
#               [('вогненноока', 1), ('непокритий', 1), ('оленячий', 1)]),
#              ('голуб', [('розполоханий', 1), ('білий', 1)]),
#              ('гольдячка', [('вбраний', 1), ('низенький', 1)]),
#              ('голічеревий', [('тягуче', 1)]),
#              ('горал', [('сніжний', 1), ('дикий', 1)]),
#              ('горність', [('смішний', 1)]),
#              ('городянин', [('смішні', 1), ('пришелепкуватий', 1)]),
#              ('господа', [('справжній', 1)]),
#              ('господар', [('повний', 1)]),
#              ('григорій',
#               [('приголомшений', 2),
#                ('керований', 1),
#                ('збентежений', 1),
#                ("пам'ятний", 1),
#                ('закосичений', 1)]),
#              ('гриць', [('розпалений', 1), ('захмелілий', 1)]),
#              ('грицько', [('чорнявий', 1)]),
#              ('грицьковий', [('здивований', 1)]),
#              ('гриця', [('спантеличений', 1)]),
#              ('громадянин', [('с.', 1)]),
#              ('гульвіс', [('бравий', 1)]),
#              ('гуляйпільц', [('засмалений', 1)]),
#              ('гігант', [('листатий', 1)]),
#              ('гість', [('несподіваний', 1), ('добрий', 1), ('бажаний', 1)]),
#              ('дама', [('катерининський', 1)]),
#              ('демон', [('красений', 1), ('гордий', 1)]),
#              ('демона', [('невідомий', 1)]),
#              ('дерсу', [('придуркуватий', 1)]),
#              ('диктатор', [('мускулястий', 1)]),
#              ('дитина',
#               [('вражі', 1),
#                ('хороший', 1),
#                ('новий', 1),
#                ('сонний', 1),
#                ('маленький', 1),
#                ('малий', 1)]),
#              ('дитино', [('бідна', 1)]),
#              ('дитися', [('білий', 1)]),
#              ('доньки', [('сірковий', 1)]),
#              ('доправда', [('божественний', 1)]),
#              ('дослідник', [('учений', 1)]),
#              ('дочка', [('гарний', 1), ('вража', 1), ('щасливий', 1)]),
#              ('дракон',
#               [('легендарний', 1),
#                ('реальний', 1),
#                ('справжній', 1),
#                ('найбільший', 1)]),
#              ('друг',
#               [('старий', 2),
#                ('вірний', 2),
#                ('єдиний', 1),
#                ('добрий', 1),
#                ('милий', 1)]),
#              ('дубельтівка',
#               [('прекрасний', 1), ('ноиенький', 1), ('набійницький', 1)]),
#              ('дунаєвський', [('рідний', 1)]),
#              ('дух', [('великий', 1), ('злий', 1), ('кінський', 1)]),
#              ('дядько', [('рудий', 1), ('вусатий', 1)]),
#              ('дівотий', [('нормальний', 1), ('строге', 1), ('ніжний', 1)]),
#              ('дівчина',
#               [('химерний', 3),
#                ('вража', 2),
#                ('розмальований', 2),
#                ('чужий', 1),
#                ('-о', 1),
#                ('ставний', 1),
#                ('гостроязикий', 1),
#                ('спритний', 1),
#                ('замріяний', 1),
#                ('дивовижний', 1)]),
#              ('дід', [('дебелий', 1), ('бородатий', 1), ('старий', 1)]),
#              ('дідуган', [('вусатий', 1), ('старий', 1)]),
#              ('дідусик', [('старенький', 1)]),
#              ('ентузіаст', [('примусовий', 1)]),
#              ('жертва', [('нерухомий', 1)]),
#              ('жовтяк', [('добрий', 1)]),
#              ('жінка',
#               [('середній', 1),
#                ('полтавський', 1),
#                ('літень', 1),
#                ('привітний', 1)]),
#              ('завойовник', [('гордий', 1)]),
#              ('зайчик',
#               [('сонячний', 4),
#                ('сміхотливий', 1),
#                ('віддзеркалений', 1),
#                ('надзвичайний', 1)]),
#              ('заливая', [('нашийник', 1)]),
#              ('залицяльник', [('всесвітній', 1)]),
#              ('запорожка', [('давний', 1)]),
#              ('засланець',
#               [('перший', 1), ('найперший', 1), ('політичний', 1)]),
#              ('збігець', [('запопадливий', 1)]),
#              ('звір',
#               [('хутряний', 2),
#                ('морський', 1),
#                ('цькований', 1),
#                ('страхітний', 1),
#                ('схожий', 1),
#                ('хитрий', 1),
#                ('дрібний', 1),
#                ('цінний', 1),
#                ('хижий', 1)]),
#              ('звірка', [('хижий', 1)]),
#              ('звірок',
#               [('смугастий', 3), ('маленький', 1), ('хвостатий', 1)]),
#              ('звіролова', [('веселя', 1)]),
#              ('звірюка', [('здоровенний', 1)]),
#              ('земляки', [('знайомий', 1)]),
#              ('злодюжка', [('плюгавий', 1)]),
#              ('злодій', [('потенціальний', 1), ('державний', 1)]),
#              ('злочинець',
#               [('державний', 2), ('страшний', 1), ('крупний', 1)]),
#              ('змія', [('окиата', 1), ('гримуча', 1)]),
#              ('зять', [('цибатий', 5), ('мовчазний', 1)]),
#              ('зірка', [('ясненький', 1)]),
#              ('й', [('циклопічний', 1)]),
#              ('кавалер', [('старий', 1)]),
#              ('каторжанина', [('перший', 1)]),
#              ('каторжник', [('перший', 1), ('найперший', 1), ('відомий', 1)]),
#              ('качка', [('японський', 1), ('дивний', 1)]),
#              ('клієнт', [('спантеличений', 1)]),
#              ('коза', [('дикий', 4)]),
#              ('козак', [('уссурійський', 2), ('різний', 1)]),
#              ('колективізатор', [('колгоспний', 1)]),
#              ('коляк', [('просунений', 1)]),
#              ('командир', [('личкований', 1)]),
#              ('комаха', [('сонячний', 1), ('подібний', 1)]),
#              ('коник', [('різний', 1), ('стрілецький', 1)]),
#              ('конкістадор', [('екзальтований', 1)]),
#              ('коній', [('нав’ючений', 2), ('добрий', 1)]),
#              ('кооператор', [('старий', 1), ('гемороїдальний', 1)]),
#              ('королевич', [('пишний', 1), ('молодий', 1)]),
#              ('котик', [('закохані', 1)]),
#              ('коханець',
#               [('четвертий', 1), ('похідний', 1), ('вогненнозорий', 1)]),
#              ('краля', [('мальований', 1), ('писаний', 1)]),
#              ('крам', [('різний', 1)]),
#              ('красень', [('високий', 1), ('дебелий', 1)]),
#              ('красуня',
#               [('тая', 1), ('найперший', 1), ('дивний', 1), ('чистий', 1)]),
#              ('кубанець', [("п'ятий", 1), ('новоросійський', 1)]),
#              ('куркул', [('суджений', 1)]),
#              ('кім-гі', [('добрий', 1), ('смішний', 1)]),
#              ('кінь',
#               [('сідланий', 2),
#                ('дикий', 1),
#                ('нав’ючений', 1),
#                ('передній', 1),
#                ('кован', 1),
#                ('бідолашний', 1)]),
#              ('кішечко', [('смугастий', 1)]),
#              ('кішка',
#               [('зв’язаний', 2),
#                ('дурен', 1),
#                ('домашній', 1),
#                ('отакий', 1),
#                ('добрий', 1),
#                ('тая', 1),
#                ('вража', 1),
#                ('великий', 1),
#                ('велетенський', 1),
#                ('нерухомий', 1)]),
#              ('кішки', [('дохлий', 1)]),
#              ('ластівочко', [('божевільний', 1)]),
#              ('ласун', [('малий', 1)]),
#              ('лемент', [('собачий', 1)]),
#              ('лицар', [('розпалений', 1), ('рогатий', 1)]),
#              ('личина', [('лихий', 1)]),
#              ('лошака', [('добрий', 1)]),
#              ('льдо', [('огненная', 1)]),
#              ('любки', [('пристібаючія', 1)]),
#              ('людець', [('душ', 1)]),
#              ('людина',
#               [('різний', 2),
#                ('добрий', 2),
#                ('вимучений', 2),
#                ('обірваний', 1),
#                ('випадковий', 1),
#                ('змарнований', 1),
#                ('списаний', 1),
#                ('молодий', 1),
#                ('тая', 1),
#                ('рідні', 1)]),
#              ('люстерка', [('круглий', 1)]),
#              ('мавка', [('лісовий', 1)]),
#              ('майор', [('бравий', 1), ('чорнобривий', 1), ('слідчий', 1)]),
#              ('майстр', [('вправний', 1), ('наснажений', 1)]),
#              ('малоросійський', [('химерний', 1)]),
#              ('маль', [('дурне', 1)]),
#              ('маляр', [('геніальний', 1)]),
#              ('мама', [('вража', 2), ('одеса-', 1)]),
#              ('мандза', [('сірковий', 1), ('знайомий', 1)]),
#              ('мандрівник', [('змучений', 2)]),
#              ('маніяк', [('божевільний', 1)]),
#              ('марійка', [('гостра', 1), ('морозівний', 1)]),
#              ('матер', [('старенький', 1), ('божий', 1)]),
#              ('материна', [('слізний', 1)]),
#              ('мати',
#               [('дурний', 1),
#                ('невидний', 1),
#                ('старий', 1),
#                ('рідний', 1),
#                ('бідна', 1)]),
#              ('матінка', [('старий', 1)]),
#              ('мертвяк', [('живий', 1)]),
#              ('мешканець',
#               [('експансивний', 1), ('основний', 1), ('давній', 1)]),
#              ('мисливаць',
#               [('справжній', 2),
#                ('старий', 1),
#                ('перший', 1),
#                ('знаменитий', 1),
#                ('нашорошений', 1)]),
#              ('мисливець',
#               [('знаменитий', 1), ('стихійний', 1), ('інстинктовий', 1)]),
#              ('мисливка', [('здобуваючія', 1)]),
#              ('мовчанка', [('гнітючий', 1)]),
#              ('мокієнко', [('акуратний', 1)]),
#              ('мороз', [('старий', 7), ("п'ятдесятиступневий", 1)]),
#              ('мороза', [('старий', 2)]),
#              ('морозенко', [('старший', 1)]),
#              ('мошкара', [('різний', 1)]),
#              ('муравйов', [('новітній', 1), ('амурський', 1)]),
#              ('набійниця', [('напханий', 1), ('повний', 1)]),
#              ('надуть', [('відповідальний', 1)]),
#              ('наталка',
#               [('насуплений', 2),
#                ('дикий', 1),
#                ('крайній', 1),
#                ('перший', 1)]),
#              ('націоналіст', [('зоологічний', 1)]),
#              ('начальник',
#               [('великий', 5),
#                ('больший', 1),
#                ('сердитий', 1),
#                ('придуркуватий', 1),
#                ('розцяцькований', 1),
#                ('більший', 1),
#                ('уповноважений', 1),
#                ('героїчний', 1),
#                ('дурний', 1)]),
#              ('нащадка', [('гордий', 1)]),
#              ('нащадок', [('закинений', 1)]),
#              ('невідомий', [('темний', 1)]),
#              ('нерпа', [('рудий', 1)]),
#              ('нетр', [('уссурійський', 1)]),
#              ('нетрище', [('дикий', 1)]),
#              ('нетря', [('буйний', 1)]),
#              ('олень',
#               [('молодий', 2),
#                ('шляхетний', 1),
#                ('гордий', 1),
#                ('плямистий', 1),
#                ('сірий', 1),
#                ('рогатий', 1),
#                ('миршавий', 1),
#                ('екзотичний', 1)]),
#              ('оленя', [('плямистий', 2)]),
#              ('оленіти', [('намальований', 1)]),
#              ('омуля', [('давний', 1), ('легендарня', 1)]),
#              ('осавути', [('козацький', 1)]),
#              ('особа', [('великий', 1), ('відповідальний', 1)]),
#              ('отаман', [('страхітливий', 1)]),
#              ('охотник', [('знаменитий', 1)]),
#              ('охотінспектор', [('старший', 1), ('енергійний', 1)]),
#              ('пак', [('совєтський', 1), ('передаючія', 1), ('останній', 1)]),
#              ('пан', [('великий', 3)]),
#              ('панна', [('недоторканний', 1), ('старший', 1)]),
#              ('панянка', [('прекрасноокий', 1), ('мальований', 1)]),
#              ('пані', [('елегантний', 1)]),
#              ('панія',
#               [('літній', 1), ('відповідальний', 1), ('ексцентричний', 1)]),
#              ('парубок', [('густобровий', 1)]),
#              ('пас', [('обірваний', 1)]),
#              ('пасажир',
#               [('останній', 1), ('здезорієнтований', 1), ('нетерплячий', 1)]),
#              ('патріар', [('каторжанський', 1)]),
#              ('патріарха', [('каторжанський', 1)]),
#              ('патріот', [('бердичівський', 1)]),
#              ('пе', [('гігантський', 1)]),
#              ('переможець', [('шалений', 1)]),
#              ('переселенець', [('новий', 1)]),
#              ('пес',
#               [('якутський', 3),
#                ('великий', 3),
#                ('гостровухий', 2),
#                ('вірний', 2),
#                ('здоровення', 1),
#                ('звіровий', 1),
#                ('добрий', 1),
#                ('здивований', 1),
#                ('миршавий', 1),
#                ('скажений', 1)]),
#              ('племений', [('напівміфічний', 1), ('наївний', 1)]),
#              ('потвір', [('велетенський', 1)]),
#              ('представник', [('вбраний', 1)]),
#              ('привид', [('страшний', 1), ('страшніший', 1), ('гейби', 1)]),
#              ('прикордонник', [('японський', 1), ('поставлений', 1)]),
#              ('приятель', [('старий', 1), ('щирий', 1), ('добрий', 1)]),
#              ('протопоп', [('навіжений', 1)]),
#              ('професор', [('справжній', 1), ('веселий', 1)]),
#              ('пташка', [('мрійноголос', 1)]),
#              ('пташок', [('співучий', 1)]),
#              ('птиць', [('велетенський', 1), ('невиданий', 1)]),
#              ('півень', [('пишнобарвний', 1), ('пишнопер', 1), ('збитий', 1)]),
#              ('пінкертон', [('невдалий', 1)]),
#              ('піонера', [('перший', 1)]),
#              ('піт', [('противний', 1), ('холодний', 1)]),
#              ('радівон', [('п’яний', 1)]),
#              ('рекордсмен', [('зухвал', 1)]),
#              ('риба', [('священня', 1), ('чудний', 1)]),
#              ('рись', [('туя', 2)]),
#              ('розбійник', [('двоногий', 1)]),
#              ('роса', [('буйний', 1)]),
#              ('рушати', [('спущений', 1)]),
#              ('самець', [('молодший', 1), ('розпалений', 1)]),
#              ('самиця',
#               [('мрійноокий', 1), ('граційний', 1), ('здоровенний', 1)]),
#              ('сатаний', [('чорний', 1)]),
#              ('син',
#               [('рідний', 1), ('сучий', 1), ('чортовий', 1), ('вражий', 1)]),
#              ('службовка', [('військовий', 1)]),
#              ('сміливець', [('безумний', 1)]),
#              ('сміливка', [('безумний', 1)]),
#              ('собака',
#               [('звіровий', 2),
#                ('здоровенний', 1),
#                ('гостровухий', 1),
#                ('мисливський', 1),
#                ('подурілий', 1),
#                ('здичавілий', 1),
#                ('задоволений', 1),
#                ('великий', 1),
#                ('скажений', 1)]),
#              ('соболя', [('пишний', 1)]),
#              ('совий', [('нечутій', 1)]),
#              ('сокола', [('гордий', 1)]),
#              ('солова', [('тутешній', 1)]),
#              ('спортсмен', [('вправний', 1)]),
#              ('співбесідник', [('цибатий', 1)]),
#              ('співець', [('непереможний', 1)]),
#              ('спітнілий', [('розпатланий', 1)]),
#              ('становик', [('межа', 1), ('сизий', 1)]),
#              ('стиль', [('вокальний', 1), ('європейський', 1)]),
#              ('сторожа', [('непроханий', 1)]),
#              ('стрілець', [('знающий', 1), ('безжалісний', 1)]),
#              ('судаков', [('низенький', 1)]),
#              ('суддя', [('грізний', 1)]),
#              ('сук', [('дебелий', 1), ('замашний', 1)]),
#              ('супруга', [('розгублений', 1)]),
#              ('сікач', [('вепрячий', 1)]),
#              ('сірий', [('буланий', 1), ('вороний', 1)]),
#              ('сірк', [('точний', 1)]),
#              ('сірка', [('старий', 3), ('знаменитіший', 1)]),
#              ('сірко',
#               [('старий', 84),
#                ('хитріший', 1),
#                ('залитий', 1),
#                ('навколишній', 1),
#                ('поглядаючія', 1)]),
#              ('сірно', [('старий', 1)]),
#              ('сірчихий', [('старий', 6)]),
#              ('таваріще', [('следователь', 1)]),
#              ('таймень', [('здоровенний', 1), ('менший', 1)]),
#              ('талісман', [('могутній', 1)]),
#              ('тая', [('білий', 1), ('мадонна', 1)]),
#              ('тварина',
#               [('гордий', 3),
#                ('високий', 1),
#                ('граційний', 1),
#                ('химерня', 1),
#                ('дикий', 1),
#                ('живий', 1),
#                ('рудуватий', 1),
#                ('великий', 1),
#                ('прегарний', 1),
#                ('зацькований', 1)]),
#              ('тваринячий', [('безвідчитний', 1)]),
#              ('тенор', [('лагідний', 1)]),
#              ('тетерук', [('празниковий', 1)]),
#              ('тигра',
#               [('житий', 2),
#                ('старий', 1),
#                ('уссурійський', 1),
#                ('убитий', 1)]),
#              ('товариш', [('рідний', 2), ('чотириногий', 1)]),
#              ('товаришка', [('вірний', 1), ("прип'ятий", 1)]),
#              ('товаріщ', [('дорогити', 1)]),
#              ('трудар', [('чесний', 1), ('полтавський', 1)]),
#              ('тубільець', [('екзотичний', 1)]),
#              ('тубілька', [('смішний', 1)]),
#              ('турок', [('владивостоцький', 2)]),
#              ('удегеєць', [('старий', 1)]),
#              ('фарися', [('імпотентний', 1)]),
#              ('фотограф', [('звичайний', 1)]),
#              ('хабаровець', [('чудний', 1), ('знайомий', 1)]),
#              ('хетагуровка', [('ентузіастка', 1)]),
#              ('хехцира', [('голубий', 1)]),
#              ('хижак', [('великий', 1)]),
#              ('хитро', [('збіс', 1)]),
#              ('хлопець',
#               [('останній', 1),
#                ('низенький', 1),
#                ('енергійний', 1),
#                ('гостроносий', 1),
#                ('прекрасний', 1),
#                ('скажений', 1),
#                ('підбадьорений', 1),
#                ('дебелий', 1),
#                ('добрий', 1),
#                ('тайговий', 1)]),
#              ('хлопчина', [('примітивний', 1)]),
#              ('царя', [('незнаний', 1), ('оспіваний', 1)]),
#              ('циклоп', [('велетенський', 1), ('двоокий', 1)]),
#              ('чекіст', [('славний', 1)]),
#              ('чоловік', [('золотий', 1), ('бідолашний', 1)]),
#              ('чоловічок', [('наївний', 1), ('лісовий', 1)]),
#              ('чуба', [('буйний', 1)]),
#              ('чужина', [('чужий', 1)]),
#              ('чужинець', [('далекий', 1)]),
#              ('шелест', [('тріскотнява', 1), ('підозрілий', 1)]),
#              ('шибайгол',
#               [('одчайдушний', 1), ('молодий', 1), ('безжурний', 1)]),
#              ('шукач',
#               [('хоробрий', 1), ("сп'янілий", 1), ('екзальтований', 1)]),
#              ('юнак', [('русявий', 1), ('молодий', 1), ('бородатий', 1)]),
#              ('юний', [('журливий', 1)]),
#              ('якут',
#               [('бронзовий', 2),
#                ('засмалений', 1),
#                ('подібний', 1),
#                ('страшний', 1),
#                ('широкогрудий', 1)]),
#              ('янгол', [('святій', 1)]),
#              ('японець', [('косоокий', 1)]),
#              ('єнот', [('тендітний', 1)]),
#              ('ізюбр', [('далекий', 1)]),
#              ('ізюбрина', [('лапчатий', 1)]),
#              ('імператор', [('російський', 1)]),
#              ('імпотент', [('згальванізований', 1)]),
#              ('індійці', [('джеклондонівський', 1)]),
#              ('інженер', [('кваліфікуваний', 1)]),
#              ('істота', [('двоногий', 1), ('живий', 1)]),
#              ('іцько', [('старенький', 1)])])

# %%
collocations.get('сірко')
# Out:
# [('старий', 84),
#  ('хитріший', 1),
#  ('залитий', 1),
#  ('навколишній', 1),
#  ('поглядаючія', 1)]

# %% [markdown]
# **IMPORTANT!!!**
#
# Чомусь ``json`` не зберігає корректно весь ``dict``, тому краще перезапустити самостійно, щоб впевнитись в результаті
