# %%
import os

from IPython.display import display, Markdown, Image

# %%
REPO_PATH = os.path.dirname(os.path.dirname(os.path.dirname(os.getcwd())))
TASK_PATH = os.path.join(REPO_PATH, "tasks", "02-structural-linguistics")
DATA_PATH = os.path.join(TASK_PATH, "data")

# %%
def show_markdown(path):
    with open(path, 'r') as fh:
        content = fh.read()
    display(Markdown(content))

# %%
show_markdown(os.path.join(TASK_PATH, "3-collocations.md"))
# Out:
# ## Колокації
#
# Одним із важливих аспектів будь-якої природної мови є сполучуваність слів. В англійській мові поняття сполучуваності дуже відчутне і присутнє у всіх мовних структурах: ми кажемо _"make a mistake",_ але _"do a favour";_ ми кажемо _"big surprise",_ але _"great anger";_ ми кажемо _"highly unlikely",_ але _"seriously wrong"._
#
# ### 1. Англійська мова
#
# У цьому завданні вам потрібно дослідити сполучуваність дієслів одного синонімного ряду з прислівниками. Наприклад, ми частіше кажемо _"love somebody dearly", "honor somebody highly",_ але _"admire somebody greatly"._
#
# **Завдання:**
# 1. продовжте синонімний ряд дієслів: _"say", "tell", "speak", "claim", "communicate"_
# 2. напишіть функцію, яка знаходить у реченні дієслово (за складеним раніше синонімним рядом) і витягає усі можливі прислівники на "-ly", якими це дієслово керує
# 3. напишіть програму, яка знайде усі можливі прислівники для ваших дієслів у [корпусі блогів](data/blog2008.txt)
# 4. на виході програма повинна видати десять найчастотніших прислівників для кожного дієслова (разом із частотою). Приклад виводу:
# 	```
# 	say: (loudly, 51), (silently, 45), (quietly, 10)
# 	tell: (quietly, 100), (loudly, 61), (seriously, 5)
# 	```
# 5. збережіть програму та результати аналізу на корпусі (вивід) у директорії з вашим іменем
#
# Синоніми можна знайти у тезаурусах (http://www.thesaurus.com/, https://www.merriam-webster.com/thesaurus) чи [WordNet](http://wordnetweb.princeton.edu/perl/webwn).
#
# Підказка: зверніть увагу на те, що у природній мові дієслова можуть мати різні форми, а прислівників може бути по декілька.
#
# ### 2. Українська мова
#
# У цьому завданні вам потрібно дослідити сполучуваність іменників-істот з прикметниками.
#
# **Завдання:**
# 1. напишіть функцію, яка знаходить у реченні іменник, що позначає істоту, і витягає усі прикметники, якими цей іменник керує
# 2. напишіть програму, яка знайде усі можливі словосполучення прикметників та іменників-істот у [романі "Тигролови"](data/tyhrolovy.txt)
# 3. на виході програма повинна видати усі знайдені словосполучення та їх частоти. Приклад виводу:
# 	```
# 	84: старий сірко
# 	5: великий начальник
# 	```
# 4. збережіть програму та результати виводу в директорії з вашим іменем
#
# Підказка: можна шукати послідовність прикметника та іменника і визначати словосполучення через pymorphy2. Також можна попрацювати з деревами залежностей через StanfordNLP, але можливо доведеться запускати код десь на Google Colab, бо там дуже великі моделі для української мови.
#
# ### Джерела
#
# Ви можете використати будь-яку мову програмування та будь-яку NLP-бібліотеку.
#
# Корпус блогів взятий з [Political Blog Corpora](http://www.cs.cmu.edu/~ark/blog-data/).

# %% [markdown]
# ### Part 1

# %%
import re
import gc
import json
import spacy
import pandas as pd

from collections import Counter, OrderedDict
from functools import reduce
from multiprocessing import cpu_count
from tqdm import tqdm
from tqdm.contrib.concurrent import process_map

# %%
nlp_en = spacy.load('en_core_web_md')

# %%
synonyms = ["say", 
            "add", "announce", "answer", "assert", "claim", "convey", "declare", "deliver",
            "disclose", "do", "estimate", "express", "maintain", "mention", "read", "repeat", "reply",
            "report", "respond", "reveal", "speak", "state", "suggest", "tell", "voice", "affirm", 
            "allege", "communicate", "conjecture", "divulge", "flap", "gab", "guess", "imagine", 
            "imply", "jaw", "judge", "lip", "opine", "orate", "perform", "pronounce", "rap", "recite", 
            "rehearse", "relate", "remark", "render", "rumor", "spiel", "utter", "verbalize", "yak"]

# %%
def count_adv(sentence, verbs=synonyms):
    tokens = nlp_en(sentence)
    cnt = Counter()
    
    for token in tokens:
        if token.pos_ == 'ADV' and token.text[-2:] == 'ly' and token.dep_ == 'advmod':
            for ancestor in token.ancestors:
                if ancestor.lemma_ in verbs and ancestor.pos_ == 'VERB':
                    cnt.update({(ancestor.lemma_, token.lower_):1})
    return cnt

# %%
corpus_df = pd.read_table(os.path.join(DATA_PATH, 'blog2008.txt'), names=["text"])

# %%
# %%time

try:
    with open('collocations_en.json', 'r') as file_:
        collocations = json.load(file_)
except FileNotFoundError:
    lst = process_map(count_adv, corpus_df.text.values, max_workers=cpu_count())
    total_cntr = reduce((lambda x, y: x + y), lst)

    collocations = {}
    for (verb, adv), count in total_cntr.items():
        collocations[verb] = collocations.get(verb, []) + [(adv, count)]
        
    collocations = {verb: sorted(cnt, key=lambda x: x[1], reverse=True)[:10] for verb, cnt in collocations.items()}
    
    with open('collocations_en.json', 'w') as file_:
        json.dump(collocations, file_, sort_keys=True, indent=4)
    
    del lst, total_cntr
    gc.collect()
# Out:
# CPU times: user 1.1 ms, sys: 85 µs, total: 1.19 ms
# Wall time: 745 µs

# %%
OrderedDict(sorted(collocations.items()))
# Out:
# OrderedDict([('add',
#               [['only', 38],
#                ['really', 27],
#                ['simply', 13],
#                ['certainly', 11],
#                ['actually', 10],
#                ['probably', 9],
#                ['quickly', 9],
#                ['early', 8],
#                ['currently', 7],
#                ['fully', 5]]),
#              ('affirm',
#               [['simply', 3],
#                ['repeatedly', 2],
#                ['falsely', 2],
#                ['constantly', 1],
#                ['traditionally', 1],
#                ['hopelessly', 1],
#                ['clearly', 1]]),
#              ('allege',
#               [['only', 4],
#                ['subsequently', 3],
#                ['officially', 2],
#                ['potentially', 2],
#                ['personally', 2],
#                ['flatly', 2],
#                ['wrongly', 2],
#                ['directly', 2],
#                ['primarily', 1],
#                ['intimately', 1]]),
#              ('announce',
#               [['recently', 17],
#                ['officially', 12],
#                ['publicly', 9],
#                ['early', 9],
#                ['only', 8],
#                ['shortly', 6],
#                ['finally', 5],
#                ['nearly', 4],
#                ['proudly', 4],
#                ['essentially', 4]]),
#              ('answer',
#               [['directly', 10],
#                ['actually', 9],
#                ['only', 8],
#                ['really', 7],
#                ['finally', 7],
#                ['honestly', 6],
#                ['exactly', 5],
#                ['completely', 4],
#                ['carefully', 3],
#                ['definitively', 3]]),
#              ('assert',
#               [['only', 8],
#                ['simply', 5],
#                ['blithely', 4],
#                ['really', 4],
#                ['scientifically', 3],
#                ['merely', 3],
#                ['forcefully', 3],
#                ['probably', 2],
#                ['apparently', 2],
#                ['falsely', 2]]),
#              ('claim',
#               [['falsely', 82],
#                ['only', 66],
#                ['actually', 23],
#                ['simply', 18],
#                ['really', 16],
#                ['nearly', 14],
#                ['repeatedly', 12],
#                ['previously', 10],
#                ['merely', 10],
#                ['apparently', 9]]),
#              ('communicate',
#               [['effectively', 4],
#                ['directly', 3],
#                ['freely', 1],
#                ['really', 1],
#                ['only', 1],
#                ['verbally', 1],
#                ['apparently', 1],
#                ['loudly', 1],
#                ['hopefully', 1],
#                ['daily', 1]]),
#              ('conjecture', [['captivatingly', 1]]),
#              ('convey',
#               [['accurately', 3],
#                ['highly', 2],
#                ['usually', 2],
#                ['fully', 2],
#                ['strongly', 2],
#                ['relatively', 2],
#                ['only', 2],
#                ['sharply', 1],
#                ['positively', 1],
#                ['directly', 1]]),
#              ('declare',
#               [['publicly', 16],
#                ['only', 16],
#                ['finally', 7],
#                ['immediately', 7],
#                ['obviously', 6],
#                ['recently', 6],
#                ['repeatedly', 5],
#                ['falsely', 5],
#                ['officially', 4],
#                ['absolutely', 4]]),
#              ('deliver',
#               [['directly', 6],
#                ['actually', 5],
#                ['really', 5],
#                ['nearly', 4],
#                ['only', 4],
#                ['probably', 3],
#                ['obviously', 3],
#                ['recently', 3],
#                ['quickly', 3],
#                ['simply', 3]]),
#              ('disclose',
#               [['fully', 9],
#                ['publicly', 8],
#                ['only', 6],
#                ['immediately', 4],
#                ['recently', 3],
#                ['previously', 3],
#                ['newly', 3],
#                ['unwittingly', 2],
#                ['properly', 2],
#                ['anonymously', 2]]),
#              ('divulge',
#               [['directly', 1],
#                ['exactly', 1],
#                ['really', 1],
#                ['currently', 1]]),
#              ('do',
#               [['exactly', 48],
#                ['only', 29],
#                ['actually', 29],
#                ['really', 15],
#                ['probably', 13],
#                ['nearly', 10],
#                ['certainly', 9],
#                ['simply', 9],
#                ['poorly', 9],
#                ['quickly', 9]]),
#              ('estimate',
#               [['nearly', 8],
#                ['only', 6],
#                ['previously', 3],
#                ['actually', 2],
#                ['easily', 2],
#                ['likely', 2],
#                ['wrongly', 2],
#                ['approximately', 1],
#                ['appallingly', 1],
#                ['fully', 1]]),
#              ('express',
#               [['only', 9],
#                ['repeatedly', 6],
#                ['profoundly', 4],
#                ['freely', 4],
#                ['actually', 3],
#                ['privately', 3],
#                ['certainly', 3],
#                ['really', 3],
#                ['publicly', 3],
#                ['finally', 3]]),
#              ('guess',
#               [['only', 17],
#                ['really', 9],
#                ['actually', 9],
#                ['simply', 5],
#                ['finally', 4],
#                ['politically', 4],
#                ['absolutely', 3],
#                ['probably', 3],
#                ['apparently', 2],
#                ['merely', 2]]),
#              ('imagine',
#               [['only', 18],
#                ['simply', 7],
#                ['possibly', 7],
#                ['especially', 5],
#                ['really', 4],
#                ['fundamentally', 3],
#                ['mostly', 3],
#                ['immediately', 3],
#                ['perfectly', 2],
#                ['truly', 2]]),
#              ('imply',
#               [['strongly', 7],
#                ['only', 4],
#                ['certainly', 3],
#                ['really', 3],
#                ['clearly', 2],
#                ['broadly', 2],
#                ['miserably', 2],
#                ['partly', 1],
#                ['regionally', 1],
#                ['differently', 1]]),
#              ('judge',
#               [['only', 7],
#                ['kindly', 6],
#                ['harshly', 5],
#                ['solely', 4],
#                ['accurately', 3],
#                ['magically', 1],
#                ['quickly', 1],
#                ['sternly', 1],
#                ['unanimously', 1],
#                ['regularly', 1]]),
#              ('maintain',
#               [['only', 5],
#                ['actually', 3],
#                ['probably', 2],
#                ['consistently', 2],
#                ['actively', 2],
#                ['perfectly', 2],
#                ['properly', 2],
#                ['rapidly', 1],
#                ['certainly', 1],
#                ['physically', 1]]),
#              ('mention',
#               [['only', 29],
#                ['really', 9],
#                ['barely', 7],
#                ['specifically', 7],
#                ['certainly', 6],
#                ['briefly', 5],
#                ['recently', 5],
#                ['prominently', 4],
#                ['hardly', 4],
#                ['finally', 4]]),
#              ('opine',
#               [['similarly', 1],
#                ['woderfully', 1],
#                ['previously', 1],
#                ['successfully', 1],
#                ['utterly', 1],
#                ['suddenly', 1],
#                ['finally', 1],
#                ['separately', 1],
#                ['frankly', 1]]),
#              ('perform',
#               [['poorly', 6],
#                ['only', 4],
#                ['badly', 4],
#                ['brilliantly', 3],
#                ['adequately', 2],
#                ['lately', 2],
#                ['tacitly', 2],
#                ['traditionally', 2],
#                ['heroically', 2],
#                ['expertly', 1]]),
#              ('pronounce',
#               [['ostentatiously', 1],
#                ['routinely', 1],
#                ['substantively', 1],
#                ['nearly', 1],
#                ['quickly', 1],
#                ['similarly', 1],
#                ['officially', 1],
#                ['suddenly', 1],
#                ['only', 1],
#                ['certainly', 1]]),
#              ('rap', [['particularly', 1], ['usually', 1]]),
#              ('read',
#               [['actually', 28],
#                ['simply', 13],
#                ['correctly', 11],
#                ['recently', 11],
#                ['really', 11],
#                ['apparently', 11],
#                ['only', 10],
#                ['especially', 10],
#                ['carefully', 8],
#                ['widely', 7]]),
#              ('recite',
#               [['sharply', 4],
#                ['simply', 3],
#                ['invariably', 2],
#                ['robotically', 1],
#                ['rapidly', 1],
#                ['properly', 1]]),
#              ('rehearse', [['carefully', 2], ['thoroughly', 1]]),
#              ('relate',
#               [['directly', 14],
#                ['tangentially', 4],
#                ['closely', 3],
#                ['specifically', 3],
#                ['especially', 2],
#                ['probably', 2],
#                ['only', 2],
#                ['actually', 2],
#                ['recently', 2],
#                ['clearly', 2]]),
#              ('remark',
#               [['really', 4],
#                ['recently', 2],
#                ['surely', 2],
#                ['tartly', 1],
#                ['finally', 1],
#                ['essentially', 1],
#                ['only', 1],
#                ['consequently', 1],
#                ['bitterly', 1],
#                ['famously', 1]]),
#              ('render',
#               [['nearly', 2],
#                ['immediately', 2],
#                ['practically', 1],
#                ['effectively', 1],
#                ['vaguely', 1],
#                ['properly', 1],
#                ['politically', 1],
#                ['artfully', 1],
#                ['typically', 1],
#                ['essentially', 1]]),
#              ('repeat',
#               [['only', 6],
#                ['merely', 5],
#                ['actually', 4],
#                ['dutifully', 3],
#                ['simply', 3],
#                ['frequently', 3],
#                ['clearly', 2],
#                ['nearly', 2],
#                ['probably', 2],
#                ['unfortunately', 2]]),
#              ('reply',
#               [['simply', 12],
#                ['only', 6],
#                ['really', 4],
#                ['highly', 3],
#                ['absolutely', 3],
#                ['recently', 2],
#                ['actually', 2],
#                ['probably', 2],
#                ['exactly', 2],
#                ['sarcastically', 2]]),
#              ('report',
#               [['only', 40],
#                ['recently', 40],
#                ['previously', 23],
#                ['actually', 21],
#                ['widely', 20],
#                ['nearly', 14],
#                ['directly', 13],
#                ['finally', 13],
#                ['apparently', 12],
#                ['early', 11]]),
#              ('respond',
#               [['only', 16],
#                ['quickly', 15],
#                ['actually', 12],
#                ['immediately', 11],
#                ['simply', 9],
#                ['really', 7],
#                ['aggressively', 7],
#                ['forcefully', 6],
#                ['publicly', 6],
#                ['directly', 5]]),
#              ('reveal',
#               [['only', 15],
#                ['recently', 13],
#                ['really', 9],
#                ['truly', 7],
#                ['previously', 5],
#                ['nearly', 5],
#                ['finally', 5],
#                ['regularly', 4],
#                ['exactly', 4],
#                ['actually', 4]]),
#              ('rumor',
#               [['actually', 1],
#                ['obviously', 1],
#                ['publicly', 1],
#                ['namely', 1],
#                ['widely', 1]]),
#              ('say',
#               [['only', 445],
#                ['really', 260],
#                ['actually', 207],
#                ['simply', 136],
#                ['recently', 123],
#                ['probably', 120],
#                ['exactly', 98],
#                ['repeatedly', 78],
#                ['publicly', 76],
#                ['absolutely', 69]]),
#              ('speak',
#               [['directly', 37],
#                ['only', 25],
#                ['publicly', 22],
#                ['actually', 15],
#                ['fiercely', 12],
#                ['recently', 11],
#                ['briefly', 9],
#                ['highly', 8],
#                ['generally', 8],
#                ['really', 8]]),
#              ('state',
#               [['publicly', 22],
#                ['clearly', 20],
#                ['only', 14],
#                ['unequivocally', 13],
#                ['explicitly', 13],
#                ['recently', 9],
#                ['previously', 8],
#                ['simply', 8],
#                ['bluntly', 7],
#                ['flatly', 7]]),
#              ('suggest',
#               [['strongly', 34],
#                ['only', 31],
#                ['really', 18],
#                ['actually', 16],
#                ['falsely', 11],
#                ['directly', 10],
#                ['probably', 10],
#                ['certainly', 9],
#                ['simply', 8],
#                ['recently', 7]]),
#              ('tell',
#               [['only', 83],
#                ['really', 71],
#                ['actually', 41],
#                ['exactly', 34],
#                ['recently', 34],
#                ['probably', 30],
#                ['simply', 23],
#                ['privately', 22],
#                ['personally', 19],
#                ['absolutely', 18]]),
#              ('utter',
#               [['actually', 2],
#                ['really', 1],
#                ['verbally', 1],
#                ['deliciously', 1],
#                ['casually', 1],
#                ['pejoratively', 1],
#                ['only', 1],
#                ['basically', 1]]),
#              ('voice',
#               [['recently', 3],
#                ['openly', 2],
#                ['surprisingly', 1],
#                ['apparently', 1],
#                ['increasingly', 1],
#                ['palpably', 1],
#                ['frequently', 1],
#                ['quickly', 1],
#                ['nearly', 1],
#                ['hastily', 1]])])

# %% [markdown]
# ### Part 2

# %%
import stanfordnlp
import warnings

warnings.filterwarnings("ignore")

# %%
nlp_uk = stanfordnlp.Pipeline(lang='uk')
# Out:
# Use device: cpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/dima/stanfordnlp_resources/uk_iu_models/uk_iu_tokenizer.pt', 'lang': 'uk', 'shorthand': 'uk_iu', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/dima/stanfordnlp_resources/uk_iu_models/uk_iu_tagger.pt', 'pretrain_path': '/home/dima/stanfordnlp_resources/uk_iu_models/uk_iu.pretrain.pt', 'lang': 'uk', 'shorthand': 'uk_iu', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/home/dima/stanfordnlp_resources/uk_iu_models/uk_iu_lemmatizer.pt', 'lang': 'uk', 'shorthand': 'uk_iu', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/home/dima/stanfordnlp_resources/uk_iu_models/uk_iu_parser.pt', 'pretrain_path': '/home/dima/stanfordnlp_resources/uk_iu_models/uk_iu.pretrain.pt', 'lang': 'uk', 'shorthand': 'uk_iu', 'mode': 'predict'}
# Done loading processors!
# ---

# %%
corpus_df = pd.read_table(os.path.join(DATA_PATH, 'tyhrolovy.txt'), names=["text"])

# %%
corpus_df
# Out:
#                                                    text
# 0                                             Тигролови
# 1                                         Іван Багряний
# 2                                         ЧАСТИНА ПЕРША
# 3                                         Розділ перший
# 4                                                ДРАКОН
# ...                                                 ...
# 2653  Гриць прип'яв Заливая, щоб не втік. Так звеліл...
# 2654  Але Заливай скучав. Скучав смертельно. Вірний ...
# 2655                Подався доганяти без надії догнати.
# 2656                  Але — сміливі завжди мають щастя.
# 2657                                               1943
#
# [2658 rows x 1 columns]

# %%
def count_adj_uk(string):
    sentences = nlp_uk(string).sentences
    cnt = Counter()
    
    for sentence in sentences:
        for token in sentence.words:
            if token.upos == 'NOUN':
                res = [tkn.lemma.lower() for tkn in sentence.words 
                                 if tkn.upos == 'ADJ' and tkn.governor == int(token.index)]
                for _ in res:
                    cnt.update({(token.lemma.lower(), _):1})
    return cnt

# %%
# from torch.multiprocessing import Pool, Process, set_start_method
# try:
#      set_start_method('spawn', force=True)
# except RuntimeError:
#     pass

# %%
# %%time

try:
    with open('collocations_uk.json', 'r') as file_:
        collocations = json.load(file_)
except FileNotFoundError:
#     lst = list(map(count_adj_uk, corpus_df.text.values))
    lst = []
    for item in tqdm(corpus_df.text.values):
        lst.append(count_adj_uk(item))
    total_cntr = reduce((lambda x, y: x + y), lst)

    collocations = {}
    for (verb, adv), count in total_cntr.items():
        collocations[verb] = collocations.get(verb, []) + [(adv, count)]
        
    collocations = {verb: sorted(cnt, key=lambda x: x[1], reverse=True)[:10] for verb, cnt in collocations.items()}
    
    with open('collocations_uk.json', 'w') as file_:
        json.dump(collocations, file_, sort_keys=True, indent=4, ensure_ascii=False)
    
    del lst, total_cntr
    gc.collect()
# Out:
# CPU times: user 10.7 ms, sys: 117 µs, total: 10.9 ms
# Wall time: 9.98 ms

# %%
OrderedDict(sorted(collocations.items()))
# Out:
# OrderedDict([('абажур', [['різнокольоровий', 1], ['вибагливий', 1]]),
#              ('абрикос', [['консервований', 2]]),
#              ('авантюрник', [['індустріальний', 1]]),
#              ('агонія', [['останній', 1], ['дитячий', 1]]),
#              ('адреса', [['повний', 1]]),
#              ('азіата', [['далекий', 1], ['дикий', 1]]),
#              ('акомпанемент', [['монотонний', 1]]),
#              ('аксесуар',
#               [['дивогідний', 1],
#                ['найдивоглядніший', 1],
#                ['надзвичайний', 1]]),
#              ('аксесуара', [['фантастичний', 1], ['екзотичний', 1]]),
#              ('альфонс', [['кралі', 1]]),
#              ('аматор', [['новітний', 1], ['пржевальський', 1]]),
#              ('амбразура', [['маленький', 1]]),
#              ('амур',
#               [['широченний', 2],
#                ['скований', 1],
#                ['найвужчий', 1],
#                ['стиснений', 1]]),
#              ('амурець', [['другий', 1], ['здоровенний', 1]]),
#              ('анісовка', [['випитий', 1]]),
#              ('апарат', [['настільний', 1]]),
#              ('апатія', [['цілковитий', 1]]),
#              ('апетитовий', [['вовчий', 1]]),
#              ('арабеска', [['золотий', 3]]),
#              ('арештант', [['новий', 1], ['виснажений', 1]]),
#              ('аристократія', [['сучасний', 1]]),
#              ('армія', [['величезний', 1], ['цілий', 1], ['червоний', 1]]),
#              ('архітектура', [['шестиповерховий', 1]]),
#              ('ач', [['знятий', 1]]),
#              ('баб', [['голоспинний', 1]]),
#              ('багнет', [['тригранний', 1], ['примкнутий', 1]]),
#              ('баговиння', [['тьмяний', 1]]),
#              ('бажання', [['непереможний', 1]]),
#              ('баз', [['ліпший', 1], ['харчовий', 1]]),
#              ('база', [['битий', 1], ['камчатський', 1]]),
#              ('балоний', [['набитий', 1]]),
#              ('банд', [['перекипений', 1]]),
#              ('банда', [['великий', 3], ['озброєний', 1]]),
#              ('банячка', [['бляшаний', 1]]),
#              ('барак',
#               [['лісозаготівельний', 2],
#                ['невеликий', 1],
#                ['новий', 1],
#                ['другий', 1],
#                ['тайговий', 1],
#                ['покинений', 1],
#                ['безлюдний', 1]]),
#              ('барва', [['веселковий', 1]]),
#              ('барс', [['субтропічний', 1]]),
#              ('батьки',
#               [['розкуркулений', 1], ['розкиданий', 1], ['вражений', 1]]),
#              ('батько',
#               [['давніш', 1],
#                ['хрещений', 1],
#                ['задоволений', 1],
#                ['старий', 1]]),
#              ('баїра', [['ленінградський', 1], ['всесоюзний', 1]]),
#              ('бдітєльность', [['священний', 1]]),
#              ('безвірник', [['правовірний', 1]]),
#              ('безкрайма', [['покручений', 1]]),
#              ('безладда', [['гарячковий', 1]]),
#              ('безмежжя', [['затканий', 1]]),
#              ('безодний', [['чорний', 2]]),
#              ('безумство', [['хоробрий', 1]]),
#              ('берег',
#               [['крутий', 2],
#                ['самісінький', 1],
#                ['голім', 1],
#                ['турецький', 1],
#                ['низький', 1],
#                ['цілий', 1],
#                ['правий', 1]]),
#              ('береза', [['полярний', 1]]),
#              ('береста', [['крита', 1]]),
#              ('бескеття', [['синій', 1], ['стрімкий', 1], ['золотий', 1]]),
#              ('бескиддя', [['дикий', 1]]),
#              ('бик', [['розпалений', 1], ['другий', 1]]),
#              ('бирка',
#               [['сухий', 1],
#                ['торішній', 1],
#                ['старий', 1],
#                ['кедровий', 1],
#                ['сосновий', 1]]),
#              ('бистрий', [['гострий', 1]]),
#              ('бистроока', [['хороший', 1], ['грайливий', 1], ['смутний', 1]]),
#              ('бистроокий', [['замурзаний', 1]]),
#              ('битва', [['героїчний', 1]]),
#              ('блакиття', [['небесний', 1]]),
#              ('блиск', [['сонячний', 1], ['хворобливий', 1]]),
#              ('блиска',
#               [['фосфоричний', 1], ['здивований', 1], ['витріщений', 1]]),
#              ('блищика', [['химерня', 1]]),
#              ('бляхоя', [['цинковий', 1]]),
#              ('бляшаний', [['підкинений', 1]]),
#              ('бог',
#               [['дивний', 2],
#                ['волохатий', 2],
#                ['могутній', 2],
#                ['тутешній', 1],
#                ['лютий', 1],
#                ['безжалісний', 1],
#                ['гірський', 1]]),
#              ('божество', [['страшний', 1]]),
#              ('боклажка', [['чужий', 1]]),
#              ('борода', [['білий', 1]]),
#              ('боротьба', [['короткий', 2], ['жорстокий', 1]]),
#              ('борошно', [['заграничний', 1]]),
#              ('борщ', [['гарячий', 1]]),
#              ('бота', [['фетровий', 1]]),
#              ('бочка', [['омулевий', 1]]),
#              ('бою', [['упертогий', 1]]),
#              ('боягуза', [['гидкий', 1]]),
#              ('брама', [['розчинений', 1]]),
#              ('брат', [['щасливий', 1]]),
#              ('бревняк', [['товстий', 1]]),
#              ('брезент', [['розстелений', 1]]),
#              ('бридж', [['модний', 1], ['англійський', 1]]),
#              ('брила', [['страхітний', 1], ['великий', 1], ['кам’яний', 1]]),
#              ('брити',
#               [['величезний', 1], ['кам’яний', 1], ['поставлений', 1]]),
#              ('бров', [['нахмурений', 1]]),
#              ('брова',
#               [['крилата', 1],
#                ['заломлений', 1],
#                ['нахмурений', 1],
#                ['григорій', 1],
#                ['волохатий', 1]]),
#              ('бровий', [['насуплений', 1]]),
#              ('бронза', [['червоний', 1]]),
#              ('брусниця', [['той', 1]]),
#              ('брусок', [['товстий', 1]]),
#              ('бріти', [['насуплений', 3], ['волохатий', 2]]),
#              ('буботіння', [['чийсь', 1]]),
#              ('будень', [['всесоюзний', 1]]),
#              ('будинок',
#               [['модерний', 2],
#                ['згромаджений', 1],
#                ['найвищий', 1],
#                ['головний', 1],
#                ['крайвиконкий', 1],
#                ['шестиповерховий', 1],
#                ['величезний', 1],
#                ['новозбудований', 1]]),
#              ('будівля', [['самісінький', 1], ['великий', 1]]),
#              ('буженина', [['сакраментальний', 1]]),
#              ('бурка', [['ганчір’яний', 1], ['потворний', 1]]),
#              ('бурундук', [['занепокоєний', 1]]),
#              ('бурчання', [['радісний', 1]]),
#              ('буря', [['цілий', 1]]),
#              ('бурят', [['червоношкірий', 1]]),
#              ('бур’ян', [['сухий', 2], ['приметений', 1]]),
#              ('буфет', [['завідуючий', 1]]),
#              ('бюрократи', [['радгоспний', 1]]),
#              ('бюсти', [['опукль', 1]]),
#              ('бій',
#               [['тяжкий', 1],
#                ['кількагодинний', 1],
#                ['героїчний', 1],
#                ['великий', 1]]),
#              ('бік',
#               [['другий', 10],
#                ['приторочений', 1],
#                ['правий', 1],
#                ['протилежний', 1],
#                ['темрява', 1],
#                ['різний', 1],
#                ['підідраний', 1]]),
#              ('білка', [['летючий', 1]]),
#              ('більшість', [['абсолютний', 1]]),
#              ('бінокль',
#               [['цейсівський', 2], ['добрий', 2], ['наведений', 1]]),
#              ('біографія', [['точний', 1]]),
#              ('біцепс', [['юнацький', 1]]),
#              ('ваго', [['товаровий', 1]]),
#              ('вагон',
#               [['середній', 3],
#                ['другий', 3],
#                ['той', 1],
#                ['товаровий', 1],
#                ['порожній', 1]]),
#              ('ваза', [['скляний', 1]]),
#              ('вальса', [['мрійний', 1]]),
#              ('валянка', [['грубезний', 1]]),
#              ('валіза', [['повний', 1]]),
#              ('вата', [['пройнятий', 1]]),
#              ('ватр', [['величезний', 1], ['яскравий', 1]]),
#              ('ватяний', [['легенький', 1]]),
#              ('вбрання', [['екзотичний', 2], ['старенький', 1]]),
#              ('вдач', [['хлоп’ячий', 1]]),
#              ('вдача',
#               [['міцний', 1], ['неабиякий', 1], ['крутий', 1], ['добрий', 1]]),
#              ('ведмежий', [['зраділий', 1]]),
#              ('ведмідь',
#               [['гімалайський', 1],
#                ['волохатий', 1],
#                ['величезний', 1],
#                ['чорний', 1],
#                ['припертий', 1],
#                ['другий', 1]]),
#              ('вепр', [['роздрочений', 1]]),
#              ('вепра', [['великий', 1]]),
#              ('веремія', [['цілий', 1]]),
#              ('вершина', [['білий', 1]]),
#              ('ветеран', [['старий', 1]]),
#              ('вечір', [['місячний', 1], ['синій', 1]]),
#              ('вибагливість', [['людський', 1]]),
#              ('вибрик', [['хлоп’ячь', 1], ['зухвалий', 1]]),
#              ('вибух', [['шалений', 1]]),
#              ('виворотення', [['височенний', 1]]),
#              ('вивірка', [['місцевий', 1]]),
#              ('вигляд', [['індиферентний', 1]]),
#              ('видання', [['дешевий', 1], ['масовий', 1]]),
#              ('виклик', [['дерзкий', 1]]),
#              ('вимовий', [['кубанський', 1]]),
#              ('виноград', [['дикий', 1]]),
#              ('винуватиця', [['головний', 1]]),
#              ('випадковість', [['явний', 1]]),
#              ('виповзок', [['званий', 1]]),
#              ('випуск', [['старий', 1]]),
#              ('висновок', [['несподіваний', 1]]),
#              ('височина', [['триметровий', 1]]),
#              ('витребеньки', [['різдвяний', 1]]),
#              ('витривалість', [['дідівський', 1]]),
#              ('витягти', [['старий', 1]]),
#              ('вихор', [['джазові', 1]]),
#              ('вияти', [['найвищий', 1]]),
#              ('влада', [['переступлений', 1]]),
#              ('власть', [['совєтський', 1]]),
#              ('влітку', [['узбецький', 1], ['модний', 1]]),
#              ('вовк', [['старий', 1]]),
#              ('вовчур', [['гостровухий', 1]]),
#              ('вогкість', [['великий', 1]]),
#              ('вогнище', [['великий', 2]]),
#              ('вогонь',
#               [['раптовий', 2], ['хворобливий', 1], ['пекельний', 1]]),
#              ('вода',
#               [['кришталевий', 1],
#                ['звичайний', 1],
#                ['казковий', 1],
#                ['бистрій', 1],
#                ['мерехтливий', 1],
#                ['чорний', 1],
#                ['теплий', 1],
#                ['мрійний', 1],
#                ['холодний', 1],
#                ['гарячий', 1]]),
#              ('воднораз', [['простий', 1]]),
#              ('водоспад',
#               [['крижаний', 2],
#                ['стрімкий', 1],
#                ['мрійний', 1],
#                ['дивний', 1],
#                ['велетенський', 1]]),
#              ('вождя', [['виголошений', 1]]),
#              ('волога',
#               [['отой', 1],
#                ['казковий', 1],
#                ['цілющий', 1],
#                ['чудодійний', 1],
#                ['бадьорливий', 1]]),
#              ('волосся', [['пасемко', 1], ['русявий', 1]]),
#              ('волошка', [['синій', 1]]),
#              ('воля',
#               [['зборканий', 1],
#                ['упокорений', 1],
#                ['надзвичайний', 1],
#                ['серце', 1]]),
#              ('ворог', [['новий', 1], ['вчений', 1], ['лихий', 1]]),
#              ('вояк', [['досвідчений', 1]]),
#              ('воїстина', [['буйний', 1]]),
#              ('впертість', [['надзвичайний', 1], ['випробуваний', 1]]),
#              ('вправа', [['стрілецький', 3]]),
#              ('вправу', [['оригінальний', 1]]),
#              ('враження',
#               [['останній', 1], ['належний', 1], ['розлючений', 1]]),
#              ('вражіння',
#               [['новий', 1],
#                ['щодалі', 1],
#                ['цікавіший', 1],
#                ['колосальний', 1],
#                ['дивний', 1],
#                ['сильніше', 1]]),
#              ('встаткування', [['мисливський', 1]]),
#              ('всторч', [['гнаний', 1]]),
#              ('втома', [['смертельний', 2], ['важка', 1]]),
#              ('втіха', [['великий', 2]]),
#              ('вузлом', [['моряцький', 1]]),
#              ('вулиця',
#               [['головний', 3],
#                ['бічний', 2],
#                ['широка', 1],
#                ['обставлений', 1],
#                ['центральний', 1],
#                ['вечоровий', 1],
#                ['морозян', 1]]),
#              ('вусо', [['усміхнений', 1]]),
#              ('вусто', [['неприступний', 1], ['незайманий', 1]]),
#              ('вухо',
#               [['розпущений', 2],
#                ['гострий', 1],
#                ['чуйний', 1],
#                ['невиспаний', 1],
#                ['розідраний', 1]]),
#              ('вхід', [['підпертий', 1]]),
#              ('вчитель', [['скрипник', 1]]),
#              ('вівця', [['оточений', 1]]),
#              ('вівчарк', [['німецький', 1]]),
#              ('відгук', [['дивний', 1]]),
#              ('віддаль', [['мрійний', 1]]),
#              ('відділ', [['країв', 1], ['особий', 1]]),
#              ('відкриватель', [['експансивний', 1]]),
#              ('відпочинок', [['сталий', 1]]),
#              ('відрух', [['інстинктивний', 1]]),
#              ('відрядженець', [['різний', 1], ['відповідальний', 1]]),
#              ('відрядження', [['відповідальний', 1], ['довгий', 1]]),
#              ('відсутність', [['повний', 1]]),
#              ('відтинок', [['великий', 1]]),
#              ('відтінок', [['синій', 1]]),
#              ('відчати', [['голодний', 1]]),
#              ('відчуття', [['гострий', 1], ['незбагненний', 1]]),
#              ('віз', [['невідомий', 1]]),
#              ('візерунок',
#               [['фантастичний', 1], ['розписаний', 1], ['рудий', 1]]),
#              ('війна', [['громадянський', 1], ['убитий', 1], ['швидка', 1]]),
#              ('вік', [['різний', 1], ['півторарічний', 1], ['вічно', 1]]),
#              ('вікно',
#               [['освітлений', 2], ['цілий', 1], ['повидушуваний', 1]]),
#              ('віконечка', [['заґратований', 2]]),
#              ('він-бо', [['старший', 1]]),
#              ('вінегрет', [['прокислий', 1]]),
#              ('віник', [['березовий', 2]]),
#              ('вінчестер', [['англійський', 1]]),
#              ('віра', [['бісовий', 2], ['туя', 1], ['глибокий', 1]]),
#              ('вірність', [['безоглядний', 1]]),
#              ('віршовник', [['виряджений', 1]]),
#              ('віршівка', [['складений', 1]]),
#              ('вірьовка',
#               [['довжелезний', 1],
#                ['скручений', 1],
#                ['міцний', 1],
#                ['товст', 1]]),
#              ('віслюк', [['чортовий', 1]]),
#              ('віта', [['високий', 1]]),
#              ('вітер',
#               [['сибірський', 2],
#                ['забайкальський', 1],
#                ['лагідний', 1],
#                ['злютований', 1]]),
#              ('вітерь', [['гаряче', 1]]),
#              ('вітрина', [['розкішний', 1]]),
#              ('вітчизна', [['втрачений', 1], ['погноблений', 1]]),
#              ('вія', [['довгий', 1], ['волохатий', 1]]),
#              ('віяти', [['вогнення', 1]]),
#              ('в’язниця', [['лук’янівський', 1]]),
#              ('гавкогнява', [['радісний', 1]]),
#              ('гавкот', [['шалений', 1]]),
#              ('гавкіт', [['собачий', 1]]),
#              ('гадюка',
#               [['великий', 1],
#                ['велетенський', 1],
#                ['страшний', 1],
#                ['отруйний', 1]]),
#              ('гадючин', [['останній', 1]]),
#              ('газета', [['тайговий', 1], ['знайдений', 1]]),
#              ('гайдамака', [['диявольський', 1]]),
#              ('галас', [['несамовитий', 1], ['людський', 1]]),
#              ('галуззя', [['цілий', 1], ['мисливський', 1]]),
#              ('гальмо', [['страшний', 1]]),
#              ('галюцинація', [['явний', 1]]),
#              ('галявина',
#               [['сонячний', 1],
#                ['заллятий', 1],
#                ['широкий', 1],
#                ['зелений', 1],
#                ['великий', 1],
#                ['чистий', 1]]),
#              ('гамір', [['густий', 1]]),
#              ('ганж', [['найменший', 1]]),
#              ('гармат', [['небуватий', 1]]),
#              ('гарт', [['старий', 1], ['гостинний', 1]]),
#              ('гвинтівка',
#               [['трилінійний', 3], ['мисливський', 1], ['новенький', 1]]),
#              ('гвинтівочка', [['знаменитий', 2]]),
#              ('ген', [['п’ять', 1]]),
#              ('генерал', [['найбільший', 1]]),
#              ('геній', [['творчий', 1]]),
#              ('географія', [['прикладний', 1]]),
#              ('герой', [['національний', 1], ['бравий', 1]]),
#              ('гетьман', [['малоросійський', 1]]),
#              ('глибінь', [['більший', 1]]),
#              ('глиця', [['грубий', 1], ['дебелий', 1]]),
#              ('глузд', [['май', 1]]),
#              ('гнус', [['клятий', 1]]),
#              ('гнучка', [['строга', 1], ['граційний', 1]]),
#              ('гнів', [['розпучливіший', 1]]),
#              ('гнівий', [['всесокрушающий', 1]]),
#              ('гніт', [['тліючий', 1]]),
#              ('година',
#               [['цілий', 4], ['звичний', 1], ['лихий', 1], ['перший', 1]]),
#              ('голий', [['вкрита', 1], ['обшворганий', 1]]),
#              ('голка', [['циганський', 1]]),
#              ('голова',
#               [['оленячий', 5],
#                ['непокритий', 4],
#                ['вогненноока', 1],
#                ['захмелілий', 1],
#                ['звірячий', 1],
#                ['насмішкуватий', 1],
#                ['покладений', 1],
#                ['мерзль', 1],
#                ['людський', 1],
#                ['рогатий', 1]]),
#              ('голод',
#               [['лютий', 1],
#                ['обдурений', 1],
#                ['опанований', 1],
#                ['вовчий', 1]]),
#              ('голос',
#               [['дівочий', 11],
#                ['понурий', 4],
#                ['наталчин', 4],
#                ['другий', 3],
#                ['ніжний', 2],
#                ['парубоцький', 2],
#                ['третій', 1],
#                ['дзвінкі', 1],
#                ['дзвінкий', 1],
#                ['мрійний', 1]]),
#              ('голосок', [['тонюпький', 1], ['гострий', 1]]),
#              ('голосочка', [['срібний', 1]]),
#              ('голуб', [['розполоханий', 1], ['білий', 1]]),
#              ('гольдячка', [['вбраний', 1], ['низенький', 1]]),
#              ('голівка', [['чубатий', 2]]),
#              ('голічеревий', [['тягуче', 1]]),
#              ('гомін', [['веселий', 1]]),
#              ('гонитво', [['божевільний', 1]]),
#              ('гора',
#               [['скелястий', 2],
#                ['голий', 2],
#                ['блакитний', 1],
#                ['крутий', 1],
#                ['височенний', 1],
#                ['непрохідний', 1],
#                ['межа', 1],
#                ['неприступний', 1],
#                ['чорний', 1],
#                ['синій', 1]]),
#              ('горал', [['сніжний', 1], ['дикий', 1]]),
#              ('горбик', [['зарослий', 1]]),
#              ('гордощі', [['всеросійський', 1]]),
#              ('гордість', [['матерній', 1], ['національний', 1]]),
#              ('горло', [['вузький', 1]]),
#              ('горлянка', [['самісінький', 1]]),
#              ('горнятко', [['манюнький', 1], ['порцеляновий', 1]]),
#              ('горність', [['смішний', 1]]),
#              ('город',
#               [['славний', 2],
#                ['невеличкий', 1],
#                ['обгороджений', 1],
#                ['великий', 1]]),
#              ('городянин', [['смішні', 1], ['пришелепкуватий', 1]]),
#              ('горшка', [['святий', 1]]),
#              ('горілка', [['міцний', 1], ['медовуха', 1]]),
#              ('горіх', [['колючий', 1], ['кедровий', 1]]),
#              ('господа', [['справжній', 1]]),
#              ('господар', [['повний', 1]]),
#              ('господині', [['веселий', 1]]),
#              ('готування', [['незвичайний', 1]]),
#              ('градус', [['географічний', 1]]),
#              ('грамота', [['китайський', 1]]),
#              ('граний', [['звичайний', 1]]),
#              ('гребль', [['прорваний', 1]]),
#              ('гребінь', [['найближчий', 1], ['зелений', 1]]),
#              ('гриб', [['гадючий', 1]]),
#              ('грибок', [['торішній', 1], ['сухенький', 1], ['зморщений', 1]]),
#              ('гривка', [['тонюсінький', 1]]),
#              ('гриця', [['спантеличений', 1]]),
#              ('громадянин', [['с.', 1]]),
#              ('грона', [['набрякло', 1]]),
#              ('грошина', [['мідяний', 1]]),
#              ('груди',
#               [['повний', 1],
#                ['схудлий', 1],
#                ['волосатий', 1],
#                ['кремезний', 1],
#                ['розхристаний', 1],
#                ['григорій', 1],
#                ['дівочий', 1],
#                ['мужний', 1]]),
#              ('грунт', [['м’який', 1]]),
#              ('група',
#               [['сіркова', 1],
#                ['цілий', 1],
#                ['великий', 1],
#                ['диверсійний', 1]]),
#              ('грім', [['далекий', 1]]),
#              ('гріх', [['адамовий', 1]]),
#              ('губа',
#               [['дівочий', 2],
#                ['репнутий', 2],
#                ['порепаний', 1],
#                ['кривавий', 1],
#                ['спраглі', 1],
#                ['спідній', 1],
#                ['отакимити', 1],
#                ['шерхлі', 1],
#                ['попалений', 1],
#                ['набрякло', 1]]),
#              ('губіти', [['розмальований', 1], ['набілений', 1]]),
#              ('гукання', [['страхітний', 1]]),
#              ('гульвіс', [['бравий', 1]]),
#              ('гуляйпільц', [['засмалений', 1]]),
#              ('гулянка', [['святий', 1]]),
#              ('гумор',
#               [['добрий', 4],
#                ['всесвітній', 1],
#                ['колишній', 1],
#                ['прекрасний', 1],
#                ['давній', 1],
#                ['народний', 1],
#                ['безсмертний', 1],
#                ['український', 1]]),
#              ('гуморий', [['добрий', 3]]),
#              ('гутірка', [['веселий', 1]]),
#              ('гущавина',
#               [['найбільший', 1], ['проклятий', 1], ['великий', 1]]),
#              ('гігант', [['листатий', 1]]),
#              ('гідність',
#               [['розчавлений', 1], ['людський', 1], ['власний', 1]]),
#              ('гілка', [['другий', 1]]),
#              ('гілля', [['сплетений', 1], ['ялинковий', 1]]),
#              ('гілочка', [['мисливський', 1]]),
#              ('гільза', [['покладений', 1]]),
#              ('гін', [['шалений', 1], ['хворобливий', 1]]),
#              ('гість', [['несподіваний', 1], ['добрий', 1], ['бажаний', 1]]),
#              ('дальстрой', [['розстопроклятий', 1]]),
#              ('дама', [['катерининський', 1]]),
#              ('дах', [['густий', 1], ['обідраний', 1]]),
#              ('двері', [['розчинений', 1], ['гавкотнява', 1]]),
#              ('двк', [['цілий', 1], ['благословенний', 1]]),
#              ('двір', [['вибитий', 1]]),
#              ('двість', [['розкиданий', 1]]),
#              ('дебель', [['збитий', 1]]),
#              ('девіза', [['емалевий', 1]]),
#              ('делікатність', [['природний', 1]]),
#              ('демон', [['красений', 1], ['гордий', 1]]),
#              ('демона', [['невідомий', 1]]),
#              ('денце', [['бойовий', 1]]),
#              ('день',
#               [['перший', 6],
#                ['другий', 5],
#                ['цілий', 4],
#                ['третій', 3],
#                ["п'ятий", 2],
#                ['останній', 2],
#                ['вчорашній', 2],
#                ['пропущений', 1],
#                ['шостий', 1],
#                ['наступний', 1]]),
#              ('дерево',
#               [['рудолистий', 2],
#                ['корковий', 1],
#                ['велетенський', 1],
#                ['вивернутий', 1],
#                ['височезний', 1],
#                ['добрий', 1],
#                ['межа', 1],
#                ['освітлений', 1],
#                ['найвищий', 1],
#                ['сир', 1]]),
#              ('держава',
#               [['званий', 1],
#                ['селянський', 1],
#                ['екстериторіальний', 1],
#                ['пролетарський', 1],
#                ['сірковий', 1],
#                ['зелений', 1],
#                ['агресивний', 1]]),
#              ('дерсу', [['наївний', 1]]),
#              ('джерело', [['знайомий', 1], ['невеликий', 1]]),
#              ('дзбаний', [['великий', 1]]),
#              ('дзвін', [['малиновий', 2]]),
#              ('дзвіночка', [['рожевий', 1], ['срібний', 1]]),
#              ('дзижчання', [['тонесенький', 1]]),
#              ('дива', [['незнаний', 1], ['найчудесніший', 1]]),
#              ('диверсія', [['продуманий', 1], ['нарушитель', 1]]),
#              ('диво', [['величезний', 1], ['цей', 1]]),
#              ('дивування', [['втішний', 1]]),
#              ('диктатор', [['мускулястий', 1]]),
#              ('диктатура', [['перший', 1]]),
#              ('дикунка', [['зв’язаний', 1]]),
#              ('дикунок', [['туя', 1], ['пишний', 1]]),
#              ('дим', [['їдучий', 2], ['густий', 1]]),
#              ('дир', [['заґратований', 2]]),
#              ('дири', [['скрізний', 1]]),
#              ('диспетчер', [['станційний', 1]]),
#              ('дитина',
#               [['вражі', 1],
#                ['хороший', 1],
#                ['новий', 1],
#                ['сонний', 1],
#                ['маленький', 1],
#                ['малий', 1]]),
#              ('дитино', [['бідна', 1]]),
#              ('дитинство', [['одтятий', 1], ['золотий', 1]]),
#              ('дитися', [['білий', 1]]),
#              ('дитя', [['малий', 2]]),
#              ('диїя', [['малий', 1]]),
#              ('дно', [['камінний', 1]]),
#              ('доба', [['п’ятнадцятий', 1]]),
#              ('добрий', [['загальний', 1]]),
#              ('довідка', [['історичний', 2], ['географічний', 1]]),
#              ('додаток', [['пікантний', 1]]),
#              ('дозвіл', [['спеціальний', 1]]),
#              ('дозвілля', [['святковий', 1]]),
#              ('доказ', [['очевидний', 1]]),
#              ('долина',
#               [['блакитний', 2],
#                ['широкий', 1],
#                ['облямований', 1],
#                ['засніжений', 1]]),
#              ('доля',
#               [['ліпший', 1],
#                ['химерний', 1],
#                ['дурень', 1],
#                ['майбутнє', 1]]),
#              ('домовина', [['рудий', 1]]),
#              ('домівка', [['покинутий', 1]]),
#              ('доньки', [['сірковий', 1]]),
#              ('доправда', [['божественний', 1]]),
#              ('доп’яти', [['гарний', 1]]),
#              ('дорога',
#               [['далеку', 2],
#                ['щасливий', 1],
#                ['мокрий', 1],
#                ['їжджений', 1],
#                ['пашковий', 1]]),
#              ('доріжка', [['звіринний', 1], ['утоптаний', 1]]),
#              ('дослід', [['різний', 1]]),
#              ('дослідник', [['учений', 1]]),
#              ('дотеп', [['плаский', 1]]),
#              ('дотик', [['сторонній', 1]]),
#              ('доха', [['оленячий', 2], ['накинений', 1], ['пишний', 1]]),
#              ('дочка', [['гарний', 1], ['вража', 1], ['щасливий', 1]]),
#              ('дошка', [['зрушений', 1]]),
#              ('дощ', [['цілий', 1], ['зоряний', 1]]),
#              ('дракон',
#               [['легендарний', 1],
#                ['реальний', 1],
#                ['справжній', 1],
#                ['найбільший', 1]]),
#              ('дрантя', [['напівголий', 1]]),
#              ('дробовик', [['новенький', 1]]),
#              ('дрова', [['смоляний', 2], ['сухий', 1], ['которий', 1]]),
#              ('друг',
#               [['вірний', 3],
#                ['старий', 2],
#                ['єдиний', 1],
#                ['добрий', 1],
#                ['милий', 1]]),
#              ('дружба', [['арештантський', 1], ['коротка', 1]]),
#              ('дрібничка', [['вибагливий', 1], ['дерев’яний', 1]]),
#              ('дріт', [['товстий', 1]]),
#              ('дубельтівка',
#               [['прекрасний', 1], ['ноиенький', 1], ['набійницький', 1]]),
#              ('дубий', [['рясний', 2], ['столітній', 1]]),
#              ('дуга', [['величезний', 1], ['велетенський', 1]]),
#              ('дукач', [['стародавний', 1]]),
#              ('дум', [['понура', 1], ['бурлацький', 1]]),
#              ('думка',
#               [['химерний', 2],
#                ['млява', 1],
#                ['подібний', 1],
#                ['порван', 1],
#                ['звільнений', 1],
#                ['збаламучений', 1],
#                ['занепокоєний', 1],
#                ['химерня', 1],
#                ['старий', 1],
#                ['парубоцький', 1]]),
#              ('дуплянка', [['накритий', 1]]),
#              ('дусий', [['той', 1]]),
#              ('дух',
#               [['гірський', 2],
#                ['тигрячий', 2],
#                ['великий', 1],
#                ['звіриний', 1],
#                ['місцевий', 1],
#                ['людський', 1],
#                ['злий', 1],
#                ['кінський', 1]]),
#              ('душа',
#               [['християнський', 1],
#                ['ідолова', 1],
#                ['мисливський', 1],
#                ['ідолові', 1]]),
#              ('дядько', [['рудий', 1], ['вусатий', 1]]),
#              ('дівотий', [['нормальний', 1], ['строге', 1], ['ніжний', 1]]),
#              ('дівчина',
#               [['химерний', 3],
#                ['вража', 2],
#                ['розмальований', 2],
#                ['чужий', 1],
#                ['-о', 1],
#                ['ставний', 1],
#                ['гостроязикий', 1],
#                ['спритний', 1],
#                ['замріяний', 1],
#                ['дивовижний', 1]]),
#              ('дід', [['дебелий', 1], ['бородатий', 1], ['старий', 1]]),
#              ('дідуган', [['вусатий', 1], ['старий', 1]]),
#              ('дідусик', [['старенький', 1]]),
#              ('дійсність', [['остогидлий', 1]]),
#              ('діло',
#               [['надзвичайний', 1],
#                ['кепський', 1],
#                ['геройський', 1],
#                ['поважний', 1],
#                ['чоловіцький', 1],
#                ['великий', 1],
#                ['пусте', 1],
#                ['перший', 1],
#                ['козацький', 1]]),
#              ('діль', [['стрілецький', 1]]),
#              ('дітки', [['манюнький', 1]]),
#              ('діялект', [['григорієвий', 1]]),
#              ('едем', [['зеленій', 1]]),
#              ('екзекуція', [['страшний', 1]]),
#              ('екземпляр', [['грізний', 1]]),
#              ('екзотика',
#               [['справжній', 1], ['потрясаючий', 1], ['хапне', 1]]),
#              ('екран', [['тьмяний', 1]]),
#              ('екскурсія', [['професоровий', 1], ['історичний', 1]]),
#              ('експансивність', [['хворобливий', 1]]),
#              ('експедиція', [['довготривалий', 1], ['цілий', 1]]),
#              ('експрес',
#               [['цілий', 5],
#                ['званий', 1],
#                ['тихоокеанський', 1],
#                ['найліпший', 1],
#                ['найкомфортабельніший', 1],
#                ['першокласний', 1],
#                ['люксусовий', 1],
#                ['поштовий', 1],
#                ['напівреальний', 1]]),
#              ('екстаз', [['молитовний', 1]]),
#              ('ельдорадо',
#               [['золотий', 6],
#                ['дивний', 2],
#                ['справжній', 1],
#                ['інтернаціональний', 1],
#                ['уссурійський', 1],
#                ['химерний', 1]]),
#              ('емоція', [['сильний', 2]]),
#              ('енергія', [['невичерпаний', 1]]),
#              ('енкаведпст', [['грізний', 1]]),
#              ('ентузіазм', [['шалений', 1]]),
#              ('ентузіаст', [['примусовий', 1]]),
#              ('епопія',
#               [['винятковий', 1],
#                ['жаский', 1],
#                ['цілий', 1],
#                ['пекельний', 1],
#                ['мисливський', 1]]),
#              ('етап',
#               [['другий', 2], ['неетапний', 1], ['найдемократичніший', 1]]),
#              ('етика', [['старосвітський', 1]]),
#              ('ешелон',
#               [['товаровий', 2],
#                ['етапний', 1],
#                ['дивовижний', 1],
#                ['порожній', 1],
#                ['безконечний', 1],
#                ['набитий', 1]]),
#              ('жаг', [['нестримний', 1]]),
#              ('жага', [['п’яна', 1]]),
#              ('жаль', [['філософський', 1], ['таємний', 1]]),
#              ('жар', [['пригаслий', 1]]),
#              ('жарт',
#               [['космічний', 1],
#                ['доччиний', 1],
#                ['злий', 1],
#                ['студентський', 1]]),
#              ('жах', [['незбагненний', 1]]),
#              ('женьшений', [['магічний', 1]]),
#              ('женьшення', [['оточений', 1], ['чародійний', 1]]),
#              ('жертва',
#               [['проглинений', 1], ['замордований', 1], ['нерухомий', 1]]),
#              ('жилка', [['кривавий', 1]]),
#              ('житти', [['живий', 1]]),
#              ('життя',
#               [['межа', 1],
#                ['вовча', 1],
#                ['зламаний', 1],
#                ['сумлінний', 1],
#                ['цілий', 1]]),
#              ('жовтяк', [['добрий', 1]]),
#              ('жінка',
#               [['середній', 1],
#                ['полтавський', 1],
#                ['літень', 1],
#                ['привітний', 1]]),
#              ('забавка', [['новий', 1]]),
#              ('забаганка', [['екзотичний', 1]]),
#              ('завдання', [['головний', 1]]),
#              ('завод', [['грохітнявий', 1]]),
#              ('завойовник', [['гордий', 1]]),
#              ('заграва', [['мовчазний', 1]]),
#              ('загривка', [['чорний', 1], ['рудий', 1]]),
#              ('загін',
#               [['цілий', 1],
#                ['оточений', 1],
#                ['козацький', 1],
#                ['кінний', 1]]),
#              ('задерихвість', [['смугастий', 1]]),
#              ('зайчик',
#               [['сонячний', 4],
#                ['сміхотливий', 1],
#                ['віддзеркалений', 1],
#                ['надзвичайний', 1]]),
#              ('закапелок', [['півтемний', 1]]),
#              ('закон', [['неписаний', 1], ['тутешній', 1]]),
#              ('законність', [['революційний', 2]]),
#              ('закуток', [['найсуворіший', 1], ['непевний', 1]]),
#              ('зал', [['велелюдний', 1]]),
#              ('залицяльник', [['всесвітній', 1]]),
#              ('замовлення', [['чаклунський', 1]]),
#              ('замок', [['великий', 1]]),
#              ('запас', [['випробуваний', 1]]),
#              ('запах', [['непевний', 1]]),
#              ('записка', [['маленький', 1], ['приготовлений', 1]]),
#              ('заполоччий', [['жовтий', 1]]),
#              ('запорожка', [['давний', 1]]),
#              ('запін', [['водяний', 1]]),
#              ('заробітка', [['великий', 1]]),
#              ('заростя', [['густий', 1]]),
#              ('заряд', [['цілий', 1]]),
#              ('засланець',
#               [['перший', 1], ['найперший', 1], ['політичний', 1]]),
#              ('заслон', [['чорний', 1]]),
#              ('застава',
#               [['н-ський', 4], ['прикордонний', 1], ['поранений', 1]]),
#              ('засіб', [['чуть', 1], ['відомий', 1]]),
#              ('затвір', [['тюремний', 1]]),
#              ('затіск', [['добрий', 1]]),
#              ('захват', [['невимовний', 1]]),
#              ('зачудування', [['неабиякий', 1]]),
#              ('заїмка', [['давень', 1], ['сіркова', 1], ['сірковий', 1]]),
#              ('зборище', [['претензійний', 1]]),
#              ('зброя',
#               [['пі', 1],
#                ['неабияка', 1],
#                ['геройський', 1],
#                ['мисливський', 1],
#                ['розвішаний', 1],
#                ['путній', 1],
#                ['нарізний', 1],
#                ['різний', 1]]),
#              ('збігець', [['невідомий', 1], ['запопадливий', 1]]),
#              ('збір', [['безконечний', 1], ['черговий', 1]]),
#              ('збіс', [['чуйний', 1], ['обережний', 1]]),
#              ('звезда', [['тихоокеанская', 1]]),
#              ('звичай', [['оригінальний', 1], ['дивень', 1]]),
#              ('звичати',
#               [['козацький', 2],
#                ['старий', 1],
#                ['стрілецький', 1],
#                ['стародавний', 1]]),
#              ('звичка', [['старий', 1], ['в’язничний', 1]]),
#              ('звук', [['зрадливий', 1], ['притаєний', 1]]),
#              ('звір',
#               [['хутряний', 2],
#                ['морський', 1],
#                ['цькований', 1],
#                ['страхітний', 1],
#                ['схожий', 1],
#                ['хитрий', 1],
#                ['дрібний', 1],
#                ['цінний', 1],
#                ['хижий', 1]]),
#              ('звіринка', [['веселий', 1]]),
#              ('звірка', [['хижий', 1]]),
#              ('звірок',
#               [['смугастий', 3], ['маленький', 1], ['хвостатий', 1]]),
#              ('звіролова', [['веселя', 1]]),
#              ('звірюка', [['здоровенний', 1]]),
#              ('звіря', [['різний', 1]]),
#              ('згадки', [['рідний', 1]]),
#              ('зграя', [['цілий', 1]]),
#              ('здивування', [['неймовірний', 1]]),
#              ('здогад', [['страшний', 1]]),
#              ('здібність', [['мисливський', 1]]),
#              ('зелення', [['чиста', 1], ['ясний', 1]]),
#              ('зелень', [['буйний', 1], ['яскравий', 1]]),
#              ('земля',
#               [['рідний', 3],
#                ['солона', 3],
#                ['природний', 2],
#                ['далекий', 2],
#                ['сонячний', 1],
#                ['сирий', 1],
#                ['невідомий', 1],
#                ['фантастичний', 1],
#                ['благословенний', 1],
#                ['туя', 1]]),
#              ('земляки', [['знайомий', 1]]),
#              ('зима', [['минулий', 1]]),
#              ('злам', [['стихійний', 1]]),
#              ('зле', [['зодягнений', 1]]),
#              ('злива', [['африканський', 1]]),
#              ('злодюжка', [['плюгавий', 1]]),
#              ('злодій', [['потенціальний', 1], ['державний', 1]]),
#              ('злочин', [['сотворений', 1]]),
#              ('злочинець',
#               [['державний', 2], ['страшний', 1], ['крупний', 1]]),
#              ('змагання',
#               [['тяжкий', 1],
#                ['стрілецький', 1],
#                ['виїмковий', 1],
#                ['безперервній', 1],
#                ['лицарський', 1],
#                ['дурний', 1]]),
#              ('зморшки', [['глибокий', 1], ['прямовисний', 1]]),
#              ('зміна', [['редакційний', 1], ['великий', 1]]),
#              ('зміст', [['жаский', 1], ['незрозуміле', 1]]),
#              ('змія', [['окиата', 1], ['гримуча', 1]]),
#              ('знаменник', [['спільний', 1]]),
#              ('знання', [['професійний', 1]]),
#              ('знахідка', [['дивний', 1]]),
#              ('значення', [['таємничий', 1]]),
#              ('значок', [['ворошиловський', 1]]),
#              ('значіння', [['виїмковий', 1]]),
#              ('зненависті', [['невимовлений', 1]]),
#              ('зобов’язання', [['партійний', 1]]),
#              ('зокола', [['чорний', 1], ['невидний', 1]]),
#              ('зором', [['молодий', 1]]),
#              ('зріст', [['однаковий', 2], ['легша', 1], ['молодий', 1]]),
#              ('зсередини', [['темний', 1]]),
#              ('зуб', [['зціплений', 1], ['вовчий', 1]]),
#              ('зупинець', [['черговий', 1]]),
#              ('зупинка', [['новий', 2]]),
#              ('зустріч', [['несподіваний', 1]]),
#              ('зять', [['цибатий', 5], ['мовчазний', 1]]),
#              ('зірка', [['ясненький', 1]]),
#              ('з’їзд', [['черговий', 1]]),
#              ('йолоп', [['менший', 1]]),
#              ('кабінет', [['науковий', 1]]),
#              ('кава', [['чорний', 1], ['вбога', 1]]),
#              ('кавалер', [['старий', 1], ['сухозадий', 1]]),
#              ('кадовба', [['великий', 1]]),
#              ('казан', [['височенний', 1], ['великий', 1], ['вмазаний', 1]]),
#              ('казанок', [['похідний', 1]]),
#              ('казка',
#               [['китайський', 2],
#                ['наївний', 1],
#                ['дивний', 1],
#                ['зимовий', 1],
#                ['переповідаючія', 1],
#                ['вічний', 1]]),
#              ('кайдан', [['ті-бо', 1]]),
#              ('калоші', [['мужеський', 1]]),
#              ('кампанія', [['осінній', 1]]),
#              ('каміння',
#               [['розпечений', 2],
#                ['високий', 1],
#                ['дрібний', 1],
#                ['межа', 1]]),
#              ('камінь', [['дикий', 2]]),
#              ('капелюс', [['хутряний', 1], ['підперезаний', 1]]),
#              ('капелюю', [['шкіряний', 1]]),
#              ('капкан', [['залізній', 1]]),
#              ('карабін', [['другий', 1], ['японський', 1]]),
#              ('карбованець',
#               [['довгий', 1], ['мороз', 1], ['вбитий', 1], ['найбільший', 1]]),
#              ('карта', [['географічний', 1]]),
#              ('картина',
#               [['страхітливий', 1], ['яскравіший', 1], ['дзвінкі', 1]]),
#              ('кар’єра', [['карколомний', 1], ['перший', 1]]),
#              ('ката', [['колишній', 1]]),
#              ('катаклізм', [['космічний', 1]]),
#              ('каторжанина', [['перший', 1]]),
#              ('каторжник', [['перший', 1], ['найперший', 1], ['відомий', 1]]),
#              ('катування', [['лютий', 1]]),
#              ('качка', [['японський', 1], ['дивний', 1]]),
#              ('каша', [['березовий', 1]]),
#              ('кашкет',
#               [['синій', 1],
#                ['пропотілий', 1],
#                ['старомодний', 1],
#                ['синьоверхий', 1],
#                ['єжовський', 1]]),
#              ('кашкетик', [['парадний', 1]]),
#              ('квартал', [['1-й', 1]]),
#              ('квартира', [['окремий', 1]]),
#              ('квіта', [['останній', 1]]),
#              ('квіти', [['дивний', 1], ['межа', 1], ['подібний', 1]]),
#              ('квітка', [['паперовий', 1]]),
#              ('кедр',
#               [['височенний', 5],
#                ['високий', 2],
#                ['сорокаметровий', 1],
#                ['старий', 1],
#                ['товстий', 1]]),
#              ('кедрина', [['повалений', 3]]),
#              ('кельнер',
#               [['запопадливий', 1], ['розгублений', 1], ['перелякан', 1]]),
#              ('кладка', [['сонячний', 1]]),
#              ('клекот', [['пекельний', 1]]),
#              ('клин', [['величезний', 1], ['цілий', 1], ['зелений', 1]]),
#              ('клич', [['шалений', 1], ['жирний', 1]]),
#              ('клоктуша', [['званий', 1]]),
#              ('клопіт', [['загальний', 1], ['єдиний', 1]]),
#              ('клубок', [['страшний', 1], ['галасливий', 1]]),
#              ('клітка',
#               [['дерев’яний', 1],
#                ['зв’язуючія', 1],
#                ['невеликий', 1],
#                ['загальний', 1]]),
#              ('клієнт', [['спантеличений', 1]]),
#              ('книга', [['цілий', 1], ['надзвичайний', 1]]),
#              ('книжка', [['страшний', 1]]),
#              ('ковбанька', [['надибавшія', 1], ['тиху', 1]]),
#              ('ковдрий', [['вовняний', 1]]),
#              ('ковнір', [['величезний', 1], ['одкладний', 1]]),
#              ('кодекс', [['карний', 1]]),
#              ('кожух', [['добрий', 1]]),
#              ('коза', [['дикий', 4]]),
#              ('козак', [['уссурійський', 2], ['різний', 1]]),
#              ('козач', [['колишній', 1]]),
#              ('козеняток', [['малий', 1]]),
#              ('козуль', [['дикий', 1]]),
#              ('козуля', [['сарний', 1]]),
#              ('колгосп',
#               [['гольдяцький', 1], ['мисливський', 1], ['прикордонний', 1]]),
#              ('колективізатор', [['колгоспний', 1]]),
#              ('колесо', [['вищання', 1]]),
#              ('коло',
#               [['вогненний', 2],
#                ['барвистий', 1],
#                ['освітлений', 1],
#                ['осяяний', 1],
#                ['світляний', 1],
#                ['червоний', 1],
#                ['великий', 1]]),
#              ('колод', [['товстий', 1]]),
#              ('колода', [['велетенський', 1]]),
#              ('колоди', [['межа', 2], ['зв’язаний', 1]]),
#              ('колодка', [['метровий', 1], ['товстий', 1]]),
#              ('колон', [['арештантський', 1], ['могутній', 1]]),
#              ('колонізація', [['чужий', 1]]),
#              ('колонія', [['цілий', 1]]),
#              ('колючок', [['тонюсінький', 1]]),
#              ('коляк', [['просунений', 1]]),
#              ('коліно', [['худосочний', 1], ['жіночий', 1], ['круте', 1]]),
#              ('колір', [['пишний', 1], ['спектральний', 1]]),
#              ('командир', [['личкований', 1]]),
#              ('комаха', [['сонячний', 1], ['подібний', 1]]),
#              ('комашинка', [['манюнький', 1]]),
#              ('комбінезон', [['літунський', 1], ['зроблений', 1]]),
#              ('комет', [['диявольський', 1]]),
#              ('комета', [['гейб', 1]]),
#              ('комора', [['дебело', 1], ['обгороджений', 1]]),
#              ('компанія', [['веселий', 2], ['весело', 1], ['безжурний', 1]]),
#              ('комунхоза', [['небесний', 1]]),
#              ('комфорт',
#               [['благословенний', 1], ['мешканевий', 1], ['максимальний', 1]]),
#              ('комісія', [['військовий', 1], ['дослідний', 1]]),
#              ('конвульсія', [['страшний', 1]]),
#              ('коник', [['різний', 1], ['стрілецький', 1]]),
#              ('конкістадор', [['екзальтований', 1]]),
#              ('конституція', [['цілий', 1]]),
#              ('контингент', [['основний', 1], ['зірваний', 1]]),
#              ('контролер', [['суворий', 2]]),
#              ('контрреволюція', [['білий', 1]]),
#              ('контура', [['ламаний', 1]]),
#              ('конфлікт', [['черговий', 1]]),
#              ('коній', [['нав’ючений', 2], ['добрий', 1]]),
#              ('кооператор', [['старий', 1], ['гемороїдальний', 1]]),
#              ('копалення', [['золотий', 1]]),
#              ('копальня', [['золотий', 1]]),
#              ('копиця', [['великий', 1], ['старий', 1]]),
#              ('копія', [['причепурений', 1], ['точний', 1]]),
#              ('кора', [['березовий', 1]]),
#              ('корабель', [['потоплений', 1]]),
#              ('корал', [['блискучий', 1]]),
#              ('кордон', [['маньчжурський', 4], ['недоторканий', 1]]),
#              ('кори', [['березовий', 1], ['молодий', 1], ['ввинутий', 1]]),
#              ('коробка', [['понурий', 1], ['рудий', 1], ['брудний', 1]]),
#              ('королевич', [['пишний', 1], ['молодий', 1]]),
#              ('корінець', [['чудесний', 1]]),
#              ('коса', [['мокрий', 1], ['примкнутий', 1]]),
#              ('костяма', [['український', 1]]),
#              ('косіокий', [['отой', 1]]),
#              ('котик', [['закохані', 1]]),
#              ('коханець',
#               [['четвертий', 1], ['похідний', 1], ['вогненнозорий', 1]]),
#              ('край',
#               [['цілий', 5],
#                ['невідомий', 2],
#                ['химерний', 2],
#                ['новий', 2],
#                ['страшний', 2],
#                ['рідний', 2],
#                ['суворий', 2],
#                ['далекосхідний', 2],
#                ['омріяний', 1],
#                ['проклятий', 1]]),
#              ('краля', [['мальований', 1], ['писаний', 1]]),
#              ('крам', [['різний', 1]]),
#              ('крамниця', [['столичний', 1]]),
#              ('крамознавство', [['хутряний', 1]]),
#              ('крапка', [['мерехтливий', 1]]),
#              ('краплина', [['вогнистий', 1]]),
#              ('краплинка', [['рудий', 1]]),
#              ('краса',
#               [['дівочий', 2],
#                ['надзвичайний', 1],
#                ['цей', 1],
#                ['первісний', 1],
#                ['дикий', 1],
#                ['мужеський', 1],
#                ['жіночий', 1]]),
#              ('красень', [['високий', 1], ['дебелий', 1]]),
#              ('красуня',
#               [['тая', 1], ['найперший', 1], ['дивний', 1], ['чистий', 1]]),
#              ('краєвид', [['рожевий', 1], ['дивний', 1]]),
#              ('краєчка', [['далекі', 1]]),
#              ('країна',
#               [['дивний', 2],
#                ['вітчизний', 1],
#                ['загадковий', 1],
#                ['казковий', 1],
#                ['відкритий', 1],
#                ['найекзотичніший', 1],
#                ['дивогідний', 1],
#                ['химерн', 1],
#                ['далекий', 1],
#                ['заморський', 1]]),
#              ('крига', [['суцільний', 1]]),
#              ('крижа', [['межа', 1]]),
#              ('криза', [['житловий', 1]]),
#              ('крик',
#               [['жахливий', 2],
#                ['дитячий', 1],
# ...
#              ('майстр', [['вправний', 1], ['наснажений', 1]]),
#              ('макарон',
#               [['змотаний', 1],
#                ['тоненький', 1],
#                ['білий', 1],
#                ['залитий', 1]]),
#              ('малоросійський', [['химерний', 1]]),
#              ('маль', [['дурне', 1]]),
#              ('малюнок', [['безподібний', 1]]),
#              ('маляр', [['геніальний', 1]]),
#              ('мама', [['вража', 2], ['одеса-', 1], ['вражий', 1]]),
#              ('мандза', [['сірковий', 1], ['знайомий', 1]]),
#              ('мандри', [['довгий', 1]]),
#              ('мандрівка',
#               [['безперервний', 1], ['десятиденний', 1], ['дивний', 1]]),
#              ('мандрівник', [['змучений', 2]]),
#              ('манер', [['жидівський', 1]]),
#              ('манірка', [['салдатський', 1]]),
#              ('маніяк', [['божевільний', 1]]),
#              ('мап.', [['залізничний', 1]]),
#              ('мапа', [['величезний', 1], ['обтиканий', 1]]),
#              ('мар', [['синій', 1]]),
#              ('мар.', [['величезний', 1]]),
#              ('марево', [['викликаний', 1]]),
#              ('марка', [['золота', 1]]),
#              ('маршрутий', [['далекий', 1]]),
#              ('маса', [['отакий', 1], ['чорний', 1], ['великий', 1]]),
#              ('масив', [['великий', 1], ['суцільний', 1]]),
#              ('мастий', [['сірий', 1], ['руда', 1]]),
#              ('мась', [['цілий', 1]]),
#              ('матер', [['старенький', 1], ['божий', 1]]),
#              ('материна', [['слізний', 1]]),
#              ('мати',
#               [['дурний', 1],
#                ['невидний', 1],
#                ['старий', 1],
#                ['рідний', 1],
#                ['бідна', 1]]),
#              ('матінка', [['старий', 1]]),
#              ('машина', [['велетенський', 1]]),
#              ('маштаб', [['цілий', 1], ['колосальний', 1]]),
#              ('маячіння',
#               [['п’яний', 1], ['дивовижний', 1], ['нічний', 1], ['хворе', 1]]),
#              ('мед.', [['солодкий', 1], ['брусничний', 1]]),
#              ('межа', [['дійсний', 1], ['стиснутий', 1], ['крайній', 1]]),
#              ('мерзлот', [['вічний', 1]]),
#              ('мертвяк', [['живий', 1]]),
#              ('метал', [['тяжкий', 1], ['суворий', 1]]),
#              ('метати', [['дома', 1]]),
#              ('метр', [['дебелий', 1]]),
#              ('меч', [['уткнутий', 1]]),
#              ('мешканець',
#               [['експансивний', 1], ['основний', 1], ['давній', 1]]),
#              ('миска', [['добрий', 1], ['великий', 1], ['череп’яний', 1]]),
#              ('мисливаць',
#               [['справжній', 2],
#                ['старий', 1],
#                ['перший', 1],
#                ['знаменитий', 1],
#                ['нашорошений', 1]]),
#              ('мисливець',
#               [['знаменитий', 1], ['стихійний', 1], ['інстинктовий', 1]]),
#              ('мисливка', [['здобуваючія', 1]]),
#              ('мисник', [['різьблений', 1]]),
#              ('мистецтво', [['народний', 1]]),
#              ('мить',
#               [['короткий', 3], ['блискавичний', 1], ['безконечний', 1]]),
#              ('млявість', [['вайлуватий', 1], ['лінива', 1]]),
#              ('мова',
#               [['російський', 2],
#                ['лагідний', 1],
#                ['мисливський', 1],
#                ['грицева', 1],
#                ['власний', 1],
#                ['український', 1]]),
#              ('мовчанка', [['гнітючий', 2], ['красномовний', 1]]),
#              ('могила', [['козацький', 1]]),
#              ('моделля', [['ідеальний', 1]]),
#              ('можливість', [['невиключений', 1]]),
#              ('мозаїк', [['скелястія', 1]]),
#              ('молитво', [['енергійний', 1], ['моряцький', 1]]),
#              ('молодість',
#               [['непокірний', 1],
#                ['буйний', 1],
#                ['озвучений', 1],
#                ['скалічений', 1],
#                ['зіпсований', 1]]),
#              ('мораль', [['арештантський', 1]]),
#              ('морд', [['страхітний', 1], ['величезний', 1], ['новий', 1]]),
#              ('море',
#               [['зелений', 3],
#                ['японський', 2],
#                ['синій', 1],
#                ['сонячний', 1],
#                ['химерний', 1],
#                ['священний', 1],
#                ['дивний', 1],
#                ['найближчий', 1],
#                ['буйний', 1],
#                ['рослинний', 1]]),
#              ('морем', [['чорний', 1]]),
#              ('мороз',
#               [['старий', 6],
#                ['лютім', 3],
#                ['50-ступневий', 3],
#                ['лютий', 1],
#                ['ранішній', 1],
#                ['п’ятидесять', 1],
#                ['ступневий', 1],
#                ["п'ятдесятиступневий", 1],
#                ['менший', 1],
#                ['лють', 1]]),
#              ('морозих', [['старий', 1]]),
#              ('мотив', [['нескладний', 1]]),
#              ('моток', [['білий', 2]]),
#              ('мох', [['сухий', 1], ['густий', 1]]),
#              ('мохом', [['сивий', 1]]),
#              ('мошка', [['дрібнюсінький', 1]]),
#              ('мошкара', [['різний', 1]]),
#              ('мрія', [['нездійснений', 1], ['більший', 1]]),
#              ('мужність', [['загартований', 1], ['простий', 1]]),
#              ('музика', [['небесний', 1], ['чудернацький', 1]]),
#              ('мундир', [['генеральський', 1]]),
#              ('мура', [['химерний', 1], ['непрохідний', 1]]),
#              ('муравйов', [['новітній', 1], ['амурський', 1]]),
#              ('мілина', [['чистий', 1]]),
#              ('місто', [['розташований', 1], ['смішний', 1], ['цілий', 1]]),
#              ('місце',
#               [['другий', 2],
#                ['чистий', 2],
#                ['єдиний', 1],
#                ['різний', 1],
#                ['найуразливіший', 1],
#                ['зручний', 1],
#                ['закривавити', 1],
#                ['заякорений', 1],
#                ['відповідний', 1],
#                ['високий', 1]]),
#              ('місяць', [['останній', 1], ['пантовий', 1], ['довгий', 1]]),
#              ('місяцями', [['дядров', 1]]),
#              ('мішений', [['батьковий', 1], ['грицевій', 1]]),
#              ('мішечко', [['защічний', 1]]),
#              ('мішок', [['цілий', 1]]),
#              ('міщанство', [['всесоюзний', 1]]),
#              ('м’язкий', [['останній', 1]]),
#              ('м’яс', [['дикий', 1], ['фарбований', 1]]),
#              ('м’ясо', [['оленяче', 1]]),
#              ('наближення', [['поступовий', 1]]),
#              ('набій', [['погублений', 1]]),
#              ('набійниця', [['напханий', 1], ['повний', 1]]),
#              ('навскоси', [['почеплений', 1]]),
#              ('нагорода', [['найвищий', 1]]),
#              ('надвечірок', [['тьмяний', 1]]),
#              ('надуть', [['відповідальний', 1]]),
#              ('надія', [['щирий', 1]]),
#              ('назва',
#               [['найнеможливіший', 1], ['історичний', 1], ['відповідний', 1]]),
#              ('наказ', [['відповідний', 1]]),
#              ('накомарник', [['новісінький', 1]]),
#              ('наливка', [['медовий', 1]]),
#              ('намет',
#               [['військовий', 1],
#                ['величезний', 1],
#                ['брезент', 1],
#                ['цілий', 1]]),
#              ('наміток', [['велетенський', 1]]),
#              ('напис', [['спеціальний', 1]]),
#              ('напруга', [['надмірний', 1]]),
#              ('напруження',
#               [['найвищий', 1],
#                ['нелюдський', 1],
#                ['надзвичайний', 1],
#                ['постійний', 1]]),
#              ('напрямок', [['противний', 1], ['доказаний', 1]]),
#              ('наркомат', [['уповноважений', 1]]),
#              ('народ', [['щасливий', 1], ['смішний', 1]]),
#              ('нарти', [['запряжений', 1]]),
#              ('нархарчоприй', [['всесоюзний', 1]]),
#              ('населення',
#               [['тубільний', 1],
#                ['жіночий', 1],
#                ['рухливий', 1],
#                ['змінний', 1]]),
#              ('наснага', [['життєвий', 1]]),
#              ('наставка', [['шовковий', 1]]),
#              ('насторожку', [['зв.', 1], ['тунгузький', 1]]),
#              ('настрій',
#               [['добрий', 3],
#                ['недавний', 1],
#                ['безжурний', 1],
#                ['святкове', 1],
#                ['молодий', 1]]),
#              ('насіння', [['новий', 1]]),
#              ('наталчин', [['надітий', 1], ['дзвінкий', 1]]),
#              ('натовп', [['велетенський', 1], ['людський', 1]]),
#              ('нахила', [['вроджений', 1]]),
#              ('націоналіст', [['зоологічний', 1]]),
#              ('начальник',
#               [['великий', 5],
#                ['больший', 1],
#                ['сердитий', 1],
#                ['придуркуватий', 1],
#                ['розцяцькований', 1],
#                ['більший', 1],
#                ['уповноважений', 1],
#                ['героїчний', 1],
#                ['дурний', 1]]),
#              ('начиння', [['мисливський', 1]]),
#              ('нашийник', [['заливатий', 1]]),
#              ('нащадка', [['гордий', 1]]),
#              ('нащадок', [['закинений', 1]]),
#              ('небезпека', [['величезний', 1]]),
#              ('небо',
#               [['синій', 4],
#                ['прозорий', 2],
#                ['ясний', 2],
#                ['самісінький', 1],
#                ['нічний', 1],
#                ['заставлений', 1],
#                ['опаловий', 1]]),
#              ('невблаганність', [['караючий', 1]]),
#              ('невідомий', [['темний', 1]]),
#              ('невідповідність', [['явний', 1]]),
#              ('недовіра', [['прихований', 1]]),
#              ('незалежності', [['блаженний', 1]]),
#              ('ненависть', [['пекельний', 2]]),
#              ('ненавистю', [['нелюдський', 1]]),
#              ('неприємність', [['смішній', 1]]),
#              ('нерв', [['напнутий', 1]]),
#              ('нерпа', [['рудий', 1]]),
#              ('несподіванка',
#               [['великий', 1], ['новий', 1], ['незрозуміти', 1]]),
#              ('неспокій', [['тривожний', 1]]),
#              ('нетр', [['уссурійський', 1]]),
#              ('нетрище', [['безмежний', 1], ['загадковий', 1], ['дикий', 1]]),
#              ('нетря', [['буйний', 1], ['непрохідний', 1], ['засніжений', 1]]),
#              ('нетрі',
#               [['приамурський', 1],
#                ['бачений', 1],
#                ['вигоріль', 1],
#                ['гірський', 1],
#                ['непрохідний', 1],
#                ['найбільший', 1]]),
#              ('нещастя', [['великий', 1]]),
#              ('низина', [['болотяний', 1]]),
#              ('низка', [['цілий', 1]]),
#              ('ниток', [['білий', 1]]),
#              ('новина', [['надзвичайний', 1]]),
#              ('нога',
#               [['людський', 2],
#                ['задні', 1],
#                ['босий', 1],
#                ['правий', 1],
#                ['власний', 1],
#                ['жіночий', 1],
#                ['затискаючія', 1],
#                ['зв’язаний', 1],
#                ['передній', 1]]),
#              ('ноже', [['сперш', 1]]),
#              ('нора', [['темний', 1]]),
#              ('нота', [['перший', 1], ['низький', 1]]),
#              ('ноти', [['низький', 1]]),
#              ('нотка', [['найменший', 1]]),
#              ('ноткий', [['прихований', 1]]),
#              ('нудьгий', [['смертельний', 1]]),
#              ('нумер', [['найцікавіший', 1]]),
#              ('нів.', [['освітлений', 1]]),
#              ('ніг', [['кінський', 1]]),
#              ('ніж', [['мисливський', 1]]),
#              ('німба', [['морозяний', 1], ['веселковий', 1]]),
#              ('ніс', [['м’ясистий', 1], ['гарний', 1]]),
#              ('ніч',
#               [['чорний', 4],
#                ['цілий', 2],
#                ['безмежний', 1],
#                ['зрадливий', 1],
#                ['сибірський', 1],
#                ['сибірськая', 1],
#                ['задушливий', 1],
#                ['безсонний', 1],
#                ['відомий', 1],
#                ['перший', 1]]),
#              ('обгрунтування', [['законний', 1]]),
#              ('оберемка', [['цілий', 2]]),
#              ('обличчя',
#               [['блідий', 3],
#                ['блід', 3],
#                ['почорніти', 2],
#                ['дитячий', 2],
#                ['безжурний', 1],
#                ['металевий', 1],
#                ['расовий', 1],
#                ['милий', 1],
#                ['розчервонілий', 1],
#                ['повний', 1]]),
#              ('обов’язок', [['звичайний', 1], ['гражданський', 1]]),
#              ('оборона', [['протиповітряний', 1]]),
#              ('образ',
#               [['відтворений', 1], ['привабливий', 1], ['прибраний', 1]]),
#              ('образка', [['підглядений', 1]]),
#              ('обрий', [['блакитний', 1]]),
#              ('обрус', [['білий', 1]]),
#              ('обід', [['добрий', 1], ['к', 1]]),
#              ('обізнаність', [['величезний', 1], ['своєрідний', 1]]),
#              ('об’єкт', [['військовий', 1]]),
#              ('огпу', [['київський', 1]]),
#              ('одежа', [['важкий', 1], ['святковий', 1], ['парубоцький', 1]]),
#              ('однострій', [['бамлагівський', 2], ['химерний', 1]]),
#              ('одяг',
#               [['чудній', 2],
#                ['шкіряній', 1],
#                ['промисловий', 1],
#                ['легкий', 1],
#                ['мисливський', 1]]),
#              ('ожуга', [['чорний', 2]]),
#              ('озер', [['тьмяний', 1]]),
#              ('озеро',
#               [['велетенський', 1], ['обставлений', 1], ['бакирівський', 1]]),
#              ('окдва', [['відряджений', 1], ['контрактований', 1]]),
#              ('океан',
#               [['зелений', 2],
#                ['тихий', 1],
#                ['льодовий', 1],
#                ['хвилястий', 1],
#                ['збрижений', 1],
#                ['жахливий', 1],
#                ['безбережний', 1]]),
#              ('океань', [['безмежний', 1], ['зеленій', 1]]),
#              ('око',
#               [['мерехтливий', 5],
#                ['великий', 4],
#                ['вогкий', 4],
#                ['блискучий', 3],
#                ['здивований', 2],
#                ['гарячковий', 2],
#                ['примружений', 2],
#                ['вогнення', 1],
#                ['вогненний', 1],
#                ['змінений', 1]]),
#              ('околиць', [['подібний', 1]]),
#              ('округ', [['цілий', 2]]),
#              ('округий', [['цілий', 1]]),
#              ('олень',
#               [['молодий', 2],
#                ['шляхетний', 1],
#                ['гордий', 1],
#                ['плямистий', 1],
#                ['сірий', 1],
#                ['північний', 1],
#                ['рогатий', 1],
#                ['миршавий', 1],
#                ['екзотичний', 1]]),
#              ('оленя', [['плямистий', 2]]),
#              ('оленіти', [['намальований', 1]]),
#              ('олив', [['гарячий', 1]]),
#              ('олімпіяд', [['своєрідний', 1], ['сіркова', 1]]),
#              ('омуля', [['давний', 1], ['легендарня', 1], ['екзотичний', 1]]),
#              ('оповідання', [['грицьковий', 1]]),
#              ('оправа', [['блакитний', 1]]),
#              ('ордер', [['фальшивий', 1]]),
#              ('орнітофауна', [['субтропічний', 1]]),
#              ('осавути', [['козацький', 1]]),
#              ('осика', [['велетенський', 1], ['сухий', 1]]),
#              ('особа', [['великий', 1], ['відповідальний', 1]]),
#              ('особливість', [['зворушливий', 1]]),
#              ('осокий', [['попрорізуваний', 1]]),
#              ('остинка', [['рудий', 1]]),
#              ('ость', [['чорнуда', 1]]),
#              ('осіна', [['ранній', 1]]),
#              ('осінь', [['минулий', 1], ['золота', 1], ['справжній', 1]]),
#              ('отаман', [['страхітливий', 1]]),
#              ('охота', [['аніякісінький', 1]]),
#              ('охотник', [['знаменитий', 1]]),
#              ('охотінспектор', [['старший', 1], ['енергійний', 1]]),
#              ('очка', [['другий', 1]]),
#              ('павза', [['чорний', 1], ['довгий', 1]]),
#              ('павутиння', [['червоний', 1]]),
#              ('пада', [['загадковий', 1], ['голубий', 1], ['голий', 1]]),
#              ('падь', [['безмежний', 1], ['широкий', 1]]),
#              ('пазур', [['звірячий', 1]]),
#              ('пазух', [['білий', 1]]),
#              ...])
