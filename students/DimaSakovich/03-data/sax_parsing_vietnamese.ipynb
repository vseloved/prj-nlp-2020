# %%
import re
import json
import xml.sax

# %%
synonyms = {}

class VietnameseSynHandler(xml.sax.ContentHandler):
    def __init__(self):
        self.current_tag = ""
        
        self.parse_page = False
        self.parse_text = False
        self.parse_title = False
        
        self.syn_parse_start = False
        self.syn_parse_stop = False
        
        self.title = ""
        self.syns = []

    def startElement(self, tag, attributes):
        if tag == "page":
            self.parse_page = True
        elif tag == "text":
            self.parse_text = True
        elif tag == "title":
            self.parse_title = True
            
        self.current_tag = tag

    def endElement(self, tag):
        if tag == "page":
            self.parse_page = False
            if len(self.syns) > 0:
                synonyms[self.title] = self.syns
            self.title = ""
            self.syns = []
        elif tag == "text":
            self.parse_text = False
        elif tag == "title":
            self.parse_title = False
            
        self.current_tag = ""


    def characters(self, content):
        if self.parse_page:
            if self.parse_title:
                self.title = content
            elif self.parse_text:
                content = content.strip()
                if re.match(r"{{-syn-}}", content):
                    self.syn_parse_start = True
                    self.syn_parse_stop = False
                elif self.syn_parse_start:
                    l_content = len(content)
                    if l_content > 0:
                        self.syns.extend(re.findall(r"\[\[(.*?)\]\]", content))
                        self.syn_parse_stop = False
                    else:
                        if self.syn_parse_stop:
                            self.syn_parse_start = False
                        else:
                            self.syn_parse_stop = True

# %%
# %%time

# # create an XMLReader
parser = xml.sax.make_parser()
# parser.setFeature(xml.sax.handler.feature_namespaces, 0)

# override the default ContextHandler
Handler = VietnameseSynHandler()
parser.setContentHandler(Handler)

parser.parse("viwiktionary-20200301-pages-articles-multistream.xml")
# Out:
# CPU times: user 13.7 s, sys: 36.5 ms, total: 13.7 s
# Wall time: 13.7 s

# %%
with open('synonyms_vi.json', 'w') as file_:
    json.dump(synonyms, file_, sort_keys=True, indent=4, ensure_ascii=False)

# %%
print(json.dumps(synonyms, sort_keys=True, indent=4, ensure_ascii=False))
# Out:
# {
#     "\"": [
#         "nhà lao"
#     ],
#     "-ment": [
#         "-tion",
#         "-age",
#         "-tion"
#     ],
#     "-th": [
#         "-eth"
#     ],
#     "-trix": [
#         "-tress"
#     ],
#     "-way": [
#         "-wise"
#     ],
#     "1": [
#         "nhất"
#     ],
#     "4WD": [
#         "4x4",
#         "FWD",
#         "RWD",
#         "AWD"
#     ],
#     "4x4": [
#         "4WD"
#     ],
#     "666": [
#         "666kfds[p5w52ngs",
#         "65ew6se5666"
#     ],
#     "AKA": [
#         "a.k.a."
#     ],
#     "Abel": [
#         "Aabel",
#         "Aapel"
#     ],
#     "Alex.r": [
#         "Alex."
#     ],
#     "America": [
#         "United States of America",
#         "U.S.A.",
#         "U.S.",
#         "Columbia"
#     ],
#     "Amerika": [
#         "nieuwe wereld",
#         "Verenigde Staten van Amerika",
#         "Verenigde Staten",
#         "VS",
#         "VSA",
#         "Amerikaans",
#         "Amerikaan"
#     ],
#     "Anglo-Saxon": [
#         "Old English"
#     ],
#     "Arab": [
#         "Arabian"
#     ],
#     "August": [
#         "Aug",
#         "Aug.",
#         "Augost"
#     ],
#     "Australia": [
#         "Aussieland",
#         "land down under",
#         "New Holland",
#         "Oz",
#         "Terra Australis",
#         "Meganesia",
#         "Sahul",
#         "Aussit"
#     ],
#     "BCE": [
#         "BC"
#     ],
#     "Ba Mùn": [
#         "Đảo Khỉ"
#     ],
#     "Ba Vòng": [
#         "Bác Vọng"
#     ],
#     "Barack Obama": [
#         "Barack Hussein Obama"
#     ],
#     "Botany Bay dozen": [
#         "tester"
#     ],
#     "Britain": [
#         "Great Britain",
#         "United Kingdom",
#         "Briton"
#     ],
#     "Bru": [
#         "Bru-Vân Kiều",
#         "Bru - Vân Kiều",
#         "Bru–Vân Kiều",
#         "Vân Kiều",
#         "Mang Cong",
#         "Ma-coong",
#         "Ma Coong",
#         "Trì",
#         "Khùa"
#     ],
#     "Bushman": [
#         "San"
#     ],
#     "Buồng lái": [
#         "buồng lái"
#     ],
#     "Bài ca giữ nước": [
#         "vở|Vở",
#         "chèo",
#         "dã sử",
#         "ba",
#         "hồi",
#         "soạn giả",
#         "Tào Mạt",
#         "sáng tác",
#         "giai đoạn",
#         "Lý Thánh Tông tuyển hiền",
#         "Ỷ Lan nhiếp chính",
#         "Lý Nhân Tông học làm vua",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "Bá Đa Lộc": [
#         "Pierre Joseph Georges Pigneau de Béhaine"
#     ],
#     "Bân-lâm-gú": [
#         "Bân-lâm-gí"
#     ],
#     "Bò lếch": [
#         "Lê lếch"
#     ],
#     "Búa liềm": [
#         "Búa ",
#         "Liềm"
#     ],
#     "Bơ-mấm": [
#         "Ba Na"
#     ],
#     "Bạch Cung": [
#         "Nhà Trắng",
#         "Bạch Ốc",
#         "Tòa Bạch Ốc"
#     ],
#     "Bạch Thử": [
#         "biệt hiệu|Biệt hiệu",
#         "cảnh sát",
#         "Việt Nam Cộng hòa",
#         "White Mice",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "Bản mẫu:-deu-": [
#         "Thể loại:Mục từ tiếng Đức",
#         "Thể loại:Tiêu bản ngôn ngữ|*{{PAGENAME}}",
#         "Thể loại:Mục từ tiếng Đức|*"
#     ],
#     "Bản mẫu:-nb-": [
#         "Tiêu bản:-nob-"
#     ],
#     "Bản mẫu:-nn-": [
#         "Tiêu bản:-nno-"
#     ],
#     "Bản mẫu:-rus-": [
#         "Thể loại:Mục từ tiếng Nga",
#         "Thể loại:Tiêu bản ngôn ngữ|*{{PAGENAME}}",
#         "Thể loại:Mục từ tiếng Nga|*"
#     ],
#     "Bản mẫu:nb": [
#         "Tiêu bản:nob"
#     ],
#     "Bản mẫu:nld-biến danh cả": [
#         "Thể loại:Tiêu bản biến cách tiếng Hà Lan|{{PAGENAME}}",
#         "Thể loại:Danh từ tiếng Hà Lan"
#     ],
#     "Bản mẫu:nld-biến tính 0": [
#         "Thể loại:Tiêu bản biến cách tiếng Hà Lan|{{PAGENAME}}"
#     ],
#     "Bản mẫu:nn": [
#         "Tiêu bản:nno"
#     ],
#     "Bản mẫu:nno": [
#         "tiếng Na Uy|Tiếng Na Uy",
#         "Nynorsk",
#         "tiếng Na Uy",
#         "Nynorsk",
#         "Thể loại:Tiêu bản ngôn ngữ|{{PAGENAME}}"
#     ],
#     "Bản mẫu:nob": [
#         "tiếng Na Uy|Tiếng Na Uy",
#         "Bokmål",
#         "tiếng Na Uy",
#         "Bokmål",
#         "Thể loại:Tiêu bản ngôn ngữ|{{PAGENAME}}"
#     ],
#     "Bản mẫu:vie-n-so": [
#         "w:Thư pháp Á Đông|Thư pháp",
#         "Hình:{{TÊNTRANG}}-order.gif|60px|{{TÊNTRANG}}",
#         "Thể loại:Thư pháp chữ Nôm",
#         "Thể loại:Thư pháp chữ Nôm|*",
#         "Thể loại:Tiêu bản chữ Hán|{{PAGENAME}}"
#     ],
#     "Bắc Mỹ": [
#         "Mỹ Bắc",
#         "Mỹ Bắc"
#     ],
#     "Bệnh viện": [
#         "bệnh viện"
#     ],
#     "CHCC": [
#         "khu chung cư"
#     ],
#     "CHXHCNVN": [
#         "Việt Nam",
#         "Cộng hòa xã hội chủ nghĩa Việt Nam",
#         "CHXHCN Việt Nam"
#     ],
#     "Ca-tang": [
#         "Cơ-Tu"
#     ],
#     "Campanagara": [
#         "Campadegar",
#         "Campapura",
#         "占婆國",
#         "占波國"
#     ],
#     "Cang Mục": [
#         "Bản Thảo Cương Mục"
#     ],
#     "Cao Miên": [
#         "Căm Bốt"
#     ],
#     "Cha-cú": [
#         "Rục",
#         "Sách",
#         "A rem",
#         "A-rem",
#         "Mày",
#         "Mã liềng",
#         "Tu vang",
#         "Tu-vang",
#         "Pa leng",
#         "Pa-leng",
#         "Xe lang",
#         "Xe-lang",
#         "Tơ hung",
#         "Tơ-hung",
#         "Tắc cực",
#         "U mo",
#         "U-mo",
#         "Umo",
#         "Xá lá vàng"
#     ],
#     "Chang Tây": [
#         "Lo Chúc San"
#     ],
#     "Chile": [
#         "Chili",
#         "Chi Lê"
#     ],
#     "Chuột Trắng": [
#         "biệt hiệu|Biệt hiệu",
#         "cảnh sát",
#         "Việt Nam Cộng hòa",
#         "White Mice",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "Châu-ro": [
#         "Chơ Ro",
#         "Chơ-ro",
#         "Chơ ro",
#         "Chơro",
#         "Đơ Ro",
#         "Đơ-Ro",
#         "Đơ-ro",
#         "Đơ ro"
#     ],
#     "Chích Trợ": [
#         "Chiếc Đũa"
#     ],
#     "Chúa Trời": [
#         "Thiên Chúa"
#     ],
#     "Chúa nhật": [
#         "chủ nhật"
#     ],
#     "Chăm-rê": [
#         "Hrê",
#         "Chom Krẹ",
#         "Lùy",
#         "Luỳ"
#     ],
#     "Chơ-rai": [
#         "Gia Rai",
#         "Gia-rai",
#         "Gia rai",
#         "Giarai",
#         "Giơ Rai",
#         "Giơ-rai",
#         "Giơ rai",
#         "Tơ Buăn",
#         "Tơ-buăn",
#         "Hơbau",
#         "Hơ-bau",
#         "Hơ bau",
#         "Hơ Bau",
#         "Hdrung",
#         "Chor",
#         "Gia Lai",
#         "Gia-lai"
#     ],
#     "Chơ-ru": [
#         "Chu Ru",
#         "Chu-ru"
#     ],
#     "Chủ nhật": [
#         "Chủ Nhật",
#         "chủ nhật"
#     ],
#     "Citroën": [
#         "xe hơi",
#         "André Citroën",
#         "thành lập"
#     ],
#     "Con kde": [
#         "Ba Na",
#         "Tơ Lô",
#         "Tơ-lô",
#         "Giơ Lâng",
#         "Giơ-lâng",
#         "Rơ Ngao",
#         "Krem",
#         "Roh",
#         "A la công",
#         "Krăng",
#         "Bơ Môn",
#         "Kpăng Công",
#         "Y Lăng",
#         "Y lăng"
#     ],
#     "Cuba": [
#         "Cu-ba",
#         "Quy Ba"
#     ],
#     "Cơ Đốc giáo": [
#         "Kitô giáo",
#         "Ki-tô giáo",
#         "Thiên Chúa giáo",
#         "Chúa giáo"
#     ],
#     "Cơ-don": [
#         "Cờ Ho",
#         "Cờ ho",
#         "Cờ-ho",
#         "Cơ Ho",
#         "Cơ ho",
#         "Cơ-ho"
#     ],
#     "Cười Trình Giảo Kim": [
#         "cười|Cười",
#         "hào sảng",
#         "ngạo nghễ",
#         "điệu bộ",
#         "nhân vật",
#         "Trình Giảo Kim",
#         "Tùy Đường diễn nghĩa",
#         "Thể loại:Thành ngữ tiếng Việt"
#     ],
#     "DNA": [
#         "ADN"
#     ],
#     "DUI": [
#         "DWI"
#     ],
#     "Deutsch": [
#         "tiếng Đức|Tiếng Đức",
#         "ngôn ngữ"
#     ],
#     "Du": [
#         "Du Xuyên",
#         "quê hương"
#     ],
#     "Edrus": [
#         "Edw."
#     ],
#     "Edw.": [
#         "Edrus"
#     ],
#     "Europe": [
#         "Ancien Monde",
#         "européen",
#         "Category:Lục Địa"
#     ],
#     "Florida": [
#         "FL",
#         "Fla."
#     ],
#     "Fujiyama": [
#         "Fuji-san",
#         "富士山"
#     ],
#     "Geneva": [
#         "Genève",
#         "Giơ-ne-vơ",
#         "Nhật Nội Ngỏa"
#     ],
#     "Gesundheit": [
#         "zur Gesundheit"
#     ],
#     "Giê-su": [
#         "Giê-xu",
#         "Jesus",
#         "Gia tô",
#         "Da tô",
#         "Chúa Giê-su Ki-tô",
#         "Chúa Giê-xu Cơ Đốc",
#         "Gia tô Cơ đốc",
#         "Da tô Cơ đốc",
#         "Giê-su xứ Nazareth",
#         "Giê-su con ông Giu-se"
#     ],
#     "Giơ-lâng": [
#         "Ba Na",
#         "Tơ Lô",
#         "Tơ-lô",
#         "Rơ Ngao",
#         "Krem",
#         "Roh",
#         "Con-kde",
#         "Con Kde",
#         "A la công",
#         "Krăng",
#         "Bơ Môn",
#         "Kpăng Công",
#         "Y Lăng",
#         "Y lăng"
#     ],
#     "Giơ-lơng": [
#         "Y-lơng"
#     ],
#     "Giả Hạc": [
#         "Phi Điệp",
#         "Dã Hạc"
#     ],
#     "Giẻ Triêng": [
#         "Đgiéh",
#         "Ta Reh",
#         "Giảng Rây",
#         "Pin",
#         "Triêng",
#         "Tơ-riêng",
#         "Treng",
#         "Ta Liêng",
#         "Ve",
#         "La-Ve",
#         "Bnoong",
#         "Ca Tang"
#     ],
#     "Glatze": [
#         "Glatzkopf",
#         "Kahlkopf"
#     ],
#     "Goliath": [
#         "goliath crane"
#     ],
#     "Gul.": [
#         "Wm."
#     ],
#     "He": [
#         "Lord",
#         "Almighty",
#         "Savior",
#         "Saviour"
#     ],
#     "Hebrew": [
#         "Heberite",
#         "Eberite",
#         "Hebreian",
#         "Heberite",
#         "Eberite",
#         "Hebreian"
#     ],
#     "Hen.": [
#         "Hy"
#     ],
#     "Hoa Kỳ": [
#         "Mỹ",
#         "Mỹ quốc",
#         "Mỹ Lợi Kiên"
#     ],
#     "Hoa mào gà": [
#         "Hoa mào gà",
#         "Hoa mào gà",
#         "Hoa mào gà",
#         "Hòa mào gà",
#         "Hoa mào gà.",
#         "Hoa mào gà.",
#         "Hoa mào gà.",
#         "Hoa mào gà"
#     ],
#     "Huệ chất lan tâm": [
#         "蕙質蘭心 "
#     ],
#     "Hy": [
#         "Hen."
#     ],
#     "Hàn Quốc": [
#         "Nam Hàn",
#         "Nam Triều Tiên",
#         "Đại Hàn",
#         "Triều Tiên"
#     ],
#     "Hương Cảng": [
#         "香港"
#     ],
#     "Hệ Mặt Trời": [
#         "Thái Dương Hệ"
#     ],
#     "Hồ Chí Minh": [
#         "Nguyễn Tất Thành",
#         "Nguyễn Ái Quốc",
#         "Lý Thụy",
#         "Hồ Quang",
#         "Bác Hồ",
#         "Cụ Hồ",
#         "Ông Ké",
#         "Nguyễn Sinh Cung",
#         "Nguyễn Sinh Côông",
#         "Tất Thành",
#         "Văn Ba",
#         "Lý Thụy",
#         "Thầu Chín",
#         "Tống Văn Sơ",
#         "Lin",
#         "Già Thu",
#         "Sài Gòn"
#     ],
#     "Hồi Hồi": [
#         "回回"
#     ],
#     "I": [
#         "i"
#     ],
#     "I was about to ask why": [
#         "tôi|Tôi",
#         "sắp",
#         "hỏi",
#         "tại sao",
#         "Thể loại:Tiền tố tiếng Anh"
#     ],
#     "IBM": [
#         "ICBM",
#         "Goliath"
#     ],
#     "ICBM": [
#         "IBM"
#     ],
#     "IT": [
#         "Imformation Technology"
#     ],
#     "Ile": [
#         "I'll"
#     ],
#     "In panic": [
#         "Terror",
#         "Fear"
#     ],
#     "Industrie": [
#         "Unternehmerschaft",
#         "Volkswirtschaft",
#         "Wirtschaft"
#     ],
#     "Internet": [
#         "World Wide Web",
#         "WWW",
#         "Web",
#         "cyberspace",
#         "information superhighway",
#         "Net",
#         "net",
#         "World Wide Web",
#         "WWW",
#         "Web"
#     ],
#     "Ioh.": [
#         "Jno"
#     ],
#     "Israel": [
#         "Do Thái"
#     ],
#     "It's extremely unfortunate": [
#         "cám cảnh|Cám cảnh",
#         "thay",
#         "đáng|Đáng",
#         "tiếc",
#         "Thể loại:Tiền tố tiếng Anh"
#     ],
#     "Italia": [
#         "Italy"
#     ],
#     "Jabus": [
#         "Jac.",
#         "Jam.",
#         "Jas"
#     ],
#     "Jac.": [
#         "Jabus",
#         "Jam.",
#         "Jas"
#     ],
#     "Jam.": [
#         "Jac.",
#         "Jam.",
#         "Jas"
#     ],
#     "Jas": [
#         "Jaz",
#         "Jabus",
#         "Jac.",
#         "Jam."
#     ],
#     "Jno": [
#         "Ioh."
#     ],
#     "Jordan": [
#         "Joocđan",
#         "Joocđani",
#         "Giooc đa ni",
#         "Giooc-đa-ni",
#         "Gioocđani"
#     ],
#     "Kalman filtering": [
#         "Kalman filter"
#     ],
#     "Kartoffel": [
#         "Bramburi",
#         "Bulwe",
#         "Erdäppel",
#         "Erdapfel",
#         "Erdbirne",
#         "Grundbirn",
#         "Knolle",
#         "Krumbiir",
#         "Pudel"
#     ],
#     "Kennedy": [
#         "jk rolling"
#     ],
#     "Khmer Krôm": [
#         "Khơ-me Krôm"
#     ],
#     "Khùa": [
#         "Bru-Vân Kiều",
#         "Bru - Vân Kiều",
#         "Bru–Vân Kiều",
#         "Bru",
#         "Vân Kiều",
#         "Mang Cong",
#         "Ma-coong",
#         "Ma Coong",
#         "Trì"
#     ],
#     "Khơ-me": [
#         "Khờ-me"
#     ],
#     "Khơ-me Krôm": [
#         "Khmer Krôm"
#     ],
#     "Kinh Dương Vương": [
#         "An Dương Vương",
#         "Hùng Vương"
#     ],
#     "Kitô giáo": [
#         "đạo Kitô",
#         "Cơ Đốc giáo",
#         "đạo Cơ Đốc"
#     ],
#     "Kiều": [
#         "Không có"
#     ],
#     "Kpăng công": [
#         "Ba Na",
#         "Tơ Lô",
#         "Tơ-lô",
#         "Rơ Ngao",
#         "Giơ-lâng",
#         "Giơ Lâng",
#         "Krem",
#         "Roh",
#         "Con-kde",
#         "Con Kde",
#         "A la công",
#         "Krăng",
#         "Bơ Môn",
#         "Y Lăng",
#         "Y lăng"
#     ],
#     "Krem": [
#         "Ba Na",
#         "Tơ Lô",
#         "Tơ-lô",
#         "Giơ Lâng",
#         "Giơ-lâng",
#         "Rơ Ngao",
#         "Roh",
#         "Con-kde",
#         "Con Kde",
#         "A la công",
#         "Krăng",
#         "Bơ Môn",
#         "Kpăng Công",
#         "Y Lăng",
#         "Y lăng"
#     ],
#     "Kỳ La": [
#         "Cửa Nhượng"
#     ],
#     "La Hủ": [
#         "Xá Lá Vàng",
#         "Cò Xung",
#         "Khù Sung",
#         "Khả Quy"
#     ],
#     "Lai Châu": [
#         "Đến Châu"
#     ],
#     "Lao xá": [
#         "lao xá"
#     ],
#     "Lawr.": [
#         "Lau."
#     ],
#     "Lào": [
#         "Cộng hoà Dân chủ Nhân dân Lào"
#     ],
#     "Lâm Tâm Như": [
#         "林心如"
#     ],
#     "Lã Hậu": [
#         "Lữ Hậu"
#     ],
#     "Lão Nhai": [
#         "老街"
#     ],
#     "Lễ Hiện Xuống": [
#         "Lễ Hạ Trần",
#         "Lễ Hạ trần",
#         "Lễ Ngũ Tuần"
#     ],
#     "Lữ Hậu": [
#         "Lã Hậu"
#     ],
#     "MRI": [
#         "NMRI",
#         "MRT"
#     ],
#     "Ma-coong": [
#         "Bru-Vân Kiều",
#         "Bru - Vân Kiều",
#         "Bru–Vân Kiều",
#         "Bru",
#         "Vân Kiều",
#         "Mang Cong",
#         "Trì",
#         "Khùa"
#     ],
#     "Mai Thúc Loan": [
#         "Mai Hắc Đế",
#         "Mai Huyền Thành"
#     ],
#     "Mars": [
#         "Ares",
#         "♂"
#     ],
#     "Mich.": [
#         "Micls"
#     ],
#     "Micls": [
#         "Mich."
#     ],
#     "Microsoft Word": [
#         "Microsoft Office Word",
#         "Multi-Tool Word"
#     ],
#     "Middle East": [
#         "Mideast"
#     ],
#     "Mideast": [
#         "Middle East"
#     ],
#     "Mol": [
#         "Mon",
#         "Moan",
#         "Mual"
#     ],
#     "Moor": [
#         "Moroccan"
#     ],
#     "Moslem": [
#         "Muslim",
#         "Muslem",
#         "Muslim",
#         "Muslem",
#         "Muslim"
#     ],
#     "Mual": [
#         "Mol",
#         "Mon",
#         "Moan"
#     ],
#     "Muslem": [
#         "Muslim",
#         "Moslem",
#         "Muslim",
#         "Moslem"
#     ],
#     "Muslim": [
#         "Mussulman",
#         "Mohammedan",
#         "Mohammedist",
#         "Saracen",
#         "Muslimah",
#         "Muslimette",
#         "Muslimess",
#         "Moslem",
#         "Mohammedaner"
#     ],
#     "My": [
#         "Myr"
#     ],
#     "Mãn Châu": [
#         "滿洲"
#     ],
#     "Mông Cổ": [
#         "蒙古"
#     ],
#     "Mơ-nâm": [
#         "Xơ Đăng",
#         "Xơ-đăng",
#         "Xơ Đeng",
#         "Cà Dong",
#         "Tơ-dra",
#         "Hđang",
#         "Hà Lăng",
#         "Ka Râng",
#         "Bri La Teng",
#         "Con Lan"
#     ],
#     "Mật tông": [
#         "kim cương thừa",
#         "Mật giáo"
#     ],
#     "Mặt Trời": [
#         "Thái Dương"
#     ],
#     "Nam Mỹ": [
#         "Mỹ Nam",
#         "Mỹ Nam"
#     ],
#     "Neptune": [
#         "♆"
#     ],
#     "Netherlander": [
#         "Nederlander"
#     ],
#     "Netherlands": [
#         "Holland",
#         "Dutch"
#     ],
#     "Nga La Tư": [
#         "Nga"
#     ],
#     "Nghịch ngợm": [
#         "nghịch ngợm"
#     ],
#     "Nguyễn": [
#         "Ng̃"
#     ],
#     "Nho giáo": [
#         "Khổng giáo",
#         "Nho học"
#     ],
#     "Nhà": [
#         "nhà"
#     ],
#     "Nhà Nho": [
#         "nhà nho"
#     ],
#     "Nhà chung": [
#         "nhà chung"
#     ],
#     "Nhà chứa": [
#         "nhà chứa"
#     ],
#     "Nhà chức trách": [
#         "nhà chức trách"
#     ],
#     "Nhà cái": [
#         "nhà cái"
#     ],
#     "Nhà cầu": [
#         "nhà cầu"
#     ],
#     "Nhà dây thép": [
#         "nhà dây thép"
#     ],
#     "Nhà giáo": [
#         "nhà giáo"
#     ],
#     "Nhà gác": [
#         "nhà gác"
#     ],
#     "Nhà gái": [
#         "nhà gái"
#     ],
#     "Nhà hàng": [
#         "nhà hàng"
#     ],
#     "Nhà lao": [
#         "nhà lao"
#     ],
#     "Nhà lầu": [
#         "nhà lầu"
#     ],
#     "Nhà nghề": [
#         "nhà nghề"
#     ],
#     "Nhà ngươi": [
#         "nhà ngươi"
#     ],
#     "Nhà nho": [
#         "nhà nho"
#     ],
#     "Nhà nòi": [
#         "nhà nòi"
#     ],
#     "Nhà nước": [
#         "nhà nước"
#     ],
#     "Nhà rông": [
#         "nhà rông"
#     ],
#     "Nhà rường": [
#         "nhà rường"
#     ],
#     "Nhà sàn": [
#         "nhà sàn"
#     ],
#     "Nhà thơ": [
#         "nhà thơ"
#     ],
#     "Nhà thương": [
#         "nhà thương"
#     ],
#     "Nhà thổ": [
#         "nhà thổ"
#     ],
#     "Nhà trai": [
#         "nhà trai"
#     ],
#     "Nhà trò": [
#         "nhà trò"
#     ],
#     "Nhà trệt": [
#         "nhà trệt"
#     ],
#     "Nhà tư tưởng": [
#         "nhà tư tưởng"
#     ],
#     "Nhà văn": [
#         "nhà văn"
#     ],
#     "Nhà xí": [
#         "nhà xí"
#     ],
#     "Nhà ăn": [
#         "nhà ăn"
#     ],
#     "Nhà đoan": [
#         "nhà đoan"
#     ],
#     "Nhà đá": [
#         "nhà đá"
#     ],
#     "Nhà đèn": [
#         "nhà đèn"
#     ],
#     "Nics": [
#         "Nich."
#     ],
#     "Noong": [
#         "La-oang"
#     ],
#     "North American": [
#         "Mỹ Bắc"
#     ],
#     "Ohio": [
#         "Ô-hai-ô",
#         "Ôhaiô",
#         "OH",
#         "OH",
#         "O."
#     ],
#     "PC": [
#         "máy tính để bàn"
#     ],
#     "Pa-leng": [
#         "Rục",
#         "Sách",
#         "A rem",
#         "A-rem",
#         "Mày",
#         "Mã liềng",
#         "Tu vang",
#         "Tu-vang",
#         "Xe lang",
#         "Xe-lang",
#         "Tơ hung",
#         "Tơ-hung",
#         "Cha cú",
#         "Cha-cú",
#         "Tắc cực",
#         "U mo",
#         "U-mo",
#         "Umo",
#         "Xá lá vàng"
#     ],
#     "Pa-noong": [
#         "Bơ-noong"
#     ],
#     "Ph.D.": [
#         "PhD",
#         "doctor",
#         "philosophy",
#         "philosophy",
#         "doctor"
#     ],
#     "Phi": [
#         "Châu Phi",
#         "Phi Châu",
#         "Africa",
#         "Afrika",
#         "Африка",
#         "Afrique"
#     ],
#     "Phi Điệp": [
#         "Giả Hạc"
#     ],
#     "Pháp": [
#         "Cộng hòa Pháp",
#         "nước Pháp"
#     ],
#     "Phùng Xá": [
#         "Bùng"
#     ],
#     "Phần": [
#         "quê hương"
#     ],
#     "Phật giáo": [
#         "đạo Phật"
#     ],
#     "Phố Mới": [
#         "Tân Nhai"
#     ],
#     "Pleiku": [
#         "Plây Ku"
#     ],
#     "Quang Vũ Blog": [
#         "quangvublog"
#     ],
#     "Quả Đất": [
#         "Địa Cầu",
#         "Trái Đất"
#     ],
#     "Quảng Yên": [
#         "Khu Hồng Quảng"
#     ],
#     "Ra-clay": [
#         "Ra Glai",
#         "Ra-glai",
#         "Raglai",
#         "Ra Glây",
#         "Ra-glây",
#         "Rắc Lây",
#         "Rắc lây",
#         "Rắc-lây",
#         "Ra-rai",
#         "Hai",
#         "Noana",
#         "La Vang"
#     ],
#     "Ra-glây": [
#         "Ra Glai",
#         "Ra-glai",
#         "Raglai",
#         "Ra-clay",
#         "Ra Clay",
#         "Rắc Lây",
#         "Rắc lây",
#         "Rắc-lây",
#         "Ra-rai",
#         "Hai",
#         "Noana",
#         "La Vang"
#     ],
#     "Ra-đê": [
#         "Rha-đê"
#     ],
#     "Rha-đê": [
#         "Ra-đê"
#     ],
#     "Roh": [
#         "Ba Na",
#         "Tơ Lô",
#         "Tơ-lô",
#         "Giơ Lâng",
#         "Giơ-lâng",
#         "Rơ Ngao",
#         "Krem",
#         "Con-kde",
#         "Con Kde",
#         "A la công",
#         "Krăng",
#         "Bơ Môn",
#         "Kpăng Công",
#         "Y Lăng",
#         "Y lăng"
#     ],
#     "Romance": [
#         "Romanic"
#     ],
#     "Romanic": [
#         "Romance"
#     ],
#     "Rôma": [
#         "La Mã",
#         "Roma"
#     ],
#     "Rơ Ngao": [
#         "Ba Na",
#         "Tơ Lô",
#         "Tơ-lô",
#         "Giơ Lâng",
#         "Giơ-lâng",
#         "Krem",
#         "Roh",
#         "Con-kde",
#         "Con Kde",
#         "A la công",
#         "Krăng",
#         "Bơ Môn",
#         "Kpăng Công",
#         "Y Lăng",
#         "Y lăng"
#     ],
#     "Rắc lây": [
#         "Ra Glai",
#         "Ra-glai",
#         "Raglai",
#         "Ra Glây",
#         "Ra-glây",
#         "Ra-clay",
#         "Ra Clay",
#         "Ra-rai",
#         "Hai",
#         "Noana",
#         "La Vang"
#     ],
#     "SIDA": [
#         "SIĐA"
#     ],
#     "STFU": [
#         "shut up"
#     ],
#     "Saigon": [
#         "Sài Gòn",
#         "Sai Gon",
#         "Saigón",
#         "Saïgon"
#     ],
#     "Sao Hỏa": [
#         "Hình:Mars Valles Marineris.jpeg|nhỏ|phải|Sao Hỏa, ghép lại từ nhiều ảnh",
#         "hành tinh|Hành tinh",
#         "Thái Dương Hệ",
#         "Hỏa Tinh",
#         "Mars"
#     ],
#     "Sao Kim": [
#         "Sao Hôm",
#         "Sao Mai",
#         "Kim Tinh"
#     ],
#     "Sauk": [
#         "Sac"
#     ],
#     "Schultüte": [
#         "Zuckertüte"
#     ],
#     "Scottish": [
#         "Scotch",
#         "Scot",
#         "Lowland Scots"
#     ],
#     "Stampfer": [
#         "Küchenstampfer",
#         "Mörserkeule",
#         "Stößel"
#     ],
#     "Sự thử nghiệm": [
#         "cuộc thử nghiệm",
#         "cuộc thí nghiệm"
#     ],
#     "TV": [
#         "tivi"
#     ],
#     "Tam Điệp": [
#         "Trias"
#     ],
#     "Taser": [
#         "stun gun"
#     ],
#     "Thi Kinh": [
#         "詩經"
#     ],
#     "Thiên Chúa giáo": [
#         "Công giáo",
#         "Chúa giáo",
#         "đạo|Đạo",
#         "Thiên Chúa"
#     ],
#     "Thiên Vương Tinh": [
#         "Sao Thiên Vương"
#     ],
#     "Thánh": [
#         "thánh"
#     ],
#     "Thạch Thất": [
#         "Tứ Cửu"
#     ],
#     "Thể loại:Chữ Hán": [
#         "Thể loại:Thể loại đổi hướng"
#     ],
#     "Thể loại:Chữ Hán bộ 子 + 9 nét": [
#         "Thể loại:Chữ Hán bộ 子|09"
#     ],
#     "Thể loại:Chữ Hán bộ 龜": [
#         "Thể loại:Mục từ chữ Hán theo bộ|龜"
#     ],
#     "Thể loại:Chữ Hán bộ 龜 + 0 nét": [
#         "Thể loại:Chữ Hán bộ 龜|00"
#     ],
#     "Thể loại:Chữ thuần Nôm bộ 宀": [
#         "miên"
#     ],
#     "Thể loại:Danh từ tiếng Hán": [
#         "Thể loại:Mục từ chữ Hán"
#     ],
#     "Thể loại:Giải phẫu cơ thể người": [
#         "Thể loại:Giải phẫu học",
#         "Thể loại:Người"
#     ],
#     "Thể loại:Giải phẫu học": [
#         "Thể loại:Y học"
#     ],
#     "Thể loại:Người": [
#         "Thể loại:Lớp Thú"
#     ],
#     "Thể loại:Thành ngữ tiếng Pháp": [
#         "tiếng Pháp"
#     ],
#     "Thể loại:Thư pháp chữ Nôm": [
#         "Thể loại:Mục từ chữ Nôm",
#         "Thể loại:Mục từ có thư pháp"
#     ],
#     "Thể loại:Tính từ tiếng Hán": [
#         "Thể loại:Mục từ chữ Hán"
#     ],
#     "Thể loại:Địa danh tiếng Nga": [
#         "Thể loại:Địa danh|N",
#         "Thể loại:Mục từ tiếng Nga"
#     ],
#     "Thể loại:Động từ tiếng Hán": [
#         "Thể loại:Mục từ chữ Hán"
#     ],
#     "Tiếng Nga": [
#         "tiếng Nga"
#     ],
#     "Tiếng Đức": [
#         "tiếng Đức"
#     ],
#     "Tiều phu": [
#         "tiều phu"
#     ],
#     "Triều Tiên": [
#         "Hàn Quốc",
#         "Xứ Hàn",
#         "Cộng hòa Dân chủ Nhân dân Triều Tiên",
#         "CHDCND Triều Tiên",
#         "CHDCNDTT"
#     ],
#     "Trung Quốc": [
#         "Trung Hoa"
#     ],
#     "Trái Đất": [
#         "Địa Cầu",
#         "Quả Đất"
#     ],
#     "Trì": [
#         "Bru-Vân Kiều",
#         "Bru - Vân Kiều",
#         "Bru–Vân Kiều",
#         "Bru",
#         "Vân Kiều",
#         "Mang Cong",
#         "Ma-coong",
#         "Ma Coong",
#         "Khùa"
#     ],
#     "Trần": [
#         "Đông A"
#     ],
#     "Trần Thái Tông": [
#         "Trần Cảnh"
#     ],
#     "Tu-vang": [
#         "Rục",
#         "Sách",
#         "A rem",
#         "A-rem",
#         "Mày",
#         "Mã liềng",
#         "Pa leng",
#         "Pa-leng",
#         "Xe lang",
#         "Xe-lang",
#         "Tơ hung",
#         "Tơ-hung",
#         "Cha cú",
#         "Cha-cú",
#         "Tắc cực",
#         "U mo",
#         "U-mo",
#         "Umo",
#         "Xá lá vàng"
#     ],
#     "Tàu": [
#         "[[Trung Quốc"
#     ],
#     "Táy Mương": [
#         "Táy Chiềng"
#     ],
#     "Tân Nhai": [
#         "新街"
#     ],
#     "Tân Ước": [
#         "Tân Ước Hi văn",
#         "Kinh Thánh Hi văn"
#     ],
#     "Tây Ban Nha": [
#         "Y Pha Nho"
#     ],
#     "Tây Cống": [
#         "Sài Gòn",
#         "Thành phố Hồ Chí Minh"
#     ],
#     "Tây Vương Mẫu": [
#         "Vương Mẫu nương nương",
#         "Diêu Trì Kim Mẫu"
#     ],
#     "Tăng Sâm giết người": [
#         "Tam nhân thành hổ"
#     ],
#     "Tơ-hung": [
#         "Rục",
#         "Sách",
#         "A rem",
#         "A-rem",
#         "Mày",
#         "Mã liềng",
#         "Tu vang",
#         "Tu-vang",
#         "Pa leng",
#         "Pa-leng",
#         "Xe lang",
#         "Xe-lang",
#         "Cha cú",
#         "Cha-cú",
#         "Tắc cực",
#         "U mo",
#         "U-mo",
#         "Umo",
#         "Xá lá vàng"
#     ],
#     "Tết Nguyên Đán": [
#         "Tết",
#         "Tết ta",
#         "Tết âm lịch",
#         "Tết cổ truyền",
#         "Tết Cả"
#     ],
#     "UN": [
#         "United Nations",
#         "Liên Hiệp Quốc",
#         "LHQ"
#     ],
#     "UNO": [
#         "UN",
#         "United Nations"
#     ],
#     "USB stick": [
#         "thumb drive",
#         "USB drive",
#         "USB key"
#     ],
#     "Umo": [
#         "Rục",
#         "Sách",
#         "A rem",
#         "A-rem",
#         "Mày",
#         "Mã liềng",
#         "Tu vang",
#         "Tu-vang",
#         "Pa leng",
#         "Pa-leng",
#         "Xe lang",
#         "Xe-lang",
#         "Tơ hung",
#         "Tơ-hung",
#         "Cha cú",
#         "Cha-cú",
#         "Tắc cực",
#         "Xá lá vàng"
#     ],
#     "United Nations": [
#         "Liên Hợp Quốc",
#         "Liên Hiệp Quốc",
#         "UN"
#     ],
#     "United States": [
#         "United States of America",
#         "U.S.",
#         "U.S.A.",
#         "America",
#         "Columbia"
#     ],
#     "VNCH": [
#         "Việt Nam Cộng hòa"
#     ],
#     "Việt Nam": [
#         "Cộng hòa xã hội chủ nghĩa Việt Nam",
#         "CHXHCN Việt Nam",
#         "CHXHCNVN"
#     ],
#     "Việt Nam Cộng hòa": [
#         "chính thể|Chính thể",
#         "thành lập",
#         "ngày",
#         "tháng",
#         "năm",
#         "bán đảo",
#         "Đông Dương",
#         "Nam phần",
#         "vĩ tuyến",
#         "cáo chung",
#         "越南共和國",
#         "Việt Nam Cộng hòa quốc",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "Việt Nam Cộng hòa quốc": [
#         "Việt Nam Cộng hòa",
#         "越南共和國",
#         "Việt Nam Cộng hòa",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "Vân Kiều": [
#         "Bru-Vân Kiều",
#         "Bru - Vân Kiều",
#         "Bru–Vân Kiều",
#         "Bru",
#         "Mang Cong",
#         "Ma-coong",
#         "Ma Coong",
#         "Trì",
#         "Khùa"
#     ],
#     "Võ": [
#         "Vũ Môn"
#     ],
#     "Vũ Trinh": [
#         "Duy Chu",
#         "Lai Sơn",
#         "Nguyên Hanh",
#         "Lan Trì Ngư Giả"
#     ],
#     "Vương Trung Hiếu": [
#         "Uyên Uyên",
#         "Thoại Sơn"
#     ],
#     "Vớ bở": [
#         "vớ bẫm"
#     ],
#     "Wales": [
#         "Uy Nhĩ Sĩ"
#     ],
#     "White Mice": [
#         "biệt hiệu|Biệt hiệu",
#         "cảnh sát",
#         "Việt Nam",
#         "cộng hòa|Cộng hòa",
#         "Bạch Thử",
#         "Thể loại:Danh từ tiếng Anh"
#     ],
#     "Wikipedia": [
#         "wiki"
#     ],
#     "Wiktionary:Từ tái tạo": [
#         "Wiktionary:Từ nguyên|từ nguyên",
#         "dấu hoa thị"
#     ],
#     "Win": [
#         "Windows"
#     ],
#     "Wm.": [
#         "Gul."
#     ],
#     "Y Lăng": [
#         "Ba Na",
#         "Tơ Lô",
#         "Tơ-lô",
#         "Giơ Lâng",
#         "Giơ-lâng",
#         "Rơ Ngao",
#         "Krem",
#         "Roh",
#         "Con-kde",
#         "Con Kde",
#         "A la công",
#         "Krăng",
#         "Bơ Môn",
#         "Kpăng Công"
#     ],
#     "Yugoslav": [
#         "Jugoslavian",
#         "Yugoslavian",
#         "Jugoslavian",
#         "Yugoslavian"
#     ],
#     "Yugoslavia": [
#         "Jugoslavia"
#     ],
#     "Yugoslavian": [
#         "Jugoslavian",
#         "Yugoslav",
#         "Jugoslavian",
#         "Yugoslav"
#     ],
#     "Zuckertüte": [
#         "Schultüte"
#     ],
#     "a": [
#         "an",
#         "an",
#         "an",
#         "an",
#         "-a",
#         "para",
#         "para",
#         "para",
#         "i",
#         "také",
#         "plus",
#         "ale",
#         "však",
#         "tak",
#         "tedy",
#         "á",
#         "para",
#         "hacia",
#         "hasta",
#         "ante",
#         "junto a",
#         "si"
#     ],
#     "aankomen": [
#         "aanraken",
#         "verdikken",
#         "bijkomen"
#     ],
#     "aardbeving": [
#         "aardschok"
#     ],
#     "aardolie": [
#         "ruwe olie",
#         "minerale olie",
#         "petroleum"
#     ],
#     "abactio": [
#         "abortion"
#     ],
#     "absciss": [
#         "abscissa"
#     ],
#     "abscissa": [
#         "absciss"
#     ],
#     "absolutt": [
#         "hoàn toàn|Hoàn toàn",
#         "tuyệt đối",
#         "thuần túy",
#         "triệt"
#     ],
#     "account": [
#         "narrative",
#         "narration",
#         "relation",
#         "recital",
#         "description",
#         "explanation",
#         "rehearsal"
#     ],
#     "acquérir": [
#         "obtenir",
#         "gagner",
#         "céder|Céder",
#         "vendre",
#         "perdre|Perdre"
#     ],
#     "actualidad": [
#         "actualidades"
#     ],
#     "actualidades": [
#         "actualidad"
#     ],
#     "ad-hoc": [
#         "impromptu"
#     ],
#     "adenohypophysis": [
#         "anterior lobe",
#         "anterior pituitary"
#     ],
#     "adverbialize": [
#         "adverbialise"
#     ],
#     "adverbio": [
#         "adv."
#     ],
#     "agathodemon": [
#         "agathodaimon",
#         "agathodaemon"
#     ],
#     "agnostic": [
#         "modular",
#         "pluggable",
#         "polymorphic"
#     ],
#     "agua": [
#         "té",
#         "vertiente",
#         "marea",
#         "río"
#     ],
#     "ahora": [
#         "ahorita",
#         "ya"
#     ],
#     "ai bảo": [
#         "ai biểu"
#     ],
#     "airbag": [
#         "gossip"
#     ],
#     "airblade": [
#         "chém gió|Chém gió",
#         "xé",
#         "gió",
#         "trảm phong",
#         "大盜斩風",
#         "Thể loại:Động từ tiếng Anh"
#     ],
#     "aleatory": [
#         "stochastic",
#         "aleatoric music",
#         "chance music"
#     ],
#     "algebra": [
#         "stelkunde"
#     ],
#     "aliá": [
#         "elefanta",
#         "elefoa"
#     ],
#     "all-in": [
#         "all-inclusive"
#     ],
#     "all-inclusive": [
#         "all-in"
#     ],
#     "alphametics": [
#         "crypt-arithmetic",
#         "cryptarithmetic",
#         "cryptarithm",
#         "verbal arithmetic"
#     ],
#     "am pe": [
#         "am-pe"
#     ],
#     "amarillo": [
#         "ictérico",
#         "rompehuelgas",
#         "esquirol",
#         "crumiro"
#     ],
#     "ambo": [
#         "ambon",
#         "lectern",
#         "pulpit",
#         "ambulance driver",
#         "ambulance"
#     ],
#     "amigo": [
#         "compadre",
#         "hermano",
#         "maestro",
#         "señor",
#         "socio",
#         "tío",
#         "cuate",
#         "camarada",
#         "maese",
#         "colega",
#         "pana",
#         "amiguito",
#         "hijo"
#     ],
#     "an": [
#         "per"
#     ],
#     "and": [
#         "as well as",
#         "together with",
#         "in addition to",
#         "to#Tiếng Anh|to",
#         "so#Tiếng Anh|so",
#         "so what",
#         "ond"
#     ],
#     "and better safe than sorry": [
#         "cẩn tắc vô ưu|Cẩn tắc vô ưu"
#     ],
#     "annex": [
#         "annexe"
#     ],
#     "annexe": [
#         "annex"
#     ],
#     "anteayer": [
#         "antier",
#         "antes de ayer"
#     ],
#     "antenatal": [
#         "prenatal"
#     ],
#     "anti": [
#         "against",
#         "opposed to",
#         "contra"
#     ],
#     "anticlockwise": [
#         "ACW",
#         "counterclockwise",
#         "counter-clockwise",
#         "CCW",
#         "contraclockwise",
#         "withershins",
#         "widdershins"
#     ],
#     "antly": [
#         "chút|Chút",
#         "kiến",
#         "antlike",
#         "antish",
#         "Thể loại:Tính từ tiếng Anh"
#     ],
#     "any day": [
#         "bất cứ|Bất cứ",
#         "lúc",
#         "Thể loại:Hậu tố tiếng Anh"
#     ],
#     "aphtha": [
#         "mouth",
#         "sore",
#         "mouth",
#         "ulcer"
#     ],
#     "apropiado": [
#         "adecuado"
#     ],
#     "aqua fontis": [
#         "A.F."
#     ],
#     "aqua regia": [
#         "A.R.",
#         "aqua regis"
#     ],
#     "aquaculture": [
#         "aquiculture"
#     ],
#     "aquiculture": [
#         "aquaculture"
#     ],
#     "arcane": [
#         "esoteric"
#     ],
#     "array": [
#         "antenna array"
#     ],
#     "arsenic": [
#         "arsenical"
#     ],
#     "art": [
#         "creation",
#         "grandeur",
#         "wonder"
#     ],
#     "artic hare": [
#         "polar rabbit"
#     ],
#     "artificial intelligence": [
#         "AI"
#     ],
#     "as soon as possible": [
#         "ASAP"
#     ],
#     "asfalto": [
#         "bitumo"
#     ],
#     "asfixiar": [
#         "sufoko"
#     ],
#     "association": [
#         "association football"
#     ],
#     "astrobleme": [
#         "impact crater"
#     ],
#     "astrogliosis": [
#         "astrocytosis",
#         "Thể loại:Bệnh lý học",
#         "Thể loại:Danh từ tiếng Anh",
#         "Thể loại:Danh từ tiếng Anh đếm được"
#     ],
#     "astronomical": [
#         "astronomic"
#     ],
#     "astronomie": [
#         "sterrenkunde"
#     ],
#     "asylum": [
#         "lunatic asylum",
#         "mental asylum",
#         "mental hospital",
#         "psychiatric hospital"
#     ],
#     "atentado": [
#         "acometida",
#         "agresión",
#         "ataque"
#     ],
#     "atishoo": [
#         "achoo",
#         "kerchoo",
#         "hachoo"
#     ],
#     "atributo": [
#         "característica",
#         "cualidad",
#         "propiedad",
#         "metadata"
#     ],
#     "au nom de": [
#         "de la part de"
#     ],
#     "augend": [
#         "addend",
#         "summand"
#     ],
#     "ausschlafen": [
#         "verschlafen"
#     ],
#     "automated external defibrillator": [
#         "AED"
#     ],
#     "automatic teller machine": [
#         "ATM",
#         "automatic transaction machine"
#     ],
#     "automatic transaction machine": [
#         "ATM",
#         "automatic teller machine"
#     ],
#     "avoir": [
#         "posséder",
#         "obtenir",
#         "procurer",
#         "solde créditeur"
#     ],
#     "axis": [
#         "deer"
#     ],
#     "azután": [
#         "aztán",
#         "később",
#         "utána"
#     ],
#     "ba": [
#         "cha#Tiếng Việt|cha",
#         "tía",
#         "bố"
#     ],
#     "ba mươi sáu chước": [
#         "tam thập lục kế",
#         "tam thập lục kế tẩu vi thượng sách"
#     ],
#     "ba trợn": [
#         "cà chớn"
#     ],
#     "ba tàu": [
#         "Người Hoa"
#     ],
#     "baby": [
#         "babe",
#         "infant",
#         "zuigeling"
#     ],
#     "background": [
#         "context",
#         "setting"
#     ],
#     "backup": [
#         "back up"
#     ],
#     "bag": [
#         "sack",
#         "tote",
#         "poke",
#         "suitcase",
#         "school-bag",
#         "backpack",
#         "preference",
#         "hag",
#         "base",
#         "breathalyzer",
#         "multiset"
#     ],
#     "ball": [
#         "sphere"
#     ],
#     "ballpoint": [
#         "biro"
#     ],
#     "ballpoint pen": [
#         "biro",
#         "ball pen",
#         "ballpen"
#     ],
#     "ban công": [
#         "ban-công"
#     ],
#     "ban phước": [
#         "chúc dữ"
#     ],
#     "ban đầu": [
#         "mới đầu"
#     ],
#     "bang": [
#         "tiểu bang",
#         "exclamation mark",
#         "exclamation point"
#     ],
#     "bang zijn": [
#         "vrezen",
#         "bang",
#         "schrik"
#     ],
#     "bao bọc": [
#         "bảo vệ"
#     ],
#     "bao quanh": [
#         "bao bọc",
#         "bao phủ"
#     ],
#     "barycenter": [
#         "barycentre"
#     ],
#     "barycentre": [
#         "barycenter"
#     ],
#     "basta": [
#         "bada bastu"
#     ],
#     "basura": [
#         "inmundicia",
#         "suciedad"
#     ],
#     "basuras": [
#         "inmundicias",
#         "suciedades"
#     ],
#     "bay hơi": [
#         "bốc hơi",
#         "vaporize"
#     ],
#     "bay màu": [
#         "xóa sổ"
#     ],
#     "beaucoup": [
#         "bookoo"
#     ],
#     "beauty": [
#         "beaut"
#     ],
#     "beef": [
#         "cowflesh"
#     ],
#     "been": [
#         "poot",
#         "bot"
#     ],
#     "beeper": [
#         "pager"
#     ],
#     "before Christ": [
#         "Anno Domini"
#     ],
#     "begin": [
#         "start"
#     ],
#     "beginnen": [
#         "starten"
#     ],
#     "begorra": [
#         "begorrah"
#     ],
#     "behavior": [
#         "behaviour"
#     ],
#     "behaviour": [
#         "behavior"
#     ],
#     "belie": [
#         "misrepresent",
#         "contradict",
#         "calumniate"
#     ],
#     "believing that": [
#         "Câu",
#         "bản",
#         "hiến pháp",
#         "tin tưởng rằng|Tin tưởng rằng",
#         "Thể loại:Tiền tố tiếng Anh"
#     ],
#     "bellwether": [
#         "gauge",
#         "indicator",
#         "sign"
#     ],
#     "benefit": [
#         "benefit night",
#         "benifit match"
#     ],
#     "bent": [
#         "crooked",
#         "queer",
#         "inclination"
#     ],
#     "better": [
#         "bettor"
#     ],
#     "bettor": [
#         "better"
#     ],
#     "bfn": [
#         "cul8r",
#         "gg",
#         "bye"
#     ],
#     "bi bô": [
#         "babble"
#     ],
#     "bildungsroman": [
#         "coming of age",
#         "novel"
#     ],
#     "biodiversity": [
#         "biological",
#         "diversity"
#     ],
#     "bir": [
#         "bärs",
#         "öl"
#     ],
#     "bitter": [
#         "bitter beer"
#     ],
#     "bivouac": [
#         "military camp"
#     ],
#     "biz": [
#         "business"
#     ],
#     "biên cảnh": [
#         "biên thùy",
#         "biên giới",
#         "biên cương"
#     ],
#     "biến dạng": [
#         "biến hình"
#     ],
#     "biểu mẫu": [
#         "mẫu đơn"
#     ],
#     "biểu thị": [
#         "cho thấy",
#         "biểu hiện",
#         "biểu đạt",
#         "biểu lộ"
#     ],
#     "biểu tự": [
#         "tên chữ"
#     ],
#     "biểu đồ": [
#         "đồ thị"
#     ],
#     "biện hộ sư": [
#         "biện sư",
#         "luật sư",
#         "trạng sư",
#         "thầy cãi",
#         "thầy giùi",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "biện lí": [
#         "thẩm phán|Thẩm phán",
#         "trách nhiệm",
#         "điều tra",
#         "truy tố",
#         "buộc tội",
#         "bị cáo",
#         "tòa án",
#         "Bắc Kỳ",
#         "Pháp",
#         "số",
#         "nước",
#         "thẩm án",
#         "thẩm phán",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "biện sư": [
#         "Như",
#         "biện hộ sư",
#         "Như",
#         "biện lí",
#         "luật sư",
#         "trạng sư",
#         "thầy cãi",
#         "thầy giùi",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "blackjack": [
#         "black jack"
#     ],
#     "blank": [
#         "blank cartridge"
#     ],
#     "blind": [
#         "blind drunk"
#     ],
#     "blinking cursor": [
#         "caret",
#         "insertion point",
#         "insertion pointer"
#     ],
#     "blocklist": [
#         "blacklist"
#     ],
#     "blog": [
#         "weblog"
#     ],
#     "bloodbath": [
#         "tắm",
#         "máu",
#         "Thể loại:Danh từ tiếng Anh"
#     ],
#     "bloviate": [
#         "pontificate"
#     ],
#     "blowjob": [
#         "fellatio",
#         "oral",
#         "sex"
#     ],
#     "blue": [
#         "blue",
#         "stocking"
#     ],
#     "blâu": [
#         "con|Con",
#         "tâu",
#         "con",
#         "trâu",
#         "tâu"
#     ],
#     "blăng": [
#         "giăng|Giăng",
#         "trăng",
#         "Thể loại:Danh từ tiếng Việt trung cổ"
#     ],
#     "bohri": [
#         "unnilsepti"
#     ],
#     "boi": [
#         "Con",
#         "voi",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "bolígrafo": [
#         "biro",
#         "birome",
#         "boli",
#         "lápiz pasta",
#         "pluma"
#     ],
#     "bolígrafos": [
#         "biros",
#         "biromes",
#         "bolis",
#         "lápices pastas",
#         "plumas"
#     ],
#     "bom": [
#         "bôm",
#         "táo tây"
#     ],
#     "bom hiđrô": [
#         "bom H"
#     ],
#     "bom khinh khí": [
#         "bom hiđrô",
#         "bom H"
#     ],
#     "bona fide": [
#         "sincere",
#         "authentic",
#         "genuine",
#         "sincerely",
#         "authentically",
#         "genuinely"
#     ],
#     "bone": [
#         "boning",
#         "erection",
#         "boner",
#         "hard-on",
#         "stiffy",
#         "debone",
#         "apprehend",
#         "steal",
#         "bonk",
#         "do#Tiếng Anh|do",
#         "fuck",
#         "screw",
#         "shag"
#     ],
#     "boner": [
#         "erection",
#         "bone#Tiếng Anh|bone",
#         "hard-on",
#         "stiffy",
#         "blooper",
#         "blunder"
#     ],
#     "boogminuut": [
#         "minuut"
#     ],
#     "boogseconde": [
#         "seconde"
#     ],
#     "bookmark": [
#         "favorite",
#         "favourite",
#         "hotlink"
#     ],
#     "bookmarks": [
#         "favorites",
#         "favourites",
#         "hotlist",
#         "hotlinks"
#     ],
#     "boreal pole": [
#         "north pole"
#     ],
#     "bourgeois": [
#         "square",
#         "bourge"
#     ],
#     "brand": [
#         "brand name"
#     ],
#     "breve": [
#         "double whole note"
#     ],
#     "broadcast": [
#         "broadcasting"
#     ],
#     "broken": [
#         "damaged"
#     ],
#     "bu": [
#         "bâu",
#         "-bu"
#     ],
#     "bui": [
#         "nguyên ủy|Nguyên ủy",
#         "cái",
#         "chén tống",
#         "nghĩa",
#         "chỉ",
#         "có",
#         "vậy",
#         "盃",
#         "Thể loại:Liên từ tiếng Việt"
#     ],
#     "buildup": [
#         "accumulation"
#     ],
#     "bullshit": [
#         "BS",
#         "bull",
#         "bullcrap",
#         "horseshit"
#     ],
#     "bureau": [
#         "table"
#     ],
#     "burglarize": [
#         "burglarise",
#         "burgle"
#     ],
#     "burgle": [
#         "burglarise",
#         "burglarize"
#     ],
#     "burnt": [
#         "burned"
#     ],
#     "business": [
#         "enterprise",
#         "firm",
#         "venture"
#     ],
#     "but": [
#         "yet",
#         "although",
#         "ac",
#         "bar",
#         "unless",
#         "excepting",
#         "excluding",
#         "with the exception of",
#         "without",
#         "stump",
#         "fin",
#         "objectif",
#         "dessein",
#         "point",
#         "uyluk"
#     ],
#     "butter": [
#         "butter up"
#     ],
#     "buttstock": [
#         "stock",
#         "shoulder stock"
#     ],
#     "buxom": [
#         "busty",
#         "curvaceous",
#         "curvy",
#         "shapely"
#     ],
#     "buy": [
#         "purchase",
#         "aby",
#         "accept",
#         "believe",
#         "swallow",
#         "take on"
#     ],
#     "buzz": [
#         "buzzsaw",
#         "buzz-saw"
#     ],
#     "buzzword": [
#         "buzz-word"
#     ],
#     "buôn bán": [
#         "giao thương"
#     ],
#     "buôn chứng khoán": [
#         "đầu cơ tích trữ"
#     ],
#     "buôn hương bán phấn": [
#         "mô tả|Mô tả",
#         "chung",
#         "người",
#         "lẳng lơ",
#         "đem",
#         "thân",
#         "vui",
#         "thâu",
#         "lợi lạc",
#         "bán phấn buôn hương",
#         "phường hoa",
#         "đĩ",
#         "Thể loại:Thành ngữ tiếng Việt"
#     ],
#     "buối": [
#         "bụi|Bụi",
#         "cây",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "buối bù": [
#         "Như",
#         "bồi bổ",
#         "Thể loại:Động từ tiếng Việt"
#     ],
#     "buồi": [
#         "dương vật"
#     ],
#     "buồn": [
#         "thiểu não",
#         "buồn bã",
#         "buồn rầu"
#     ],
#     "buồn thiu": [
#         "buồn thỉu buồn thiu",
#         "buồn xo",
#         "buồn thỉu"
#     ],
#     "buồng lái": [
#         "ca bin"
#     ],
#     "bye": [
#         "cul8r",
#         "gg",
#         "bfn"
#     ],
#     "bà ngoại": [
#         "bà nội"
#     ],
#     "bà nội": [
#         "bà ngoại"
#     ],
#     "bài hát": [
#         "bài ca",
#         "ca khúc"
#     ],
#     "bàn đạp": [
#         "pê-đan"
#     ],
#     "bàng an": [
#         "bàng ien"
#     ],
#     "bàng ien": [
#         "bàng an"
#     ],
#     "bào huy": [
#         "huy hiệu|Huy hiệu",
#         "in",
#         "áo choàng",
#         "coats of arms",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "bày vẽ": [
#         "bày biện",
#         "vẽ vời",
#         "vẽ chuyện"
#     ],
#     "bá đạo": [
#         "gian đạo",
#         "cường đạo",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "bác bỏ": [
#         "từ chối"
#     ],
#     "bác sĩ": [
#         "thầy thuốc",
#         "thú y sĩ",
#         "y sĩ",
#         "y tá",
#         "dược sĩ",
#         "doctor",
#         "medical",
#         "doctor",
#         "M.D.",
#         "physician",
#         "vet",
#         "vétérinaire"
#     ],
#     "bách khoa toàn thư": [
#         "từ điển bách khoa"
#     ],
#     "bách thú": [
#         "sở thú",
#         "zoo",
#         "dierentuin",
#         "зоосад",
#         "zoo"
#     ],
#     "bái": [
#         "bái chổi"
#     ],
#     "bái mạng": [
#         "lễ|Lễ",
#         "bề trên",
#         "xa",
#         "lạy|Lạy",
#         "biểu",
#         "hiệu",
#         "vua",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "bám bíu": [
#         "bám víu"
#     ],
#     "bán phấn buôn hương": [
#         "Như",
#         "buôn hương bán phấn",
#         "Thể loại:Thành ngữ tiếng Việt"
#     ],
#     "bánh da lợn": [
#         "bánh bao",
#         "bánh quy"
#     ],
#     "bánh giầy": [
#         "bánh dày",
#         "bánh dầy"
#     ],
#     "bánh mì": [
#         "bánh mỳ",
#         "bánh kẹp",
#         "bánh mì kẹp",
#         "bánh mỳ kẹp",
#         "xăng-đuých",
#         "xăng-uých"
#     ],
#     "bánh phở": [
#         "phở",
#         "phở khô"
#     ],
#     "báo lá cải": [
#         "lóng",
#         "tờ|Tờ",
#         "báo",
#         "chuyên",
#         "đăng",
#         "tin",
#         "giật gân",
#         "rẻ tiền",
#         "câu",
#         "khách",
#         "tin vịt",
#         "câu khách",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "báo trước": [
#         "cảnh báo",
#         "báo"
#     ],
#     "bát": [
#         "chén"
#     ],
#     "bãi binh": [
#         "ngưng|Ngưng",
#         "chiến",
#         "罷兵",
#         "罷兵",
#         "Thể loại:Động từ tiếng Việt"
#     ],
#     "bãi bồi": [
#         "phù sa bãi bồi"
#     ],
#     "bãi công": [
#         "đình công"
#     ],
#     "bê bò": [
#         "bê",
#         "bờ"
#     ],
#     "bê đê": [
#         "đồng tính luyến ái",
#         "đồng tính"
#     ],
#     "bình minh": [
#         "rạng đông",
#         "sáng tinh mơ"
#     ],
#     "bình phong": [
#         "trấn phong"
#     ],
#     "bí mật": [
#         "bí ẩn",
#         "thuyệt mật",
#         "mật"
#     ],
#     "bích quy": [
#         "bánh quy",
#         "bánh bích quy"
#     ],
#     "bóc ngắn cắn dài": [
#         "làm ngắn cắn dài"
#     ],
#     "bói toán": [
#         "bói"
#     ],
#     "bóng": [
#         "banh"
#     ],
#     "bóng đá": [
#         "đá banh",
#         "đá bóng"
#     ],
#     "bót": [
#         "bốt",
#         "bàn chải",
#         "wachtpost",
#         "borstel"
#     ],
#     "bôm": [
#         "bom"
#     ],
#     "bông": [
#         "hoa"
#     ],
#     "bú cặc": [
#         "thổi kèn",
#         "sục cặc"
#     ],
#     "bút chiến": [
#         "luận chiến"
#     ],
#     "bút danh": [
#         "ký tên"
#     ],
#     "băng ca": [
#         "băng-ca"
#     ],
#     "băng rôn": [
#         "biểu ngữ"
#     ],
#     "bơ thực vật": [
#         "ma-ga-rin",
#         "mác-ga-rin"
#     ],
#     "bơi": [
#         "bơi lội"
#     ],
#     "bướm": [
#         "bươm bướm"
#     ],
#     "bướng bỉnh": [
#         "ngoan cố",
#         "cứng đầu",
#         "ương bướng"
#     ],
#     "bưởi chùm": [
#         "bưởi đắng"
#     ],
#     "bưởng": [
#         "đọc|Đọc",
#         "trại",
#         "chữ",
#         "bang",
#         "tập hợp|Tập hợp",
#         "nhóm",
#         "người",
#         "chuyên",
#         "khai thác",
#         "quặng",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "bạc": [
#         "trắng"
#     ],
#     "bạch kim": [
#         "platin",
#         "Pt"
#     ],
#     "bạch đôi": [
#         "la"
#     ],
#     "bại tử": [
#         "xả trận"
#     ],
#     "bạn": [
#         "quý vị"
#     ],
#     "bạn hữu": [
#         "bằng hữu"
#     ],
#     "bạng duật tương trì, ngư ông đắc lợi": [
#         "duật bạng tương tranh, ngư nhân đắc lợi"
#     ],
#     "bản đồ": [
#         "địa đồ"
#     ],
#     "bản đồ tư duy": [
#         "giản đồ ý"
#     ],
#     "bảng": [
#         "đơn vị tiền tệ cơ bản của anh và nhiều nước hoặc lãnh thổ khác: ireland"
#     ],
#     "bảo": [
#         "biểu"
#     ],
#     "bảo hộ": [
#         "bảo vệ"
#     ],
#     "bất chợt": [
#         "đột xuất"
#     ],
#     "bất khả chiến bại": [
#         "vô địch",
#         "vô đối"
#     ],
#     "bất thường": [
#         "quái dị",
#         "khác thường"
#     ],
#     "bất đắc kỳ tử": [
#         "lăn đùng ra chết"
#     ],
#     "bấu víu": [
#         "bám bíu",
#         "bám víu"
#     ],
#     "bầu bạn": [
#         "bạn bè",
#         "bạn hữu",
#         "bằng hữu",
#         "bè bạn",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "bầy": [
#         "bọn",
#         "đoàn"
#     ],
#     "bẩn thỉu": [
#         "dơ bẩn"
#     ],
#     "bật mí": [
#         "tiết lộ"
#     ],
#     "bắt đầu": [
#         "khởi đầu",
#         "mở đầu",
#         "khởi động"
#     ],
#     "bằng phẳng": [
#         "phẳng"
#     ],
#     "bếu": [
#         "béo"
#     ],
#     "bề ngoài": [
#         "bên ngoài"
#     ],
#     "bệnh": [
#         "bịnh",
#         "trục trặc"
#     ],
#     "bệnh viện": [
#         "Nhà",
#         "khám",
#         "chữa bệnh",
#         "người bệnh",
#         "nhà thưong"
#     ],
#     "bị cáo": [
#         "Người",
#         "tố cáo",
#         "phạm tội",
#         "bên bị",
#         "Thể loại:Danh từ tiếng Việt"
#     ],
#     "bịt kín": [
#         "che đậy",
#         "che phủ",
#         "phủ kín"
#     ],
#     "bịt miệng": [
#         "bịt mồm",
#         "dán miệng",
#         "dán mồm",
#         "che miệng",
#         "khóa miệng",
# ...
#         "懿范"
#     ],
#     "戈": [
#         "qua"
#     ],
#     "戟": [
#         "棘",
#         "长戟",
#         "手戟",
#         "双戟",
#         "halberd",
#         "halbert",
#         "Thể loại:Danh từ tiếng Quan Thoại"
#     ],
#     "持续": [
#         "继续",
#         "Thể loại:Động từ tiếng Quan Thoại"
#     ],
#     "挨近": [
#         "ai cận|Ai cận",
#         "Thể loại:Động từ tiếng Hán"
#     ],
#     "授剪": [
#         "thọ tiễn"
#     ],
#     "接近": [
#         "tiếp cận|Tiếp cận",
#         "Thể loại:Động từ tiếng Hán"
#     ],
#     "教義": [
#         "lòng|Lòng",
#         "kính",
#         "tin",
#         "giáo điều",
#         "宗教",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "文範": [
#         "nguyên tắc|Nguyên tắc",
#         "nói",
#         "viết",
#         "ngôn ngữ",
#         "khoa học|Khoa học",
#         "nghiên cứu",
#         "ngôn ngữ",
#         "văn phạm",
#         "grammar",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "斗拱": [
#         "vòm|Vòm",
#         "nối",
#         "mái",
#         "tường",
#         "vững",
#         "đấu củng",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "斜拉桥": [
#         "斜张桥"
#     ],
#     "新街": [
#         "Tân Nhai"
#     ],
#     "日": [
#         "天",
#         "夜",
#         "日报",
#         "日本",
#         "日薄西山",
#         "日不暇给",
#         "日常",
#         "日场",
#         "日程",
#         "日出",
#         "日戳",
#         "日德兰半岛",
#         "日耳曼人",
#         "日工",
#         "日光",
#         "日光灯",
#         "日光浴",
#         "日规",
#         "日晷",
#         "日后",
#         "日华",
#         "日环食",
#         "日积月累",
#         "日记",
#         "日间",
#         "日见",
#         "日渐",
#         "日界线",
#         "日久见人心",
#         "日久天长",
#         "日就月将",
#         "日喀则",
#         "日刊",
#         "日来",
#         "日理万机",
#         "日历",
#         "日轮",
#         "日落",
#         "日冕",
#         "日暮",
#         "日暮途穷",
#         "日内",
#         "日内瓦",
#         "日内瓦湖",
#         "日偏食",
#         "日期",
#         "日期变更线",
#         "日前",
#         "日侨",
#         "日趋",
#         "日全食",
#         "日惹",
#         "日日",
#         "日色",
#         "日上三竿",
#         "日射病",
#         "日食",
#         "日头",
#         "日托",
#         "日文",
#         "日息",
#         "日下",
#         "日心说",
#         "日新月异",
#         "日薪",
#         "日夜",
#         "日以继夜",
#         "日益",
#         "日影",
#         "日用",
#         "日用品",
#         "日语",
#         "日元",
#         "日圆",
#         "日月",
#         "日月如梭",
#         "日晕",
#         "日照",
#         "日臻",
#         "日志",
#         "日中",
#         "日子"
#     ],
#     "明日": [
#         "あす"
#     ],
#     "春菜餅": [
#         "bánh|Bánh",
#         "bột",
#         "gạo",
#         "cán",
#         "mỏng",
#         "cuốn",
#         "rau",
#         "ít",
#         "thịt",
#         "Trần Nhân Tông",
#         "xuân thái bính",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "書く": [
#         "かく"
#     ],
#     "月有盈虧": [
#         "nguyệt hữu doanh khuy"
#     ],
#     "有女懷春, 吉士誘之": [
#         "hữu nữ hoài xuân, cát sĩ dụ chi"
#     ],
#     "服務員": [
#         "phục vụ viên"
#     ],
#     "朝近": [
#         "triều cận|Triều cận",
#         "Thể loại:Động từ tiếng Hán"
#     ],
#     "杭": [
#         "くい"
#     ],
#     "棪": [
#         "nguyên danh|Nguyên danh",
#         "văn sĩ",
#         "w:Nhiếp Cám Nỗ|Nhiếp Cám Nỗ",
#         "diễm",
#         "Thể loại:Mục từ chữ Nôm"
#     ],
#     "椅子": [
#         "いす"
#     ],
#     "欧元区": [
#         "âu",
#         "nguyên",
#         "khu",
#         "Hình:Eurozone_map-2009.svg|nhỏ|欧元区 (2009)",
#         "Wiktionary:Bính âm|Bính âm",
#         "ōu",
#         "yuán",
#         "qū"
#     ],
#     "毛": [
#         "け"
#     ],
#     "氣": [
#         "Khí tượng",
#         "Khí công",
#         "Khí vận",
#         "Không khí",
#         "Nguyên khí",
#         "Thiên khí",
#         "Âm khí",
#         "Bế khí",
#         "Khách khí",
#         "Huyết khí",
#         "Chánh khí",
#         "Chí khí",
#         "Dũng khí",
#         "Hạo khí",
#         "Điện khí",
#         "Hòa khí",
#         "Khí hậu",
#         "Khí số",
#         "Yếm khí",
#         "Xuân khí",
#         "Vượng khí",
#         "Tính khí",
#         "Xú khí",
#         "Thần khí",
#         "Sát khí",
#         "Nộ khí",
#         "Tài khí",
#         "Tà khí",
#         "Khinh khí",
#         "Ngạo khí",
#         "Khí phách",
#         "Ám khí",
#         "Thể loại:Danh từ tiếng Quan Thoại"
#     ],
#     "水": [
#         "氵"
#     ],
#     "汗": [
#         "あせ"
#     ],
#     "池": [
#         "いけ"
#     ],
#     "沈魚落雁": [
#         "trầm ngư lạc nhạn",
#         "chim sa, cá lặn"
#     ],
#     "油菜": [
#         "du thái"
#     ],
#     "流星": [
#         "lưu tinh",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "流星馬": [
#         "ngựa|Ngựa",
#         "chạy",
#         "hỏa tốc",
#         "dịch trạm",
#         "lưu tinh mã",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "淡水魚": [
#         "Đạm thủy ngư",
#         "Wiktionary:Bính âm|Bính âm",
#         "cá nước ngọt",
#         "fresh water fish"
#     ],
#     "混芒": [
#         "hỗn mang|Hỗn mang"
#     ],
#     "濬哲": [
#         "tuấn triết"
#     ],
#     "熠": [
#         "tập"
#     ],
#     "爱": [
#         "thích"
#     ],
#     "犬": [
#         "犭",
#         "狗"
#     ],
#     "狂飆": [
#         "cuồng tiêu"
#     ],
#     "猟": [
#         "狩"
#     ],
#     "王子": [
#         "皇子"
#     ],
#     "理当": [
#         "理所当然",
#         "应该承当",
#         "应当",
#         "should",
#         "ought",
#         "should"
#     ],
#     "瑞兆": [
#         "thụy triệu"
#     ],
#     "瑞雲": [
#         "thụy vân"
#     ],
#     "甲士": [
#         "giáp sĩ"
#     ],
#     "留班": [
#         "留級",
#         "重讀",
#         "蹲班",
#         "留級",
#         "重讀",
#         "㨆班"
#     ],
#     "留級": [
#         "留班",
#         "重讀",
#         "蹲班",
#         "留班",
#         "重讀",
#         "㨆班"
#     ],
#     "畢業": [
#         "tất nghiệp"
#     ],
#     "當事": [
#         "đương sự"
#     ],
#     "痛風": [
#         "thống phong"
#     ],
#     "發作": [
#         "phát tác"
#     ],
#     "白族": [
#         "滇僰",
#         "叟",
#         "爨氐",
#         "西爨",
#         "白蛮",
#         "白人",
#         "僰人",
#         "Bai",
#         "ethnic",
#         "group"
#     ],
#     "皇": [
#         "vua"
#     ],
#     "皇媳": [
#         "Con",
#         "dâu",
#         "hoàng đế",
#         "phu nhân|Phu nhân",
#         "hoàng thái tử",
#         "hoàng tức",
#         "công nương",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "皇子": [
#         "王子"
#     ],
#     "盃": [
#         "Cái",
#         "chén",
#         "duy nhất|Duy nhất",
#         "chỉ",
#         "có",
#         "vậy",
#         "bui",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "睍睍": [
#         "hiển hiển"
#     ],
#     "睏": [
#         "睏覺"
#     ],
#     "睏覺": [
#         "睏"
#     ],
#     "知": [
#         "智",
#         "智"
#     ],
#     "硕士": [
#         "Wiktionary:Bính âm|Bính âm"
#     ],
#     "碩須": [
#         "Wikipedia"
#     ],
#     "秋": [
#         "あき",
#         "とき"
#     ],
#     "立つ": [
#         "たつ"
#     ],
#     "篔簹": [
#         "vân đương"
#     ],
#     "絵": [
#         "え"
#     ],
#     "緩": [
#         "缓",
#         "缓"
#     ],
#     "繃帶": [
#         "băng đai"
#     ],
#     "继室": [
#         "继配",
#         "second",
#         "wife"
#     ],
#     "缓": [
#         "緩",
#         "緩"
#     ],
#     "网志": [
#         "网络日志 ",
#         "部落格",
#         "博客"
#     ],
#     "罵": [
#         "傌",
#         "㐷"
#     ],
#     "罷兵": [
#         "ngưng|Ngưng",
#         "chiến",
#         "bãi binh",
#         "bãi binh",
#         "Thể loại:Động từ tiếng Hán"
#     ],
#     "羅": [
#         "h",
#         "h"
#     ],
#     "羶": [
#         "膻"
#     ],
#     "羼": [
#         "混合",
#         "混杂"
#     ],
#     "老街": [
#         "Lão Nhai"
#     ],
#     "聞く": [
#         "きく"
#     ],
#     "聲母": [
#         "thanh mẫu"
#     ],
#     "臥": [
#         "nằm|Nằm",
#         "ngủ|Ngủ",
#         "nằm",
#         "ngủ"
#     ],
#     "臨淄": [
#         "Lâm Truy"
#     ],
#     "良い": [
#         "よい",
#         "いい"
#     ],
#     "花娘": [
#         "dụng ngữ|Dụng ngữ",
#         "xuất hiện",
#         "khoảng",
#         "thời",
#         "w:Lê sơ|Lê sơ",
#         "mô tả",
#         "phường",
#         "gái",
#         "hành nghề",
#         "bán dâm",
#         "đôi khi",
#         "xướng ca",
#         "花賣娘",
#         "hoa nương",
#         "đĩ",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "花賣娘": [
#         "dụng ngữ|Dụng ngữ",
#         "xuất hiện",
#         "khoảng",
#         "thời",
#         "Lê sơ",
#         "mô tả",
#         "phường",
#         "gái",
#         "hành nghề",
#         "bán dâm",
#         "đôi khi",
#         "xướng ca",
#         "nàng hoa",
#         "ả hoa",
#         "gái bán hoa",
#         "gái hoa",
#         "cái hoa",
#         "cô hoa",
#         "con hoa",
#         "花娘",
#         "hoa mại nương",
#         "đĩ",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "芳菜": [
#         "vân đài"
#     ],
#     "若作和羹, 爾惟鹽梅": [
#         "nhược tác hòa canh, nhĩ duy diêm mai"
#     ],
#     "茄蠬鬼": [
#         "Nguyên",
#         "chữ",
#         "krung",
#         "làng nước",
#         "loài|Loài",
#         "quỷ",
#         "hành vi",
#         "dơi",
#         "chuyên",
#         "hút máu",
#         "bà",
#         "đẻ",
#         "Hưng Hóa",
#         "w:Lê Quý Đôn|Lê Quý Đôn",
#         "w:Trương Quốc Dụng|Trương Quốc Dụng",
#         "w:Phạm Thận Duật|Phạm Thận Duật",
#         "ma cà rồng",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "草簽": [
#         "thảo thiêm"
#     ],
#     "萐莆": [
#         "tiệp phủ"
#     ],
#     "董理": [
#         "đổng lí"
#     ],
#     "蓽門閨竇": [
#         "tất môn khuê đậu"
#     ],
#     "蘇維埃社會主義共和國聯盟": [
#         "Союз Советских Социалистических Республик",
#         "Thể loại:Địa danh tiếng Hán"
#     ],
#     "蜻蜓": [
#         "蜻",
#         "蜓"
#     ],
#     "血": [
#         "ち"
#     ],
#     "術": [
#         "vận dụng|Vận dụng",
#         "khéo léo",
#         "Võ thuật",
#         "Mĩ thuật",
#         "Nghệ thuật",
#         "Tà thuật",
#         "Thuật sĩ",
#         "Học thuật",
#         "Kĩ thuật",
#         "Nhu thuật",
#         "Phép thuật",
#         "Yêu thuật",
#         "Kiếm thuật",
#         "Y thuật",
#         "Học thuật",
#         "Thể loại:Tính từ tiếng Việt trung cổ"
#     ],
#     "衣裳": [
#         "衣装"
#     ],
#     "補用": [
#         "bổ dụng"
#     ],
#     "西瓜": [
#         "すいか"
#     ],
#     "西貢": [
#         "Tây Cống"
#     ],
#     "言う": [
#         "いう"
#     ],
#     "試合": [
#         "しあい"
#     ],
#     "譎": [
#         "谲"
#     ],
#     "谲": [
#         "譎"
#     ],
#     "賀捷": [
#         "hạ tiệp"
#     ],
#     "赠物": [
#         "tặng|Tặng",
#         "vật",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "越南": [
#         "南国",
#         "越南国"
#     ],
#     "越南共和國": [
#         "chính thể|Chính thể",
#         "thành lập",
#         "ngày",
#         "tháng",
#         "năm",
#         "bán đảo",
#         "Đông Dương",
#         "Nam phần",
#         "vĩ tuyến",
#         "cáo chung",
#         "Việt Nam Cộng hòa quốc",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "蹉陷": [
#         "sa hãm"
#     ],
#     "蹲班": [
#         "留班",
#         "留級",
#         "重讀"
#     ],
#     "躞蹀": [
#         "tiệp điệp"
#     ],
#     "軍具": [
#         "dụng cụ|Dụng cụ",
#         "quân sự",
#         "quân cụ",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "軍械": [
#         "võ khí|Võ khí",
#         "quân sự",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "輕讀": [
#         "弱讀",
#         "弱讀"
#     ],
#     "近い": [
#         "ちかい"
#     ],
#     "追う": [
#         "おう"
#     ],
#     "逝世": [
#         "去世",
#         "下世",
#         "老了",
#         "死",
#         "死亡"
#     ],
#     "遅い": [
#         "おそい"
#     ],
#     "郷に入っては郷に従え": [
#         "nhập gia tùy tục",
#         "nhập gia tùy tục, nhập giang tùy khúc|nhập giang tùy khúc"
#     ],
#     "酒": [
#         "さけ"
#     ],
#     "重複思考": [
#         "trùng phức tư khảo"
#     ],
#     "重讀": [
#         "強讀",
#         "留級",
#         "留班",
#         "蹲班",
#         "強讀",
#         "留級",
#         "留班",
#         "蹲班"
#     ],
#     "量子物理学": [
#         "量子力学"
#     ],
#     "金": [
#         "钅",
#         "钅"
#     ],
#     "金剛": [
#         "kim cương"
#     ],
#     "镌刻": [
#         "雕刻",
#         "degrade",
#         "engrave"
#     ],
#     "镌损": [
#         "减少",
#         "削弱",
#         "degrade",
#         "engrave"
#     ],
#     "镌级": [
#         "降低官阶"
#     ],
#     "镌罚": [
#         "降职惩罚",
#         "business",
#         "profession"
#     ],
#     "镌责": [
#         "降级追究责任"
#     ],
#     "阁楼": [
#         "gian",
#         "lưng chừng",
#         "căn nhà",
#         "hẹp",
#         "tối tăm",
#         "chứa",
#         "vật dụng",
#         "ít",
#         "thiết thực",
#         "ngủ",
#         "tạm",
#         "bữa",
#         "tầng lửng",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "阮": [
#         "阮琴"
#     ],
#     "阿尔法射线": [
#         "射线",
#         "α",
#         "射线"
#     ],
#     "阿尔法粒子": [
#         "α",
#         "粒子"
#     ],
#     "阿拉伯数字": [
#         "阿拉伯数码"
#     ],
#     "阿片": [
#         "鸦片"
#     ],
#     "阿罗汉": [
#         "罗汉",
#         "應供",
#         "應真",
#         "真人"
#     ],
#     "阿羅漢": [
#         "罗汉",
#         "應供",
#         "應真",
#         "真人"
#     ],
#     "阿门": [
#         "阿們"
#     ],
#     "阿飞": [
#         "牛仔"
#     ],
#     "降": [
#         "hạ"
#     ],
#     "陨石": [
#         "天石",
#         "石陨石",
#         "铁陨石",
#         "石铁陨石",
#         "meteorite",
#         "Thể loại:Danh từ tiếng Quan Thoại",
#         "Thể loại:Thiên văn học"
#     ],
#     "陰謀論": [
#         "conspiracy theory"
#     ],
#     "雪郵差": [
#         "tuyết bưu sai"
#     ],
#     "雾": [
#         "薄雾",
#         "烟霞",
#         "罩雾",
#         "霾"
#     ],
#     "霾": [
#         "雾",
#         "薄雾",
#         "罩雾",
#         "煙霞"
#     ],
#     "青い": [
#         "あおい"
#     ],
#     "靠行": [
#         "léo hánh|Léo hánh",
#         "靠近",
#         "挨近",
#         "接近",
#         "傍近",
#         "Thể loại:Động từ tiếng Hán"
#     ],
#     "靠近": [
#         "靠行",
#         "挨近",
#         "接近",
#         "傍近",
#         "Thể loại:Động từ tiếng Hán"
#     ],
#     "領主": [
#         "Chúa tể",
#         "lĩnh địa",
#         "lĩnh chúa",
#         "诸侯",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "領土": [
#         "lĩnh thổ"
#     ],
#     "領地": [
#         "đất|Đất",
#         "phong",
#         "lĩnh chúa",
#         "khoảnh|Khoảnh",
#         "đất",
#         "người",
#         "định cư",
#         "lĩnh địa",
#         "地轄",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "頭": [
#         "元",
#         "元"
#     ],
#     "題材": [
#         "đề tài"
#     ],
#     "題詞": [
#         "đề từ"
#     ],
#     "顔": [
#         "かお"
#     ],
#     "顶楼": [
#         "gian",
#         "lưng chừng",
#         "căn nhà",
#         "hẹp",
#         "tối tăm",
#         "chứa",
#         "vật dụng",
#         "ít",
#         "thiết thực",
#         "ngủ",
#         "tạm",
#         "bữa",
#         "tầng lửng",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "颖": [
#         "穎",
#         "sharp",
#         "point",
#         "穎",
#         "sharp",
#         "clever",
#         "gifted"
#     ],
#     "風濕": [
#         "phong thấp"
#     ],
#     "食う": [
#         "くう"
#     ],
#     "馅饼": [
#         "hãm bính"
#     ],
#     "馏": [
#         "餾",
#         "distill"
#     ],
#     "駅": [
#         "えき"
#     ],
#     "骨": [
#         "骨头"
#     ],
#     "高い": [
#         "たかい"
#     ],
#     "鰥寡孤独": [
#         "quan quả cô đơn"
#     ],
#     "鸟窝": [
#         "巢"
#     ],
#     "黽": [
#         "黾",
#         "勉",
#         "釗",
#         "捓",
#         "劬",
#         "掙",
#         "俛",
#         "勔",
#         "挣",
#         "佡"
#     ],
#     "黾": [
#         "黽",
#         "釗",
#         "捓",
#         "劬",
#         "掙",
#         "俛",
#         "勔",
#         "挣",
#         "佡"
#     ],
#     "龍星旗": [
#         "long tinh kì|Long tinh kì",
#         "Thể loại:Danh từ tiếng Hán"
#     ],
#     "개": [
#         "y",
#         "y",
#         "y",
#         "y"
#     ],
#     "둘": [
#         "두",
#         "이",
#         "二",
#         "nhị"
#     ],
#     "별": [
#         "성",
#         "星",
#         "tinh"
#     ],
#     "셋": [
#         "삼",
#         "三",
#         "tam"
#     ],
#     "왕비": [
#         "Vương phi",
#         "Trung điện",
#         "중전"
#     ],
#     "은": [
#         "는"
#     ],
#     "중전": [
#         "Vương phi",
#         "Trung điện"
#     ],
#     "치치할": [
#         "tề|Tề",
#         "cáp|Cáp",
#         "nhĩ|Nhĩ",
#         "thành phố",
#         "Mãn Châu",
#         "chữ viết",
#         "tiếng Triều Tiên",
#         "Trung Quốc",
#         "Hàn Quốc",
#         "치치하얼",
#         "齊齊哈爾",
#         "齐齐哈尔",
#         "チチハル",
#         "Qiqihar",
#         "Чичихар",
#         "ᠴᠢᠴᠢᠬᠠᠷ",
#         "ᠴᡳᠴᡳᡤᠠᡵ"
#     ],
#     "하나": [
#         "일",
#         "一",
#         "nhất"
#     ],
#     "𒀭𒁇": [
#         "𒀭𒁇𒋤"
#     ],
#     "𒀭𒁇𒋤": [
#         "𒀭𒁇"
#     ],
#     "𒀴": [
#         "𒀵"
#     ],
#     "𒀵": [
#         "𒀴"
#     ],
#     "𡦂": [
#         "字",
#         "𡨸",
#         "𡦂喃",
#         "Thể loại:Unicode CJK Unified Ideographs Extension B"
#     ],
#     "𡨸": [
#         "字",
#         "𡦂",
#         "Quốc âm thi tập",
#         "糝",
#         "𢚸",
#         "掩",
#         "掩",
#         "鴈",
#         "封",
#         "Thể loại:Unicode CJK Unified Ideographs Extension B"
#     ],
#     "𤇼": [
#         "húy|Húy",
#         "Trần Thiếu Đế",
#         "Yên",
#         "Thể loại:Mục từ chữ Nôm"
#     ]
# }

# %% [markdown]
# There are still some thrash from other languages, but currently I don't see any approaches how to filter it. Maybe just use detect_lang tool. But in this case execution will be much slower.
