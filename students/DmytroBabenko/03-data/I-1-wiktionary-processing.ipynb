# %%
import json
from typing import List, Dict
from xml.sax import handler, make_parser

# %% [markdown]
# In this tas we select *Afrikaans* language and consider the file *afwiktionary-20200301-pages-articles-multistream.xml.bz2*  in https://dumps.wikimedia.org/afwiktionary/20200301/

# %%
class AfrikaansSynonymGenerator(handler.ContentHandler):
    PAGE = 'page'
    TITLE = 'title'
    TEXT = 'text'
    REVISION = 'revision'

    SYNONYM_TAG = "{{sinonieme}}"
    AFTER_SYNONYM_TAG = "{{"

    START_TAG = '[['
    END_TAG = ']]'

    def __init__(self):
        handler.ContentHandler.__init__(self)
        self.path = []
        self.cur_title: str = None
        self.__start_parse_synonym = False
        self.__cur_synonym_lines: List[str] = []
        self.__synonym_dict: Dict[str, List[str]] = dict()

    def get_synonyms_dict(self):
        return self.__synonym_dict

    def startElement(self, name, attrs):
        self.path.append(name)

    def endElement(self, name):
        if self.__is_text_in_revision_in_page():
            if self.__start_parse_synonym:
                self.__finish_parse_synonym()
        self.path.pop()

    def characters(self, content):
        if self.__is_title_in_page():
            self.cur_title = content

        if self.__is_text_in_revision_in_page():
            if self.SYNONYM_TAG in content:
                self.__start_parse_synonym = True
            else:
                if self.__start_parse_synonym:
                    if self.AFTER_SYNONYM_TAG in content:
                        self.__finish_parse_synonym()
                    else:
                        self.__cur_synonym_lines.append(content)

    def __finish_parse_synonym(self):
        words = []
        for line in self.__cur_synonym_lines:
            words += self.__acquire_words_from_line(line)

        if self.cur_title is not None and len(words) > 0:
            self.__synonym_dict[self.cur_title] = words

        self.__cur_synonym_lines = []
        self.__start_parse_synonym = False

    def __acquire_words_from_line(self, line: str):
        text = line.strip("#").strip()
        if len(text) == 0:
            return []

        words = []
        start_pos = 0
        while start_pos < len(text):
            start_pos = text.find(self.START_TAG, start_pos)
            if start_pos == -1:
                break

            end_pos = text.find(self.END_TAG, start_pos)
            if end_pos == -1:
                break

            word = text[start_pos + 2: end_pos]
            if len(word) > 0:
                words.append(word)

            start_pos = end_pos + 2

        return words

    def getParentElement(self):
        if len(self.path) == 0:
            return None
        return self.path[-1]

    def __is_title_in_page(self):
        if len(self.path) < 2:
            return False

        if self.path[-1] != self.TITLE:
            return False

        return self.path[-2] == self.PAGE

    def __is_text_in_revision_in_page(self):
        if len(self.path) < 3:
            return False

        if self.path[-1] != self.TEXT:
            return False

        if self.path[-2] != self.REVISION:
            return False

        return self.path[-3] == self.PAGE

# %%
# !ls data
# Out:
# afwiktionary-20200301-pages-articles-multistream.xml
# eswiktionary-20200301-pages-articles-multistream.xml
# official-2014.combined-withalt.m2

# %%
file = "data/afwiktionary-20200301-pages-articles-multistream.xml"

# %% [markdown]
# Let's parse words with their synonyms from this file

# %%
parser = make_parser()
synonym_generator = AfrikaansSynonymGenerator()
parser.setContentHandler(synonym_generator)
parser.parse(file)

# %%
synonyms = synonym_generator.get_synonyms_dict()

# %%
synonyms
# Out:
# {'selfstandige naamwoord': ['substantief'],
#  'werkwoord': ['verbum'],
#  'byvoeglike naamwoord': ['adjektief'],
#  'Noors': ['Noorweegs'],
#  'sider': ['appelwyn'],
#  'amper': ['byna'],
#  'aarde': ['grond'],
#  'kruistog': ['kruisvaart'],
#  'reënboog': ['reentboog'],
#  'hond': ['brak'],
#  'reentboog': ['reënboog'],
#  'substantief': ['zelfstandig naamwoord', 'nomen'],
#  'verlede deelwoord': ['voltooide deelwoord'],
#  'voltooide deelwoord': ['verlede deelwoord'],
#  'appelwyn': ['sider'],
#  'pluralis': ['meervoud'],
#  'bywoord': ['adverbium'],
#  'moeder': ['ma'],
#  'vader': ['pa'],
#  'broer': ['broeder', 'boet'],
#  'far': ['fader'],
#  'fader': ['far'],
#  'bror': ['broder'],
#  'broder': ['bror'],
#  'man': ['himen'],
#  'Xhosa': ['Kôsa'],
#  'afrikáner': ['bóer'],
#  'afrikander': ['bóer'],
#  'zulu': ['zulù'],
#  'dag': ['etmaal'],
#  'herero': ['hereró'],
#  'Mann': ['Ehemann', 'Gatte', 'Gemahl'],
#  'mahdum': ['oğul'],
#  'week': ['sennight'],
#  'funksiewoord': ['werkwoord', 'verbum'],
#  'verbum': ['werkwoord'],
#  'soortnaam': ['spesienaam'],
#  'Noorweegs': ['Noors'],
#  'Nieu-Noors': ['Nuwe Noors', 'Nynorsk'],
#  'Neunorwegisch': ['Nynorsk'],
#  'Nynorsk': ['New Norse'],
#  'Bokmål': ['Boekmaal'],
#  'sevinç': ['neşe', 'sürur'],
#  'beygir': ['at'],
#  'rinoceronte': ['abada'],
#  'feutre': ['chapeau de feutre'],
#  'chapeau de feutre': ['feutre'],
#  'Mari': ['Çeremiş'],
#  'Tsjeremis': ['Mari'],
#  'Sorani': ['Soranca'],
#  'Iers': ['Iers-Gaelisch', 'Gaelisch'],
#  'weerlig': ['blits', 'bliksem'],
#  'ja': ['yes'],
#  'Botswana': ['Botsuana'],
#  'chino': ['mandarín'],
#  'china': ['bra'],
#  'kruisvaart': ['kruistog'],
#  'Jiddisj': ['Jode-Duits'],
#  'lingua Vietnamensis': ['lingua Annamica', 'lingua Vietnamica'],
#  'veselperske': ['mango'],
#  'biblioteek': ['boekery'],
#  'lessenaar': ['skryftafel'],
#  'skryftafel': ['lessenaar'],
#  'vervoeg': ['konjugeer'],
#  'konjugeer': ['vervoeg'],
#  'as': ['indien'],
#  'das': ['dassie'],
#  'ons': ['hectogram'],
#  'ek': ['ekke'],
#  'ekke': ['ek'],
#  'sleng': ['groeptaal'],
#  'groeptaal': ['slang', 'sleng'],
#  'groepstaal': ['slang', 'sleng'],
#  'slang': ['groeptaal'],
#  'Oeigoers': ['Oejgoers',
#   'Oudoeigoers',
#   'Oudoejgoers',
#   'Oejgoers',
#   'Nieuw-Oeigoers',
#   'Nieuw-Oejgoers',
#   'Oejgoers',
#   'Siberisch',
#   'Oost-Turks',
#   'Noordoost-Turks',
#   'Oeigoers-Ogoezisch',
#   'Oejgoers-Ogoezisch',
#   'Oejgoers',
#   'Karloeks',
#   'Oost-Turks',
#   'Zuidoost-Turks'],
#  'Uyghur': ['Uigurian',
#   'Uighurian',
#   'Uiguric',
#   'Uighuric',
#   'Uigurian',
#   'Uighurian',
#   'Uiguric',
#   'Uighuric',
#   'Modern Uigur',
#   'Neo-Uigur',
#   'Uigurian',
#   'Uighurian',
#   'Uiguric',
#   'Uighuric',
#   'Siberian',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Northeastern Turkic',
#   'Uigurian',
#   'Uighurian',
#   'Uiguric',
#   'Uighuric',
#   'Karluk',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Southeastern Turkic'],
#  'Uigur': ['Uigurian',
#   'Uighurian',
#   'Uiguric',
#   'Uighuric',
#   'Uigurian',
#   'Uighurian',
#   'Uiguric',
#   'Uighuric',
#   'Modern Uigur',
#   'Neo-Uigur',
#   'Uigurian',
#   'Uighurian',
#   'Uiguric',
#   'Uighuric',
#   'Siberian',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Northeastern Turkic',
#   'Uigurian',
#   'Uighurian',
#   'Uiguric',
#   'Uighuric',
#   'Karluk',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Southeastern Turkic'],
#  'Uighur': ['Uigurian',
#   'Uighurian',
#   'Uiguric',
#   'Uighuric',
#   'Uigurian',
#   'Uighurian',
#   'Uiguric',
#   'Uighuric',
#   'Modern Uigur',
#   'Neo-Uigur',
#   'Uigurian',
#   'Uighurian',
#   'Uiguric',
#   'Uighuric',
#   'Siberian',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Northeastern Turkic',
#   'Uigurian',
#   'Uighurian',
#   'Uiguric',
#   'Uighuric',
#   'Karluk',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Southeastern Turkic'],
#  'Uigurian': ['Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uiguric',
#   'Uighuric',
#   'Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uiguric',
#   'Uighuric',
#   'Modern Uigur',
#   'Neo-Uigur',
#   'Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uiguric',
#   'Uighuric',
#   'Siberian',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Northeastern Turkic',
#   'Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uiguric',
#   'Uighuric',
#   'Karluk',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Southeastern Turkic'],
#  'Uighurian': ['Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uiguric',
#   'Uighuric',
#   'Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uiguric',
#   'Uighuric',
#   'Modern Uigur',
#   'Neo-Uigur',
#   'Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uiguric',
#   'Uighuric',
#   'Siberian',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Northeastern Turkic',
#   'Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uiguric',
#   'Uighuric',
#   'Karluk',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Southeastern Turkic'],
#  'Uiguric': ['Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uigurian',
#   'Uighurian',
#   'Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uigurian',
#   'Uighurian',
#   'Modern Uigur',
#   'Neo-Uigur',
#   'Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uigurian',
#   'Uighurian',
#   'Siberian',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Northeastern Turkic',
#   'Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uigurian',
#   'Uighurian',
#   'Karluk',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Southeastern Turkic'],
#  'Uighuric': ['Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uigurian',
#   'Uighurian',
#   'Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uigurian',
#   'Uighurian',
#   'Modern Uigur',
#   'Neo-Uigur',
#   'Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uigurian',
#   'Uighurian',
#   'Siberian',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Northeastern Turkic',
#   'Uigur',
#   'Uighur',
#   'Uygur',
#   'Uyghur',
#   'Uigurian',
#   'Uighurian',
#   'Karluk',
#   'Eastern Turki',
#   'East Turki',
#   'Eastern Turkic',
#   'Southeastern Turkic'],
#  'Oejgoers': ['Oeigoers',
#   'Oudoeigoers',
#   'Oudoejgoers',
#   'Oeigoers',
#   'Nieuw-Oeigoers',
#   'Nieuw-Oejgoers',
#   'Oeigoers',
#   'Siberisch',
#   'Oost-Turks',
#   'Noordoost-Turks',
#   'Oeigoers-Ogoezisch',
#   'Oejgoers-Ogoezisch',
#   'Oeigoers',
#   'Karloeks',
#   'Oost-Turks',
#   'Zuidoost-Turks'],
#  'Oeigoer': ['Oejgoer',
#   'Oejgoer',
#   'Oejgoer',
#   'Siberiër',
#   'Oos-Turk',
#   'Noordoos-Turk',
#   'Oejgoer',
#   'Karloek',
#   'Oos-Turk',
#   'Suidoos-Turk'],
#  'Oejgoer': ['Oeigoer',
#   'Oeigoer',
#   'Oeigoer',
#   'Siberiër',
#   'Oost-Turk',
#   'Noordoost-Turk',
#   'Oeigoer',
#   'Karloek',
#   'Oost-Turk',
#   'Zuidoost-Turk'],
#  'Oeigoerse': ['Oejgoerse',
#   'Oejgoerse',
#   'Oejgoerse',
#   'Siberische',
#   'Oost-Turkse',
#   'Noordoost-Turkse',
#   'Oejgoerse',
#   'Karloekse',
#   'Oost-Turkse',
#   'Zuidoost-Turkse'],
#  'Oejgoerse': ['Oeigoerse',
#   'Oeigoerse',
#   'Oeigoerse',
#   'Siberische',
#   'Oost-Turkse',
#   'Noordoost-Turkse',
#   'Oeigoerse',
#   'Karloekse',
#   'Oost-Turkse',
#   'Zuidoost-Turkse'],
#  'Uygur': ['eski Uygur',
#   'Sibir Türkü',
#   'Şimalî Türk',
#   'Kuzey Türk',
#   'Karluk',
#   'Doğu Türk',
#   'Şarkî Türk'],
#  'tercüme': ['çeviri'],
#  'çeviri': ['tercüme'],
#  'tłumaczenie': ['przekład'],
#  'przekład': ['tłumaczenie'],
#  'isiAfrikansi': ['isiBhulu', 'Kategorie:Woorde in Xhosa|Afrikansi'],
#  'isiBhulu': ['isiAfrikansi', 'Kategorie:Woorde in Xhosa|Bhuluisi'],
#  'Maleisies': ['Maleis'],
#  'Iakoute': ['Yakoute'],
#  'Yakoute': ['Iakoute'],
#  'iakoute': ['yakoute'],
#  'yakoute': ['iakoute'],
#  'dankie': ['tramma kassie'],
#  'balado': ['podcast'],
#  '𐌰𐌽𐌳𐌰𐌿𐌲𐌹': ['𐌰𐌽𐌳𐌰𐍅𐌻𐌴𐌹𐌶𐌽', '𐌰𐌽𐌳𐌰𐍅𐌻𐌹𐍄𐌹', '𐌻𐌿𐌳𐌾𐌰', '𐌰𐌽𐌳𐍅𐌰𐌹𐍂𐌸𐌹'],
#  '𐌰𐌽𐌳𐍅𐌰𐌹𐍂𐌸𐌹': ['𐌰𐌽𐌳𐌰𐍅𐌻𐌴𐌹𐌶𐌽', '𐌰𐌽𐌳𐌰𐌿𐌲𐌹', '𐌰𐌽𐌳𐌰𐍅𐌻𐌹𐍄𐌹'],
#  'İspanyol': ['İspanyalı'],
#  'İspanyalı': ['İspanyol'],
#  'Bosniër': ['Bosniaak'],
#  'Bosnische': ['Bosniaakse'],
#  'bosniaque': ['bosnien'],
#  'bosnien': ['bosniaque'],
#  'Bosnien': ['Bosniaque'],
#  'Bosnienne': ['Bosniaque'],
#  'lyfjabúð': ['apótek'],
#  'apótek': ['lyfjabúð'],
#  'farmacologia': ['farmacia'],
#  'farmacia': ['botica'],
#  'akupunktuur': ['akupunksie',
#   'naaldprikking',
#   'naaldebehandeling',
#   'naaldterapie'],
#  'akupunksie': ['akupunktuur',
#   'naaldprikking',
#   'naaldebehandeling',
#   'naaldterapie'],
#  'naaldprikking': ['akupunktuur',
#   'akupunksie',
#   'naaldebehandeling',
#   'naaldterapie'],
#  'naaldterapie': ['akupunktuur',
#   'akupunksie',
#   'naaldprikking',
#   'naaldebehandeling'],
#  'naaldbehandeling': ['akupunktuur',
#   'akupunksie',
#   'naaldprikking',
#   'naaldterapie'],
#  'naaldebehandeling': ['akupunktuur',
#   'akupunksie',
#   'naaldprikking',
#   'naaldterapie'],
#  'erdwolf': ['maanhaarjakkals',
#   'nadroejakkals',
#   'nadroe',
#   'gheip',
#   'weerwolf',
#   'aardwolf'],
#  'aardwolf': ['maned jackal'],
#  'kalp': ['yürek'],
#  'kalb': ['yürek'],
#  'mot': ['jipal'],
#  'daut': ['däm'],
#  'mann': ['guma',
#   'wer',
#   'ceorl|ċeorl',
#   'wer',
#   'ceorl|ċeorl',
#   'gebedda|ġebędda'],
#  'Gattin': ['Ehefrau', 'Gemahlin', 'Frau'],
#  'sotho du Nord': ['sotho septentrional'],
#  'forskaut': ['jáskaut', 'jákvætt rafskaut'],
#  'jáskaut': ['forskaut', 'jákvætt rafskaut'],
#  'jákvætt rafskaut': ['forskaut', 'jáskaut'],
#  'cemi': ['çoğul'],
#  'cem': ['çoğul'],
#  'interlingue': ['occidental'],
#  'antoniem': ['teenoorgestelde'],
#  'august': ['høstmåned'],
#  'februar': ['blidemåned'],
#  'januar': ['glugmåned'],
#  'nov': ['novi'],
#  'fast': ['beinahe', 'nahezu'],
#  'beinahe': ['fast', 'nahezu'],
#  'almost': ['nearly'],
#  'nearly': ['almost'],
#  'nästan': ['närapå'],
#  'närapå': ['nästan'],
#  'nahezu': ['fast', 'beinahe'],
#  'ἀφρικάανς': ['ἀφρικανική',
#   'ἀφρικανικὴ γλῶσσα',
#   'ἀφρικανολλανδικὴ γλῶσσα',
#   'ἀφρικανολλανδική',
#   'Kategorie:Woorde in Grieks (Katharewoesa)|αφρικάανς'],
#  'αφρικάανς': ['αφρικανική γλώσσα',
#   'αφρικανικά',
#   'αφρικανολλανδική γλώσσα',
#   'αφρικανολλανδικά'],
#  'αφρικανολλανδικά': ['αφρικάανς',
#   'αφρικανική γλώσσα',
#   'αφρικανικά',
#   'αφρικανολλανδική γλώσσα'],
#  'αφρικανικά': ['αφρικάανς',
#   'αφρικανική γλώσσα',
#   'αφρικανολλανδικά',
#   'αφρικανολλανδική γλώσσα'],
#  'αφρικανική γλώσσα': ['αφρικάανς',
#   'αφρικανικά',
#   'αφρικανολλανδικά',
#   'αφρικανολλανδική γλώσσα'],
#  'αφρικανολλανδική γλώσσα': ['αφρικάανς',
#   'αφρικανική γλώσσα',
#   'αφρικανικά',
#   'αφρικανολλανδικά'],
#  'ἀφρικανολλανδικὴ γλῶσσα': ['ἀφρικανολλανδική',
#   'ἀφρικάανς',
#   'ἀφρικανικὴ γλῶσσα',
#   'ἀφρικανική',
#   'Kategorie:Woorde in Grieks (Katharewoesa)|αφρικανολλανδικὴ γλῶσσα'],
#  'γαλλική γλώσσα': ['γαλλικά'],
#  'γαλλικά': ['γαλλική γλώσσα'],
#  'γαλλικὴ γλῶσσα': ['γαλλική'],
#  'αγγλική γλώσσα': ['αγγλικά'],
#  'αγγλικά': ['αγγλική γλώσσα'],
#  'ἀγγλικὴ γλῶσσα': ['ἀγγλική',
#   'Kategorie:Woorde in Grieks (Katharewoesa)|αγγλικὴ γλῶσσα'],
#  'ολλανδική γλώσσα': ['ολλανδικά'],
#  'ολλανδικά': ['ολλανδική γλώσσα'],
#  'ὁλλανδικὴ γλῶσσα': ['ὁλλανδική',
#   'Kategorie:Woorde in Grieks (Katharewoesa)|ολλανδικὴ γλῶσσα'],
#  'ελληνική γλώσσα': ['ελληνικά'],
#  'ελληνικά': ['ελληνική γλώσσα'],
#  'ἑλληνικὴ γλῶσσα': ['ἑλληνική',
#   'Kategorie:Woorde in Grieks (Katharewoesa)|ελληνικὴ γλῶσσα'],
#  'hollandes': ['hollandesi'],
#  'hollandesi': ['hollandes'],
#  'echtgenote': ['vrouw'],
#  'vrouw': ['echgenoete'],
#  'épouse': ['femme'],
#  'femme': ['épouse'],
#  'echtgenoot': ['man', 'gade'],
#  'mari': ['époux'],
#  'bang': ['adhaan'],
#  'zulua lingvo': ['zulua'],
#  'zulua': ['zulua lingvo'],
#  'глаз': ['око'],
#  'око': ['глаз'],
#  'Boekmaal': ['Bokmål'],
#  'adhaan': ['bang'],
#  'rapaz': ['garoto'],
#  'luns': ['segunda feira'],
#  'martes': ['terceira feira'],
#  'mércores': ['cuarta feira'],
#  'xoves': ['quinta feira'],
#  'venres': ['sexta feira'],
#  'jaj': ['pem'],
#  'soror': ['irmã'],
#  'zulù': ['zulu'],
#  'viejo': ['anciano'],
#  'wif': ['frowe|frōwe', 'cwen|cwēn', 'gebedde|ġebędde'],
#  'frowe': ['wif|ƿīf', 'cwen|cƿēn'],
#  'guma': ['wer', 'ceorl|ċeorl'],
#  'gebedda': ['mann|mǫnn', 'wer', 'ceorl|ċeorl'],
#  'wer': ['guma',
#   'mann|mǫnn',
#   'ceorl|ċeorl',
#   'mann|mǫnn',
#   'ceorl|ċeorl',
#   'gebedda|ġebędda'],
#  'gebedde': ['wif|wīf', 'cwen|cwēn'],
#  'Ou Nederlands': ['Ou Wesnederfrankies'],
#  'Oudnederlands': ['Oud-Westnederfrankisch'],
#  'Ou Wesnederfrankies': ['Oudnederlands', 'Ou Nederlands'],
#  'Ou Hoogduits': ['Ou Duits', 'Oudduits'],
#  'Oudhoogduits': ['Ou Duits', 'Oudduits'],
#  'Oudduits': ['Ou Hoogduits', 'Oudhoogduits'],
#  'Ou Duits': ['Ou Hoogduits', 'Oudhoogduits'],
#  'Middelnederlands': ['Diets', 'Duuts'],
#  'Diets': ['Middelnederlands'],
#  'Duuts': ['Middelnederlands'],
#  'Ou Nederduits': ['Ou Saksies'],
#  'Oudnederduits': ['Ou Saksies'],
#  'Oudsaksies': ['Ou Nederduits'],
#  'Ou Saksies': ['Ou Nederduits'],
#  'Middelnederduits': ['Middelsaksisch'],
#  'Nederduits': ['Nedersaksies', 'Nederlands', 'Hollands'],
#  'Middelsaksies': ['Middelnederduits'],
#  'negatief': ['ontkenning', 'ontkenningswoord'],
#  'an': ['a'],
#  'a': ['an'],
#  'reductie': ['korting'],
#  'Ermäßigung': ['Nachlass'],
#  'ankomst': ['framkomst'],
#  'framkomst': ['ankomst'],
#  'middag': ['kvällsmat'],
#  'kvällsmat': ['middag'],
#  'nedsättning': ['rabatt'],
#  'rabatt': ['nedsättning'],
#  'supper': ['dinner'],
#  'dinner': ['supper'],
#  'seña': ['dirección'],
#  'dirección': ['seña|señas'],
#  'reducción': ['rebaja'],
#  'rebaja': ['reducción'],
#  'mantequilla': ['manteca'],
#  'manteca': ['mantequilla'],
#  'sang': ['gesang'],
#  'Swazi': ['Swati'],
#  'Swati': ['Swazi'],
#  'yes': ['ja', 'yea', 'aye', 'ay'],
#  'yea': ['yes', 'ja', 'aye', 'ay'],
#  'aye': ['yes', 'ja', 'yea'],
#  'ay': ['yes', 'ja', 'yea'],
#  '𐍆𐌰𐌳𐌰𐍂': ['𐌰𐍄𐍄𐌰'],
#  '𐌰𐍄𐍄𐌰': ['𐍆𐌰𐌳𐌰𐍂'],
#  'vrees': ['angst'],
#  '𐌼𐌰𐌹𐌸𐌼𐍃': ['𐌲𐌹𐌱𐌰'],
#  '𐌲𐌹𐌱𐌰': ['𐌼𐌰𐌹𐌸𐌼𐍃'],
#  '𐍃𐌺𐌰𐌻𐌺𐍃': ['𐌸𐌹𐌿𐍃'],
#  '𐌸𐌹𐌿𐍃': ['𐍃𐌺𐌰𐌻𐌺𐍃'],
#  '𐌻𐌹𐌲𐍂𐍃': ['𐌱𐌰𐌳𐌹'],
#  '𐌷𐌻𐌰𐌹𐍆𐍃': ['𐌱𐍂𐌰𐌿𐌸'],
#  '𐌱𐍂𐌰𐌿𐌸': ['𐌷𐌻𐌰𐌹𐍆𐍃'],
#  '𐌻𐌰𐌹𐍃𐌰𐍂𐌴𐌹𐍃': ['𐍄𐌰𐌻𐌶𐌾𐌰𐌽𐌳𐍃'],
#  '𐍆𐍂𐌰𐌸𐌹': ['𐌰𐌷𐌰', '𐌷𐌿𐌲𐍃'],
#  '𐍆𐌰𐌹𐍂𐌲𐌿𐌽𐌹': ['𐌱𐌰𐌹𐍂𐌲𐍃'],
#  '𐌱𐌰𐌽𐌳𐍅𐌰': ['𐍄𐌰𐌹𐌺𐌽𐍃'],
#  '𐌻𐌿𐌳𐌾𐌰': ['𐌰𐌽𐌳𐌰𐌿𐌲𐌹', '𐌰𐌽𐌳𐌰𐍅𐌻𐌴𐌹𐌶𐌽', '𐌰𐌽𐌳𐌰𐍅𐌻𐌹𐍄𐌹'],
#  '𐍅𐌰𐌼𐌱𐌰': ['𐌺𐌹𐌻𐌸𐌴𐌹'],
#  '𐌼𐌰𐍅𐌹': ['𐌼𐌰𐌲𐌰𐌸𐍃'],
#  '𐌸𐌹𐌿𐌳𐌰𐌽𐌲𐌰𐍂𐌳𐌹': ['𐌸𐌹𐌿𐌳𐌹𐌽𐌰𐍃𐍃𐌿𐍃'],
#  'gesang': ['sang'],
#  'musiek': ['toonkuns'],
#  'toonkuns': ['musiek'],
#  'offer': ['koerbaan'],
#  '𐍃𐌰𐌹𐍅𐍃': ['𐌻𐌰𐌲𐌿𐍃', '𐌼𐌰𐍂𐌴𐌹'],
#  'nieuvorming': ['neologisme', 'nuutskepping'],
#  'neologisme': ['nuutskepping', 'nieuvorming'],
#  '𐌰𐌹𐍂𐌸𐌰𐍃𐍅𐌴𐌹𐌽': ['𐌰𐌹𐍂𐌸𐌰𐍆𐌰𐍂𐌷𐍃'],
#  '𐌰𐌹𐍂𐌸𐌰𐍆𐌰𐍂𐌷𐍃': ['𐌰𐌹𐍂𐌸𐌰𐍃𐍅𐌴𐌹𐌽'],
#  '𐌲𐌰𐌷𐌿𐌲𐌳𐍃': ['𐌰𐌷𐌰'],
#  '𐌲𐌰𐌺𐌿𐍃𐍄𐍃': ['𐌺𐌿𐍃𐍄𐌿𐍃'],
#  '𐌲𐌰𐌽𐌹𐍃𐍄𐍃': ['𐌽𐌰𐍃𐌴𐌹𐌽𐍃'],
#  '𐌼𐌰𐌲𐌰𐌸𐍃': ['𐌼𐌰𐍅𐌹'],
#  '𐌼𐌰𐌽𐌰𐍃𐌴𐌸𐍃': ['𐍆𐌰𐌹𐍂𐍈𐌿𐍃'],
#  '𐍆𐌰𐌹𐍂𐍈𐌿𐍃': ['𐌼𐌰𐌽𐌰𐍃𐌴𐌸𐍃'],
#  '𐌵𐌴𐌽𐍃': ['𐌵𐌹𐌽𐍉'],
#  '𐌵𐌹𐌽𐍉': ['𐌵𐌴𐌽𐍃'],
#  '𐍄𐌰𐌹𐌺𐌽𐍃': ['𐌱𐌰𐌽𐌳𐍅𐌰'],
#  '𐌽𐌰𐍃𐌴𐌹𐌽𐍃': ['𐌲𐌰𐌽𐌹𐍃𐍄𐍃'],
#  '𐍃𐌿𐌽𐌿𐍃': ['𐌱𐌰𐌿𐍂'],
#  '𐌺𐌿𐍃𐍄𐌿𐍃': ['𐌲𐌰𐌺𐌿𐍃𐍄𐍃'],
#  '𐌸𐌹𐌿𐌳𐌹𐌽𐌰𐍃𐍃𐌿𐍃': ['𐌸𐌹𐌿𐌳𐌰𐌽𐌲𐌰𐍂𐌳𐌹'],
#  '𐍃𐌹𐌲𐌿𐍃': ['𐍃𐌹𐌲𐌹𐍃'],
#  '𐍃𐌹𐌲𐌹𐍃': ['𐍃𐌹𐌲𐌿𐍃'],
#  '𐌰𐌷𐌰': ['𐌲𐌰𐌷𐌿𐌲𐌳𐍃', '𐍆𐍂𐌰𐌸𐌹', '𐌷𐌿𐌲𐍃'],
#  '𐌷𐌿𐌲𐍃': ['𐌰𐌷𐌰', '𐍆𐍂𐌰𐌸𐌹'],
#  '𐌰𐌷𐌼𐌰': ['𐌰𐌽𐌸𐍃'],
#  '𐌼𐌰𐌽𐌽𐌰': ['𐌲𐌿𐌼𐌰', '𐌱𐌰𐍂𐌰', '𐌻𐌹𐌿𐌸𐍃', '𐍅𐌰𐌹𐍂', '𐌴𐍂𐌻𐍃'],
#  '𐌲𐌿𐌼𐌰': ['𐌼𐌰𐌽𐌽𐌰', '𐌱𐌰𐍂𐌰', '𐌻𐌹𐌿𐌸𐍃', '𐍅𐌰𐌹𐍂', '𐌴𐍂𐌻𐍃'],
#  '𐌱𐌰𐍂𐌰': ['𐌼𐌰𐌽𐌽𐌰', '𐌲𐌿𐌼𐌰', '𐌻𐌹𐌿𐌸𐍃', '𐍅𐌰𐌹𐍂', '𐌴𐍂𐌻𐍃'],
#  'bara': ['endast'],
#  '𐌻𐌹𐌿𐌸𐍃': ['𐌼𐌰𐌽𐌽𐌰', '𐌲𐌿𐌼𐌰', '𐌱𐌰𐍂𐌰', '𐍅𐌰𐌹𐍂', '𐌴𐍂𐌻𐍃'],
#  '𐌴𐍂𐌻𐍃': ['𐌼𐌰𐌽𐌽𐌰', '𐌲𐌿𐌼𐌰', '𐌱𐌰𐍂𐌰', '𐍅𐌰𐌹𐍂', '𐌻𐌹𐌿𐌸𐍃'],
#  '𐍅𐌰𐌹𐍂': ['𐌼𐌰𐌽𐌽𐌰', '𐌲𐌿𐌼𐌰', '𐌱𐌰𐍂𐌰', '𐌻𐌹𐌿𐌸𐍃', '𐌴𐍂𐌻𐍃'],
#  '𐌷𐌹𐌿𐌷𐌼𐌰': ['𐌼𐌰𐌽𐌰𐌲𐌴𐌹'],
#  '𐌼𐌰𐌻𐌼𐌰': ['𐌰𐌿𐍂'],
#  '𐌰𐌿𐍂': ['𐌼𐌰𐍂𐌹𐍃𐌰𐌹𐍅𐍃', '𐌼𐌰𐍂𐌴𐌹', '𐌻𐌰𐌲𐌿𐍃'],
#  '𐌼𐌰𐍂𐌴𐌹': ['𐌼𐌰𐍂𐌹𐍃𐌰𐌹𐍅𐍃', '𐌰𐌿𐍂', '𐌻𐌰𐌲𐌿𐍃', '𐌻𐌰𐌲𐌿𐍃', '𐍃𐌰𐌹𐍅𐍃'],
#  '𐌼𐌰𐍂𐌹𐍃𐌰𐌹𐍅𐍃': ['𐌰𐌿𐍂', '𐌼𐌰𐍂𐌴𐌹', '𐌻𐌰𐌲𐌿𐍃'],
#  '𐌻𐌰𐌲𐌿𐍃': ['𐍃𐌰𐌹𐍅𐍃', '𐌼𐌰𐍂𐌴𐌹', '𐌼𐌰𐍂𐌹𐍃𐌰𐌹𐍅𐍃', '𐌰𐌿𐍂', '𐌼𐌰𐍂𐌴𐌹'],
#  '𐌽𐌿𐍄𐌰': ['𐍆𐌹𐍃𐌺𐌾𐌰'],
#  '𐍆𐌹𐍃𐌺𐌾𐌰': ['𐌽𐌿𐍄𐌰'],
#  '𐍅𐌴𐌹𐌷𐌰': ['𐌲𐌿𐌳𐌾𐌰'],
#  '𐌲𐌿𐌳𐌾𐌰': ['𐍅𐌴𐌹𐌷𐌰'],
#  '𐌰𐍂𐌱𐌾𐌰': ['𐌰𐍂𐌱𐌹𐌽𐌿𐌼𐌾𐌰'],
#  '𐌰𐍂𐌱𐌹𐌽𐌿𐌼𐌾𐌰': ['𐌰𐍂𐌱𐌾𐌰'],
#  '𐌲𐌰𐍃𐌹𐌽𐌸𐌾𐌰': ['𐌲𐌰𐍃𐌹𐌽𐌸𐌰'],
#  '𐌲𐌰𐍃𐌹𐌽𐌸𐌰': ['𐌲𐌰𐍃𐌹𐌽𐌸𐌾𐌰'],
#  '𐌲𐌰𐍄𐌹𐌼𐍂𐌾𐍉': ['𐍄𐌹𐌼𐍂𐌾𐍉', '𐌱𐌿𐍂𐌾𐍉', '𐌱𐌰𐍅𐌹𐌸𐌰'],
#  '𐍄𐌹𐌼𐍂𐌾𐍉': ['𐌲𐌰𐍄𐌹𐌼𐍂𐌾𐍉', '𐌱𐌿𐍂𐌾𐍉', '𐌱𐌰𐍅𐌹𐌸𐌰'],
#  '𐌱𐌿𐍂𐌾𐍉': ['𐌱𐌰𐍅𐌹𐌸𐌰', '𐌲𐌰𐍄𐌹𐌼𐍂𐌾𐍉', '𐍄𐌹𐌼𐍂𐌾𐍉'],
#  '𐌱𐌰𐍅𐌹𐌸𐌰': ['𐌱𐌿𐍂𐌾𐍉', '𐌲𐌰𐍄𐌹𐌼𐍂𐌾𐍉', '𐍄𐌹𐌼𐍂𐌾𐍉'],
#  'irmão': ['mano', 'frade'],
#  'mano': ['irmão'],
#  'frade': ['irmão'],
#  'irmã': ['mana', 'sóror'],
#  'mana': ['irmã'],
#  'sóror': ['irmã'],
#  'rapariga': ['meretriz'],
#  'pike': ['jente'],
#  'stúlka': ['stelpa'],
#  'stelpa': ['stúlka'],
#  'chica': ['muchacha'],
#  'muchacha': ['chica'],
#  'garoto': ['rapaz'],
#  'menino': ['criança'],
#  'criança': ['menino', 'menina'],
#  'strákur': ['drengur'],
#  'Tsonga': ['Shangaan', 'Shangana'],
#  'Tsua-Ronga': ['Tsonga'],
#  'Thonga': ['Tswa-Ronga', 'Tsonga'],
#  'Sjangaan': ['Tsonga'],
#  'Shangaan': ['Tsonga'],
#  'Shangana': ['Tsonga'],
#  'Nama': ['Hottentots'],
#  '𐌼𐌰𐌽𐌰𐌲𐌴𐌹': ['𐌷𐌹𐌿𐌷𐌼𐌰'],
#  '𐍆𐍂𐍉𐌳𐌴𐌹': ['𐍆𐍂𐌰𐌸𐌾𐌴𐌹', '𐌲𐌰𐍆𐍂𐌰𐌸𐌾𐌴𐌹'],
#  'khoeb': ['aob'],
#  'khoes': ['taras', 'aos'],
#  'aob': ['khoeb'],
#  'aos': ['khoes'],
#  'taras': ['khoes', 'aos'],
#  'khoe-i': ['khoeb', 'khoes'],
#  'dukuya': ['lukunya|elukunya'],
#  'lukunya': ['dukuya|endukuya'],
#  'kitok': ['lipoŋ|elipoŋ', 'ŋoroyioni|eŋoroyioni'],
#  'ŋoroyioni': ['kitok|enkitok', 'lipoŋ|elipoŋ'],
#  'lipoŋ': ['kitok|enkitok', 'ŋoroyioni|eŋoroyioni'],
#  '𐌺𐌹𐌻𐌸𐌴𐌹': ['𐍅𐌰𐌼𐌱𐌰'],
#  '𐌻𐌹𐌿𐍄𐌴𐌹': ['𐌷𐍉𐌻', '𐌻𐌹𐍄𐌰'],
#  '𐌻𐌹𐍄𐌰': ['𐌻𐌹𐌿𐍄𐌴𐌹'],
#  '𐌷𐍉𐌻': ['𐌻𐌹𐌿𐍄𐌴𐌹'],
#  '𐌱𐌰𐌿𐍃𐌴𐌹': ['𐌱𐌰𐌻𐍅𐌰𐍅𐌴𐌹𐍃𐌴𐌹', '𐌿𐌽𐍃𐌴𐌻𐌴𐌹'],
#  '𐌱𐌰𐌻𐍅𐌰𐍅𐌴𐌹𐍃𐌴𐌹': ['𐌱𐌰𐌿𐍃𐌴𐌹', '𐌿𐌽𐍃𐌴𐌻𐌴𐌹'],
#  '𐌿𐌽𐍃𐌴𐌻𐌴𐌹': ['𐌱𐌰𐌿𐍃𐌴𐌹', '𐌱𐌰𐌻𐍅𐌰𐍅𐌴𐌹𐍃𐌴𐌹'],
#  '𐍄𐌰𐌻𐌶𐌾𐌰𐌽𐌳𐍃': ['𐌻𐌰𐌹𐍃𐌰𐍂𐌴𐌹𐍃'],
#  '𐍆𐍂𐌰𐌿𐌾𐌹𐌽𐍉𐌽𐌳𐍃': ['𐍂𐌴𐌹𐌺𐍃'],
#  '𐍂𐌴𐌹𐌺𐍃': ['𐍆𐍂𐌰𐌿𐌾𐌹𐌽𐍉𐌽𐌳𐍃'],
#  '𐌰𐌹𐍈𐍃': ['𐌼𐌰𐍂𐌷𐍃'],
#  '𐌼𐌰𐍂𐌷𐍃': ['𐌰𐌹𐍈𐍃'],
#  '𐍃𐌰𐌿𐌹𐌻': ['𐍃𐌿𐌽𐌽𐍉'],
#  '𐍃𐌿𐌽𐌽𐍉': ['𐍃𐌰𐌿𐌹𐌻'],
#  '𐍉𐌸𐌰𐌻': ['𐍉𐌸𐌻𐌹'],
#  '𐍉𐌸𐌻𐌹': ['𐍉𐌸𐌰𐌻'],
#  'montagne': ['mont'],
#  'mont': ['muntanya'],
#  'montagna': ['monte'],
#  'monte': ['montanha'],
#  'βουνό': ['όρος'],
#  'βουνόν': ['ὄρος'],
#  'ὄρος': ['βουνόν', 'Kategorie:Woorde in Grieks (Katharewoesa)|ορος'],
#  '𐌱𐌰𐌹𐍂𐌲𐍃': ['𐍆𐌰𐌹𐍂𐌲𐌿𐌽𐌹'],
#  '𐌀𐌈𐌋𐌄𐌅': ['𐌋𐌄𐌂'],
#  '𐌋𐌄𐌂': ['𐌉𐌕𐌀 𐌋𐌄𐌂'],
#  '𐌀𐌉𐌖𐌐': ['𐌉𐌈𐌛𐌖𐌑𐌖𐌕', '𐌉𐌈𐌛𐌖𐌔𐌖𐌕'],
#  '𐌉𐌕𐌀 𐌋𐌄𐌂': ['𐌋𐌄𐌂'],
#  'zal': ['zult'],
#  'spruit': ['loop', 'beek'],
#  'beek': ['loop', 'spruit'],
#  'beke': ['spruite', 'lope'],
#  'utsikt': ['utsyn'],
#  'utsyn': ['utsikt'],
#  'midday': ['noon'],
#  'noon': ['midday'],
#  'muntanya': ['mont'],
#  'montanha': ['monte'],
#  'sacrificio': ['offerta'],
#  'offerta': ['sacrificio'],
#  'ubawo': ['utata'],
#  'ma': ['moeder', 'mamma'],
#  'umntakwethu': ['ubhuti'],
#  'umfowethu': ['ubhuti'],
#  'boeta': ['ouboet', 'ouboetie', 'grootboet', "'ta"],
#  "'ta": ['boeta'],
#  'ousus': ['ousie'],
#  'ousie': ['ousus'],
#  'Kamaal': ['Maandag'],
#  'недела': ['седмица'],
#  'Johannisbeere': ['Ribisel'],
#  'Ribisel': ['Johannisbeere'],
#  'Schwarze Johannisbeere': ['Aalbeere', 'Ahlbeere', 'Cassis'],
#  'Cassis': ['Schwarze Johannisbeere', 'Aalbeere', 'Ahlbeere'],
#  'Aalbeere': ['Schwarze Johannisbeere', 'Cassis'],
#  'Ahlbeere': ['Schwarze Johannisbeere', 'Cassis'],
#  'witte bes': ['witte aalbes'],
#  'witte aalbes': ['witte bes'],
#  'Albanees': ['Albaans', 'Albanies'],
#  'Albanies': ['Albanees', 'Albaans'],
#  'Albaans': ['Albanees', 'Albanies'],
#  'Albanese': ['Skipetare'],
#  'Sorbies': ['Wendies'],
#  'Sorb': ['Lusatian', 'Wend'],
#  'Wendies': ['Sorbies'],
#  'Wend': ['Sorb', 'Sorbian', 'Lusatian'],
#  'Sorbian': ['Sorb', 'Lusatian', 'Wend'],
#  'Wendish': ['Sorbian', 'Lusatian'],
#  'Wendic': ['Sorbian', 'Lusatian'],
#  'Lusatian': ['Sorb', 'Sorbian', 'Wend'],
#  'Upper Lusatian': ['Upper Sorbian'],
#  'Upper Sorbian': ['Upper Lusatian'],
#  'Lower Lusatian': ['Lower Sorbian'],
#  'Lower Sorbian': ['Lower Lusatian'],
#  'albanisch': ['skipetarisch'],
#  'albanesisch': ['skipetarisch'],
#  'skipetarisch': ['albanisch', 'albanesisch'],
#  'Albanisch': ['Skipetarisch'],
#  'Albanesisch': ['Skipetarisch'],
#  'Skipetarisch': ['Albanesisch'],
#  'Skipetare': ['Albaner', 'Albanese'],
#  'Skipetarin': ['Albanerin', 'Albanesin'],
#  'Sorbe': ['Wende'],
#  'Wende': ['Sorbe'],
#  'Sorbin': ['Wendin'],
#  'Wendin': ['Sorbin'],
#  'Sorbisch': ['Wendisch'],
#  'Wendisch': ['Sorbisch'],
#  'sorbisch': ['wendisch'],
#  'wendisch': ['sorbisch'],
#  'platteland': ['land'],
#  'earth': ['soil'],
#  'pagus': ['vicus'],
#  'vicus': ['pagus'],
#  'Djamaal': ['Sondag'],
#  'Djalaal': ['Saterdag'],
#  'Fieldaal': ['Dinsdag'],
#  'Idaal': ['Woensdag'],
#  'Iestiedjlaal': ['Donderdag'],
#  'Iestieklaal': ['Vrydag'],
#  'дочка': ['доня'],
#  'доня': ['дочка'],
#  'жінка': ['дружина'],
#  'дружина': ['жінка'],
#  'rekenaar': ['kitsrekenaar', 'komper', 'blikbrein'],
#  'Noor': ['Noorweër'],
#  'Noorse': ['Noorweegse'],
#  'Norseman': ['Northman'],
#  'Northman': ['Norseman'],
#  'Nuwe Noors': ['Nieu-Noors', 'Nynorsk'],
#  'ordinatrum': ['instrumentum computatorium', 'computatrum'],
#  'computadora': ['ordenador', 'computador'],
#  'computador': ['ordenador', 'computadora'],
#  'ordenador': ['computadora', 'computador'],
#  'Computer': ['Rechner'],
#  'Rechner': ['Computer'],
#  'dator': ['datamaskin'],
#  'datamaskin': ['dator'],
#  'computer': ['počítač'],
#  'komputer': ['počítač'],
#  'Kashubian': ['Kashube',
#   'Kashub',
#   'Kassubian',
#   'Cassubian',
#   'Kasubian',
#   'Casubian'],
#  'Kashube': ['Kashubian', 'Kassubian', 'Kasubian', 'Cassubian', 'Casubian'],
#  'Kashub': ['Kashubian', 'Kassubian', 'Kasubian', 'Cassubian', 'Casubian'],
#  'Kaschube': ['Pomorane', 'Kassube'],
#  'Kassube': ['Kaschube', 'Pomorane'],
#  'Pomorane': ['Kaschube', 'Kassube'],
#  'kaschubisch': ['pomoranisch', 'kassubisch'],
#  'kassubisch': ['kaschubisch', 'pomoranisch'],
#  'pomoranisch': ['kaschubisch', 'kassubisch'],
#  'Kaschubisch': ['Pomoranisch', 'Kassubisch'],
#  'Kassubisch': ['Kaschubisch', 'Pomoranisch'],
#  'Pomoranisch': ['Kaschubisch', 'Kassubisch'],
#  'Kaschubin': ['Pomoranin', 'Kassubin'],
#  'Kassubin': ['Kaschubin', 'Pomoranin'],
#  'Pomoranin': ['Kaschubin', 'Kassubin'],
#  'September': ['Scheiding'],
#  'Oktober': ['Gilbhart', 'Weinmond'],
#  'Dezember': ['Julmond'],
#  'Juni': ['Brachet'],
#  'Juli': ['Heuert'],
#  'Juno': ['Brachet'],
#  'Brachet': ['Juni', 'Juno'],
#  'počítač': ['computer'],
#  'υπολογιστής': ['ηλεκτρονικός υπολογιστής', 'κομπιούτερ'],
#  'κομπιούτερ': ['ηλεκτρονικός υπολογιστής', 'υπολογιστής'],
#  'ὑπολογιστής': ['ἠλεκτρονικὸς ὑπολογιστής',
#   'Kategorie:Woorde in Grieks (Katharewoesa)|υπολογιστής'],
#  'ordinador': ['computadora'],
#  'tarakilishi': ['tarakishi', 'kompyuta'],
#  'ad': ['isim'],
#  'chłop': ['mąż', 'slëbnik'],
#  'sonde': ['peilstif'],
#  'peilstif': ['sonde'],
#  'karı': ['eş', 'zevce'],
#  'hereró': ['herero'],
#  'mario': ['ĉeremiso'],
#  'ĉeremiso': ['mario'],
#  'Tchérémisse': ['Mari'],
#  'Cheremis': ['Mari'],
#  'Cheremiss': ['Mari'],
#  'koca': ['eş', 'zevç'],
#  'er': ['erkek', 'nefer'],
#  'nefer': ['kimse', 'kişi', 'er'],
#  'kadın': ['bayan', 'hanım'],
#  'hanım': ['kadın', 'bayan'],
#  'bayan': ['hanım'],
#  'birinciteşrin': ['ekim', 'teşrinievvel', 'ilkteşrin'],
#  'ilkteşrin': ['ekim', 'teşrinievvel', 'birinciteşrin'],
#  'ikinciteşrin': ['kasım', 'teşrinisani', 'sonteşrin'],
#  'sonteşrin': ['kasım', 'teşrinisani', 'ikinciteşrin'],
#  'ikincikânun': ['ocak', 'kânunusani', 'sonkânun'],
#  'sonkânun': ['ocak', 'kânunusani', 'ikincikânun'],
#  'birincikânun': ['aralık', 'kânunuevvel', 'ilkkânun'],
#  'ilkkânun': ['aralık', 'kânunuevvel', 'birincikânun'],
#  'sene': ['yıl', 'sâl'],
#  'kerime': ['kız evlât', 'kız'],
#  'birader': ['kardeş', 'erkek kardeş'],
#  'erkek kardeş': ['kardeş', 'birader'],
#  'kız kardeş': ['kardeş', 'hemşire'],
#  'peder': ['baba'],
#  'anne': ['ana', 'valide'],
#  'valide': ['ana', 'anne'],
#  'isim': ['ad'],
#  'ruz': ['gün', 'yevm', 'gündüz'],
#  'yevm': ['gün', 'ruz', 'gündüz'],
#  'gece': ['leyl'],
#  'vallei': ['dal'],
#  'dal': ['vallei'],
#  'pem': ['jaj'],
#  'Noord-Opperduits': ['Opperfrankisch'],
#  'Wes-Opperduits': ['Alemannies', 'Alamannies'],
#  'Oos-Opperduits': ['Beiers', 'Beiers-Oostenryks'],
#  'Beiers-Oostenryks': ['Beiers', 'Oos-Opperduits'],
#  'Beiers': ['Beiers-Oostenryks', 'Oos-Opperduits'],
#  'Alemannies': ['Wes-Opperduits'],
#  'Alamannies': ['Wes-Opperduits'],
#  'Opperfrankies': ['Noord-Opperduits'],
#  'Lotarings': ['Lotarings-Frankies', 'Lorreins'],
#  'Lotharings': ['Lotarings-Frankies', 'Lorreins'],
#  'Lotarings-Frankies': ['Lotarings'],
#  'Lotharings-Frankies': ['Lotarings'],
#  '𐌉𐌈𐌛𐌖𐌔𐌖𐌕': ['𐌀𐌉𐌖𐌐'],
#  '𐌉𐌈𐌛𐌖𐌑𐌖𐌕': ['𐌀𐌉𐌖𐌐'],
#  'Volsinii': ['Volsinii Veteres', 'Volsinii Novi'],
#  'Volsinii Veteres': ['Volsinii'],
#  'Volsinii Novi': ['Volsinii'],
#  'volk': ['nasie', 'mens|mense', 'menigte', 'gepeupel'],
#  'nasie': ['volk'],
#  'urn': ['lykbus'],
#  'lykbus': ['urn'],
#  'endast': ['bara'],
#  'kun': ['bare'],
#  'bare': ['kun'],
#  'yalnız': ['sırf', 'sadece'],
#  'sadece': ['yalnız', 'sırf'],
#  'bok': ['bøk'],
#  'afríkaans': ['afríkanska'],
#  'marts': ['tordmåned'],
#  'augusti': ['skördemånad'],
#  'maart': ['lentemaand', 'windmaand'],
#  'mei': ['bloeimaand'],
#  'augustus': ['oogstmaand', 'hittemaand'],
#  'Vollek': ['Natioun'],
#  'bøk': ['bok'],
#  'roðarunni': ['kveði'],
#  'sennight': ['week'],
#  "se'nnight": ['week', 'Kategorie:Woorde in Engels|senight'],
#  'Jode-Duits': ['Jiddisj'],
#  'γαλλική': ['γαλλικὴ γλῶσσα'],
#  'ἀγγλική': ['ἀγγλικὴ γλῶσσα',
#   'Kategorie:Woorde in Grieks (Katharewoesa)|αγγλική'],
#  'ἀφρικανική': ['ἀφρικανικὴ γλῶσσα',
#   'ἀφρικάανς',
#   'ἀφρικανολλανδικὴ γλῶσσα',
#   'ἀφρικανολλανδική',
#   'Kategorie:Woorde in Grieks (Katharewoesa)|αφρικανική'],
#  'ἀφρικανολλανδική': ['ἀφρικανολλανδικὴ γλῶσσα',
#   'ἀφρικανικὴ γλῶσσα',
#   'ἀφρικανική',
#   'ἀφρικάανς',
#   'Kategorie:Woorde in Grieks (Katharewoesa)|αφρικανολλανδική'],
#  'ὁλλανδική': ['ὁλλανδικὴ γλῶσσα',
#   'Kategorie:Woorde in Grieks (Katharewoesa)|ολλανδική'],
#  'ἑλληνική': ['ἑλληνικὴ γλῶσσα',
#   'Kategorie:Woorde in Grieks (Katharewoesa)|ελληνική'],
#  'טאטע': ['פאטער|פֿאָטער'],
#  'פאטער': ['טאטע|טאַטע'],
#  'מאמע': ['מוטער'],
#  'מוטער': ['מאמע|מאַמע'],
#  'מענטש': ['פערזאן|פּערזאָן'],
#  'פערזאן': ['מענטש'],
#  'פארשוין': ['מענטש'],
#  'קירך': ['צערקװע'],
#  'ביורא': ['אפיס|אָפֿיס'],
#  'אפיס': ['ביורא|ביוראָ'],
#  'װײב': ['פרױ|פֿרױ'],
#  'דײטש': ['דײטשיש|דײַטשיש'],
#  'דײטשיש': ['דײטש|דײַטש'],
#  'פילקע': ['באל|באַל'],
#  'באל': ['פילקע|פּילקע'],
#  'פרױ': ['װײב|װײַב'],
#  'צערקװע': ['קירך'],
#  'yiddish': ['yidiche', 'judéo-allemand'],
#  'yidiche': ['yiddish', 'judéo-allemand'],
#  'judéo-allemand': ['yiddish', 'yidiche'],
#  'peuple': ['nation'],
#  'people': ['nation'],
#  'bureau': ['kantoor', 'schrijftafel'],
#  'kachoube': ['poméranien'],
#  'cachoube': ['poméranien'],
#  'bourg': ['ville|petite ville'],
#  'townlet': ['town|small town'],
#  'filet': ['rets'],
#  'rets': ['filet'],
#  'dygn': ['dag'],
#  'tagnokto': ['tago'],
#  'tago': ['tagnokto'],
#  'vallée': ['val'],
#  'val': ['meerval'],
#  'jour': ['journée'],
#  'journée': ['jour'],
#  'Frü': ['Wief'],
#  'Wief': ['Frü'],
#  'däm': ['daut'],
#  'den': ['denneboom'],
#  'des': ["'s"],
#  'selfstandige werkwoord': ['hoofwerkwoord'],
#  'hoofwerkwoord': ['selfstandige werkwoord'],
#  '-en': ['-a'],
#  '-n': ['-a'],
#  '-ne': ['-a'],
#  '-ene': ['-a'],
#  '-a': ['-i'],
#  '-i': ['-a'],
#  'echgenoet': ['man'],
#  'echgenoete': ['vrouw'],
#  'zöster': ['sjwester'],
#  'sjwester': ['zöster'],
#  'diksjenaer': ['waordebook'],
#  'waordebook': ['diksjenaer'],
#  'Pennsilvanië-Duits': ['Pennsilvanies'],
#  'Osmaans': ['Osmaanse Turks', 'Ottomaans'],
#  'Middelosmaans': ['Middelottomaans'],
#  'gade': ['echtgenote', 'vrouw'],
#  'pòmòrsczi jãzëk': ['kaszëbsczi jãzek', 'kaszëbizna'],
#  'małżonek': ['mąż'],
#  'døgn': ['dag'],
#  'døger': ['dag'],
#  'samdøgur': ['dagur'],
#  'dio': ['jorno'],
#  'jorno': ['dio'],
#  'astronomie': ['sterrenkunde'],
#  'pemjep': ['DungluQ'],
#  'DungluQ': ['pemjep'],
#  'bemoeial': ['bemoeisieke'],
#  'bemoeisieke': ['bemoeial'],
#  'hvězdářství': ['astronomie'],
#  'vat': ['neem'],
#  'супруга': ['жена'],
#  'мужчина': ['муж'],
#  'супруг': ['муж'],
#  'сопруга': ['жена'],
#  'manneskja': ['maður'],
#  'stjernelære': ['astronomi'],
#  'astronomi': ['gökbilim', 'ilmi heyet', 'felekiyat'],
#  'ilmi heyet': ['gökbilim', 'astronomi', 'felekiyat'],
#  'felekiyat': ['astroloji',
#   'ilmi nücum',
#   'gökbilim',
#   'astronomi',
#   'ilmi heyet'],
#  'Astronomie': ['Sternkunde', 'Himmelskunde'],
#  'Sternkunde': ['Himmelskunde', 'Astronomie'],
#  'Himmelskunde': ['Sternkunde', 'Astronomie'],
#  'sterrenkunde': ['astronomie'],
#  'ægtemand': ['mand', 'mage'],
#  'ektemann': ['mann'],
#  'Ehemann': ['Gatte', 'Gemahl', 'Mann'],
#  'Gatte': ['Ehemann', 'Gemahl', 'Mann'],
#  'maki': ['ektamaður', 'maður', 'ektakona', 'kona'],
#  'spouse': ['husband', 'wife'],
#  'mücerret': ['soyut', 'abstre'],
#  'Française': ['Franse'],
#  'reeds': ['al'],
#  'caisson': ['kofferdam', 'kisdam'],
#  'kofferdam': ['kisdam', 'caisson'],
#  'kisdam': ['kofferdam', 'caisson'],
#  'vloedvlakte': ['beemd', 'landouw'],
#  'hen': ['kip'],
#  'hoenders': ['hoenderen'],
#  'Nederlandia': ['Batavia', 'Hollandia'],
#  'Hollandia': ['Batavia', 'Nederlandia'],
#  'Batavia': ['Hollandia', 'Nederlandia'],
#  'duel': ['tweegevecht'],
#  'grand-maman': ['mémé'],
#  'pépé': ['papi', 'grand-papa'],
#  'grand-papa': ['pépé', 'papi'],
#  'dwaaltuin': ['doolhof'],
#  'お前': ['あなた', '手前', 'お宅', '君', 'あんた', '貴様'],
#  '若し': ['なら', 'ならば'],
#  'アフリカーンス語': ['アフリカーンス'],
#  'アフリカーンス': ['アフリカーンス語'],
#  '竜馬': ['龍馬'],
#  '竜王': ['龍王', 'Kategorie:Speletjies'],
#  '龍馬': ['竜馬', 'Kategorie:Speletjies'],
#  '龍王': ['竜王', 'Kategorie:Speletjies'],
#  '地球': ['世界', 'Kategorie:Planete'],
#  '私': ['俺', '我', 'あたし', '僕'],
#  '貴様': ['あなた', 'あんた', 'お宅', 'お前', '手前', '君'],
#  '済みません': ['有難う', 'どうも'],
#  '有難う': ['済みません', 'どうも'],
#  '酒': ['お酒'],
#  'vlieg in jou moer in': ['gaan na die duiwel', 'fokof', 'voertsek', 'skoert'],
#  'blits': ['weerlig', 'bliksem'],
#  '雷': ['雷鳴', '電光'],
#  'donderweer': ['onweer'],
#  'bliksem': ['moer', 'neuk', 'donner'],
#  '世界': ['地球'],
#  'なら': ['ならば', '若し'],
#  'hoenderkop': ['suip|gesuip',
#   'diep in die bottel kyk|het diep in die bottel gekyk',
#   'elmboog lig|het die elmboog gelig',
#   'tiermelk drink|het tiermelk gedrink',
#   'die skoot hoog deur hê|het die skoot hoog deur',
#   'sleeptong praat|praat sleeptong',
#   'ry druiwekar|het druiwekar gery',
#   'na die kelder ruik|ruik na die kelder',
#   'geolie|is geolie',
#   'hoog in die takke wees|is hoog in die takke',
#   'in die arms van Bacchus|is in die arms van Bacchus',
#   'twee rye spore loop|loop twee rye spore'],
#  'dronk': ['hoenderkop|hoenderkop wees',
#   'suip|gesuip wees',
#   'diep in die bottel kyk|diep in die bottel gekyk het',
#   'elmboog lig|die elmboog gelig het',
#   'tiermelk drink|tiermelk gedrink het',
#   'die skoot hoog deur hê',
#   'sleeptong praat',
#   'ry druiwekar|druiwekar gery het',
#   'na die kelder ruik',
#   'geolie|geolie wees',
#   'hoog in die takke|hoog in die takke wees',
#   'in die arms van Bacchus|in die arms van Bacchus wees',
#   'twee rye spore loop'],
#  'drink': ['suip'],
#  'tiermelk drink': ['drink', 'suip'],
#  'steel': ['lang vingers hê'],
#  'skaakmat': ['mat'],
#  '今日は': ['今晩は', 'お早う'],
#  'hijack': ['steal', 'privateer', 'commandeer', 'pirate', 'Kategorie:Gereg'],
#  'idioot': ['moroon', 'domkop'],
#  'na-aap': ['namaak'],
#  'asblik': ['vullisdrom'],
#  'advokadopeer': ['avokado'],
#  'hanger': ['halssnoer'],
#  'hoer': ['prostituut', 'ligtekooi'],
#  'prostituut': ['hoer', 'ligtekooi'],
#  'bordeel': ['hoerhuis'],
#  'atmosfeer': ['dampkring'],
#  'снять': ['убрать'],
#  'снимать': ['убирать'],
#  'взгляд': ['взор', 'мнение'],
#  'молитва': ['моление'],
#  'veldkool': ['bokkool', 'hotnotskool'],
#  'всюду': ['везде', 'повсеместно'],
#  'когда': ['в какое время'],
#  'сад': ['сквер'],
#  'хвост': ['репица', 'очередь'],
#  'сегодня': ['нынче'],
#  'слишком': ['чересчур', 'чрезмерно', 'излишне'],
#  'путь': ['дорога'],
#  'partykeer': ['partymaal', 'soms'],
#  'отчего': ['почему'],
#  'kameleon': ['trapsuutjie', 'verkleurmannetjie'],
#  'vlieënier': ['loods', 'piloot'],
#  'kordaat': ['dapper'],
#  'met': ['mee'],
#  'letter': ['karakter'],
#  'draaikolk': ['maalgat'],
#  'tydens': ['gedurende'],
#  'loop': ['beek', 'spruit'],
#  'plantkunde': ['botanie'],
#  'botanie': ['plantkunde'],
#  'chemie': ['skeikunde'],
#  'skeikunde': ['chemie'],
#  'swael': ['swawel'],
#  'swawel': ['swael'],
#  'Proto-Germaans': ['Germaans'],
#  'eierrond': ['eiervormig', 'ovaalvormig', 'ellipties', 'eirond'],
#  'fisika': ['natuurkunde'],
#  'veral': ['hoofsaaklik'],
#  'sowat': ['omtrent', 'ongeveer', 'nagenoeg'],
#  'miskien': ['dalk'],
#  'dalk': ['miskien'],
#  'deeltjie': ['partikel'],
#  'partikel': ['deeltjie'],
#  'heelal': ['kosmos', 'ruimte', 'universum'],
#  'universum': ['heelal'],
#  'kosmos': ['heelal', 'ruimte', 'universum'],
#  'verskeie': ['etlike'],
#  "'s": ['des'],
#  'etlike': ['verskeie'],
#  'dassie': ['das'],
#  'motwortel': ['akkewani'],
#  'akkewani': ['motwortel'],
#  'mofhartbees': ['Lichtenstein-hartbees'],
#  'varkslaai': ['snotwortel', 'varkwortel'],
#  'swartneusrooibok': ['swartgesigrooibok'],
#  'swartgesigrooibok': ['swartneusrooibok'],
#  'adverbium': ['bywoord'],
#  'boks': ['doos'],
#  'doos': ['boks'],
#  'adjektief': ['byvoeglike naamwoord'],
#  'maatkolf': ['volumetriese fles'],
#  'my': ['myne'],
#  'omdat': ['aangesien', 'want'],
#  'tronk': ['gevangenis', 'tjoekie'],
#  'gevangenis': ['tronk', 'tjoekie'],
#  'hei': ['heide'],
#  'lewe': ['leef'],
#  'onse': ["ons s'n"],
#  "ons s'n": ['onse'],
#  'dus': ['daarom', 'gevolglik'],
#  'surrogaat': ['plaasvervanger'],
#  'plaasvervanger': ['surrogaat'],
#  'bevolking': ['populasie', 'inwonertal'],
#  'populasie': ['bevolking', 'inwonertal'],
#  'inwonertal': ['bevolking', 'populasie'],
#  'sedert': ['sinds'],
#  'alsook': ['alsmede'],
#  'nou': ['tans', 'teenswoordig'],
#  'bywoordelike voornaamwoord': ['voornaamwoordelike bywoord'],
#  'voornaamwoordelike bywoord': ['bywoordelike voornaamwoord'],
#  'neem': ['vat'],
#  'grootskedebek': ['Amerikaanse peddie'],
#  'sommige': ['party'],
#  "Ge'ez": ['Ethiopies'],
#  'party': ['sommige'],
#  'Khmer': ['Kambodjaans'],
#  'boot': ['skip', 'skuit'],
#  'provinsie': ['previnsie'],
#  'tydperk': ['era', 'periode'],
#  'arsenopiriet': ['arseenpiriet'],
#  'arseenpiriet': ['arsenopiriet'],
#  'sfaleriet': ['blende', 'sinkblende'],
#  'mee': ['met'],
#  'daarom': ['dus', 'gevolglik'],
#  'verander': ['wysig'],
#  'wysig': ['verander'],
#  'hoewel': ['alhoewel', 'ofskoon'],
#  'alhoewel': ['hoewel', 'ofskoon'],
#  'ofskoon': ['alhoewel', 'hoewel'],
#  'tans': ['nou', 'teenswoordig'],
#  'teenswoordig': ['tans', 'nou'],
#  'soms': ['partykeer', 'partymaal'],
#  'kry': ['vind'],
#  'schot': ['zeeforel'],
#  'aanwesig': ['teenwoordig'],
#  'klemtoon': ['aksent', 'nadruk'],
#  'homogram': ['homograaf'],
#  'homograaf': ['homogram'],
#  'cerise': ['kersierooi'],
#  'chalkopiriet': ['koperpiriet'],
#  'koperpiriet': ['chalkopiriet'],
#  'hou': ['houd'],
#  'houd': ['hou'],
#  'hoofsaaklik': ['veral'],
#  'aangesien': ['want', 'omdat'],
#  'want': ['aangesien', 'omdat'],
#  'nuwemaan': ['donkermaan'],
#  'тобой': ['тобою'],
#  'тобою': ['тобой'],
#  'skouerblad': ['scapula'],
#  'gedurende': ['tydens'],
#  'wilddief': ['stroper'],
#  'geneesmiddel': ['medisyne', 'medikasie'],
#  'medisyne': ['geneesmiddel', 'medikasie'],
#  'medikasie': ['geneesmiddel', 'medisyne'],
#  'kamma': ['kammakastig', 'kamstig', 'kastig'],
#  'volumetriese fles': ['maatkolf'],
#  'onmiddellik': ['dadelik'],
#  'finansieel': ['geldelik'],
#  'dadelik': ['onmiddellik'],
#  'meteen': ['onmiddellijk', 'direct'],
#  'inligting': ['informasie'],
#  'informasie': ['inligting'],
#  'meteens': ['skielik'],
#  'skuurweerstand': ['skuurvastheid'],
#  'skuurvastheid': ['skuurweerstand'],
#  'optel': ['oplig'],
#  'oplig': ['optel'],
#  'e-boekleser': ['e-leser'],
#  'e-leser': ['e-boekleser'],
#  'syfer': ['sypel'],
#  'zambezirivierhaai': ['zambezihaai', 'stierhaai'],
#  'zambezihaai': ['zambezirivierhaai', 'stierhaai'],
#  'sypel': ['syfer'],
#  'skaaldier': ['krustasee'],
#  'krustasee': ['skaaldier'],
#  'min': ['minus'],
#  'toordokter': ['sangoma'],
#  'Asteeks': ['Nahuatl'],
#  'Nahuatl': ['Asteeks'],
#  'beide': ['albei'],
#  'albei': ['beide'],
#  'belowe': ['beloof'],
#  'beloof': ['belowe'],
#  'akkerboom': ['eikeboom'],
#  'eik': ['eikeboom', 'akkerboom'],
#  'eikeboom': ['eik', 'akkerboom'],
#  'trek': ['stoot'],
#  'kasteel': ['burg'],
#  'waarskynlik': ['seker'],
#  'byna': ['amper'],
#  'present': ['geskenk', 'kado'],
#  'geskenk': ['kado', 'present'],
#  'vind': ['kry'],
#  'uiteindelik': ['eindelik'],
#  'chirurg': ['snydokter'],
#  'dûkerke': ['earsfuttel'],
#  'earsfuttel': ['dûkerke'],
#  'eerbiedig': ['respekvol'],
#  'diarree': ['maagwerking', 'buikloop', 'skittery'],
#  'buikloop': ['maagwerking', 'diarree', 'skittery'],
#  'seker': ['waarskynlik'],
#  'ligtekooi': ['hoer', 'prostituut'],
#  'maagwerking': ['diarree', 'buikloop', 'skittery'],
#  'suide': ['suid'],
#  'noorde': ['noord'],
#  'ooste': ['oos'],
#  'weste': ['wes'],
#  'indien': ['as'],
#  'lyk': ['kadawer'],
#  'klere': ['kleding'],
#  'leem': ['leemgrond'],
#  'openbaar': ['publiek'],
#  'openbare': ['publieke'],
#  'stelsel': ['sisteem'],
#  'filosofie': ['wysbegeerte'],
#  'huidiglik': ['tans', 'nou', 'teenswoordig', 'deesdae'],
#  'paling': ['aal'],
#  'aal': ['aalt'],
#  'peetvader': ['peetpa'],
#  'sosiaal': ['maatskaplik'],
#  'sosiale': ['maatskaplike'],
#  'bomwerper': ['bomvliegtuig'],
#  'afskakel': ['deaktiveer'],
#  'aanskakel': ['aktiveer'],
#  'aktiveer': ['aanskakel'],
#  'deaktiveer': ['afskakel'],
#  'baie dankie': ['tramma kassie'],
#  'kos': ['voedsel'],
#  'pens': ['grootpens'],
#  'kaal': ['naak'],
#  'kaalgat': ['poedelnakend'],
#  'ruitjiespens': ['netpens'],
#  'netpens': ['ruitjiespens'],
#  'twaalfvingerige derm': ['duodenum'],
#  'duodenum': ['twaalfvingerige derm'],
#  'blindederm': ['appendiks'],
#  'dikderm': ['kolon'],
#  'kolon': ['dikderm'],
#  'voordat': ['voor'],
#  'slik': ['slib'],
#  'slib': ['slik'],
#  'opkom': ['opgaan'],
#  'voedsel': ['kos'],
#  'bangheid': ['vrees', 'angs', 'skrik'],
#  'dakpan': ['dakteël'],
#  'seisoen': ['jaargety'],
#  'jaargety': ['seisoen'],
#  'Ou Testament': ['Hebreeuse Bybel'],
#  'leer': ['leder'],
#  'kous': ['sokkie'],
#  'onderskei': ['differensieer'],
#  'kwal': ['jellievis', 'drilvis'],
#  'dief': ['boef'],
#  'skielik': ['meteens'],
#  'nooi': ['uitnooi'],
#  'uitnooi': ['nooi'],
#  'gratis': ['kosteloos'],
#  'oppervlakte': ['area'],
#  'kloof': ['ravyn'],
#  'ravyn': ['kloof'],
#  'leisel': ['teuel'],
#  'teuel': ['leisel', 'toom'],
#  'nar': ['hofnar', 'paljas', 'ar', 'arreslee'],
#  'laasgenoemde': ['laasgemelde'],
#  'laasgemelde': ['laasgenoemde'],
#  'eersgenoemde': ['eersgemelde'],
#  'eersgemelde': ['eersgenoemde'],
#  'elektrovalensie': ['ioonbinding'],
#  'beweeg': ['skuif'],
#  'eindelik': ['uiteindelik'],
#  'waterblommetjie': ['vleikos'],
#  'besoedeling': ['omgewingsbesoedeling'],
#  'platsak': ['boomskraap'],
#  'nu': ['nou'],
#  'naak': ['kaal'],
#  'dessert': ['nagereg'],
#  'huil': ['grens', 'ween', 'tjank'],
#  'юг': ['зюйд'],
#  'boomskraap': ['platsak'],
#  'зюйд': ['юг'],
#  'rolprent': ['film', 'fliek'],
#  'prent': ['illustrasie', 'beeld'],
#  'fliek': ['rolprent', 'film'],
#  'aalmoes': ['geskenk', 'bydrae'],
#  'maalgat': ['draaikolk'],
#  'mikologie': ['swamkunde'],
#  'swamkunde': ['mikologie'],
#  'tourbillon': ['maëlstrom'],
#  'warrelwind': ['dwarrelwind'],
#  'dwarrelwind': ['warrelwind'],
#  'orkaan': ['sikloon', 'tifoon'],
#  'leef': ['lewe'],
#  'adrenalien': ['epinefrien'],
#  'geleentheid': ['kans'],
#  'hulleself': ['hulself'],
#  'julleself': ['julself'],
#  'julself': ['julleself'],
#  'hulself': ['hulleself'],
#  'kleintongetjie': ['huig'],
#  'akteur': ['toneelspeler'],
#  'menstruasie': ['maandstonde'],
#  'maandstonde': ['menstruasie'],
#  'onteenseglik': ['onbetwisbaar', 'onweerlegbaar'],
#  'periode': ['tydperk'],
#  'fasie': ['aangesig', 'bakkies', 'gelaat', 'gevreet', 'tronie', 'fasiebord'],
#  'vormduur': ['vormleeftyd'],
#  'nogtans': ['nietemin'],
#  'nietemin': ['nogtans'],
#  ...}

# %% [markdown]
# Save the reuslt into file

# %%
out_file =
