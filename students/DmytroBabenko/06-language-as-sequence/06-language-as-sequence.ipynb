# %%
import pandas as pd
import random
from nltk.tokenize import sent_tokenize, word_tokenize

# %%
import string
import re
from typing import List
import json

# %%
def write_to_file(data: str, file: str):
    with open(file, 'w') as f:
        f.write(data)

# %%
def read_file(file):
    result = []
    with open(file) as f:
        lines = f.readlines()
        for line in lines:
            l = line.strip()
            if len(l) > 0:
                result.append(l)
    return result

# %%
def load_json(file):
    with open(file) as json_file:
        data = json.load(json_file)
    
    return data

# %% [markdown]
# # Data

# %%
data_file = "data/corpus.txt"

# %%
data = read_file(data_file)

# %% [markdown]
# ## Generate dataset

# %%
class DatasetGenerator:
    
    END_OF_SENT_PUNCT = ['.', '!', '?']
    
    
    def generate(self, data: List[str]):
        result = []
        for data_line in data:
            result += self.generate_for_text(data_line)
        return result

    def generate_for_text(self, text: str):
        sentences = sent_tokenize(text)

        size = len(sentences)
        start = 0
        result = []
        i = 0
        while i < size:
            num_of_sents = self.get_random_num_of_sentences()
            end = i + num_of_sents if i + num_of_sents < len(sentences) else size

            data = self.__generate_data_for_sentences(sentences[i:end])
            i = end

            result.append(data)

        return result

    def __generate_data_for_sentences(self, sentences: List[str]):

        result = []
        sentences_size = len(sentences)
        for i in range(0, sentences_size):

            sent_data = []
            tokens = word_tokenize(sentences[i])
            tokens_size = len(tokens) 
            should_set_end_word = False
            for j in range(tokens_size- 1, -1, -1):
                token = tokens[j]
                
                if token in self.END_OF_SENT_PUNCT:
                    if j == tokens_size - 1 and i < sentences_size - 1:
                        should_set_end_word = True
                    continue

                word = self.__randomly_lowercase_word(token, word_idx=j, sent_idx=i)
                
                if should_set_end_word:
                    sent_data.insert(0, [word, True])
                    should_set_end_word = False
                else:
                    sent_data.insert(0, [word, False])

            result += sent_data

        return result

    def __randomly_lowercase_word(self, word: str, word_idx: int, sent_idx: int):
        if sent_idx == 0 or word_idx > 0:
            return word

        should_be_lower = random.choice([True, False])
        if should_be_lower:
            return word.lower()

        return word

    def __is_punctuation(self, token: str):
        if token in string.punctuation:
            return True
        return False

    def __is_end_word_in_sent(self, word: str, word_idx: int, num_token_in_sents: int):
        if self.word_pattern.match(word) is None:
            return False

        if word_idx == num_token_in_sents - 1:
            return True

    def get_random_num_of_sentences(self):
        num = random.choices([1, 2, 3, 4], weights=[1, 12, 4, 3], k=1)[0]
        return num

# %%
dataset_generator = DatasetGenerator()

# %%
text = "Suicide won't oure shyness problems.  [Headline over Beth Winship's teen-advice column, Morning Union , Springfield, (Massachusetts), .  Submitted by .]"

# %%
dataset_generator.generate_for_text("Suicide won't oure shyness problems.  [Headline over Beth Winship's teen-advice column, Morning Union , Springfield, (Massachusetts), .  Submitted by .]")
# Out:
# [[['Suicide', False],
#   ['wo', False],
#   ["n't", False],
#   ['oure', False],
#   ['shyness', False],
#   ['problems', True],
#   ['[', False],
#   ['Headline', False],
#   ['over', False],
#   ['Beth', False],
#   ['Winship', False],
#   ["'s", False],
#   ['teen-advice', False],
#   ['column', False],
#   [',', False],
#   ['Morning', False],
#   ['Union', False],
#   [',', False],
#   ['Springfield', False],
#   [',', False],
#   ['(', False],
#   ['Massachusetts', False],
#   [')', False],
#   [',', True],
#   ['submitted', False],
#   ['by', False],
#   [']', False]]]

# %%
dataset = dataset_generator.generate(data)

# %% [markdown]
# Save dataet to json file

# %%
dataset_file = "data/dataset.json"
write_to_file(data=json.dumps(dataset), file=dataset_file)

# %% [markdown]
# ## N-Gram

# %%
def read_n_gram_file(ngram_file):
    result = dict()
    lines = read_file(ngram_file)
    for line in lines:
        line_split = line.split('\t')
        key = ' '.join(line_split[1:])
        result[key] = line_split[0]
        
    return result

# %% [markdown]
# Here, we use ngrams downloaded from here: https://www.ngrams.info/download_coca.asp

# %%
five_gram_dict = read_n_gram_file("data/w5.txt")

# %%
five_gram_dict
# Out:
# {'a babe in the woods': '16',
#  'a baby at her breast': '6',
#  'a baby brother or sister': '9',
#  'a baby crying in the': '6',
#  'a baby girl was born': '6',
#  'a baby in a stroller': '8',
#  'a baby in her arms': '28',
#  'a baby in his arms': '6',
#  'a baby in the house': '10',
#  'a baby into the world': '12',
#  'a baby of her own': '12',
#  'a baby on her hip': '11',
#  'a baby on the way': '41',
#  'a baby out of wedlock': '16',
#  'a bachelor of arts degree': '16',
#  'a Bachelor of Arts degree': '9',
#  'a bachelor of fine arts': '9',
#  'a bachelor of science degree': '27',
#  'a bachelor of science in': '6',
#  'a back corner of the': '6',
#  'a back room of the': '8',
#  'a back seat to a': '7',
#  'a back seat to other': '7',
#  'a back seat to the': '66',
#  'a background check on him': '7',
#  'a background report on the': '6',
#  'a backlog of more than': '11',
#  'a backup plan in case': '7',
#  'a bad call from the': '6',
#  'a bad case of indigestion': '6',
#  'a bad case of the': '43',
#  'a bad day at the': '16',
#  'a bad day at work': '14',
#  'a bad day for the': '13',
#  'a bad day on the': '8',
#  'a bad deal for the': '10',
#  'a bad experience with a': '14',
#  'a bad feeling about it': '7',
#  'a bad feeling about the': '6',
#  'a bad feeling about this': '26',
#  'a bad guy after all': '6',
#  'a bad idea after all': '9',
#  'a bad idea because it': '8',
#  'a bad idea for the': '12',
#  'a bad idea to do': '6',
#  'a bad idea to go': '7',
#  'a bad idea to have': '8',
#  'a bad idea whose time': '8',
#  'a bad influence on the': '7',
#  'a bad name in the': '6',
#  'a bad part of town': '14',
#  'a bad place to be': '22',
#  'a bad place to start': '15',
#  'a bad reaction to the': '7',
#  'a bad seat in the': '6',
#  'a bad sign for the': '9',
#  'a bad situation even worse': '6',
#  'a bad taste in his': '11',
#  'a bad taste in my': '14',
#  'a bad taste in the': '12',
#  'a bad taste in their': '6',
#  'a bad taste in your': '13',
#  'a bad thing after all': '8',
#  'a bad thing at all': '8',
#  'a bad thing for a': '9',
#  'a bad thing for the': '14',
#  'a bad thing if you': '7',
#  'a bad thing to be': '12',
#  'a bad thing to do': '31',
#  'a bad thing to have': '17',
#  'a bad thing to say': '9',
#  'a bad time for me': '6',
#  'a bad time for the': '6',
#  'a bad time of it': '10',
#  'a bad time to be': '12',
#  'a bad way to die': '6',
#  'a bad way to go': '13',
#  'a bad way to live': '7',
#  'a bad way to spend': '7',
#  'a bad way to start': '15',
#  'a bad week for the': '6',
#  'a bad word to say': '10',
#  'a bad year for the': '6',
#  'a badge and a gun': '9',
#  'a badge of honor and': '8',
#  'a badge of honor for': '10',
#  'a badge of honor to': '12',
#  'a bag of chips and': '8',
#  'a bag of frozen vegetables': '7',
#  'a bag of ice on': '7',
#  'a bag of potato chips': '45',
#  'a bag over her head': '9',
#  'a bag over his head': '21',
#  'a bag over your head': '8',
#  'a bagel with cream cheese': '7',
#  'a baking pan and bake': '9',
#  'a baking sheet and bake': '29',
#  'a baking sheet and keep': '6',
#  'a baking sheet and place': '9',
#  'a baking sheet and roast': '8',
#  'a baking sheet and set': '7',
#  'a baking sheet and toast': '8',
#  'a baking sheet coated with': '6',
#  'a baking sheet in a': '12',
#  'a baking sheet lined with': '20',
#  'a baking sheet with a': '6',
#  'a baking sheet with cooking': '7',
#  'a baking sheet with parchment': '35',
#  'a baking stone in the': '10',
#  'a balance between the need': '7',
#  'a balance between the two': '13',
#  'a balance between these two': '6',
#  'a balance between those two': '6',
#  'a balance between work and': '10',
#  'a balance of power between': '14',
#  'a balance of power in': '27',
#  'a balance of power that': '13',
#  'a balance to be struck': '6',
#  'a balanced budget amendment and': '6',
#  'a balanced budget amendment to': '32',
#  'a balanced budget and a': '7',
#  'a balanced budget and the': '6',
#  'a balanced budget by the': '12',
#  'a balanced budget for the': '7',
#  'a balanced budget in seven': '24',
#  'a balanced budget in the': '13',
#  'a balanced-budget amendment to the': '9',
#  'a ball and tossed it': '6',
#  'a ball back and forth': '13',
#  'a ball in the air': '7',
#  'a ball or a strike': '7',
#  'a ball out of the': '8',
#  'a ball with a stick': '6',
#  'a ballistic missile defense system': '8',
#  'a ballot initiative that would': '12',
#  'a ballot measure that would': '7',
#  'a ban on assault weapons': '26',
#  'a ban on gay marriage': '7',
#  'a ban on human cloning': '8',
#  'a ban on late-term abortions': '11',
#  'a ban on partial-birth abortion': '7',
#  'a ban on same-sex marriage': '7',
#  'a ban on smoking in': '8',
#  'a ban on soft money': '12',
#  'a ban on the export': '6',
#  'a ban on the importation': '6',
#  'a ban on the sale': '12',
#  'a ban on the use': '15',
#  'a band saw to cut': '7',
#  'a Band-Aid on a gaping': '7',
#  'a bang but a whimper': '6',
#  'a bank account in the': '7',
#  'a banner year for the': '9',
#  'a bar across the street': '7',
#  'a bar of soap and': '9',
#  'a bar of soap into': '6',
#  'a barbecue grill over a': '22',
#  'a barbed wire fence and': '6',
#  'a barbell with an overhand': '12',
#  'a bargain compared to the': '6',
#  'a bargain with the devil': '8',
#  'a barrage of criticism from': '11',
#  'a barrage of phone calls': '8',
#  'a barrage of questions about': '11',
#  'a barrage of questions from': '7',
#  'a barrage of six home': '6',
#  'a barrel for the first': '12',
#  'a barrel in New York': '7',
#  'a barrel of crude oil': '10',
#  'a barrel on the ICE': '10',
#  'a barrel on the New': '37',
#  'a base from which to': '22',
#  'a base of operations for': '12',
#  'a base of support among': '7',
#  'a baseball bat to the': '6',
#  'a baseball cap and a': '8',
#  'a baseball cap with a': '9',
#  'a baseline from which to': '10',
#  'a bases-loaded jam in the': '6',
#  'a basic knowledge of the': '7',
#  'a basic part of the': '17',
#  'a basic understanding of how': '13',
#  'a basic understanding of the': '25',
#  'a basic understanding of what': '8',
#  'a basin of warm water': '9',
#  'a basis for a new': '8',
#  'a basis for decision making': '8',
#  'a basis for the development': '7',
#  'a basis from which to': '7',
#  'a basis on which to': '10',
#  'a bat out of hell': '27',
#  'a bath and go to': '7',
#  'a battalion commander in the': '6',
#  'a battery of psychological tests': '9',
#  'a battery of tests to': '7',
#  'a battle between good and': '12',
#  'a battle for control of': '17',
#  'a battle for the soul': '13',
#  'a battle of the bands': '16',
#  'a battle of the sexes': '15',
#  'a beacon of hope and': '8',
#  'a beacon of hope for': '11',
#  'a beam of light to': '9',
#  'a bear of a man': '22',
#  'a bearded man in a': '8',
#  'a bearded man with a': '6',
#  'A beat as she holds': '6',
#  'a beating in the press': '7',
#  'a beautiful day for a': '11',
#  'a beautiful day here in': '6',
#  'a beautiful day in the': '11',
#  'a beautiful part of the': '16',
#  'a beautiful piece of work': '7',
#  'a beautiful place to live': '7',
#  'a beautiful thing to see': '11',
#  'a beautiful view of the': '23',
#  'a beautiful woman in a': '10',
#  'a beautiful woman in her': '9',
#  'a beautiful woman with a': '7',
#  'a beautiful work of art': '6',
#  'a beautiful young woman and': '9',
#  'a beautiful young woman named': '8',
#  'a beautiful young woman who': '14',
#  'a beautiful young woman with': '7',
#  'a bed and breakfast in': '8',
#  'a bed for the night': '12',
#  'a bed in a room': '9',
#  'a bed in the back': '6',
#  'a bed of hot coals': '11',
#  'a bed of pine needles': '10',
#  'a bed to a chair': '6',
#  'a beeline for the door': '6',
#  'a beer and a cigarette': '6',
#  'a beer at the bar': '9',
#  'a beer from the fridge': '11',
#  'a beer in his hand': '18',
#  'a beer in one hand': '11',
#  'a beer out of the': '16',
#  'a Beeson Physician Faculty Scholar': '17',
#  'a before and an after': '8',
#  'a beginning and a middle': '7',
#  'a beginning and an end': '32',
#  'a beginning endless forms most': '10',
#  'a behind the scenes look': '7',
#  'a behind-the-scenes look at how': '6',
#  'a behind-the-scenes look at the': '20',
#  'a behind-the-scenes tour of the': '8',
#  'a being that has never': '8',
#  'a belief in the existence': '8',
#  'a belief in the importance': '10',
#  'a belief in the power': '7',
#  'a belief on the part': '6',
#  'a belief that there is': '6',
#  'a believer in the power': '7',
#  'a believer out of me': '7',
#  'a bench and watched the': '6',
#  'a bench in a park': '6',
#  'a bench in front of': '20',
#  'a bench in the park': '8',
#  'a bench in the shade': '8',
#  'a bench in the sun': '6',
#  'a bench with a view': '6',
#  'a bench with your feet': '6',
#  'a bend in the river': '22',
#  'a bend in the road': '31',
#  'a bend in the trail': '14',
#  'a beneficial effect on the': '7',
#  'a berth in the NCAA': '6',
#  'a Best of Show gold': '10',
#  'a best supporting actor Oscar': '9',
#  'a best supporting actress Oscar': '7',
#  'a bet on the future': '8',
#  'a better actor than I': '6',
#  'a better appreciation of the': '10',
#  'a better appreciation of what': '6',
#  'A better approach is to': '7',
#  'A better approach would be': '7',
#  'a better bet than the': '6',
#  'a better chance for success': '6',
#  'a better chance in the': '13',
#  'a better chance of achieving': '7',
#  'a better chance of beating': '6',
#  'a better chance of becoming': '7',
#  'a better chance of being': '35',
#  'a better chance of finding': '12',
#  'a better chance of getting': '52',
#  'a better chance of keeping': '7',
#  'a better chance of making': '13',
#  'a better chance of not': '6',
#  'a better chance of reaching': '6',
#  'a better chance of seeing': '8',
#  'a better chance of succeeding': '12',
#  'a better chance of success': '16',
#  'a better chance of survival': '23',
#  'a better chance of surviving': '24',
#  'a better chance of winning': '38',
#  'a better chance than the': '7',
#  'a better chance to get': '11',
#  'a better chance to make': '6',
#  'a better chance to win': '15',
#  'a better chance with the': '6',
#  'a better choice than the': '8',
#  'a better class of people': '7',
#  'a better conclusion than a': '17',
#  'a better deal for the': '12',
#  'a better deal if you': '7',
#  'a better deal than a': '6',
#  'a better deal than the': '7',
#  'a better description of the': '9',
#  'a better example of the': '6',
#  'a better explanation for the': '7',
#  'a better feel for the': '22',
#  'a better feel for what': '6',
#  'a better fit to the': '6',
#  'a better frame of mind': '18',
#  'a better future for all': '6',
#  'a better future for our': '12',
#  'a better future for the': '10',
#  'a better future for their': '8',
#  'a better future for themselves': '7',
#  'a better grasp of the': '19',
#  'a better grip on the': '19',
#  'a better handle on how': '7',
#  'a better handle on it': '7',
#  'a better handle on the': '21',
#  'a Better Homes and Gardens': '7',
#  'A better idea is to': '7',
#  'a better idea of how': '32',
#  'a better idea of the': '28',
#  'a better idea of what': '67',
#  'a better idea of where': '13',
#  'a better idea than the': '6',
#  'a better job in the': '25',
#  'a better job in this': '6',
#  'a better job of addressing': '6',
#  'a better job of communicating': '11',
#  'a better job of controlling': '7',
#  'a better job of educating': '15',
#  'a better job of enforcing': '7',
#  'a better job of explaining': '19',
#  'a better job of getting': '15',
#  'a better job of handling': '7',
#  'a better job of it': '22',
#  'a better job of keeping': '15',
#  'a better job of making': '17',
#  'a better job of managing': '8',
#  'a better job of preparing': '11',
#  'a better job of protecting': '22',
#  'a better job of providing': '6',
#  'a better job of taking': '7',
#  'a better job of teaching': '15',
#  'a better job of that': '8',
#  'a better job on the': '10',
#  'a better job than most': '8',
#  'a better job than that': '6',
#  'a better job than the': '25',
#  'a better job than they': '10',
#  'a better job than we': '7',
#  'a better job than what': '6',
#  'a better job with the': '8',
#  'a better life and a': '6',
#  'a better life for all': '18',
#  'a better life for her': '8',
#  'a better life for herself': '9',
#  'a better life for my': '6',
#  'a better life for myself': '7',
#  'a better life for our': '7',
#  'a better life for the': '13',
#  'a better life for their': '20',
#  'a better life for themselves': '21',
#  'a better life in a': '7',
#  'a better life in America': '7',
#  'a better life in the': '17',
#  'a better life than I': '6',
#  'a better life than the': '7',
#  'a better life than they': '9',
#  'a better look at a': '6',
#  'a better look at her': '15',
#  'a better look at him': '20',
#  'a better look at his': '11',
#  'a better look at it': '20',
#  'a better look at the': '67',
#  'a better look at them': '6',
#  'a better look at what': '8',
#  'a better man than I': '14',
#  'a better person because of': '7',
#  'a better person for it': '9',
#  'a better person than I': '10',
#  'a better picture of the': '15',
#  'a better picture of what': '13',
#  'a better place because of': '6',
#  'a better place for a': '7',
#  'a better place for all': '8',
#  'a better place for us': '6',
#  'a better place in which': '12',
#  'a better place than this': '6',
#  'a better place to be': '17',
#  'a better place to live': '63',
#  'a better place to work': '8',
#  'a better position than the': '7',
#  'a better position to decide': '6',
#  'a better position to make': '7',
#  'a better position to understand': '7',
#  'a better quality of life': '80',
#  'a better rate of return': '10',
#  'a better record than the': '7',
#  'a better relationship between the': '9',
#  'a better relationship with the': '16',
#  'a better sense of how': '30',
#  'a better sense of humor': '8',
#  'a better sense of the': '37',
#  'a better sense of what': '29',
#  'a better sense of whether': '6',
#  'A better solution would be': '7',
#  'a better standard of living': '30',
#  'a better team than we': '10',
#  'a better than even chance': '8',
#  'a better time for the': '10',
#  'a better time of it': '9',
#  'a better time to be': '13',
#  'a better track record than': '6',
#  'a better understanding about the': '6',
#  'a better understanding of both': '8',
#  'a better understanding of each': '6',
#  'a better understanding of his': '9',
#  'a better understanding of how': '95',
#  'a better understanding of one': '6',
#  'a better understanding of our': '12',
#  'a better understanding of the': '427',
#  'A better understanding of the': '22',
#  'a better understanding of their': '29',
#  'a better understanding of these': '12',
#  'a better understanding of this': '20',
#  'a better understanding of what': '78',
#  'a better understanding of where': '6',
#  'a better understanding of why': '13',
#  'a better understanding of your': '7',
#  'a better view of the': '82',
#  'a better way forward for': '6',
#  'a better way of doing': '16',
#  'a better way of life': '35',
#  'a better way to be': '6',
#  'a better way to deal': '12',
#  'a better way to do': '53',
#  'a better way to get': '21',
#  'a better way to go': '25',
#  'a better way to handle': '13',
#  'a better way to keep': '11',
#  'a better way to live': '7',
#  'a better way to make': '20',
#  'a better way to manage': '6',
#  'a better way to put': '19',
#  'a better way to say': '9',
#  'a better way to spend': '11',
#  'a better word for it': '7',
#  'a better world for our': '6',
#  'a bias in favor of': '20',
#  'a bicycle built for two': '7',
#  'A bicycle was stolen from': '9',
#  'a bid for the presidency': '9',
#  'a bid to become the': '9',
#  'a bid to buy the': '8',
#  'a big advantage in the': '8',
#  'a big believer in the': '11',
#  'a big bite of the': '6',
#  'a big bite out of': '33',
#  'a big blow to the': '6',
#  'a big boost for the': '7',
#  'a big boost to the': '6',
#  'a big brass key to': '7',
#  'a big break in the': '8',
#  'a big change for the': '6',
#  'a big change from the': '15',
#  'a big change in the': '17',
#  'a big chunk of change': '11',
#  'a big chunk of his': '9',
#  'a big chunk of it': '10',
#  'a big chunk of its': '8',
#  'a big chunk of money': '14',
#  'a big chunk of my': '7',
#  'a big chunk of that': '12',
#  'a big chunk of the': '69',
#  'A big chunk of the': '6',
#  'a big chunk of their': '8',
#  'a big chunk of your': '6',
#  'a big chunk out of': '19',
#  'a big contributor to the': '9',
#  'a big day for the': '9',
#  'a big day for you': '6',
#  'a big day in the': '6',
#  'a big deal about it': '41',
#  'a big deal about that': '6',
#  'a big deal about the': '22',
#  'a big deal about this': '10',
#  'a big deal and it': '6',
#  'a big deal at the': '9',
#  'a big deal because it': '7',
#  'a big deal for a': '10',
#  'a big deal for me': '15',
#  'a big deal for the': '13',
#  'a big deal for us': '7',
#  'a big deal for you': '8',
#  'a big deal in a': '7',
#  'a big deal in our': '6',
#  'a big deal in the': '24',
#  'a big deal of it': '47',
#  'a big deal of the': '9',
#  'a big deal out of': '179',
#  'a big deal that he': '7',
#  'a big deal to be': '6',
#  'a big deal to have': '7',
#  'a big deal to him': '10',
#  'a big deal to me': '15',
#  'a big deal to the': '7',
#  'a big deal to you': '8',
#  'a big debate about whether': '6',
#  'a big debate in the': '7',
#  'a big decision to make': '7',
#  'a big dent in the': '13',
#  'a big difference between a': '27',
#  'a big difference between being': '11',
#  'a big difference between having': '6',
#  'a big difference between that': '7',
#  'a big difference between the': '38',
#  'a big difference between what': '10',
#  'a big difference if you': '7',
#  'a big difference in a': '6',
#  'a big difference in his': '7',
#  'a big difference in how': '25',
#  'a big difference in my': '12',
#  'a big difference in our': '7',
#  'a big difference in terms': '7',
#  'a big difference in the': '58',
#  'a big difference in their': '11',
#  'a big difference in this': '9',
#  'a big difference in what': '12',
#  'a big difference in your': '9',
#  'a big difference when you': '8',
#  'a big drop in the': '6',
#  'a big effect on the': '8',
#  'a big factor in the': '24',
#  'a big fan of hers': '7',
#  'a big fan of his': '21',
#  'a big fan of mine': '7',
#  'a big fan of the': '80',
#  'a big fan of these': '6',
#  'a big fan of this': '10',
#  'a big fan of your': '12',
#  'a big fan of yours': '35',
#  'a big fish in a': '22',
#  'a big fuss about it': '10',
#  'a big gap between the': '8',
#  'a big glass of milk': '6',
#  'a big grin on his': '19',
#  'a big group of people': '7',
#  'a big guy with a': '14',
#  'a big heart and a': '7',
#  'a big help to me': '8',
#  'a big hit at the': '7',
#  'a big hit from the': '6',
#  'a big hit in the': '13',
#  'a big hit on the': '12',
#  'a big hit with the': '19',
#  'a big hole in it': '8',
#  'a big hole in my': '13',
#  'a big hole in the': '56',
#  'a big house and a': '9',
#  'a big house in the': '10',
#  'a big house with a': '8',
#  'a big hug and a': '14',
#  'a big hug and kiss': '6',
#  'a big impact in the': '6',
#  'a big impact on how': '11',
#  'a big impact on me': '8',
#  'a big impact on our': '11',
#  'a big impact on the': '44',
#  'a big impact on your': '10',
#  'a big impression on me': '11',
#  'a big impression on the': '6',
#  'a big improvement on the': '7',
#  'a big improvement over the': '17',
#  'a big increase in the': '15',
#  'a big influence on me': '7',
#  'a big influence on the': '8',
#  'a big issue for a': '6',
#  'a big issue for me': '6',
#  'a big issue for the': '14',
#  'a big issue in the': '27',
#  'a big issue in this': '10',
#  'a big issue of it': '7',
#  'a big issue out of': '9',
#  'a big job ahead of': '9',
#  'a big job to do': '11',
#  'a big jump in the': '9',
#  'a big kick out of': '46',
#  'a big kiss on the': '6',
#  'a big laugh out of': '7',
#  'a big leap of faith': '11',
#  'a big loss for the': '8',
#  'a big man and he': '7',
#  'a big man in a': '16',
#  'a big man in his': '7',
#  'a big man in the': '6',
#  'a big man on campus': '7',
#  'a big man with a': '34',
#  'a big moment for him': '6',
#  'a big one for me': '8',
#  'a big one in the': '8',
#  'a big pain in the': '7',
#  'a big part in that': '8',
#  'a big part in the': '24',
#  'a big part in this': '8',
#  'a big part of a': '12',
#  'a big part of her': '20',
#  'a big part of his': '46',
#  'a big part of how': '11',
#  'a big part of it': '119',
#  'A big part of it': '6',
#  'a big part of its': '9',
#  'a big part of life': '10',
#  'a big part of me': '12',
#  'a big part of my': '66',
#  'a big part of our': '58',
#  'a big part of that': '64',
#  'A big part of that': '13',
#  'a big part of the': '318',
#  'A big part of the': '28',
#  'a big part of their': '24',
#  'a big part of this': '44',
#  'a big part of what': '52',
#  'a big part of who': '6',
#  'a big part of why': '18',
#  'a big part of your': '29',
#  'a big party for her': '6',
#  'a big percentage of the': '6',
#  'a big piece of it': '6',
#  'a big piece of the': '28',
#  'a big player in the': '18',
#  'a big player in this': '6',
#  'a big plus for the': '6',
#  'a big pot of money': '7',
#  'a big price to pay': '8',
#  'a big problem for a': '7',
#  'a big problem for him': '6',
#  'a big problem for me': '8',
#  'a big problem for the': '27',
#  'a big problem for them': '7',
#  'a big problem for us': '6',
#  'a big problem in the': '17',
#  'a big problem in this': '10',
#  'a big problem with that': '9',
#  'a big problem with the': '10',
#  'a big problem with this': '6',
#  'a big production out of': '6',
#  'a big question mark in': '6',
#  'a big reason for the': '13',
#  'a big reason why the': '12',
#  'a big role in determining': '7',
#  'a big role in how': '8',
#  'a big role in that': '8',
#  'a big role in the': '47',
#  'a big role in this': '8',
#  'a big room with a': '8',
#  'a big round of applause': '30',
#  'a big say in the': '6',
#  'a big selling point for': '6',
#  'a big share of the': '9',
#  'a big shot in the': '7',
#  'a big sigh of relief': '28',
#  'a big sign on the': '8',
#  'a big sign that says': '6',
#  'a big smile and a': '13',
#  'a big smile on her': '23',
#  'a big smile on his': '54',
#  'a big smile on my': '13',
#  'a big smile on your': '6',
#  'a big splash in the': '8',
#  'a big stake in the': '14',
#  'a big step for me': '8',
#  'a big step for the': '6',
#  'a big step forward with': '6',
#  'a big step in that': '10',
#  'a big step in the': '20',
#  'a big step up from': '14',
#  'a big story in the': '7',
#  'a big supporter of the': '18',
#  'a big table in the': '7',
#  'a big thank you to': '13',
#  'a big thing for me': '10',
#  'a big thing for them': '7',
#  'a big thing in my': '6',
#  'a big thing in the': '10',
#  'a big thing of it': '6',
#  'a big thing out of': '17',
#  'a big victory for the': '13',
#  'a big wad of cash': '6',
#  'a big waste of time': '19',
#  'a big way in the': '14',
#  'a big win for the': '17',
#  'a big win for us': '6',
#  'a big world out there': '15',
#  'a bigger bite out of': '6',
#  'a bigger deal than it': '9',
#  'a bigger fool than I': '6',
#  'a bigger impact on the': '9',
#  'a bigger part of the': '19',
#  'a bigger piece of the': '24',
#  'a bigger problem than the': '8',
#  'a bigger role for the': '7',
#  'a bigger role in the': '10',
#  'a bigger share of the': '40',
#  'a bigger slice of the': '9',
#  'a bigger story than the': '6',
#  'a bigger threat to the': '9',
#  'a bill in Congress that': '9',
#  'a bill in Congress to': '11',
#  'a bill in the House': '11',
#  'a bill in the Senate': '12',
#  'a bill in the state': '7',
#  'a bill introduced in the': '8',
#  'a bill making it a': '6',
#  'a bill of rights for': '14',
#  'a Bill of Rights to': '7',
#  'a bill of rights to': '6',
#  'a Bill of Rights was': '6',
#  'a bill on the floor': '7',
#  'a bill out of the': '7',
#  'a bill passed by Congress': '7',
#  'a bill passed by the': '15',
#  "a bill that does n't": '15',
#  'a bill that does not': '8',
#  'a bill that the president': '6',
#  'a bill that will be': '7',
#  'a bill that will help': '7',
#  'a bill that would add': '9',
#  'a bill that would allow': '45',
#  'a bill that would ban': '19',
#  'a bill that would bar': '6',
#  'a bill that would be': '6',
#  'a bill that would create': '9',
#  'a bill that would do': '6',
#  'a bill that would establish': '6',
#  'a bill that would extend': '7',
#  'a bill that would force': '6',
#  'a bill that would give': '22',
#  'a bill that would have': '95',
#  'a bill that would impose': '9',
#  'a bill that would make': '31',
#  'a bill that would permit': '8',
#  'a bill that would prohibit': '14',
#  'a bill that would provide': '8',
#  'a bill that would raise': '8',
#  'a bill that would require': '54',
#  'a bill that would take': '6',
#  'a bill to create a': '16',
#  'a bill to the floor': '18',
#  'a bill to the president': '6',
#  'a bill was introduced in': '6',
#  'a billion and a half': '42',
#  'a billion dollars a day': '19',
#  'a billion dollars a week': '7',
#  'a billion dollars a year': '77',
#  'a billion dollars for the': '9',
#  'a billion dollars from the': '6',
#  'a billion dollars in sales': '7',
#  'a billion dollars in the': '15',
#  'a billion dollars out of': '6',
#  'a billion dollars over the': '7',
#  'a billion dollars worth of': '21',
#  'a billion people around the': '10',
#  'a billion years after the': '15',
#  'a billion years or so': '8',
#  'a billionth of a meter': '10',
#  'a billionth of a second': '11',
#  'a biological explanation for the': '6',
#  'a biological or chemical attack': '8',
#  'a biologist with the U.S.': '7',
#  'a biology professor at the': '13',
#  'a bipartisan group of congressional': '6',
#  'a bipartisan group of senators': '11',
#  'a bird in a cage': '9',
#  'a bird in the hand': '11',
#  'a bird with a broken': '8',
#  "a bird's-eye view of the": '36',
#  'a birdie putt on the': '8',
#  'a birthday party for her': '11',
#  'a birthday party for him': '11',
#  'a birthday party for one': '8',
#  'a bit ahead of the': '6',
#  'a bit at a time': '26',
#  'a bit better than the': '11',
#  'a bit closer to the': '8',
#  'a bit concerned about the': '6',
#  'a bit different from the': '12',
#  'a bit farther down the': '10',
#  'a bit faster than the': '6',
#  'a bit higher than the': '12',
#  'a bit in the last': '14',
#  'a bit in the past': '6',
#  'a bit larger than the': '12',
#  'a bit later in the': '23',
#  'A bit later in the': '13',
#  'a bit less than the': '15',
#  'a bit like Alain Delon': '6',
#  'a bit like trying to': '15',
#  'a bit long in the': '9',
#  'a bit longer than the': '9',
#  'a bit longer than usual': '6',
#  'a bit more about how': '6',
#  'a bit more about what': '6',
#  'a bit more attention to': '6',
#  'a bit more complex than': '8',
#  'a bit more complicated than': '16',
#  'a bit more difficult to': '12',
#  'a bit more of a': '36',
#  'a bit more of the': '12',
#  'a bit more than a': '29',
#  'a bit more than half': '7',
#  'a bit more than I': '9',
#  'a bit more than just': '7',
#  'a bit more than that': '16',
#  'a bit more than the': '13',
#  'a bit more than you': '8',
#  'a bit more time to': '6',
#  'a bit more to the': '9',
#  'a bit of a backlash': '9',
#  'a bit of a bad': '6',
#  'a bit of a bind': '6',
#  'a bit of a blur': '8',
#  'a bit of a bore': '6',
#  'a bit of a break': '13',
#  'a bit of a breeze': '7',
#  'a bit of a buzz': '6',
#  'a bit of a celebrity': '8',
#  'a bit of a challenge': '27',
#  'a bit of a crisis': '6',
#  'a bit of a departure': '9',
#  'a bit of a different': '13',
#  'a bit of a disappointment': '17',
#  'a bit of a double': '7',
#  'a bit of a gamble': '11',
#  'a bit of a hard': '8',
#  'a bit of a head': '8',
#  'a bit of a headache': '6',
#  'a bit of a joke': '8',
#  'a bit of a kick': '7',
#  'a bit of a legend': '6',
#  'a bit of a letdown': '16',
#  'a bit of a loner': '11',
#  'a bit of a long': '10',
#  'a bit of a mess': '21',
#  'a bit of a misnomer': '14',
#  'a bit of a mystery': '33',
#  'a bit of a nuisance': '7',
#  'a bit of a pain': '6',
#  'a bit of a panic': '6',
#  'a bit of a paradox': '11',
#  'a bit of a political': '7',
#  'a bit of a problem': '74',
#  'a bit of a puzzle': '11',
#  'a bit of a question': '8',
#  'a bit of a reach': '7',
#  'a bit of a rebel': '6',
#  'a bit of a red': '6',
#  'a bit of a risk': '8',
#  'a bit of a setback': '6',
#  'a bit of a shock': '53',
#  'a bit of a smile': '6',
#  'a bit of a snob': '10',
#  'a bit of a stir': '8',
#  'a bit of a strange': '8',
#  'a bit of a stretch': '52',
#  'a bit of a struggle': '11',
#  'a bit of a surprise': '71',
#  'a bit of a temper': '8',
#  'a bit of a twist': '6',
#  'a bit of a walk': '8',
#  'a bit of a wild': '6',
#  'a bit of advice for': '9',
#  'a bit of all three': '6',
#  'a bit of an adjustment': '7',
#  'a bit of an edge': '13',
#  'a bit of an exaggeration': '19',
#  'a bit of an issue': '6',
#  'a bit of an odd': '10',
#  'a bit of an old': '6',
#  'a bit of an outsider': '7',
#  'a bit of an overstatement': '13',
#  'a bit of an understatement': '11',
#  'a bit of attention to': '6',
#  'a bit of bad luck': '6',
#  'a bit of effort to': '6',
#  'a bit of fun at': '6',
#  'a bit of getting used': '6',
#  'a bit of good luck': '7',
#  'a bit of good news': '21',
#  'a bit of help from': '6',
#  'a bit of information about': '7',
#  'a bit of information that': '8',
#  'a bit of money to': '9',
#  'a bit of olive oil': '10',
#  'a bit of the old': '9',
#  'a bit of the world': '7',
#  'a bit of time in': '9',
#  'a bit of time on': '7',
#  'a bit of time to': '21',
#  'a bit of time with': '8',
#  'a bit of trouble with': '7',
#  'a bit of water and': '7',
#  'a bit of what he': '9',
#  'a bit of work to': '7',
#  'a bit off the wall': '7',
#  'A Bit on the Side': '6',
#  'a bit out of control': '12',
#  'a bit out of hand': '9',
#  'a bit out of place': '13',
#  'a bit out of step': '7',
#  'a bit out of the': '14',
#  'a bit over the top': '25',
#  'a bit over the years': '8',
#  'a bit part in a': '6',
#  'a bit part in the': '6',
#  'a bit player in the': '16',
#  'a bit rough around the': '6',
#  'a bit slow on the': '6',
#  'a bit smaller than the': '10',
#  'a bit surprised by the': '6',
#  'a bit taken aback by': '6',
#  'a bit to do with': '8',
#  'a bit to make sure': '7',
#  'a bit to the left': '12',
#  'a bit to the right': '9',
#  'a bit to the side': '11',
#  'a bit too big for': '6',
#  'a bit too close to': '9',
#  'a bit too much for': '8',
#  'a bit too much of': '18',
#  'a bit too much to': '9',
#  'a bite of her sandwich': '7',
#  'a bite of his sandwich': '6',
#  'a bite out of crime': '10',
#  'a bite out of it': '10',
#  'a bite out of the': '28',
#  'a bite out of your': '8',
#  'a bite taken out of': '6',
#  'a bite to eat and': '12',
#  'a bite to eat with': '6',
#  'a bitter pill to swallow': '15',
#  'a bitter taste in my': '6',
#  'a black and a white': '7',
#  'a black and white issue': '12',
#  'a black and white photo': '9',
#  'a black and white photograph': '6',
#  'a black and white picture': '9',
#  'a black and white television': '8',
#  'a black belt in judo': '8',
#  'a black belt in karate': '16',
#  'a black belt in tae': '6',
#  'a black dress and a': '9',
#  'a black eye and a': '9',
#  'a black eye for the': '6',
#  'a black father and a': '6',
#  'a black hole at the': '11',
#  'a black hole for the': '6',
#  'a black hole in space': '6',
#  'a black hole in the': '16',
#  'a black leather jacket and': '16',
#  'a black Lincoln Town Car': '6',
#  'a black man accused of': '8',
#  'a black man and a': '20',
#  'a black man in a': '25',
#  'a black man in America': '15',
#  'a black man in his': '6',
#  'a black man in the': '21',
#  'a black man living in': '7',
#  'a black man on the': '6',
#  'a black man who had': '15',
#  'a black man who has': '8',
#  'a black man who is': '13',
#  'a black man who was': '13',
#  'a black man with a': '23',
#  'a black person to be': '6',
#  'a black plastic garbage bag': '9',
#  'a black robe and a': '6',
#  'a black skirt and a': '7',
#  'a black suit with a': '7',
#  'a black T-shirt and jeans': '7',
#  'a black T-shirt with the': '6',
#  'a black tank top and': '7',
#  'a black woman in a': '8',
#  'a black woman in the': '7',
#  'a black woman who was': '7',
#  'a black woman with a': '7',
#  'a black-tie dinner at the': '10',
#  'a blade of grass or': '6',
#  'a blank canvas on which': '6',
#  'a blank check for the': '7',
#  'a blank check to the': '7',
#  'a blank expression on his': '10',
#  'a blank look on her': '7',
#  ...}

# %%
d[0].split('\t')[1:]
# Out:
# ['a', 'babe', 'in', 'the', 'woods']

# %% [markdown]
# # Testing

# %%
from sklearn.metrics import classification_report

# %% [markdown]
# - Напишіть базове рішення та метрику для тестування якості.
# - Для тестування використайте корпус run-on-test.json. Формат корпусу:
# ```
# [
#   [
#     ["Thanks", false],
#     ["for", false],
#     ["talking", false],
#     ["to", false],
#     ["me", true],
#     ["let", false],
#     ["'s", false],
#     ["meet", false],
#     ["again", false],
#     ["tomorrow", true],
#     ["Bye", false],
#     [".", false]
#   ],
# ...
# ]
# ```

# %%
test_file = "../../../tasks/06-language-as-sequence/run-on-test.json"

# %%
test_data = load_json(test_file)

# %% [markdown]
# ## Baseline

# %%
class StubBaselineRunOnSentences:
    
    def find_sentences(self, merged_sentences: List[str]):
        result = []
        sentence_tokens_list = []
        for merged_sentence in merged_sentences:
            tokens = word_tokenize(merged_sentence)
            sentence_tokens_list.append(tokens)
            
            
        return self.classify_stub(sentence_tokens_list)
        
        
    
    
    def classify_stub(self, sentence_tokens_list):
        #TODO: insert call of classification model
        result = []
        for tokens in sentence_tokens_list:
            sent_result = [[token, False] for token in tokens]
            result.append(sent_result)
        return result

# %% [markdown]
# ## Metric

# %%
class Metric:
    
    @staticmethod
    def measure(result_true, result_predicted):
        assert len(result_true) == len(result_predicted)
        
        size = len(result_true)
        y_pred_flatten, y_true_flatten = [], []
        num_of_mathced_sentences = 0
        
        for i in range(0, size):
            sent_true = result_true[i]
            sent_pred = result_predicted[i]
            
            
            y_true = np.array(sent_true)[:, 1]
            y_pred = np.array(sent_pred)[:, 1]
            
            y_true_flatten += y_true.tolist()
            y_pred_flatten += y_pred.tolist()
            
            if sum(y_true == y_pred) == len(y_pred):
                num_of_mathced_sentences += 1
            
            
        return classification_report(y_true_flatten, y_pred_flatten), num_of_mathced_sentences / size

# %% [markdown]
# Let's show example of this metric on test data vs predicted result in stub baseline

# %%
stub_baseline_run_on_sentecnes = StubBaselineRunOnSentences()

# %%
sentence_tokens_list = [ np.array(item)[:, 0].tolist() for item in test_data]

# %%
test_pred_data = stub_baseline_run_on_sentecnes.classify_stub(sentence_tokens_list)

# %%
clf_report, matched_sents = Metric.measure(test_data, test_pred_data)

# %%
print(clf_report)
# Out:
#               precision    recall  f1-score   support
#
#        False       0.97      1.00      0.98      4542
#         True       0.00      0.00      0.00       155
#
#     accuracy                           0.97      4697
#    macro avg       0.48      0.50      0.49      4697
# weighted avg       0.94      0.97      0.95      4697

# %%
print(f"There are matched {100 * matched_sents}% sentences.")
# Out:
# There are matched 25.0% sentences.
