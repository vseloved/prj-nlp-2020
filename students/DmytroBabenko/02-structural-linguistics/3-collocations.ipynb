# %% [markdown]
# # Колокації

# %% [markdown]
# ### 1. Англійська мова

# %% [markdown]
# У цьому завданні вам потрібно дослідити сполучуваність дієслів одного синонімного ряду з прислівниками. Наприклад, ми частіше кажемо "love somebody dearly", "honor somebody highly", але "admire somebody greatly".

# %% [markdown]
# #### Завдання:

# %% [markdown]
# #### 1. продовжте синонімний ряд дієслів: "say", "tell", "speak", "claim", "communicate"

# %% [markdown]
# "say", "tell", "speak", "claim", "communicate", "express", "talk", "report", "notify", "argue", "report"

# %%
verbs = ["say", "tell", "speak", "claim", "communicate", 
         "express", "talk", "report", "notify", "argue", "report"]

# %% [markdown]
# #### 2. напишіть функцію, яка знаходить у реченні дієслово (за складеним раніше синонімним рядом) і витягає усі можливі прислівники на "-ly", якими це дієслово керує

# %%
import spacy
import stanfordnlp
from typing import List, Dict

# %%
stanfordnlp.download('en')
# Out:
# Using the default treebank "en_ewt" for language "en".
# Would you like to download the models for: en_ewt now? (Y/n)
# n

# %%
nlp = stanfordnlp.Pipeline()
# Out:
# Use device: gpu
# ---
# Loading: tokenize
# With settings:
# {'model_path': '/home/dbabenko/stanfordnlp_resources/en_ewt_models/en_ewt_tokenizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: pos
# With settings:
# {'model_path': '/home/dbabenko/stanfordnlp_resources/en_ewt_models/en_ewt_tagger.pt', 'pretrain_path': '/home/dbabenko/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# ---
# Loading: lemma
# With settings:
# {'model_path': '/home/dbabenko/stanfordnlp_resources/en_ewt_models/en_ewt_lemmatizer.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Building an attentional Seq2Seq model...
# Using a Bi-LSTM encoder
# Using soft attention for LSTM.
# Finetune all embeddings.
# [Running seq2seq lemmatizer with edit classifier]
# ---
# Loading: depparse
# With settings:
# {'model_path': '/home/dbabenko/stanfordnlp_resources/en_ewt_models/en_ewt_parser.pt', 'pretrain_path': '/home/dbabenko/stanfordnlp_resources/en_ewt_models/en_ewt.pretrain.pt', 'lang': 'en', 'shorthand': 'en_ewt', 'mode': 'predict'}
# Done loading processors!
# ---

# %% [markdown]
# ##### Необхідна функція представленна нище

# %%
def find_verbs_with_associated_adverbs(nlp, text: str, verbs: List[str], 
                                       verb_adverb: Dict[str, Dict[str, int]] = None):
    doc = nlp(text)
    
    if verb_adverb is None:
        verb_adverb = dict()
    
    for sent in doc.sentences:
        for token in sent.dependencies:
            if token[0].lemma not in verbs:
                continue

            if token[2].upos !='ADV':
                continue


            verb = token[0].lemma
            adverb = token[2].lemma

            if verb not in verb_adverb:
                verb_adverb[verb] = dict()

            if adverb not in verb_adverb[verb]:
                verb_adverb[verb][adverb] = 1
            else:
                verb_adverb[verb][adverb] += 1        
    
    return verb_adverb

# %% [markdown]
# ##### Приклад використання даної функції

# %%
sentence_example = "I was curious how the Obama campaign was going to deal with this new development , since they had claimed loudly last week that al-Maliki had definitively moved away from McCain 's position and over to their own.\n"

# %%
find_verbs_with_associated_adverbs(nlp, text=sentence_example, verbs=verbs)
# Out:
# /pytorch/aten/src/ATen/native/cuda/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# {'claim': {'loudly': 1}}

# %% [markdown]
# #### 3. напишіть програму, яка знайде усі можливі прислівники для ваших дієслів у корпусі блогів

# %%
corpus_file = "../../../tasks/02-structural-linguistics/data/blog2008.txt"

# %%
def read_file(file: str):
    lines = []
    with open(file) as file_in:        
        for line in file_in:
            lines.append(line)
            
    return lines

# %%
corpus = read_file(corpus_file)

# %%
corpus
# Out:
# ['Happy New Year .\n',
#  'And just for another thing to celebrate , Dr. David Whitehouse , the British astronomer and former science editor of the BBC , tells us : " \' The fact is that the global temperature of 2007 is statistically the same as 2006 and every year since 2001 \' " Global warming stopped ?\n',
#  'Surely not .\n',
#  'What heresy is this ?\n',
#  "Have n't we been told that the science of global warming is settled beyond doubt and that all that 's left to the so-called sceptics is the odd errant glacier that refuses to melt ?\n",
#  '" Are n\'t we told that if we do n\'t act now rising temperatures will render most of the surface of the Earth uninhabitable within our lifetimes ?\n',
#  "But as we digest these apocalyptic comments , read the recent IPCC 's Synthesis report that says climate change could become irreversible .\n",
#  'Witness the drama at Bali as news emerges that something is not quite right in the global warming camp .\n',
#  '" With only few days remaining in 2007 , the indications are the global temperature for this year is the same as that for 2006 - there has been no warming over the 12 months .\n',
#  'But is this just a blip in the ever upward trend you may ask ?\n',
#  'The fact is that the global temperature of 2007 is statistically the same as 2006 as well as every year since 2001 .\n',
#  'Global warming has , temporarily or permanently , ceased .\n',
#  'Temperatures across the world are not increasing as they should according to the fundamental theory behind global warming - the greenhouse effect . "\n',
#  '( italics added )\n',
#  'Whatever warming trend was going on has flattened out in the last seven years .\n',
#  'Which is an odd thing , because China and India have been pumping out more CO2 from cars and industry .\n',
#  'A bunch of ugly facts are nailing the biggest scare story in history .\n',
#  "We 're safe !\n",
#  "Let 's celebrate !\n",
#  "Dr. Whitehouse 's wonderful news will make a lot of people angry .\n",
#  "They do n't want to believe good things about Mother Earth .\n",
#  "They 've put their money on Bad News for Momma .\n",
#  'Which makes you wonder what they really want .\n',
#  'The rest of us can heave a happy sigh and go back to the party .\n',
#  'Have a Happy New Year !\n',
#  'There is so much to celebrate .\n',
#  'James Lewis blogs at dangeroustimes.wordpress.com /\n',
#  'A US diplomat working for the Agency for International Development was shot and killed along with his driver in the Sudanese capitol of Khartoum : It was not immediately known if the attack had a political motive or was a random crime .\n',
#  'Though Darfur , far to the west , is engulfed in violence , the Sudanese capital and its surroundings rarely see political violence or attacks by Islamic militants .\n',
#  'The Sudanese driver was killed immediately , and the American died of his injuries within hours , officials said .\n',
#  '" This afternoon , the American officer succumbed to his injuries and passed away , " said Walter Braunohler , the spokesman at the U.S. Embassy in Khartoum .\n',
#  'Braunohler said the diplomat , whose name was not released , worked for the U.S. Agency for International Development .\n',
#  'The Sudanese Foreign Ministry identified the wounded American as a humanitarian aid official and said he was shot five times in the hand , shoulder and belly .\n',
#  "The diplomat underwent surgery following the attack , according to the ministry 's statement .\n",
#  "The ministry identified the Sudanese driver who was killed as 40-year-old Abdel Rahman Abbas and said the attack occurred around 4 a.m. local time as the car was heading to a western suburb of Sudan 's capital , Khartoum .\n",
#  'What was an AID official doing driving around at 4 : 00 AM ?\n',
#  'Answering that question may go a long way tol solving the mystery of his shooting .\n',
#  "The diplomat 's murder came just a day after a joint African Union-United Nations force was deployed in Darfur .\n",
#  'No one knows if there is any connection to that event .\n',
#  'With all the turmoil in Pakistan , another electoral crisis taking place , this one in Kenya , has taken place under the media radar .\n',
#  'Forces of the opposition are rioting in several cities following what the United States is calling " voting irregularities " in the presidential election .\n',
#  'Incumbent president Mwai Kibaki who won an election 5 years ago defeating former strongman Daniel Arap Moi declared himself the winner over challenger Raila Odinga despite early returns giving Odinga a million vote lead .\n',
#  'At that point , the electoral commission , which was in charge of counting the votes , went virtually dark and what emerged after a delay of several hours was a truly bizarre outcome : The farcical nature of the vote will only heighten their disappointment .\n',
#  'The electoral commission initially claimed that roughly a quarter of returning officers disappeared for 36 hours without announcing results and had switched off their mobile phones .\n',
#  'When results did finally emerge , Mr Odinga saw a one million vote lead overturned .\n',
#  'Opinion polls showed that the contest was always going to be close , but if the official results are correct , Kenyans voted in an inexplicably bizarre manner .\n',
#  "After turfing out 20 of Mr Kibaki 's cabinet ministers and reducing his party to a rump in the simultaneous parliamentary poll , they apparently voted in an entirely different manner in the presidential race .\n",
#  'This set off a series of riots by supporters of Mr. Odinga in cities across the country : Troops in riot gear were deployed in their thousands around the capital as trucks full of soldiers raced through the deserted streets towards the slum areas .\n',
#  'In the opposition heartland city of Kisumu in the west , more than 53 people have died as authorities were believed to have instituted a shoot-on-sight curfew .\n',
#  "Another 40 were killed overnight in Nairobi , taking the toll since Thursday 's vote to 124 .\n",
#  "As in many African countries , the differences are more tribal than political with Mr. Odinga 's Luo tribe feeling that it had been getting short shrift for years from Kbaki 's Kikuyu tribe .\n",
#  "The fact that Odinga had crafted what he thought was a solid majority coalition with other tribes apparently did n't take into account Kbaki 's electoral chicanery .\n",
#  'In many cities , there are shoot on sight orders given to troops to stop the rioting .\n',
#  'It is doubtful that Kbaki will revisit the results of the election .\n',
#  'And for that , Kenya will suffer the consequences of living with one more president who flouts the will of the people by rigging the democratic process in his favor .\n',
#  "Frequent American Thinker contributor and noted terrorism expert Walid Phares has a sharp analysis of the reasons behind Benazir Bhutto 's assassination as well as a detailed summary of al-Qaeda 's plans , set in motion years ago , that appear to be coming to fruition : The long-term plan of the Taliban and al Qaeda in Afghanistan during the 1990s was to eventually spread to Pakistan and seize power , and , ultimately after 1999 , to seize the nukes , too .\n",
#  'Miscalculating on September 11 , Osama bin Laden lost Kabul and the jihadi war room crossed into their eastern neighbor .\n',
#  'Plan B was then to seize Waziristan and gradually Talibanize the country , grabbing the " doomsday " devices in the end .\n',
#  'For the last seven years , the jihadi hydra protected by the fundamentalist tribes , hooking up with the local Islamist movements and with tentacles deep inside the defense and intelligence apparatus , attempted to spread in that direction .\n',
#  'President Pervez Musharraf , unable to determine the extent of radical influence in his own services , moved slowly and reluctantly on the containment strategies .\n',
#  'This lost time resulted in several assassination attempts and allowed a widening of the jihadi networks in the country .\n',
#  "Reacting to the breach of national security , he tightened the rope on the opposition , frustrating his secular opponents and alienating the nation 's Supreme Court .\n",
#  "The descent into generalized violence was spiraling out of his government 's control and working to al Qaeda 's satisfaction .\n",
#  'Both bin Laden and Ayman al-Zawahiri , as well as Taliban leader Mullah Omar , acting as jihadi supreme rulers of the country , pressed on with calls for assassination and fatwas for regime change .\n',
#  'By 2006 , Mr. Musharraf was fighting on two fronts : taking on the jihadi forces , including the homegrown ones on the one hand ; and dealing with the pressures from his secular opposition on the other hand .\n',
#  "From early 2007 , as Taliban operatives based in enclaves in the border areas continued to strike inside Afghanistan , al Qaeda 's messages beaming out of Pakistan and violence were unrestrained .\n",
#  'The United States pressed Mr. Musharraf to change direction .\n',
#  'Phares argues that Musharraf , at the urging of the US , took certain steps that appeared to address many outstanding issues facing the Pakistani government including real attempts at political reconciliation and confronting the terrorists .\n',
#  "But it was the return of Bhutto that really began the process of change : Former political enemies were n't smooth on reconciling : While Mrs. Bhutto began negotiating with Mr. Musharraf , demanding a purge in the military , Mr. Sharif called for Mr. Musharraf 's resignation .\n",
#  "In addition , the president of the high court refused to recognize the general 's election as president .\n",
#  'These turbulences triggered frustrations among the military as it was marching to confront the most lethal enemy in the North-West region .\n',
#  'And taking advantage of this dizzying political storm , the jihadi forces launched their urban offensive culminating with the suicidal Red Mosque intifada in Islamabad in the summer .\n',
#  'And as Mr. Musharraf was steering the wheels toward political reconfiguration , terror attacks targeted various cities as well as military personnel across the country .\n',
#  'But the return of Mrs. Bhutto to Pakistan sent a positive message to the public and a negative one to the radical Islamists .\n',
#  'The daughter of a prominent leader , a member of a political family , a former prime minister in her own right - and , above all , a liberal Muslim woman - Mrs. Bhutto projected the possibility of a leap toward more balanced politics and greater steps toward pluralism - two ingredients for progress toward democracy .\n',
#  'Her dialogue with Mr. Musharraf made possible the return of Mr. Sharif and the global march to new elections .\n',
#  "The bickering politicians did n't let go of their sour feelings toward each other , but the political process was about to gradually return to the country .\n",
#  "Given Musharraf 's confrontation with the extremists , any return to political normalcy would necessarily mean a foiling of al-Qaeda 's plans - which ultimately sought the possession of nuclear weapons .\n",
#  'The religious parties would be severely weakened if elections involving all parties were held , hence , Bhutto had to go : Indeed , the greatest losers in the upcoming elections , and in any democratic elections mobilizing large and experienced secular forces , would be the Islamists .\n',
#  'Their six-party coalition achieved legislative power because of the absence of the secular and democratic forces .\n',
#  "Now that Mr. Musharraf is n't in love with the jihadi forces anymore , several assassination attempts later ; and after the seculars saw with their naked eyes what the fundamentalists were preparing for the country , the slice of Islamist vote was projected to shrink .\n",
#  'Mrs. Bhutto was the reason for this future political defeat .\n',
#  'But beyond these political considerations , it was a war of ideas that the Taliban and their ilk feared the most .\n',
#  "It is one thing for the radicals to measure themselves in comparison with the military 's authoritarianism .\n",
#  "But it is another thing to be blasted ideologically by a woman who would dominate Pakistan 's politics .\n",
#  'By jihadi standards it was unbearable to see Lady Benazir seizing the premiership of the executive power .\n',
#  'A staunch modernist and a genuine Muslim , she would have been their worst nightmare .\n',
#  'With her in power , forget about the Talibanization : There would be no suppression of women and no brutalization of minorities .\n',
#  'There would be fierce empowerment of civil society .\n',
#  'This is why the combined " war room " of al Qaeda , the neo-Taliban and the Pakistani jihadists decided to eliminate her .\n',
#  "The radicals may have been given a big assist by elements within Musharraf 's government .\n",
#  'But unless there is some kind of international investigation that would feature the full cooperation of the Musharraf government , such a connection is not likely to be found .\n',
#  'With the political process in chaos ( elections are likely to be delayed ) and support for Musharraf disappearing ( a belief he was personally involved in the assassination ) , Pakistan is on the edge of an abyss where anything could happen - including a takeover by those sympathetic with al-Qaeda .\n',
#  'If that were to happen , it is likely that there would be unanimous support among western goverments to destroy or neutralize Pakistani nuclear weapons .\n',
#  "The world just ca n't afford to give al-Qaeda what they have long sought ; access to weapons of mass destruction .\n",
#  'Barack Obama has moved out to a solid lead over Hillary Clinton and John Edwards while Mike Huckabee and Mitt Romney have distanced themselves from the rest of the GOP field according to a new Des Moines Register poll released last night .\n',
#  'Obama leads the Democratic pack with 32 % while Hillary Clinton is second with 25 % followed closely by Edwards at 24 % .\n',
#  'On the Republican side , Huckabee enjoys a 32 % - 26 % lead over Mitt Romney with John McCain a distant third at 13 % .\n',
#  'Fred Thomas comes in with a disappointing 9 % and is tied with Ron Paul .\n',
#  'No one is sure exactly what to make of this poll , taken over the holidays and showing an extreme voilatility : This totally shatters the CW of the political crowd here in Des Moines , which had been convinced that Edwards was on fire and really might win , and that Huck was totally imploding .\n',
#  "( Although the polling stopped yesterday , before today 's Huck presser fiasco .\n",
#  "It also reaffirms my instinct that Fred Thompson is n't booking a flight to New Hampshire .\n",
#  'Indeed , the story on the ground over the last few days coming out of Iowa was Obama and Huckabee falling back while Romney and Hillary were moving up .\n',
#  'So much for our vaunted political press .\n',
#  "The effect of the holiday on those numbers simply ca n't be quantified .\n",
#  'How focused are people on the caucuses ?\n',
#  'The fact that so many - up to 46 % of Republicans - would be willing to change their vote between now and the caucuses on Thursday night is telling .\n',
#  'It could mean that a sizable portion of both Democrats and Republicans will walk into their caucus site not knowing who they will support for president .\n',
#  "I guess we 'll all have to wait until late Thursday night to find out what Iowans really think .\n",
#  'Conservative blogger John Hawkins has compiled a list of " The 40 Most Obnoxious Quotes of 2007 " and there are some real doozies in the mix .\n',
#  'Some examples : 31 ) " I do n\'t know what it \'s going to take for people to really wake up and understand that they [ the Bush administration ] are liars and they are murderers . "\n',
#  '-- Joy Behar from The View25 ) " When I see a stroller now , I see it as someone who evicted a person with AIDS , right or wrong . "\n',
#  '-- Brian Basinger , president of the Harvey Milk Lesbian Gay Bisexual and Transsexual Democratic Club on the horror of having to live near heterosexual families in San Francisco .\n',
#  '19 ) " I propose a limitation be put on how many sqares [ sic ] of toilet paper can be used in any one sitting .\n',
#  'Now , I do n\'t want to rob any law-abiding American of his or her God-given rights , but I think we are an industrious enough people that we can make it work with only one square per restroom visit , except , of course , on those pesky occasions where 2 to 3 could be required . "\n',
#  '-- Sheryl Crow at the Huffington Post9 ) " I hear about Tony Snow and say to myself , well , stand up every day , lie to the American people at the behest of your dictator-esque boss and well , how could a cancer NOT grow in you .\n',
#  'Work for Fox News , spinning the truth in to a billion knots and how can your gut not rot ?\n',
#  "I know , it 's terrible .\n",
#  'I admit it .\n',
#  "I do n't wish anyone harm , even Tony Snow .\n",
#  'And I do hope he recovers or at least does what he feels is best and surrounds himself with friends and family for his journey .\n',
#  'But in the back of my head there \'s Justin Timberlake \'s " What goes around , goes around , comes around , comes all the way back around , ya . "\n',
#  '-- Charles Karel Bouley at The Huffington Post " 3 ) A friend of ours said if the same laws were applied to U.S. Presidents as were applied to the Nazis after WWII , that every single one of them , every last rich white one of them , from Truman on would be hung to death and shot .\n',
#  'And this current administration is no exception .\n',
#  'They should be hung and tried and shot as war criminals . "\n',
#  '-- Zack de la Rocha , Rage Against The MachineFollow the link to discover the # 1 most obnoxious quote of the year .\n',
#  'According to pollster Rasmussen , the number of Americans who identify themselves as Republican has risen to a two year high : The number of Americans who consider themselves to be Republicans jumped nearly two percentage points in December to 34.2 % .\n',
#  "That 's the largest market share for the Republican brand in nearly two years , since January 2006 ( see history from January 2004 to present ) .\n",
#  'At the same time , the number of Democrats fell to 36.3 % .\n',
#  "That 's down a point compared to a month ago .\n",
#  'During 2007 , the number of Democrats has ranged from a low of 35.9 % in July to a high of 37.8 % in February .\n',
#  'The reason for the jump in self identified Republicans ?\n',
#  'Greater confidence in the party to fight the war on terror would seem to be the key .\n',
#  "While it has not affected President Bush 's approval ratings , recent international events - including the improving situation in Iraq - reminds voters why they prefer the Republican party over the Democrats when it comes to national security .\n",
#  'The percentage of people who identify as Republicans has risen sharply since the 2006 mid term debacle : A year ago at this time , the Democrats had a 6.9 percentage point advantage as they prepared to formally take control of Congress following their victories in Election 2006 .\n',
#  'It remains to be seen whether the Republican gains can last , but it is startling to note that the Democrats have lost two-thirds of the partisan advantage since taking control of Congress .\n',
#  'Perhaps the American people are suffering from " buyer \'s remorse " when it comes to congressional Democrats who have failed to pass any significant legislation since taking over .\n',
#  'At the very least this news - if it holds - will mean that Democrats would probably only realize modest gains at the ballot box next November - if they win anything at all .\n',
#  'A far cry from the heady days last summer when it appeared the Democrats would almost run the table in the Senate and continue building a bigger majority in the House .\n',
#  "Despite calls for the January 8 vote to go forward as scheduled by both major opposition parties , the Pakistani electoral commission has postponed parliamentary elections until next month : USA TODAY 's Paul Wiseman reports that the Pakistani election commission , citing uncivil unrest following the assassination of political leader Benazir Bhutto last month , just announced that it will delay upcoming parliamentary elections by nearly six weeks .\n",
#  'Balloting will be rescheduled from Jan . 8 to Feb. 18 .\n',
#  'Wiseman says the decision has been anticipated all week .\n',
#  "But Bhutto 's Pakistan Peoples Party has rejected any postponement of the original date of Jan . 8 , raising the possibility that Bhutto supporters will take their protests into the streets .\n",
#  "The Peoples Party ' s governing board was meeting today to decide how to respond .\n",
#  'The other leading opposition party -- the Pakistan Muslim League of former Prime Minister Nawaz Sharif -- had also opposed any delay .\n',
#  'Sharif has also called for Musharraf to resign and a " Government of National Unity " be installed before the elections in order to insure fairness of the vote .\n',
#  'This is not likely as Musharraf will seek to maintain strict control over the vote .\n',
#  "This may cause the opposition parties to boycott the election which would lead to a victory by Musharraf 's coalition of nationalist and religious parties .\n",
#  "The Pakistani People 's Party is deciding today whether to stage protests against the delay .\n",
#  'Given the tense mood in the major cities , such a demonstration could easily spin out of control and become a bloodbath .\n',
#  'And waiting in the wings is the military who have been on the sidelines so far but may assert itself if the chaos in the streets begins to break down social order .\n',
#  'Post election violence in Kenya continues to escalate as tribal warfare has now broken out in the slums of major cities and a church where dozens of people were hiding to escape the violence was torched : According to witnesses and Red Cross officials , up to 50 people died inside the church in a small village in western Kenya after a furious crowd doused it with gasoline and set it on fire .\n',
#  'In Nairobi , the capital , tribal militias squared off against each other in several slums , with gunshots ringing out and clouds of black smoke wafting over the shanties .\n',
#  'The death toll across the country is steadily rising .\n',
#  'Witnesses indicate that more than 250 people have been killed in the past two days in bloodshed connected to a disputed election Kenya held last week .\n',
#  'That election featured what the European Union is calling " ballot rigging " by the winner , incumbent President Mwai Kibaki , denying the opposition a clear victory at the polls .\n',
#  'Meanwhile , oppositon leader Raila Odinga has called for a million people to march tomorrow , raising concerns of a real bloodbath .\n',
#  'There are several reasons behind the violence : The violence has been a mix of hooliganism , political protest and ethnic bloodletting .\n',
#  "Most of the victims have been Kikuyus , the tribe of the president and Kenya 's traditional ruling class .\n",
#  'Kikuyus have dominated business and politics since independence in 1963 .\n',
#  'They run shops , restaurants , banks and factories across Kenya , from the Indian Ocean coast to the scenic savannah to the muggy shores of Lake Victoria in the west .\n',
#  "They make up only 22 percent of the population and are part of Kenya 's mosaic of roughly 40 ethnic groups , which have intermarried and coexisted for decades .\n",
#  "But the election controversy has created a new dynamic in which many of Kenya 's other tribes , furious about the ballot rigging that may have kept Mr. Kibaki in power , have vented their frustrations against them .\n",
#  "Opposing the Kikuyu 's are a coalition of tribes including the Luos , to which Mr. Odinga belongs .\n",
#  "It is this coalition that sought to supplant Kibaki but were thwarted by the President 's electoral shennanigans .\n",
#  'The once prosperous and peaceful country is rapidly turning into just another failed state in Africa .\n',
#  'One can only hope that the situation can be resolved before a Rwanda like tragedy occurs .\n',
#  'The government of Pakistan has done an about face and now says that former Prime Minister Benazir Bhutto was not killed when she hit her head on a sun roof lever : Caretaker Interior Minister Hamid Nawaz Khan has asked the media and people to " forgive and ignore " comments made by his ministry \'s spokesman Javed Iqbal Cheema which were slammed by her Pakistan People \'s Party as " lies " and led to an uproar at home and abroad .\n',
#  'The Interior Minister made the apology during a briefing for Pakistani newspaper editors on Monday .\n',
#  'Punjab province on Tuesday issued a front-page advertisement in newspapers that offered a reward of Rs 1 crore for information about a gunman and a suspected suicide bomber seen in the photos and video footage of the assassination .\n',
#  "The government 's apparent damage control exercise on Cheema 's comments made at a news conference a day after Bhutto was assassinated at Liaquat Bagh in Rawalpindi on December 27 , came after TV channels aired privately shot photos and video footage which showed a gunman shooting at Bhutto .\n",
#  "The Pakistan People 's Party leader is seen in the footage falling through the sun-roof before the suicide bomber detonated his explosives .\n",
#  'The briefing by caretaker Prime Minister Mohammedmian Soomro was also attended by the foreign , interior and information ministers and senior officials .\n',
#  'They offered a pretty lame explanation for the " confusion : " Khan said the spokesman \'s comments may have been a mistake as " we are faujis ( soldiers ) and we are not so articulate to present our views as you journalists can " .\n',
#  'Both the interior minister and spokesman Cheema are retired army officers .\n',
#  '" I am sorry if that happened and please forgive us and ignore the comment , " he told the editors .\n',
#  "Earlier , Prime Minister Soomro tried to defend the interior ministry 's spokesman , saying he was just relaying facts that had been told to him , especially about the cause of death .\n",
#  '" We are conducting an investigation and all TV footage , all evidence , that would be available will help in reaching a definite conclusion , " Soomro told the editors .\n',
#  'So how did Bhutto die ?\n',
#  "The government still is n't saying definitively but it would appear that they are giving credence to reports that Bhutto was shot to death .\n",
#  'The question is will they dare make that announcement ?\n',
#  'Most analysts think that President Musharraf is reluctant to admit to the possibility of gunshots killing Bhutto because it would give impetus to the charge that his government provided inadequate security to the former prime minister .\n',
#  "Indeed , the video of the two assassins shows them easily getting by the few soldiers who were there for Bhutto 's protection .\n",
#  'There has even been some sources in the government who have admitted that the military was probably involved in the assassination .\n',
#  'Musharraf is still resisting an international investigation into the murder .\n',
#  'Whether they can keep that up is up to the United States .\n',
#  "So far , we 've supported Musharraf , believing that there is very little choice given the danger of who might replace him if we did n't .\n",
#  "But if the Pakistani government makes us look like fools for standing behind them , they should n't expect that support to be absolute .\n",
#  "Do n't quite know what to make of this .\n",
#  "If Kucinich does n't think he can win , what the heck is he doing in the race except fulfilling some vanity wish .\n",
#  'But for whatever reason , there is little doubt that telling his supporters to caucus for Obama as a second choice will give the Illinois senator a boost on Thursday night : Representative Dennis Kucinich urged his Iowa followers today to select Senator Barack Obama as their second choice at the caucuses on Thursday if his support is not strong enough to be viable in the 1,781 precincts across the state .\n',
#  '" Senator Obama and I have one thing in common : Change , " Mr. Kucinich said in a statement today .\n',
#  'The two spoke briefly by telephone before Mr. Obama flew here for an afternoon rally .\n',
#  'In a statement , Mr. Obama took advantage of the opportunity to point out that he , along with Mr. Kucinich , opposed the war in Iraq .\n',
#  '" He and I have been fighting for a number of the same priorities , " Mr. Obama said .\n',
#  'Four years ago , during his first presidential bid , Mr. Kucinich announced a similar second-choice partnership with John Edwards .\n',
#  'At the time , aides to Mr. Edwards said it helped contribute to his second-place finish in the caucuses .\n',
#  'In a close race , this could make the difference between first and second for Obama .\n',
#  'The fact that Kucinich is at about 1 % in Iowa and has no organization in the state could mean that his help would be marginal .\n',
#  "But even if it makes a difference in just a handful of precincts , I 'm sure Obama is n't going to mind .\n",
#  "While we were enjoying New Year 's day on Wednesday Iran hanged 13 convicted criminals on Wednesday , including the mother of two young children who had been found guilty of murdering her husband after discovering he was having an affair , reports said .\n",
#  "Raheleh Zamani , who reportedly chopped her husband 's body into pieces , was hanged alongside seven men convicted of murder , in a mass execution at Tehran 's Evin prison , the Iranian Student Correspondents ' Association ( ISCA ) reported .\n",
#  'Three drug traffickers were also hanged on Wednesday in public in a square in the central city of Qom and another two in the eastern city of Zahedan , state media reported .\n',
#  'Pictures from Qom showed the three blindfolded men , their bodies hanging limply from nooses attached to cranes as dusk fell , the winter snow falling heavily .\n',
#  'The hangings , the first reported in 2008 , were the latest in a growing number of executions in the Islamic republic as the authorities impose a drive they say is aimed at improving security in society .\n',
#  'President Ahmadinejad , who spoke to receptive audiences at Columbia University and the United Nations just a few months ago presides over a country which currently makes more use of the death penalty than any other country apart from China .\n',
#  'Capital offences in Iran include murder , rape , armed robbery , serious drug trafficking and adultery .\n',
#  'Human rights groups have accused Iran of excessive resort to the death penalty , but the authorities say capital punishment is an effective deterrent that is only used after an exhaustive judicial process .\n',
#  'Hmmm , a death penalty for adultery .\n',
#  'Now that should get those Columbia University academics as upset as they were upon hearing from Ahmadinejad that Iran had no homosexuals .\n',
#  'After a week of false statements , lies , and dismissive apologies , Pakistani President Pervez Musharraf now says that he is disatisfied with the probe into former Prime Minister Benazir Bhutto \'s death and is asking Scotland Yard for help : " One should not give a statement that \'s 100 percent final .\n',
#  'That \'s the flaw that we suffer from , " Musharraf said at a news conference , noting that more evidence was emerging about the attack .\n',
#  '" We needed more experience , maybe more forensic and technical experience that our people do n\'t have .\n',
#  'Therefore I thought Scotland Yard may be more helpful . "\n',
#  "Musharraf said he also reached out to British investigators for assistance to dispel accusations that Pakistan 's military or intelligence services were involved .\n",
#  '" We do n\'t mind going to any extent , as nobody is involved from the government or agency side , " he said .\n',
#  "Speaking a week after Bhutto 's assassination in a shooting and suicide bombing , Musharraf denied there had been a security lapse and implied that Bhutto , who was greeting supporters through the sunroof of her armored vehicle at the time of the attack , was partly responsible .\n",
#  '" Who is to be blamed for her coming out ( of ) her vehicle ? " he asked , adding that others in the vehicle had not been hurt in the attack .\n',
#  'When in doubt , blame the victim .\n',
#  'Reports in the immediate aftermath of the bombing said that as far back as November , Bhutto believed Musharraf was deliberately withholding security forces that could have made her safer .\n',
#  'Unless he feared Bhutto more than the street riotors , I doubt whether that was really true .\n',
#  "More likely , he did n't trust the army to protect her .\n",
#  'And when she requested that Musharraf allow her to use western private security firms , he refused .\n',
#  "I do n't think Musharraf wanted Bhutto dead .\n",
#  'But I think he is just too weak and indecisive to have done what was needed to protect her .\n',
#  "I honestly do n't know how either party 's caucus results will play out tonight .\n",
#  "Usually , you can get a good idea of perhaps not a winner but at least you can figure out who 's up , who 's down , and who 's on life support .\n",
#  'Not with the Iowa Caucuses .\n',
#  'Races in both parties are just too close to call .\n',
#  'So many variables .\n',
#  'So much volatility among the voters .\n',
#  'And the polls are whacky .\n',
#  'As an example , here are the final two polls out on Iowa .\n',
#  'First , ARG : Mike Huckabee 29 % ( 23 % ) Mitt Romney 24 % ( 32 % ) Fred Thompson 13 % ( 7 % ) John McCain 11 % ( 11 % ) Rudy Giuliani 8 % ( 6 % ) Ron Paul 6 % ( 6 % ) Duncan Hunter 4 % ( 2 % ) Undecided 4 % ( 11 % ) ( Number in parentheses is from ARG survey taken last week ) The spread between Huckabee and Romney is the margin of error which means they are virtually tied .\n',
#  "Note Thompson 's huge bump .\n",
#  'Is he surging ?\n',
#  "Many think so although he probably does n't have enough juice to catch either front runner for second place .\n",
#  'But a strong third sends him along the campaign trail - despite what you might have heard about him dropping out .\n',
#  '( Fred and his staff are denying the filthy rumor every chance they get . )\n',
#  "Meanwhile , Zogby 's daily tracking poll ( three day rolling average ) tells a little different story :* Huckabee - 31 % * Romney - 25 % * Thompson - 11 %*McCain - 10 % Here the Huckster opens up a slight lead on Romney with Thompson and McCain far back in the pack .\n",
#  'On the Democratic side , Obama has sprinted into the lead : Democrat Barack Obama continued his upward momentum through the evening before the Iowa caucuses , capturing the lead ahead of rivals John Edwards and Hillary Clinton. .\n',
#  'Meanwhile , Republican Mike Hucakbee widened his lead over Mitt Romney down the stretch , the newest and last Reuters/C - SPAN / Zogby daily telephone tracking poll in Iowa shows .\n',
#  'Obama broke through the 30 % barrier for the first time , gaining 31 % support after another strong day leading up to the caucuses .\n',
#  "But more dramatic was Clinton 's four-point drop in this last day of tracking .\n",
#  'Edwards moved into second place by himself after another day where he steadily gained ground .\n',
#  'This fifth and final daily tracking poll was conducted using live telephone operators in the Zogby call center in Upstate New York .\n',
#  'Edwards finished this Zogby daily tracking in Iowa in the same place as four years ago , when Zogby correctly identified the finishing order of the candidates in that caucus .\n',
#  'Hillary Clinton has been playing down her chances the last 48 hours and could very well finish 3rd .\n',
#  'All of this matters little in the end .\n',
#  'The process of caucusing is complicated for the Democrats and it is possible for any of the top three candidates to win or come in third .\n',
#  "We 'll see by midnight tonight central time .\n",
#  'While we stand in awe of the willingness of our troops in Iraq to sacrifice themselves for the Nation , the fewer that are required to do so , the better .\n',
#  'And the news on that front is good .\n',
#  'As can be seen in the chart below , our military deaths in December dropped to 23 from 37 in November .\n',
#  "December deaths are down over 80 % ( 82 % ) from May 's peak this year of 126 .\n",
#  'Assuming this reflects a permanent change in the correlation of forces in Iraq - and it is likely that it does , although we can not be certain of it - it reflects a tremendous achievement on the part of General Petraeus , since this is the result not of retreating from our objectives in Iraq but of advancing toward them - of executing the mission .\n',
#  'What of Iraqi deaths ?\n',
#  'Iraqi security forces and civilian fatalities are also down in December from November .\n',
#  'Iraqi deaths are down only by a small amount - from 560 in November to 534 in December , although that difference is not small if you are one of the ones who are now still alive .\n',
#  "And the decline from this year 's peak in February of 3,014 is a drop of 82 % ( ! ) .\n",
#  'Are we out of the woods in Iraq ?\n',
#  'It would seem not .\n',
#  "We have General Odierno 's estremely disturbing cri de coeur at the end of November , which we can assume was endorsed by his chief , General Petraeus .\n",
#  'So far as we know , General Odierno \'s point " A window of opportunity has opened for the government to reach out to its former foes , said Army Lt . Gen . Raymond T. Odierno , the commander of day-to-day U.S. military operations in Iraq , but \' it \'s unclear how long that window is going to be open . \' " has not been resolved .\n',
#  'While some economic indicators , such as the Iraq Stock Exchange and the value of the Iraqi dinar , are showing real strength , the status of the estimated 4 million internal and external refugees remains open , as does the high unemployment rate , estimated at over 40 % .\n',
#  "But the fatalities figures are good news on the war-fighting front and we do n't want to miss them .\n",
#  "Success does n't always announce itself .\n",
#  "It 's important not to miss it when it is achieved .\n",
#  'These pages recently said goodbye to global warming .\n',
#  'Ironically , the current spell of global warming , such as it is , can be expected to end just as the Kyoto treaty ends in 2012 , but having nothing to do with reduced emissions from fossil fuels .\n',
#  "For the remainder of this century , it will be global cooling we 'll have to worry about , according to highly credentialed Russian scientist , Dr. Oleg Sorokhtin.Dr .\n",
#  'Sorokhtin , Merited Scientist of Russia and fellow of the Russian Academy of Natural Sciences , is staff researcher of the Oceanology Institute .\n',
#  'He explains the recent warming as a natural trend . "\n',
#  'Earth is now at the peak of one of its passing warm spells .\n',
#  'It started in the 17th century when there was no industrial influence on the climate to speak of and no such thing as the hothouse effect .\n',
#  'The current warming is evidently a natural process and utterly independent of hothouse gases . "\n',
#  'So what will happen in the future ? "\n',
#  'Astrophysics knows two solar activity cycles , of 11 and 200 years .\n',
#  'Both are caused by changes in the radius and area of the irradiating solar surface .\n',
#  'The latest data , obtained by Habibullah Abdusamatov , head of the Pulkovo Observatory space research laboratory , say that Earth has passed the peak of its warmer period , and a fairly cold spell will set in quite soon , by 2012 .\n',
#  'Real cold will come when solar activity reaches its minimum , by 2041 , and will last for 50-60 years or even longer . "\n',
#  'Physical and mathematical calculations predict a new Ice Age .\n',
#  'It will come in 100,000 years , at the earliest , and will be much worse than the previous .\n',
#  'Europe will be ice-bound , with glaciers reaching south of Moscow . "\n',
#  'The high standing of Dr. Sorkhtin and the inherent plausibility of his argument that climate will continue to follow the same basic causal factor , solar activity , make this another heavy blow to the heavy breathing of the global warming alarmists , who insist there is no argument at all .\n',
#  'A US report shows how the enemy controlled the information on the battlefield in Fallujah and used this to force the US and Iraqi forces out , in the first battle there .\n',
#  'The Belmont Club points out UPI coverage of the report by Shaun Waterman .\n',
#  'Here is how the enemy worked : First they kidnapped reporters from major Western news sources , driving them out of the city , and leaving only Al Jazeera , Al Arabiya and local stringers controlled by the enemy as the sole sources of news .\n',
#  "When the US returned with many embedded journalists and cut the enemy 's information monopoly we won .\n",
#  'These figures demonstrate how the insurgency purposely drove the press from the field to recreate the information monopoly they found so advantageous in the opening days of the First Fallujah , when only journalists from Al Jazeera and Al Arabiya were reporting from the scene .\n',
#  'The kidnapping campaign compelled news outlets to rely on stringers who could then be controlled by the insurgency and who could be counted on to miraculously stumble on photo opportunities showing insurgents in action , such as the Pulitzer Prize winning photograph of an Iraqi election worker being killed on Haifa Street .\n',
#  'The effective riposte again turned out to be finding ways to break the reportorial stranglehold the enemy had established .\n',
#  'The information blockade runners turned out to be bloggers and journalists embedded in the military , of whom Michael Yon is perhaps the most famous .\n',
#  'The Iraqi bloggers were protected by their anonymity and the embedded journalists were protected by coalition troops .\n',
#  'These reporters outflanked the wall of " access journalism " which was gradually restricting the majors and created alternative sources of reportage .\n',
#  'Although few in number these blockade runners played a pivotal role in penetrating the " bodyguard of lies " with which al-Qaeda and the Sunni insurgency had surrounded itself .\n',
#  'Mike Huckabee is pretty slick .\n',
#  "He 's the one Republican who 's been boosted by the big media .\n",
#  'Those media headlines got him off to a fast start .\n',
#  'But a couple of days ago he got the press laughing at his shenanigans with his " I \'m NOT negative ! " press conference .\n',
#  '" Mike Huckabee said Monday he would n\'t run a TV ad he \'d prepared blistering Republican rival Mitt Romney as dishonest .\n',
#  'Then he showed it to a room packed with reporters and cameramen . "\n',
#  'So Huckabee is talking to a giant media fest with dozens of TV cameras , surrounded by five anti-Mitt posters .\n',
#  "But he 's very come-to-Jesus about it .\n",
#  "You see , he 's not actually going to run that negative ad on Mitt , because he 's a good person .\n",
#  "And just to show the press that he had the negative ad all ready to run , he 'll tell them all the Mitt criticisms he 's not going to put on TV .\n",
#  '" We have run it positive .\n',
#  'We have gotten here by being positive . "\n',
#  'Even the reporters laughed it up .\n',
#  'So Huckabee tried to get his negative ad out for free , and still got to claim that he was being positive .\n',
#  'Is that slick or what ?\n',
#  'It \'s like the guy whose wife tells him he sounds angry , and he screams at her , " I \'m NOT MAD !! "\n',
#  'A lot of people like Huckabee in person , but he looks like a basically angry man to me .\n',
#  'At his pheasant hunting press show he ended up shooting his 20-gauge shotgun over the heads of the onlookers .\n',
#  "That 's just lousy firearms safety , as any hunter knows .\n",
#  "But Huck was n't sorry .\n",
#  'He said it was his way of telling Mitt Romney just " do n\'t get in my way . "\n',
#  'The press asked him if he really meant to say that , and he just said it again .\n',
#  'He did mean it .\n',
#  "You just do n't do that in a presidential primary .\n",
#  "This is n't High Noon in Dodge City .\n",
#  'Blasting your shotgun over the heads of the press looks like an impulsive action , by a man who allows his anger to take over his judgment .\n',
#  'This is the same guy who \'s written a book called , " Kids who kill : Confronting Our Culture of Violence . "\n',
#  "But he did n't set a good example by shooting off his shotgun over people 's heads .\n",
#  "Huck 's not a conservative but a populist politician , like Bill Clinton and Jimmy Carter .\n",
#  '" I \'m out to change the Republican Party " is his way of saying it .\n',
#  'But then he calls himself a conservative .\n',
#  "Huckabee is n't good on foreign policy , so he makes really basic mistakes .\n",
#  'His advisors just say " he was n\'t briefed " on things like Pakistan and the assassination of Bhutto .\n',
#  "The trouble is that a president ca n't just brush up on this dangerous world when some headline story comes up .\n",
#  "He 's got to be ahead of the curve .\n",
#  'A US president should know that Pakistan has been at the center of the war on terror since before 9/11/01 , when the Taliban sheltered Osama Bin Laden .\n',
#  "Pakistan 's intelligence service set up the Taliban in the first place .\n",
#  'Today it looks like the same AQ-Taliban goons killed Benazir Bhutto .\n',
#  "This ca n't be news to a presidential candidate .\n",
#  "And that 's only Pakistan : What about Russia , China , the Middle East ?\n",
#  "It 's just not good enough .\n",
#  "America ca n't settle for a politician who 's not up to speed , and who violates firearms safety rules to send a political message .\n",
#  "We ca n't afford a politician who plays the liberal media against the conservative base .\n",
#  "Let 's leave the slicksters to the Democrats .\n",
#  'We have better candidates .\n',
#  'James Lewis blogs at dangeroustimes.wordpress.com /\n',
#  'In the aftermath of the " upset " victories in yesterday \'s Iowa caucus by Republican Mike Huckabee and Democrat Barack Obama , both the mainstream media and the political commentariat are in a lather over what these results portend for the 2008 presidential race .\n',
#  'The answer : Very little .\n',
#  'The history of the Iowa caucus shows that it is a poor predictor of who the eventual presidential nominees will be , let alone who will win the general election .\n',
#  'For example : In 1972 , the eventual Democratic nominee George McGovern came in second to Edmund Muskie .\n',
#  'In 1976 , the eventual Democratic nominee , and winner of the general election , Jimmy Carter came in second to an " uncommitted " slate of delegates .\n',
#  'In 1980 , George H.W. Bush bested Ronald Reagan in the Republican caucus .\n',
#  'In 1988 , both George H.W. Bush and Michael Dukakis , the eventual nominees of their respective parties , came in third .\n',
#  "In 1992 , Democrat Tom Harkin won his party 's caucus .\n",
#  "Indeed , the only non-incumbent to win his party 's caucus and then go on to win the general election was George W. Bush in 2000 .\n",
#  'Moreover , we should not forget that Iowa is far from representative of the nation as a whole , either in terms of demographics or economics .\n',
#  "So the fact that a particular candidate appeals to a plurality of his party 's voters in Iowa does not tell us how well he or she will do in other state primaries .\n",
#  "In short , the fact that Huckabee and Obama earned first place honors in this year 's Iowa caucus tells us nothing about their respective candidacies that we did n't already know , to wit , that they are serious candidates for their party 's nomination .\n",
#  'That being said , I believe the " message " out of Iowa is very different for the Democratic and Republican front-runners .\n',
#  "For the Democrats , Obama 's victory , and John Edwards ' second-place finish , clearly indicates that Hillary Clinton 's nomination is not inevitable and that she has much to worry about heading into New Hampshire and Super Tuesday .\n",
# ...
#  'The answer is a real Republican would not .\n',
#  'Senator McCain , as we have seen above , is NOT a Republican and should not , in any way , shape , or form , be on the 2008 Republican ticket .\n',
#  'He is an open border advocate as is Hillary Clinton , Barack Obama , and George Soros !\n',
#  'He has fought against term limits , one of the issues that millions of Americans want and demand , as well as fighting against our dependence on foreign oil !\n',
#  "Senator McCain 's stance on the issues is typically like a Democrat 's ; that is , any which way the wind blows .\n",
#  "It is high-time that Republicans stood up and demanded that we get candidates who uphold our Party 's platform .\n",
#  "If not , then we can either sit at home or write in the only real conservative on the ticket , Fred Thompson 's name , in disgust over the RINOs ( Romney , Giuliani , and McCain ) .\n",
#  'Maybe the GOP needs a tour out in the wilderness in order to produce another Reagan .\n',
#  'But in any event , this writer , and probably many more Americans wo n\'t be voting for a RINO in November so to the RNC , here is a helpful hint : " reexamine who you put forth on the ticket , unless wandering in the wilderness is something you enjoy . "\n',
#  'The prospect of a ringing defeat in New Hampshire has led to speculation that Hillary Clinton soon will fold up her tent and abandon the quest that has animated most of her adult life .\n',
#  "I do n't buy it .\n",
#  'Not now .\n',
#  'I see a slightly different scenario playing out .\n',
#  'But then again , I am prone to a certain amount of wishful thinking when it comes to the fate of the former First Lady / junior Senator from New York .\n',
#  "Robert Schrum speculates that Hillary may be running out of money : She has probably spent much of the $ 100 million that she 's raised , and last week her big givers were being urgently importuned to raise more .\n",
#  'Incredibly , the one-time Dem juggernaut may struggle financially to reach Feb .\n',
#  'I am not nearly as wired-in to Team Clinton as Schrum , but I have never noticed a weakness in the fund-raising department when it comes to the Clintons .\n',
#  'They know how to lean on the moneybags .\n',
#  'In the worst instance , a personal loan to the campaign from the ample Clinton coffers could keep her in the race until the February primaries .\n',
#  'I would love to hear the conversation between the loving couple when Hill asks Bill to co-sign the loan , though .\n',
#  'It is probably true that more members of the Clinton machine , political pros who may see a looming post-Clinton era and want to have a career in it , may be contemplating jumping ship .\n',
#  'So the question becomes what would Hillary do about defectors , especially those who join the Obama surge ?\n',
#  'If the past is any guide , pressure will be brought to bear .\n',
#  'No need to specify what kind of pressure it might be , but the Clinton machine has long demonstrated an ability to keep its own house in order when it comes to protecting secrets and supporting the boss .\n',
#  'Which raises the interesting possibility of insiders spilling their guts in retaliation for the retaliation they have received after jumping ship .\n',
#  'There are a lot of people who have observed the Clintons in a lot of trying circumstances .\n',
#  'If it truly looks like the SS Clinton has taken on water , is listing and about to sink , then the floodgates could open .\n',
#  'It is too soon to actually predict a Wagnerian Götterdämmerung , but neither can one be ruled out as a pure fantasy .\n',
#  'For now , that mere possibility will do quite nicely .\n',
#  'All of a sudden , Hillary has become my candidate of hope for change .\n',
#  'Hat tip : Clarice Feldman Update : Just heard the tearing-up speech and agree with Rush that it was a strategized move , intended to evoke sympathy .\n',
#  "She 's long been told she needs to humanize herself , so that voters can connect with her .\n",
#  'She is also known to have charmed plenty of people in high level small gatherings .\n',
#  'Robert Shrum wrote today : Contrary to the caricatures , Hillary Clinton is a real person , often funny in private , with engaging qualities that have been well-hidden in this campaign .\n',
#  'But the hour is late and even if the real Hillary emerges , voters might see it as just another contrivance .\n',
#  'I see that charm-emitting small group sub-personality as another contrivance , too .\n',
#  'Hillary has a number of distinctly different modes of behavior , appropriate to her goals and circumstances .\n',
#  'Someone like Shrum would see Hillary \'s passionate and vulnerable side as the " real Hillary " whereas I see it as another behavioral modality , used mostly on people she needs to cultivate .\n',
#  'It is a private side , which makes it seem real to those experiencing it .\n',
#  'But there are other private sides : the unimportant staff , treated coldly ; and of course , the private side with Bill .\n',
#  'We hear of the stormy , foul-mouthed raging arguments because they are so audible .\n',
#  'But who knows what else ?\n',
#  'Update : Clarice Feldman emails me : " Edwards \' guy Joe Trippi says she is out of money -- she had $ 35 million in Oct and is spending $ 20 a month .\n',
#  'For what it \'s worth . "\n',
#  'That is an incredible cash burn .\n',
#  'So she will have to cut back drastically if she stays in the race .\n',
#  'She operated regally because she believed in her own inevitability .\n',
#  'That is too much to raise suddenly .\n',
#  'Maybe she is smart enough to see the handwriting on the wall .\n',
#  'Nothing like firing a lot of insiders to generate bad press .\n',
#  'IF she does pull the plug and wants to stay in politics as a Senator , she needs to handle this with dignity , and undoubtedly is aiming for sympathy .\n',
#  'Tearing-up but keeping control could be the first step in withdrawing .\n',
#  'The Götterdämmerung remains a fantasy .\n',
#  'You can judge a man ( or a political movement ) by his enemies .\n',
#  'Tom Maguire notes an interesting thing about the left : Let me see if I understand this - John Edwards and the Krugman Democrats want to negotiate with the Iranians and North Koreans but not the drug companies or health insurers .\n',
#  'Well , as long as we are clear who the bad guys are .\n',
#  "Commenter Steveaz explains the thinking : I 'm seeing a pattern here .\n",
#  'If a threat is real and deadly , the Democrats want to talk to it , not " fight " it .\n',
#  'But if a threat is illusory , mundane , and invisible , then the Democrats want to " fight " it .\n',
#  'Of course , their idea of a fight is to convene a commission .\n',
#  'But just like their " war " on poverty , the Dem \'s " fights " against " Big Pharma " and " Big Oil " are only attempts to gain votes .\n',
#  'Maybe it \'s better that the Democrats wo n\'t " fight " Iranian nukes and global Islamofascism .\n',
#  'If they did , we \'d have to sit thru CNN \'s " analysis " of a zillion politicized commission-reports , And a Valerie Plame , a Gorelick , or a Downing Street Memo can always get slipped into these committees to ensure the " punches " fall on the Left \'s favorite villains : Americans and Republicans .\n',
#  'No wonder why when Dems are in charge our enemies steal our lunch money .\n',
#  'Are these guys suicidal or what ?\n',
#  'A couple of Iranian patrol boats took off after three US naval warships and , according to the Pentagon , " harrased " the ships in the narrow Straits of Hormuz : In what U.S. officials called a serious provocation , Iranian Revolutionary Guard boats harassed and provoked three U.S. Navy ships in the strategic Strait of Hormuz , threatening to explode the American vessels .\n',
#  'U.S. forces were on the verge of firing on the Iranian boats in the early Sunday incident , when the boats turned and moved away , a Pentagon official said .\n',
#  '" It is the most serious provocation of this sort that we \'ve seen yet , " said the official , who spoke on condition of anonymity because he was not authorized to speak on the record .\n',
#  'The incident occurred at about 5 a.m. local time Sunday as a U.S. Navy cruiser , destroyer and frigate were on their way into the Persian Gulf and passing through the strait - a major oil shipping route .\n',
#  'Five small boats began charging the U.S. ships , dropping boxes in the water in front of the ships and forcing the U.S. ships to take evasive maneuvers , the Pentagon official said .\n',
#  'There were no injuries but the official said there could have been , because the Iranian boats turned away " literally at the very moment that U.S. forces were preparing to open fire " in self defense .\n',
#  'The official said he did n\'t have the precise transcript of communications that passed between the two forces , but said the Iranians radioed something like " we \'re coming at you and you \'ll explode in a couple minutes . "\n',
#  'Iran has been aggressive against US ships in the Straits before .\n',
#  'But this kind of action smacks of suicide - something it appears they wanted the Americans to think .\n',
#  'More likely they were hoping to start an incident that would have the rest of the world calling for the Navy to leave the Persian Gulf alltogether .\n',
#  'Not very smart - but neither is buzzing a missile frigate .\n',
#  'Our seamen have a long memory and few forget what happened to the USS Cole when a small boat filled with explosives crashed into her , killing 17 men .\n',
#  'No doubt there will be more incidents of this nature in the future as the Iranians continue to test our resolve .\n',
#  "I almost did n't want to blog about this today but it was the last debate before voting begins and some of you may have wondered why a premier political site like AT was n't covering it .\n",
#  "I 'm talking about the Republican Debate last night on Fox .\n",
#  'For those who were able to keep awake through it all , I congratulate you .\n',
#  'I , myself was unable to keep my eyes open and missed the last 15 thrilling minutes .\n',
#  'But from what I saw , I would make the following observations .1 .\n',
#  'Mitt Romney had his best debate in months and may have reversed the McCain momentum a little .\n',
#  "It probably wo n't be enough for him to win but it will keep him close enough that he can go on to Michigan with some confidence .\n",
#  'In fact , if he can narrow the gap to 5 points or less , Romney may be able to claim a comeback of sorts .2 .\n',
#  'McCain disappeared last night .\n',
#  'He was subdued and had little energy .\n',
#  'Perhaps he was playing it safe .\n',
#  'If so , he made a mistake .3 .\n',
#  "Mike Huckabee lacked his usual charm and wit , could n't answer a direct question about his tax increases while governor of Arkansas , and generally stunk up the place .\n",
#  'For his sake , I hope no one in South Carolina was watching .4 .\n',
#  'Fred Thompson should employ a comfy red chair rather than his red pickup truck as a campaign symbol .\n',
#  'Thompson has excelled in these roundtable debates where everyone is seated and the mood is a little more relaxed .\n',
#  "His performance wo n't help him in New Hampshire but for his sake , I hope everyone in South Carolina was watching .\n",
#  'Rudy Giuliani was better last night than he was in the ABC debate on Saturday .\n',
#  'But the focus has gone off of Giuliani and he is going to have to find a way to recapture interest in his campaign .\n',
#  'Right now , no one cares about Florida which is where Rudy is pinning most of his hopes .\n',
#  'He seems to have moved into the background with the focus on these early primaries .\n',
#  'Summary : Fred won on points .\n',
#  "Romney on style and because he needed to hit a home run , should be declared the overall winner. I 'd say McCain was the loser because he failed to rise to the challenge and appeared to be resting on his laurels .\n",
#  "It should n't hurt him enough that he loses tomorrow but it will probably take away some of his momentum .\n",
#  'Drudge notes that there is talk about Hillary withdrawing altogether from the race for the Democratic nomination , indicating staffers are concerned about protecting the Clinton brand .\n',
#  'But I suspect Jay Cost has a better explanation : This is not 1992 any more and she has not the numerical and geographic advantages that made it possible for him to be " the comeback kid " who came from behind to walk off with the nomination : Super Tuesday was designed by southern Democrats after Mondale \'s nomination in 1984 .\n',
#  'They wanted to use their weight to nominate a more moderate candidate who would better reflect their interests .\n',
#  'The plan backfired in 1988 , as Al Gore and Jesse Jackson effectively neutralized one another , and Michael Dukakis won the nomination .\n',
#  'But the plan succeeded in 1992 -- as Bill Clinton lost seven of the first nine contests , but still won the nomination .\n',
#  'This points out a critical difference between Bill and Hillary .\n',
#  'Bill won the nomination when the battle came to his home turf .\n',
#  "The South was Clinton 's firewall in 1992 .\n",
#  'It was going to get behind Bill almost regardless of where he finished in the previous contests .\n',
#  'Hillary has no firewall that is based upon regional affinity .\n',
#  "Of course , she is currently strong in many of this year 's Super Tuesday states -- California , New Jersey , Connecticut , etc .\n",
#  'However , she is not a favorite daughter .\n',
#  'These states are not nearly as dependable for her as Tennessee , Mississippi , and South Carolina were for Bill .\n',
#  'Another critical difference can be noted when we look at the results of the early contests .\n',
#  'Of the contests prior to Super Tuesday , they were split five ways : Harkin , Kerrey , Tsongas , Brown , and Clinton all won at least one contest before March 10 .\n',
#  'There was no significant consolidation of the race because the early states kept disagreeing with one another .\n',
#  'This helped Bill .\n',
#  'He could lose and lose and lose because no single opponent won and won and won .\n',
#  'Hillary does not enjoy this kind of advantage .\n',
#  'The 2008 Democratic contest is between Clinton and Obama .\n',
#  'So , if she loses seven of the first eight contests contests , Obama wins seven of the first eight .\n',
#  'This would create a dramatically different dynamic than in 1992 .\n',
#  "Thus , we see here two of Clinton 's relative weaknesses as a frontrunner .\n",
#  'She has no firewall that stems from her geographical roots .\n',
#  'She also does not have the luxury of multiple opponents .\n',
#  'President Pervez Musharraf said in an interview broadcast last night on " 60 Minutes " that Prime Minister Benazir Bhutto was to blame for her own assassination : For standing up outside the car , I think it was she to blame alone -- nobody else .\n',
#  'Responsibility is hers , " the former general told CBS \' " 60 Minutes . "\n',
#  'Bhutto was killed December 27 in Rawalpindi , south of the Pakistani capital Islamabad , while she was standing in an armored moving car after rallying supporters for now-postponed parliamentary elections .\n',
#  'Her head was above the roof and unprotected at the time of the attack .\n',
#  "The cause of her death is not clear : a bomber blew himself up near Bhutto 's limousine and videotape showed a gunman present , though no autopsy has been carried out .\n",
#  'Asked if Bhutto could have been shot , Musharraf said , " Yes , absolutely , yes .\n',
#  'Possibility . "\n',
#  'He has said he welcomes an international investigation .\n',
#  'Musharraf , who seized power in a bloodless coup in 1999 , rejected criticism that his government did not do enough to provide security to Bhutto , who was seeking to regain the post of prime minister .\n',
#  'He noted that she had already survived one assassination attempt and " was given more security than any other person . "\n',
#  "Musharraf is n't doing himself any good with western audiences by blaming the victim for her own death .\n",
#  ...]

# %%
find_verbs_with_associated_adverbs(nlp, text=corpus[6], verbs=verbs)
# Out:
# /pytorch/aten/src/ATen/native/cuda/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.
# {}

# %%
doc = nlp(corpus[6])
# Out:
# /pytorch/aten/src/ATen/native/cuda/LegacyDefinitions.cpp:19: UserWarning: masked_fill_ received a mask with dtype torch.uint8, this behavior is now deprecated,please use a mask with dtype torch.bool instead.

# %%
def find_all_adverb_with_associated_verbs(nlp, corpus: List[str], verbs: List[str]):
    result = dict()
    for text in corpus:
        find_verbs_with_associated_adverbs(nlp, text=text, verbs=verbs, verb_adverb=result)
    
    return result

# %%
import warnings
warnings.filterwarnings('ignore')

# %%
verb_assoc_adverb = find_all_adverb_with_associated_verbs(nlp, corpus, verbs)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-84-1a0df4e40c92> in <module>
# ----> 1 verb_assoc_adverb = find_all_adverb_with_associated_verbs(nlp, corpus, verbs)
#
# <ipython-input-83-1f241039cc2b> in find_all_adverb_with_associated_verbs(nlp, corpus, verbs)
#       2     result = dict()
#       3     for text in corpus:
# ----> 4         find_verbs_with_associated_adverbs(nlp, text=text, verbs=verbs, verb_adverb=result)
#       5
#       6     return result
#
# <ipython-input-63-8e7416e9da21> in find_verbs_with_associated_adverbs(nlp, text, verbs, verb_adverb)
#       1 def find_verbs_with_associated_adverbs(nlp, text: str, verbs: List[str],
#       2                                        verb_adverb: Dict[str, Dict[str, int]] = None):
# ----> 3     doc = nlp(text)
#       4
#       5     if verb_adverb is None:
#
# ~/.local/lib/python3.7/site-packages/stanfordnlp/pipeline/core.py in __call__(self, doc)
#     174         if isinstance(doc, str) or isinstance(doc, list):
#     175             doc = Document(doc)
# --> 176         self.process(doc)
#     177         return doc
#
# ~/.local/lib/python3.7/site-packages/stanfordnlp/pipeline/core.py in process(self, doc)
#     168         for processor_name in self.processor_names:
#     169             if self.processors[processor_name] is not None:
# --> 170                 self.processors[processor_name].process(doc)
#     171         doc.load_annotations()
#     172
#
# ~/.local/lib/python3.7/site-packages/stanfordnlp/pipeline/pos_processor.py in process(self, doc)
#      30         preds = []
#      31         for i, b in enumerate(batch):
# ---> 32             preds += self.trainer.predict(b)
#      33         preds = unsort(preds, batch.data_orig_idx)
#      34         batch.conll.set(['upos', 'xpos', 'feats'], [y for x in preds for y in x])
#
# ~/.local/lib/python3.7/site-packages/stanfordnlp/models/pos/trainer.py in predict(self, batch, unsort)
#      69         self.model.eval()
#      70         batch_size = word.size(0)
# ---> 71         _, preds = self.model(word, word_mask, wordchars, wordchars_mask, upos, xpos, ufeats, pretrained, word_orig_idx, sentlens, wordlens)
#      72         upos_seqs = [self.vocab['upos'].unmap(sent) for sent in preds[0].tolist()]
#      73         xpos_seqs = [self.vocab['xpos'].unmap(sent) for sent in preds[1].tolist()]
#
# ~/.local/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/.local/lib/python3.7/site-packages/stanfordnlp/models/pos/model.py in forward(self, word, word_mask, wordchars, wordchars_mask, upos, xpos, ufeats, pretrained, word_orig_idx, sentlens, wordlens)
#     120         lstm_inputs = PackedSequence(lstm_inputs, inputs[0].batch_sizes)
#     121
# --> 122         lstm_outputs, _ = self.taggerlstm(lstm_inputs, sentlens, hx=(self.taggerlstm_h_init.expand(2 * self.args['num_layers'], word.size(0), self.args['hidden_dim']).contiguous(), self.taggerlstm_c_init.expand(2 * self.args['num_layers'], word.size(0), self.args['hidden_dim']).contiguous()))
#     123         lstm_outputs = lstm_outputs.data
#     124
#
# ~/.local/lib/python3.7/site-packages/torch/nn/modules/module.py in __call__(self, *input, **kwargs)
#     530             result = self._slow_forward(*input, **kwargs)
#     531         else:
# --> 532             result = self.forward(*input, **kwargs)
#     533         for hook in self._forward_hooks.values():
#     534             hook_result = hook(self, input, result)
#
# ~/.local/lib/python3.7/site-packages/stanfordnlp/models/common/hlstm.py in forward(self, input, seqlens, hx)
#     100             cs.append(ct)
#     101
# --> 102             input = PackedSequence(h.data + torch.sigmoid(self.gate[l](input.data)) * highway_func(self.highway[l](input.data)), input.batch_sizes)
#     103
#     104         if self.pad:
#
# KeyboardInterrupt:

# %% [markdown]
# #### 4. на виході програма повинна видати десять найчастотніших прислівників для кожного дієслова (разом із частотою). Приклад виводу:

# %% [markdown]
# #### 5. збережіть програму та результати аналізу на корпусі (вивід) у директорії з вашим іменем

# %% [markdown]
# ### 2. Українська мова

# %% [markdown]
# #### 1. напишіть функцію, яка знаходить у реченні іменник, що позначає істоту, і витягає усі прикметники, якими цей іменник керує

# %% [markdown]
# #### 2. напишіть програму, яка знайде усі можливі словосполучення прикметників та іменників-істот у романі "Тигролови"

# %% [markdown]
# #### 3. на виході програма повинна видати усі знайдені словосполучення та їх частоти. Приклад виводу: <br/>
# 84: старий сірко <br/>
# 5: великий начальник <br/>

# %% [markdown]
# #### 4. збережіть програму та результати виводу в директорії з вашим іменем
