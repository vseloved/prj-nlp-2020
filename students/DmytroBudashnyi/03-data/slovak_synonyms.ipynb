# %%
import re
import xml.sax

# %%
articles_filename = './data/skwiktionary-20200301-pages-articles.xml'

# %%
class ArticlesHandler(xml.sax.ContentHandler):
    LANG_PATTERN = '== Slovenčina =='
    SYN_PATTERN = '==== Synonymá ===='
    SYN_REGEXP = re.compile(".\[\[(\w+)\]\].?")

    def __init__(self):
        self.current_data = ""
        self.title = ""
        self.text = []
        self.synonym_list = []

    def _find_synonyms(self):
        lang_detected = False
        syn_detected = False

        synonym_lines = []
        for line in self.text:
            #print(line)
            if line == self.LANG_PATTERN:
                lang_detected = True
            elif lang_detected and line == self.SYN_PATTERN:
                syn_detected = True
            elif lang_detected and syn_detected and line.startswith('=='):
                lang_detected = False
                syn_detected = False
                break
            elif lang_detected and syn_detected:
                synonym_lines.append(line)

        return self.SYN_REGEXP.findall(' '.join(synonym_lines))

    # Call when an element starts
    def startElement(self, tag, attributes):
        self.current_data = tag

    # Call when an elements ends
    def endElement(self, tag):
        if self.current_data == 'text':
            synonyms = self._find_synonyms()
            if synonyms:
                self.synonym_list.append(list(set(synonyms + [self.title])))
        self.current_data = ""
        self.text = []

    # Call when a character is read
    def characters(self, content):
        if self.current_data == "title":
            self.title = content
        elif self.current_data == 'text':
            content = content.strip()
            if content:
                self.text.append(content)

# %%
def parse_articles(filename):
    parser = xml.sax.make_parser()
    # turn off namepsaces
    parser.setFeature(xml.sax.handler.feature_namespaces, 0)

    # override the default ContextHandler
    handler = ArticlesHandler()
    parser.setContentHandler(handler)

    parser.parse(filename)

    # shitty code FTW
    return handler.synonym_list

# %%
synonym_list = parse_articles(articles_filename)

# %%
len(synonym_list)
# Out:
# 531

# %%
synonym_list
# Out:
# [['mať', 'pôvod', 'matka', 'mater', 'mamka', 'mama', 'mamička'],
#  ['abatiša', 'opátka'],
#  ['abiturient', 'maturant'],
#  ['ablácia', 'denudácia', 'odnos'],
#  ['mimoriadnosť',
#   'abnormálnosť',
#   'pomätenosť',
#   'nezvyčajnosť',
#   'úchylnosť',
#   'nenormálnosť'],
#  ['abonent', 'předplatitel'],
#  ['abortovať', 'potratiť'],
#  ['abortácia', 'interrupcia', 'abortus', 'výškrab', 'potrat'],
#  ['zdrobnenina', 'deminutívum'],
#  ['prológ', 'úvod', 'predslov'],
#  ['oplzlosť', 'frivolnosť', 'necudnosť'],
#  ['tata', 'otec', 'papa', 'ocko', 'otecko', 'apa', 'tatko', 'tato'],
#  ['zdraviť', 'vítať'],
#  ['i', 'aj', 'a', 'plus', 'ale'],
#  ['o', 'na', 'k', 'v', 'po', 'ohľadom', 'ohľadne'],
#  ['existovať', 'jestvovať', 'byť'],
#  ['urobiť', 'robiť', 'vyrobiť'],
#  ['vlastniť', 'mať'],
#  ['nadpriemerný',
#   'ozrutný',
#   'dospelý',
#   'mnohopočetný',
#   'priveľký',
#   'veľkolepý',
#   'masívny',
#   'vplyvný',
#   'významný',
#   'vysoký',
#   'silný',
#   'veľký',
#   'dôležitý',
#   'extrémny',
#   'obrovský',
#   'dlhý',
#   'nadšený',
#   'početný',
#   'vyrastený'],
#  ['mašina', 'stroj'],
#  ['milá', 'dievča', 'dievka', 'dievčina', 'deva'],
#  ['osvedčenie', 'vysvedčenie', 'potvrdenie'],
#  ['grátis', 'zadarmo', 'zdarma'],
#  ['latinčina', 'latina'],
#  ['jazyk', 'reč'],
#  ['zriedka', 'niekedy'],
#  ['lokál', 'lokatív'],
#  ['HG', 'HptGefr'],
#  ['experimentalista', 'experimentátor'],
#  ['bundáš', 'pes', 'havkáč', 'dunčo', 'havo', 'havko', 'bastard'],
#  ['názov', 'meno', 'pomenovanie'],
#  ['propozícia', 'návrh', 'nápad'],
#  ['slogan', 'heslo', 'motto'],
#  ['zamestnanie',
#   'oblasť',
#   'miesto',
#   'priestor',
#   'post',
#   'pozícia',
#   'poradie',
#   'umiestnenie',
#   'dejisko',
#   'funkcia',
#   'pľac',
#   'kapacita',
#   'zóna',
#   'časť'],
#  ['fotelka', 'kreslo', 'úrad'],
#  ['svetlo', 'lampa', 'žiarenie', 'deň'],
#  ['vaňa', 'žľab', 'koryto', 'riečisko'],
#  ['úsilie',
#   'zamestnanie',
#   'dielo',
#   'úloha',
#   'povinnosť',
#   'produkt',
#   'robota',
#   'pracovisko',
#   'práca'],
#  ['spájanie',
#   'združovanie',
#   'ucelenie',
#   'integrácia',
#   'zjednotenie',
#   'scelenie'],
#  ['šikanéria', 'šikanácia', 'šikanovanie'],
#  ['väznica', 'žalár'],
#  ['auto', 'automobil'],
#  ['substantívum', 'podstatné meno'],
#  ['požiarnik', 'hasič'],
#  ['žandár', 'policajt'],
#  ['väzenie', 'väznica', 'žalár'],
#  ['holohumnica', 'mlat'],
#  ['kundivál',
#   'cikoš',
#   'kjelbas',
#   'salám',
#   'vták',
#   'cicina',
#   'cicinbrus',
#   'jebák',
#   'péro',
#   'fas',
#   'kokot',
#   'penis',
#   'švonec',
#   'chuj',
#   'čurák',
#   'pičus'],
#  ['taverna', 'hostinec', 'krčma', 'šenk'],
#  ['poliš', 'policajt'],
#  ['primeranosť', 'adekvátnosť'],
#  ['adekvátny', 'primeraný'],
#  ['Oľbinov', 'Albinov'],
#  ['patrola', 'sledovanie', 'pozorovanie'],
#  ['príklad', 'vzor', 'úloha', 'ukážka', 'prípad'],
#  ['chlap', 'muž', 'manžel', 'pán'],
#  ['hocikto', 'niekto', 'človek', 'ľudstvo', 'civilizácia', 'osoba'],
#  ['hej', 'pravdaže', 'dobre', 'áno'],
#  ['publikácia', 'brožúra', 'zväzok', 'kniha'],
#  ['živočích', 'zviera'],
#  ['kvetina', 'bylina', 'rastlina'],
#  ['driek', 'pás'],
#  ['ročník', 'letá', 'rok', 'a'],
#  ['slovník', 'encyklopédia', 'lexikón'],
#  ['údajne', 'vraj'],
#  ['ľadvina', 'oblička'],
#  ['svetlo', 'zmena', 'šichta', 'deň', 'škola', 'práca'],
#  ['vonku', 'pod', 'nebo'],
#  ['plnoletý', 'dospelý', 'zrelý'],
#  ['dravec', 'šelma'],
#  ['pomýlený', 'zlý', 'chybný'],
#  ['nieže', 'nie', 'kdeže'],
#  ['nezhoda', 'protest', 'nesúhlas'],
#  ['pendant', 'náprotivok'],
#  ['ratolesť', 'potomok', 'decko', 'dieťa'],
#  ['prameň', 'studnica', 'zdroj', 'žriedlo'],
#  ['veľa', 'dačo', 'niečo', 'čosi', 'voľačo', 'trocha'],
#  ['dôkaz', 'dôvod', 'argument'],
#  ['hop', 'hopsa'],
#  ['čestný',
#   'celý',
#   'vhodný',
#   'želateľný',
#   'ctihodný',
#   'šikovný',
#   'vyhovujúci',
#   'prívetivý',
#   'láskavý',
#   'dobrý',
#   'talentovaný',
#   'chutný',
#   'príjemný',
#   'prijateľný',
#   'vľúdny',
#   'poriadny',
#   'užitočný',
#   'kvalitný',
#   'akceptovateľný',
#   'schopný',
#   'priaznivý'],
#  ['adjektívum', 'prídavné meno'],
#  ['krátky',
#   'primalý',
#   'tesný',
#   'slabý',
#   'neveľký',
#   'drobný',
#   'málopočetný',
#   'malý'],
#  ['džbán', 'krčah'],
#  ['urna', 'popolnica'],
#  ['žihľava', 'pŕhľava'],
#  ['žihľava', 'pŕhľava'],
#  ['mrákota', 'mdloba', 'bezvedomie'],
#  ['podlaha', 'dlážka'],
#  ['stálica', 'slnko', 'hviezda'],
#  ['hvezdáreň', 'observatórium'],
#  ['ornica', 'krajina', 'dlážka', 'Zemeguľa', 'kontinent', 'zem'],
#  ['obežnica', 'planéta'],
#  ['zrod', 'pôvod'],
#  ['obežnica', 'satelit'],
#  ['zrod', 'vznik'],
#  ['juchú', 'hurá', 'aleluja'],
#  ['rúbať', 'sekať', 'ťať'],
#  ['tomahawk', 'valaška', 'topor', 'sekera'],
#  ['dotaz', 'otázka'],
#  ['vytešený', 'šťastný', 'radostný', 'blažený'],
#  ['natešený', 'blažený', 'euforický', 'šťastný'],
#  ['podagra', 'dna', 'pakostnica', 'lámka'],
#  ['bez', 'šeřík'],
#  ['mužský', 'chlapský', 'muž', 'pánsky', 'chlap', 'manžel'],
#  ['verzia', 'charakter', 'vzhľad', 'podoba', 'forma', 'tvar'],
#  ['Wikislovník:Kaviareň/Archív 2012', 'synonymum'],
#  ['hocikde', 'všade'],
#  ['korózia', 'hrdzavenie'],
#  ['Kamalarai', 'gamilarájčina', 'Gamilaroi', 'Kamilarai', 'Kamilaroi'],
#  ['kengura', 'klokan', 'kenguru'],
#  ['babka', 'starká'],
#  ['mola', 'motýľ'],
#  ['koža', 'derma', 'pokožka'],
#  ['hrdlo', 'krk'],
#  ['bujak', 'býk'],
#  ['ústredie', 'centrum', 'centrála', 'stredisko', 'stred', 'jadro'],
#  ['cukrovka', 'diabetes'],
#  ['črvotoč', 'červotoč'],
#  ['batizmus', 'baťovstvo'],
#  ['batizmus', 'baťovstvo'],
#  ['tribadizmus', 'tribadia', 'lesbizmus', 'sapfizmus'],
#  ['leska',
#   'lesbičanka',
#   'buzerantka',
#   'teplá',
#   'buziška',
#   'lesbička',
#   'lesba',
#   'homoška'],
#  ['leska',
#   'lesbičanka',
#   'buzerantka',
#   'teplá',
#   'buziška',
#   'lesbička',
#   'lesba',
#   'homoška'],
#  ['aberačný', 'odchylný'],
#  ['habešský', 'etiópsky', 'abesínsky'],
#  ['abiotický', 'neživotný'],
#  ['dnešný', 'súčasný', 'moderný'],
#  ['abdominálny', 'brušný'],
#  ['amorálny', 'nemravný', 'nemorálny'],
#  ['hrušeň', 'hruška'],
#  ['bezškrupulózny', 'bezohľadný', 'neetický'],
#  ['fibrózny', 'vláknitý', 'väzivový'],
#  ['gangrenózny', 'sneťový'],
#  ['guľatý', 'guľovitý'],
#  ['nemoc', 'choroba'],
#  ['telesný', 'fyzický'],
#  ['heretický', 'kacírsky'],
#  ['sacharid', 'cukor'],
#  ['obilovina', 'obilnina'],
#  ['emočný', 'emocionálny'],
#  ['internacionálny', 'medzinárodný'],
#  ['nedbanlivý', 'nenútený', 'nonšalantný', 'ležérny'],
#  ['autokratický', 'absolutistický'],
#  ['necyklický', 'acyklický'],
#  ['tubera', 'suchoty', 'tuberkulóza'],
#  ['suchotiny', 'suchoty', 'tubera'],
#  ['levulóza', 'fruktóza'],
#  ['pľúcny', 'pulmonálny'],
#  ['pyj', 'penis'],
#  ['dekoratívny', 'okrasný', 'ozdobný'],
#  ['morušovník', 'moruša'],
#  ['hluchost', 'hluchota'],
#  ['kalcium', 'vápnik'],
#  ['chalífa', 'kalif'],
#  ['anabaptizmus', 'novokrstenectvo'],
#  ['absolutizmus', 'autokracia'],
#  ['mosaizmus', 'judaizmus'],
#  ['dóm', 'katedrála'],
#  ['kysličník', 'oxid'],
#  ['opera', 'spevohra'],
#  ['oxygén', 'kyslík'],
#  ['kálium', 'draslík'],
#  ['atmosféra', 'ovzdušie', 'nálada', 'duch', 'nadanie', 'založenie', 'myseľ'],
#  ['nitrogénium', 'dusík'],
#  ['abdominálny', 'brušný'],
#  ['abnormálny', 'nezvyčajný', 'mimoriadny', 'zvláštny'],
#  ['adverbiálny', 'príslovkový'],
#  ['náhly', 'pálčivý', 'akútny', 'prudký'],
#  ['anomálny', 'nezvyčajný', 'neprirodzený'],
#  ['domýšľavý', 'nadutý', 'arogantný'],
#  ['voňavý', 'aromatický'],
#  ['promptnosť',
#   'expresnosť',
#   'rýchlosť',
#   'švung',
#   'prevodovka',
#   'rapídnosť',
#   'čerstvosť',
#   'friškosť',
#   'bleskurýchlosť',
#   'frišnosť',
#   'bystrosť',
#   'bleskovosť',
#   'rapidita'],
#  ['liturgický', 'bohoslužobný'],
#  ['predvianočný', 'adventný'],
#  ['tučný', 'objemný', 'plnoštíhly', 'korpulentný', 'zavalitý'],
#  ['chytený', 'frcnutý', 'drgnutý'],
#  ['hladný', 'lačný'],
#  ['dermálny', 'kožný'],
#  ['hypodermálny', 'podkožný'],
#  ['pokožkový', 'epidermálny'],
#  ['pečeňový', 'hepatálny'],
#  ['bukovina', 'bučina'],
#  ['ponáhľať sa', 'súriť'],
#  ['východný', 'orientálny'],
#  ['bigotný', 'pobožnostkársky'],
#  ['poľnohospodársky', 'agrárny'],
#  ['amfotérny', 'obojaký'],
#  ['šmykľavý', 'klzký'],
#  ['možno', 'azda', 'hádam'],
#  ['lingvistika', 'jazykoveda'],
#  ['tepna', 'artéria'],
#  ['celoeurópsky', 'paneurópsky'],
#  ['osový', 'axiálny'],
#  ['cirkulačný', 'obehový'],
#  ['apendikálny', 'apendikulárny'],
#  ['zvieratníkový', 'zodiakálny'],
#  ['svalový', 'muskulárny'],
#  ['interdentálny', 'medzizubný'],
#  ['znelý', 'zvučný'],
#  ['borovica', 'bôr', 'sosna'],
#  ['vaginálny', 'pošvový'],
#  ['kvaternárny', 'štvorzložkový'],
#  ['výstrelok',
#   'extrémnosť',
#   'extrém',
#   'krajnosť',
#   'výstrednosť',
#   'extravagancia'],
#  ['vodík', 'hydrogén'],
#  ['kremík', 'silícium'],
#  ['bifurkačný', 'rozdeľovací'],
#  ['posmrtný', 'záhrobný'],
#  ['výchovný', 'edukačný'],
#  ['hemostatikum', 'hemostyptikum'],
#  ['sviňa', 'prasnica'],
#  ['suka', 'psica'],
#  ['deka-', 'da'],
#  ['chrček', 'škrečok'],
#  ['trudovina', 'akné'],
#  ['lumbálny', 'bedrový'],
#  ['prenosný', 'nákazlivý', 'infekčný'],
#  ['rubeola', 'ružienka'],
#  ['anemogamia',
#   'vetrosnubnosť',
#   'vetromilnosť',
#   'vetrosprašnosť',
#   'anemofília'],
#  ['Brazília', 'Brazílska federatívna republika'],
#  ['Argentínska republika', 'Argentína'],
#  ['striedavka', 'malária'],
#  ['protikresťanský', 'antikresťanský'],
#  ['hranostaj', 'hermelín'],
#  ['kvapavka', 'tripeľ', 'gonorea'],
#  ['epilepsia', 'padúcnica'],
#  ['bielokrvnosť', 'leukémia', 'bledokrvnosť'],
#  ['nádorový', 'tumorový'],
#  ['cerebrálny', 'mozgový'],
#  ['Albánska republika', 'Albánsko'],
#  ['ovčie kiahne', 'varicela'],
#  ['kiahne', 'sypanice'],
#  ['privátny', 'osobný', 'súkromný'],
#  ['enzým', 'biokatalyzátor'],
#  ['obrovský', 'enormný', 'ohromný', 'nesmierny'],
#  ['autonómny', 'nezávislý'],
#  ['šesťuholníkový', 'hexagonálny'],
#  ['moruša', 'morušovník'],
#  ['pernoperný', 'bilabiálny', 'obojperný'],
#  ['pohlavný', 'sexuálny'],
#  ['genitálny', 'pohlavný'],
#  ['ekvatoriálny', 'rovníkový'],
#  ['herniálny', 'prietržný'],
#  ['purulentný', 'hnisavý'],
#  ['ochorenie', 'choroba'],
#  ['nákazlivý', 'infekčný'],
#  ['chcenie', 'žiadostivosť'],
#  ['močopudný', 'diuretický'],
#  ['mútovník', 'dbanka', 'maselnica', 'mútovnica'],
#  ['minerál', 'nerast'],
#  ['domáci', 'pôvodný', 'domorodý', 'miestny'],
#  ['bozk', 'pocel'],
#  ['bosorkyně', 'bosorka', 'bosořice'],
#  ['fluorit', 'kazivec'],
#  ['periost', 'okostica'],
#  ['hormón', 'inkrét'],
#  ['lejak', 'prietrž', 'lejavica', 'hernia'],
#  ['pitevný', 'obdukčný'],
#  ['trojklaný nerv', 'trigeminus'],
#  ['prýštiť', 'vytryskovať', 'vystrekovať', 'brýzgať'],
#  ['vretenica', 'zmija'],
#  ['faryngálny', 'hltanový'],
#  ['pórovitý', 'porézny'],
#  ['myšlienka', 'nápad'],
#  ['malina', 'malinčiak', 'maliník', 'malináč'],
#  ['cukrovkár', 'diabetik'],
#  ['tumor', 'novotvar', 'nádor'],
#  ['bránica', 'diafragma'],
#  ['súmestie', 'konurbácia'],
#  ['súmestie', 'konurbácia'],
#  ['platidlo', 'peniaze', 'mena'],
#  ['gate', 'nohavice'],
#  ['omša', 'eucharistia'],
#  ['Ruská federácia', 'Rusko'],
#  ['herec', 'komediant'],
#  ['Adamovo jablko', 'ohryzok'],
#  ['liturgický', 'bohoslužobný'],
#  ['urín', 'moč', 'urína'],
#  ['análny', 'ritný'],
#  ['orálny', 'ústny'],
#  ['takmer', 'bezmála', 'skoro', 'temer'],
#  ['piadimužík', 'piadimužíček', 'škriatok', 'trpaslík', 'trpaslíček'],
#  ['hraničný', 'demarkačný'],
#  ['tepna', 'artéria'],
#  ['riť', 'konečník'],
#  ['krivica', 'rachitída'],
#  ['osrdcovník', 'perikard'],
#  ['pošva', 'vagína'],
#  ['dráždec', 'klitoris'],
#  ['predstojnica', 'prostata'],
#  ['prsník', 'ňadro'],
#  ['glukóza', 'dextróza'],
#  ['malomocenstvo', 'lepra'],
#  ['karyokinéza', 'mitóza'],
#  ['incestný', 'krvismilný'],
#  ['incestný', 'krvismilný'],
#  ['krvismilstvo', 'incest'],
#  ['alumínium', 'hliník'],
#  ['ukolébavka', 'uspávanka'],
#  ['hematit', 'krveľ'],
#  ['nemecký', 'vlčiak'],
#  ['malík', 'malíček'],
#  ['zázvor', 'ďumbier'],
#  ['narkoman', 'toxikoman', 'narkotik'],
#  ['somár', 'osol'],
#  ['sulfid', 'sírnik'],
#  ['zubár', 'stomatológ'],
#  ['malík', 'malíček'],
#  ['sopliak', 'holopysk'],
#  ['tyč', 'žrď'],
#  ['cudzopasník', 'parazit'],
#  ['odpustiť', 'prepáčiť'],
#  ['gáza', 'mul'],
#  ['arkebúza', 'hákovnica'],
#  ['hrča', 'sumec'],
#  ['rabbi', 'rabi', 'rabín'],
#  ['bicykel', 'velocipéd', 'koleso'],
#  ['velocipéd', 'koleso'],
#  ['akcia', 'účastina'],
#  ['kozmonautika', 'astronautika'],
#  ['matice', 'matka'],
#  ['matka', 'matica'],
#  ['robota', 'lopota', 'dřina'],
#  ['strechan', 'dóma'],
#  ['referendum', 'plebiscit'],
#  ['oběžnice', 'planeta'],
#  ['bomba', 'puma'],
#  ['akomodácia', 'adaptácia', 'prispôsobenie'],
#  ['meštianstvo', 'buržoázia'],
#  ['bravčovina', 'mäso'],
#  ['počítať', 'rátať', 'kalkulovať', 'počtovať'],
#  ['pľac', 'miesto', 'dejisko', 'scéna'],
#  ['hrnček', 'šálka'],
#  ['jazero', 'pleso', 'lagúna'],
#  ['ves', 'obec', 'dedina'],
#  ['vyhľadávať', 'zhľadávať', 'zhľadúvať', 'hľadať'],
#  ['slovo', 'prísľub', 'sľub', 'reč'],
#  ['napätý', 'konfliktový', 'konfliktný'],
#  ['pôvabný', 'šarmantný', 'podmanivý', 'očarujúci'],
#  ['dohliadač', 'strážca', 'dozorca'],
#  ['sprievodca', 'vôdca', 'bedeker'],
#  ['suspektný', 'podozrivý'],
#  ['reliktný', 'zvyškový'],
#  ['dešpektný', 'pohŕdavý'],
#  ['éra', 'časy', 'doba', 'roky', 'čas', 'obdobie', 'dni'],
#  ['dnu', 'vnútri', 'dovnútra'],
#  ['exportný', 'vývozný'],
#  ['krajina', 'región', 'terén', 'kraj', 'štát'],
#  ['káliový', 'draslíkový'],
#  ['káliový', 'draslíkový'],
#  ['vedieť', 'dokázať', 'znať'],
#  ['tárať', 'rozprávať', 'hovoriť'],
#  ['kura', 'kurča'],
#  ['abortus', 'interrupcia', 'potrat'],
#  ['kvetina', 'kvet'],
#  ['vyhrážka', 'hrozba'],
#  ['prieťah', 'papierovanie', 'byrokracia', 'úradný šimeľ'],
#  ['pohlavie', 'rodidlá', 'sexus', 'gender', 'prirodzenie'],
#  ['améba', 'meňavka'],
#  ['dojnica', 'dojka'],
#  ['ochabnutý', 'atrofický', 'zmenšený'],
#  ['bronchiálny', 'prieduškový'],
#  ['sobáš', 'svadba'],
#  ['vetva', 'konár', 'haluz'],
#  ['exotický', 'cudzokrajný'],
#  ['postpubertálny', 'popubertálny'],
#  ['popubertálny', 'postpubertálny'],
#  ['komfortný', 'pohodlný'],
#  ['fotofóbia', 'svetloplachosť'],
#  ['zárubňa', 'veraje'],
#  ['apoplexia', 'mŕtvica'],
#  ['zášť',
#   'nepriateľstvo',
#   'fóbia',
#   'nenávisť',
#   'nevraživosť',
#   'priek',
#   'zloba'],
#  ['karcinogénny', 'rakovinotvorný'],
#  ['jarabatý', 'jarabý'],
#  ['antisemitský', 'protižidovský'],
#  ['havária', 'nehoda'],
#  ['čechizmus', 'bohemizmus'],
#  ['rovnoslabičnosť', 'izosylabizmus'],
#  ['bodkavý', 'bodkastý'],
#  ['neverbálny', 'nonverbálny'],
#  ['obyčajný', 'bežný'],
#  ['lebka', 'lebeňa', 'lebeň'],
#  ['magnéziový', 'horčíkový'],
#  ['horčík', 'magnézium'],
#  ['horčík', 'magnézium'],
#  ['magnéziový', 'horčíkový'],
#  ['monarchia', 'kráľovstvo'],
#  ['lebkový', 'lebečný'],
#  ['lebečný', 'lebkový'],
#  ['lebeňa', 'lebeň'],
#  ['husitstvo', 'husitizmus'],
#  ['smrtka', 'koniec', 'smrť', 'zánik', 'úmrtie', 'skon'],
#  ['jablkový', 'jablčný'],
#  ['jablkový', 'jablčný'],
#  ['bál', 'ples'],
#  ['otrokárstvo', 'kupliarstvo', 'obchod s bielym mäsom'],
#  ['alumínium', 'hliník'],
#  ['nosový', 'nazálny', 'nosný'],
#  ['duševný', 'rozumový', 'mentálny', 'myšlienkový'],
#  ['cerebrospinálny', 'mozgovomiechový'],
#  ['vydieračský', 'ransomvér'],
#  ['škodlivý', 'malvér'],
#  ['softvér', 'program'],
#  ['heterogénny', 'nerovnorodý', 'nesúrodý', 'rôznorodý'],
#  ['guľatý', 'baňatý', 'vydutý'],
#  ['tendenčný', 'poplatný'],
#  ['kanonizácia', 'svätorečenie'],
#  ['hemoptýza', 'hemoptoe', 'chrlenie'],
#  ['trombocyt', 'krvná doštička'],
#  ['súmerný', 'symetrický'],
#  ['žalúdočný', 'gastrický'],
#  ['parazitný', 'cudzopasný'],
#  ['aristokratický', 'šľachtický'],
#  ['anemický', 'málokrvný'],
#  ['málokrvnosť', 'anémia'],
#  ['čadič', 'bazalt'],
#  ['čadičový', 'bazaltový'],
#  ['eratický', 'bludný'],
#  ['štátny', 'erárny'],
#  ['telnatý', 'zavalitý', 'tučný'],
#  ['plnoštíhly', 'moletný'],
#  ['krátkozraký', 'myopický'],
#  ['reuma', 'reumatizmus', 'lámka'],
#  ['nemoderný', 'zastaraný', 'staromódny'],
#  ['percentný', 'percentuálny'],
#  ['tajný', 'dôverný'],
#  ['horský', 'hôrny'],
#  ['konôpka', 'stehlík konôpka'],
#  ['element', 'zložka', 'prvok'],
#  ['odborníčka', 'expertka', 'špecialistka', 'znalkyňa'],
#  ['špecialista', 'odborník'],
#  ['toxický', 'jedovatý'],
#  ['vlasatica', 'kométa'],
#  ['relevantný', 'dôležitý', 'signifikantný'],
#  ['súčasť',
#   'podiel',
#   'segment',
#   'diel',
#   'oddiel',
#   'epizóda',
#   'kus',
#   'súčiastka',
#   'útržok',
#   'kúsok',
#   'sekcia',
#   'etapa',
#   'hlava',
#   'úsek',
#   'kapitola',
#   'časť'],
#  ['persóna', 'jednotlivec', 'indivíduum', 'človek', 'osoba'],
#  ['dakto', 'niekto', 'voľakto', 'ktosi'],
#  ['maltovník', 'maltovnica', 'kalfas'],
#  ['biedny', 'nemajetný', 'chudobný'],
#  ['hypodermálny', 'podkožný'],
#  ['identický', 'totožný'],
#  ['intenzívny', 'silný', 'veľký', 'účinný'],
#  ['výstelka', 'epitel'],
#  ['falošník', 'pokrytec'],
#  ['polový', 'polovičný'],
#  ['ľaľať',
#   'ták',
#   'hľaď',
#   'pozriteže',
#   'ny',
#   'ha',
#   'ach',
#   'pozrite',
#   'ah',
#   'á',
#   'aá',
#   'a',
#   'ľaď',
#   'ehe',
#   'pozri',
#   'pozriže',
#   'ľaľaďže',
#   'hľaďteže',
#   'ajhľa',
#   'hľaďte',
#   'ľa',
#   'ľaľa',
#   'ľaľaď',
#   'hľa',
#   'ahá',
#   'ný',
#   'ľaďže',
#   'áá',
#   'ni',
#   'tak'],
#  ['ten', 'on'],
#  ['krajový', 'oblastný', 'regionálny'],
#  ['poloboh', 'héros', 'hrdina'],
#  ['vďaka',
#   'pre',
#   'cez',
#   'miesto',
#   'poza',
#   'po',
#   'od',
#   'za',
#   'namiesto',
#   'počas',
#   'v'],
#  ['infantilný', 'detinský'],
#  ['úver', 'pôžička', 'kredit'],
#  ['úsilie', 'snaha'],
#  ['zmysel', 'účel', 'cieľ'],
#  ['závažný', 'pádny', 'presvedčivý'],
#  ['dôstojnosť', 'vážnosť', 'prísnosť', 'dôležitosť'],
#  ['nemenný', 'trvalý', 'dekopriátny', 'stály'],
#  ['kontrárny', 'opačný', 'protichodný', 'protikladný', 'protirečivý'],
#  ['jasný', 'známy', 'zreteľný', 'určitý', 'presný'],
#  ['zreteľnosť', 'určitosť', 'jasnosť', 'presnosť'],
#  ['príučka', 'poučenie', 'poučka', 'ponaučenie'],
#  ['akcentovanie', 'prízvukovanie', 'akcentuácia'],
#  ['abstrakcia', 'idealizácia'],
#  ['zavinený', 'zapríčinený'],
#  ['rozlišovanie', 'odlišovanie', 'rozoznávanie'],
#  ['námaha', 'úsilie'],
#  ['nováčik', 'debutant', 'začiatočník'],
#  ['racionálny', 'rozumový'],
#  ['roztrpčenie', 'zatrpknutosť', 'trpkosť'],
#  ['spektakulárny', 'zvláštny'],
#  ['edukačný', 'edukatívny'],
#  ['krhla', 'kanva'],
#  ['mestský', 'obecný', 'komunálny'],
#  ['trúdnik', 'choroš'],
#  ['aborigénny', 'autochtónny'],
#  ['letecký', 'aviatický'],
#  ['premýšlať', 'myslieť', 'rátať', 'hádať'],
#  ['bedrovník anízový', 'aníz'],
#  ['Rakúska republika', 'Rakúsko'],
#  ['Švajčiarska konfederácia', 'Švajčiarsko'],
#  ['meritórny', 'vecný', 'podstatný'],
#  ['éra', 'časy', 'doba', 'roky', 'desaťročie', 'obdobie', 'dekáda', 'dni'],
#  ['mládenec', 'chlapec', 'chalan', 'milý', 'šuhaj', 'mladík'],
#  ['grcanie', 'bľuvanie', 'blvanie', 'šabľovanie', 'bľutie'],
#  ['grcanec', 'grcanica', 'grcanina', 'grc'],
#  ['grganie', 'rihanie'],
#  ['šabľovanie', 'grcanie', 'blvanie'],
#  ['príklad',
#   'oštara',
#   'háčik',
#   'otázka',
#   'úloha',
#   'problém',
#   'starosť',
#   'cvičenie',
#   'oriešok',
#   'ťažkosť',
#   'hádanka'],
#  ['plameň', 'oheň', 'požiar', 'táborák', 'vatra'],
#  ['malomocenstvo', 'lepra'],
#  ['WC', 'hajzel', 'záchod', 'vécko', 'toaleta'],
#  ['pohlavie', 'dynastia', 'genus', 'rod', 'rodina', 'pokolenie'],
#  ['mandľa', 'tonzila', 'mandľovník'],
#  ['multivesmír', 'multiverzum'],
#  ['snežný', 'snehový'],
#  ['obežný', 'obehový'],
#  ['nerastný', 'minerálny'],
#  ['akomodačný', 'prispôsobovací'],
#  ['apelácia', 'apel', 'odvolanie', 'výzva'],
#  ['zložka', 'digraf'],
#  ['práve', 'akurát', 'schválne', 'just', 'zrovna'],
#  ['retiazka', 'vodítko', 'vôdzka', 'remienok'],
#  ['homosexuál', 'gay', 'gej'],
#  ['vaginálny', 'pošvový'],
#  ['Talianska republika', 'Taliansko'],
#  ['nonkonformný', 'nekonformný'],
#  ['makromolekulárny', 'vysokomolekulárny'],
#  ['Nemecká spolková republika', 'Nemecko'],
#  ['Kubánska republika', 'Kuba'],
#  ['žilový', 'venózny'],
#  ['modravý', 'modrastý'],
#  ['Belgické kráľovstvo', 'Belgicko'],
#  ['Turecká republika', 'Turecko'],
#  ['zavlečený', 'alochtónny'],
#  ['Kuvajt', 'Kuvajtský štát'],
#  ['erytrocyt', 'červená krvinka'],
#  ['Cyprus', 'Cyperská republika'],
#  ['zodpovedať', 'vyhovovať', 'pasovať'],
#  ['browser', 'prehliadač'],
#  ['belavý', 'biely', 'bledý', 'svetlý'],
#  ['Turanec', 'Ondavskoturanec'],
#  ['Brezovčan', 'Bradlianskobrezovčan'],
#  ['Brezovčan', 'Bradlianskobrezovčan'],
#  ['zelený zákal', 'glaukóm'],
#  ['jednobožstvo', 'monoteizmus'],
#  ['posmrtný', 'záhrobný'],
#  ['čmeliak', 'čmeľ'],
#  ['podkúpiť', 'podplatiť', 'kúpiť'],
#  ['rozumieť', 'chápať', 'zrieť', 'pozorovať', 'badať', 'vidieť'],
#  ['vyhovovať', 'pasovať', 'sedieť'],
#  ['stepiar', 'labkáň'],
#  ['bezhorúčkový', 'afebrilný']]
