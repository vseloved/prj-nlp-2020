# %% [markdown]
# # Повний цикл NLP-проєкту
#
# ## I. Перевірка фактів на достовірність
#
# У межах цієї задачі ви побудуєте систему видобування фактів на правилах, а також інструменти для оцінювання якості роботи цієї системи.

# %% [markdown]
# ### 1. Домен
#
# Виберіть домен, для якого можна побудувати невелику базу даних на основі [DBPedia](https://dbpedia.org/sparql). База даних повинна містити хоча б три колонки з даними.
#
# ```
#     SELECT ?cyclist ?name ?ridertype ?wiki
#         (GROUP_CONCAT(DISTINCT ?place1; SEPARATOR=", ") AS ?places1)
#         (GROUP_CONCAT(DISTINCT ?place2; SEPARATOR=", ") AS ?places2)
#         (GROUP_CONCAT(DISTINCT ?place3; SEPARATOR=", ") AS ?places3)
#     WHERE {
#         ?cyclist dct:subject dbc:Ukrainian_male_cyclists;
#         dct:subject dbc:Tour_de_France_cyclists;
#         rdfs:label ?name;
#         foaf:isPrimaryTopicOf ?wiki.
#         OPTIONAL {?cyclist dbp:ridertype ?ridertype}.
#         OPTIONAL {?place1 dbp:first ?cyclist}.
#         OPTIONAL {?place2 dbp:second ?cyclist}.
#         OPTIONAL {?place3 dbp:third ?cyclist}.
#         FILTER (langmatches(lang(?name),  "EN"))
#     }
#     GROUP BY ?cyclist ?name ?ridertype ?wiki
#     ORDER BY ?cyclist
# ```
#
# Переверіри результати можна [тут](http://dbpedia.org/snorql/?query=select+%3Fcyclist+%3Fname+%3Fridertype++%3Fwiki%0D%0A+%28GROUP_CONCAT%28DISTINCT+%3Fplace1%3B+SEPARATOR%3D%22%2C+%22%29+AS+%3Fplaces1%29%0D%0A+%28GROUP_CONCAT%28DISTINCT+%3Fplace2%3B+SEPARATOR%3D%22%2C+%22%29+AS+%3Fplaces2%29%0D%0A+%28GROUP_CONCAT%28DISTINCT+%3Fplace3%3B+SEPARATOR%3D%22%2C+%22%29+AS+%3Fplaces3%29%0D%0Awhere+%7B%0D%0A++++%3Fcyclist+dct%3Asubject+dbc%3AUkrainian_male_cyclists%3B%0D%0A++++dct%3Asubject+dbc%3ATour_de_France_cyclists%3B%0D%0A++++rdfs%3Alabel+%3Fname%3B%0D%0A++++foaf%3AisPrimaryTopicOf+%3Fwiki.%0D%0A++++OPTIONAL+%7B%3Fcyclist+dbp%3Aridertype+%3Fridertype%7D.%0D%0A++++OPTIONAL+%7B%3Fplace1+dbp%3Afirst+%3Fcyclist%7D.%0D%0A++++OPTIONAL+%7B%3Fplace2+dbp%3Asecond+%3Fcyclist%7D.%0D%0A++++OPTIONAL+%7B%3Fplace3+dbp%3Athird+%3Fcyclist%7D.%0D%0A++++FILTER+%28langmatches%28lang%28%3Fname%29%2C++%22EN%22%29%29%0D%0A%7D%0D%0AGROUP+BY+%3Fcyclist+%3Fname+%3Fridertype+%3Fwiki%0D%0AORDER+BY+%3Fcyclist%0D%0A)

# %%
from collections import defaultdict
import json
import pandas as pd
import urllib.parse

# %%
def strip_places(places):
    places2 = [
        (
            p.replace('http://dbpedia.org/resource/', '')
            .replace('_', ' ')
            .replace('–', '-') # unicode char
        ) for p in places.split(', ')
    ]
    return [p for p in places2 if p]

# %%
def read_raw_data(filename):
    with open(filename, 'r') as f:
        raw_data = json.load(f)

    data = defaultdict(dict)
    for cyclist in raw_data['results']['bindings']:
        cyclist_id = cyclist['cyclist']['value'].replace('http://dbpedia.org/resource/', '')
        data[cyclist_id]['name'] = cyclist['name']['value']
        data[cyclist_id]['rider_type'] = cyclist.get('ridertype', {}).get('value')
        data[cyclist_id]['wiki_url'] = cyclist['wiki']['value']
        data[cyclist_id]['places1'] = strip_places(cyclist['places1']['value'])
        data[cyclist_id]['places2'] = strip_places(cyclist['places2']['value'])
        data[cyclist_id]['places3'] = strip_places(cyclist['places3']['value'])

    return data

# %%
dbpedia_cyclists_df = pd.DataFrame(read_raw_data('raw_cyclists_data.json')).T
dbpedia_cyclists_df
# Out:
#                                   name              rider_type  \
# Andrei_Tchmil            Andrei Tchmil     Classics specialist
# Andriy_Hrivko            Andriy Hrivko  Puncheur/Time-trialist
# Denys_Kostyuk            Denys Kostyuk                    None
# Serguei_Outschakov  Serguei Outschakov                    None
# Serhiy_Honchar          Serhiy Honchar           Time trialist
# Volodymir_Hustov      Volodymir Hustov                 Climber
# Yaroslav_Popovych    Yaroslav Popovych             All-rounder
# Yuriy_Krivtsov          Yuriy Krivtsov                    None
#
#                                                            wiki_url  \
# Andrei_Tchmil            http://en.wikipedia.org/wiki/Andrei_Tchmil
# Andriy_Hrivko            http://en.wikipedia.org/wiki/Andriy_Hrivko
# Denys_Kostyuk            http://en.wikipedia.org/wiki/Denys_Kostyuk
# Serguei_Outschakov  http://en.wikipedia.org/wiki/Serguei_Outschakov
# Serhiy_Honchar          http://en.wikipedia.org/wiki/Serhiy_Honchar
# Volodymir_Hustov      http://en.wikipedia.org/wiki/Volodymir_Hustov
# Yaroslav_Popovych    http://en.wikipedia.org/wiki/Yaroslav_Popovych
# Yuriy_Krivtsov          http://en.wikipedia.org/wiki/Yuriy_Krivtsov
#
#                                                               places1  \
# Andrei_Tchmil       [1994 Paris-Roubaix, 1999 Milan-San Remo, 2000...
# Andriy_Hrivko                                                      []
# Denys_Kostyuk                                                      []
# Serguei_Outschakov                                                 []
# Serhiy_Honchar                                                     []
# Volodymir_Hustov                                                   []
# Yaroslav_Popovych                            [2005 Volta a Catalunya]
# Yuriy_Krivtsov                                                     []
#
#                                  places2  \
# Andrei_Tchmil       [1995 Paris-Roubaix]
# Andriy_Hrivko                         []
# Denys_Kostyuk                         []
# Serguei_Outschakov                    []
# Serhiy_Honchar      [2004 Giro d'Italia]
# Volodymir_Hustov                      []
# Yaroslav_Popovych                     []
# Yuriy_Krivtsov                        []
#
#                                                               places3
# Andrei_Tchmil       [1994 Tour of Flanders, 1995 Tour of Flanders,...
# Andriy_Hrivko                                                      []
# Denys_Kostyuk                                                      []
# Serguei_Outschakov                                                 []
# Serhiy_Honchar      [1998 UCI Road World Championships - Men's tim...
# Volodymir_Hustov                                                   []
# Yaroslav_Popovych   [2003 Giro d'Italia, 2006 Tour de Georgia, 200...
# Yuriy_Krivtsov                                                     []

# %%
tuple(dbpedia_cyclists_df.loc[:, 'wiki_url'].to_dict().values())
# Out:
# ('http://en.wikipedia.org/wiki/Andrei_Tchmil',
#  'http://en.wikipedia.org/wiki/Andriy_Hrivko',
#  'http://en.wikipedia.org/wiki/Denys_Kostyuk',
#  'http://en.wikipedia.org/wiki/Serguei_Outschakov',
#  'http://en.wikipedia.org/wiki/Serhiy_Honchar',
#  'http://en.wikipedia.org/wiki/Volodymir_Hustov',
#  'http://en.wikipedia.org/wiki/Yaroslav_Popovych',
#  'http://en.wikipedia.org/wiki/Yuriy_Krivtsov')

# %% [markdown]
# ## Трохи висновків по dbpedia
#
# Я намагався отримати дані про команди, але схоже dbpedia зберігає тільки нинішню команду спортсмена, а українські спортсмени припинили змагатися, тож цієї інформації нема. З иншого боку згадка про команди на dbpedia все ж є, але вона зібрана абсолютно безсистемно, як якісь теги впереміш з иншими тегами. Тож тут dbpedia вже підвела

# %% [markdown]
# ### 2. Видобування фактів
#
# 2.1. Напишіть програму, яка шукає статті у Вікіпедії про сутності, що належать до вашого домена, та витягає тексти цих статей.

# %% [markdown]
# Отак виглядає мій павук, що витягає дані з wikipedia
#
# ```
# # -*- coding: utf-8 -*-
# import re
# import unicodedata
# import scrapy
# from bs4 import BeautifulSoup
#
#
# class WikipediaSpider(scrapy.Spider):
#     name = 'wikipedia'
#     allowed_domains = ['en.wikipedia.org']
#     start_urls = [
#         'http://en.wikipedia.org/wiki/Andrei_Tchmil',
#         'http://en.wikipedia.org/wiki/Andriy_Hrivko',
#         'http://en.wikipedia.org/wiki/Denys_Kostyuk',
#         'http://en.wikipedia.org/wiki/Serguei_Outschakov',
#         'http://en.wikipedia.org/wiki/Serhiy_Honchar',
#         'http://en.wikipedia.org/wiki/Volodymir_Hustov',
#         'http://en.wikipedia.org/wiki/Yaroslav_Popovych',
#         'http://en.wikipedia.org/wiki/Yuriy_Krivtsov'
#     ]
#
#     def _clean(self, value):
#         #value = value.replace("\n", "").replace("\xa0", "")
#         value = value.replace('–', '-')
#         value = re.sub(r' , ', ', ', value)
#         value = re.sub(r' \( ', ' (', value)
#         value = re.sub(r' \) ', ') ', value)
#         value = re.sub(r' \)', ') ', value)
#         value = re.sub(r'\[\d.*\]', ' ', value)
#         value = re.sub(r' +', ' ', value)
#         return value.strip()
#
#     def start_requests(self):
#         for url in self.start_urls:
#             yield scrapy.Request(url=url, callback=self.parse)
#
#     def parse(self, response):
#         rows = []
#         nodes = response.css("div#mw-content-text>div.mw-parser-output>*").getall()
#
#         for html in nodes:
#             soup = BeautifulSoup(html.replace('<', ' <'), 'lxml')
#             rows.append(self._clean(soup.text))
#
#         yield {
#             'url': response.url,
#             'title': response.css('#firstHeading::text').extract_first(),
#             'rows': rows
#         }
# ```

# %% [markdown]
# 2.2. Напишіть програму, яка опрацьовує текст статті (саме сирий текст, а не таблички, якщо такі є) та витягає з нього інформацію про ваш домен. Цю інформацію ви будете порівнювати зі сформованою базою даних.

# %%
with open('/Users/dmytrobudashnyi/usr/projects/nlp_course/world_scrapah/world_scrapah/cyclists.json') as f:
    cyclists_raw_data = json.load(f)

# %%
import re

win_pattern = re.compile(r"^1st\s+([\w\-\s]+)")
place2_pattern = re.compile(r"^2nd\s+([\w\-\s]+)")
place3_pattern = re.compile(r"^3rd\s+([\w\-\s]+)")
year_pattern = re.compile(r"^(\d{4})$")
stage_pattern = re.compile(r".([Ss]tages?\s+\d+).*")
rider_type_pattern = re.compile(r".Rider\s+type\s([\w\-\\]+)\s+.*")

def parse_cyclist(data):
    result = {
        'name': data['title'],
        'rider_type': None,
        'wiki_url': data['url'],
        'places1': [],
        'places2': [],
        'places3': [],
    }
    rows = []
    for row in data['rows']:
        rows.extend([r.strip() for r in row.split("\n") if r.strip()])

    current_year = None
    for row in rows:
        #print('|{}|'.format(row))
        year_data = year_pattern.findall(row)
        if year_data:
            current_year = year_data[0]
        # 1st place
        win_data = win_pattern.findall(row)
        if win_data and not stage_pattern.search(row):
            race =  win_data[0].replace('Overall', '').strip()
            result['places1'].append('{year} {race}'.format(year=current_year, race=race))
            continue
        # 2nd place
        place2_data = place2_pattern.findall(row)
        if place2_data and not stage_pattern.search(row):
            race =  place2_data[0].replace('Overall', '').strip()
            result['places2'].append('{year} {race}'.format(year=current_year, race=race))
            continue
        # 3rd place
        place3_data = place3_pattern.findall(row)
        if place3_data and not stage_pattern.search(row):
            race =  place3_data[0].replace('Overall', '').strip()
            result['places3'].append('{year} {race}'.format(year=current_year, race=race))
            continue
        # rider type
        rider_type_data = rider_type_pattern.findall(row)
        #print('|{}|'.format(row))
        if rider_type_data:
            result['rider_type'] = rider_type_data[0]
        

    return result

cyclists_data = {}

for cyclist in cyclists_raw_data:
    cyclist_id = cyclist['url'].replace('https://en.wikipedia.org/wiki/', '')
    cyclists_data[urllib.parse.unquote(cyclist_id)] = parse_cyclist(cyclist)

wikipedia_cyclists_df = pd.DataFrame(cyclists_data).T
wikipedia_cyclists_df
# Out:
#                                   name   rider_type  \
# Andrei_Tchmil            Andrei Tchmil     Classics
# Yuriy_Krivtsov          Yuriy Krivtsov         None
# Andriy_Hrivko            Andriy Hrivko     Puncheur
# Denys_Kostyuk            Denys Kostyuk         None
# Serguei_Outschakov  Serguei Outschakov         None
# Volodymir_Hustov      Volodymir Gustov      Climber
# Serhiy_Honchar          Serhiy Honchar         Time
# Yaroslav_Popovych    Yaroslav Popovych  All-rounder
#
#                                                             wiki_url  \
# Andrei_Tchmil            https://en.wikipedia.org/wiki/Andrei_Tchmil
# Yuriy_Krivtsov          https://en.wikipedia.org/wiki/Yuriy_Krivtsov
# Andriy_Hrivko            https://en.wikipedia.org/wiki/Andriy_Hrivko
# Denys_Kostyuk            https://en.wikipedia.org/wiki/Denys_Kostyuk
# Serguei_Outschakov  https://en.wikipedia.org/wiki/Serguei_Outschakov
# Volodymir_Hustov      https://en.wikipedia.org/wiki/Volodymir_Hustov
# Serhiy_Honchar          https://en.wikipedia.org/wiki/Serhiy_Honchar
# Yaroslav_Popovych    https://en.wikipedia.org/wiki/Yaroslav_Popovych
#
#                                                               places1  \
# Andrei_Tchmil       [1991 Road race, 1991 Grand Prix Pino Cerami, ...
# Yuriy_Krivtsov      [2002 Prix des Blés d, 2004 National Time Tria...
# Andriy_Hrivko       [2005 Time trial, 2006 Time trial, 2008 Time t...
# Denys_Kostyuk       [2013 National Road Race Championships, 2013 R...
# Serguei_Outschakov                                                 []
# Volodymir_Hustov                                    [2003 Regio-Tour]
# Serhiy_Honchar      [1997 Chrono des Herbiers, 1998 Chrono des Her...
# Yaroslav_Popovych   [2000 Tour de Nouvelle-Calédonie, 2001 Under-2...
#
#                                                               places2  \
# Andrei_Tchmil       [1989 GP Industria, 1990 Grand Prix Pino Ceram...
# Yuriy_Krivtsov      [2005 Duo Normand, 2006 National Time Trial Ch...
# Andriy_Hrivko       [2005 Firenze-Pistoia, 2008 Intaka Tech Worlds...
# Denys_Kostyuk       [2008 National Road Race Championships, 2013 F...
# Serguei_Outschakov                                                 []
# Volodymir_Hustov              [2000 National Road Race Championships]
# Serhiy_Honchar      [1997 World Time Trial Championship, 2000 Chro...
# Yaroslav_Popovych                                                  []
#
#                                                               places3
# Andrei_Tchmil       [1989 Giro del Veneto, 1991 Coppa Bernocchi, 1...
# Yuriy_Krivtsov                              [2009 Chrono des Nations]
# Andriy_Hrivko       [2006 Critérium International, 2006 GP Miguel ...
# Denys_Kostyuk       [2003 Trofeo Banca Popolare di Vicenza, 2004 N...
# Serguei_Outschakov                                                 []
# Volodymir_Hustov                                                   []
# Serhiy_Honchar      [1998 World Time Trial Championship, 2001 Chro...
# Yaroslav_Popovych   [2002 Porec Trophy III, 2003 Giro d, 2003 Tour...

# %% [markdown]
# ### 3. Оцінювання результатів
#
# Розробіть метрику, яка покаже, наскільки інформація, яку ви дістали зі статей, збігається з інформацією в вашій базі даних. Скільки пропущеної інформації? Чи є часткові збіги? (Наприклад, ім'я СЕО певної компанії збігається лише частково або ім'я СЕО збігається, а роки діяльності різні.)
#
# Додайте ваші спостереження і висновки.

# %%
def measure_qaulity(correct, predicted):
    qa_stats = defaultdict(int)

    for index, row in predicted.iterrows():
        correct_row = correct.loc[index , : ]
        if row['rider_type'] is None and correct_row['rider_type'] is not None:
            pass
        elif correct_row['rider_type'] is None:
            qa_stats['rider_type'] += 1
        elif row['rider_type'] == correct_row['rider_type']:
            qa_stats['rider_type'] += 1
        elif correct_row['rider_type'].startswith(row['rider_type']):
            qa_stats['rider_type'] += 0.3
        elif row['rider_type'] and not correct_row['rider_type']:
            qa_stats['rider_type'] += 1

        if not correct_row['places1']:
            qa_stats['places1'] += 1
        for race in correct_row['places1']:
            if race in row['places1']:
                qa_stats['places1'] += 1 / len(correct_row['places1'])

        if not correct_row['places2']:
            qa_stats['places2'] += 1
        for race in correct_row['places2']:
            if race in row['places2']:
                qa_stats['places2'] += 1 / len(correct_row['places2'])

        if not correct_row['places3']:
            qa_stats['places3'] += 1
        for race in correct_row['places3']:
            if race in row['places3']:
                qa_stats['places3'] += 1 / len(correct_row['places3'])

    for key in qa_stats.keys():
        qa_stats[key] /= len(correct)

    return {
        'overall': sum(qa_stats.values()) / len(qa_stats),
        'rider_type': qa_stats['rider_type'],
        'places1': qa_stats['places1'],
        'places2': qa_stats['places2'],
        'places3': qa_stats['places3']
    }

measure_qaulity(dbpedia_cyclists_df, wikipedia_cyclists_df)
# Out:
# {'overall': 0.8614583333333332,
#  'rider_type': 0.7374999999999999,
#  'places1': 1.0,
#  'places2': 0.875,
#  'places3': 0.8333333333333333}

# %% [markdown]
# ## Ок, тепер те саме, тільки по великій кількості даних, які стосуються абсолютно всіх велосипедистів з TDF

# %%
cyclists_data = {}

for cyclist in cyclists_raw_data:
    cyclists_data[cyclist['url'].replace('https://en.wikipedia.org/wiki/', '')] = parse_cyclist(cyclist)
    
dbpedia_all_cyclists_df = pd.DataFrame(read_raw_data('raw_tdf_cyclists_data.json')).T
dbpedia_all_cyclists_df
# Out:
#                                           name           rider_type  \
# Aad_van_den_Hoek              Aad van den Hoek                 None
# Aart_Vierhouten                Aart Vierhouten                 None
# Abdel-Kader_Zaaf              Abdel-Kader Zaaf                 None
# Abelardo_Rondón                Abelardo Rondón                 None
# Abelardo_Ríos                    Abelardo Ríos                 None
# ...                                        ...                  ...
# Íñigo_Cuesta                      Íñigo Cuesta   Domestique/Climber
# Óscar_Freire                      Óscar Freire             Sprinter
# Óscar_Pereiro                    Óscar Pereiro          All-rounder
# Óscar_Sevilla                    Óscar Sevilla  Climbing specialist
# Óscar_Vargas_(cyclist)  Óscar Vargas (cyclist)                 None
#
#                                                                  wiki_url  \
# Aad_van_den_Hoek            http://en.wikipedia.org/wiki/Aad_van_den_Hoek
# Aart_Vierhouten              http://en.wikipedia.org/wiki/Aart_Vierhouten
# Abdel-Kader_Zaaf            http://en.wikipedia.org/wiki/Abdel-Kader_Zaaf
# Abelardo_Rondón              http://en.wikipedia.org/wiki/Abelardo_Rondón
# Abelardo_Ríos                  http://en.wikipedia.org/wiki/Abelardo_Ríos
# ...                                                                   ...
# Íñigo_Cuesta                    http://en.wikipedia.org/wiki/Íñigo_Cuesta
# Óscar_Freire                    http://en.wikipedia.org/wiki/Óscar_Freire
# Óscar_Pereiro                  http://en.wikipedia.org/wiki/Óscar_Pereiro
# Óscar_Sevilla                  http://en.wikipedia.org/wiki/Óscar_Sevilla
# Óscar_Vargas_(cyclist)  http://en.wikipedia.org/wiki/Óscar_Vargas_(cyc...
#
#                                                                   places1  \
# Aad_van_den_Hoek                                                       []
# Aart_Vierhouten                                                        []
# Abdel-Kader_Zaaf                                                       []
# Abelardo_Rondón                                                        []
# Abelardo_Ríos                                                          []
# ...                                                                   ...
# Íñigo_Cuesta                                                           []
# Óscar_Freire            [1999 UCI Road World Championships - Men's roa...
# Óscar_Pereiro                                                          []
# Óscar_Sevilla           [2008 Clásico RCN, 2013 Vuelta a Colombia, 201...
# Óscar_Vargas_(cyclist)                                                 []
#
#                                                                places2  \
# Aad_van_den_Hoek                                                    []
# Aart_Vierhouten                                                     []
# Abdel-Kader_Zaaf                                                    []
# Abelardo_Rondón                                                     []
# Abelardo_Ríos                                                       []
# ...                                                                ...
# Íñigo_Cuesta                                                        []
# Óscar_Freire                                       [2012 E3 Harelbeke]
# Óscar_Pereiro                                                       []
# Óscar_Sevilla           [2001 Vuelta a España, 2010 Vuelta a Colombia]
# Óscar_Vargas_(cyclist)                                              []
#
#                                        places3
# Aad_van_den_Hoek                            []
# Aart_Vierhouten                             []
# Abdel-Kader_Zaaf                            []
# Abelardo_Rondón                             []
# Abelardo_Ríos                               []
# ...                                        ...
# Íñigo_Cuesta                                []
# Óscar_Freire             [2000 Milan-San Remo]
# Óscar_Pereiro                               []
# Óscar_Sevilla                               []
# Óscar_Vargas_(cyclist)  [1989 Vuelta a España]
#
# [2492 rows x 6 columns]

# %%
with open('./tdf_cyclists.json') as f:
    cyclists_raw_data = json.load(f)

cyclists_tdf_data = {}

for cyclist in cyclists_raw_data:
    cyclist_id = cyclist['url'].replace('https://en.wikipedia.org/wiki/', '')
    cyclists_tdf_data[urllib.parse.unquote(cyclist_id)] = parse_cyclist(cyclist)

wikipedia_tdf_cyclists_df = pd.DataFrame(cyclists_tdf_data).T
wikipedia_tdf_cyclists_df
# Out:
#                                           name     rider_type  \
# Ad_Wijnands                        Ad Wijnands           None
# Abraham_Olano                    Abraham Olano  Time-trialist
# Aad_van_den_Hoek              Aad van den Hoek           None
# Abelardo_Rondón                Abelardo Rondón           None
# Abelardo_Ríos                    Abelardo Ríos           None
# ...                                        ...            ...
# Étienne_De_Beule              Étienne De Beule           None
# Óscar_Sevilla                    Óscar Sevilla       Climbing
# Óscar_Freire                      Óscar Freire       Sprinter
# Óscar_Vargas_(cyclist)  Óscar Vargas (cyclist)           None
# Íñigo_Chaurreau                Íñigo Chaurreau           None
#
#                                                                  wiki_url  \
# Ad_Wijnands                     https://en.wikipedia.org/wiki/Ad_Wijnands
# Abraham_Olano                 https://en.wikipedia.org/wiki/Abraham_Olano
# Aad_van_den_Hoek           https://en.wikipedia.org/wiki/Aad_van_den_Hoek
# Abelardo_Rondón         https://en.wikipedia.org/wiki/Abelardo_Rond%C3...
# Abelardo_Ríos            https://en.wikipedia.org/wiki/Abelardo_R%C3%ADos
# ...                                                                   ...
# Étienne_De_Beule        https://en.wikipedia.org/wiki/%C3%89tienne_De_...
# Óscar_Sevilla            https://en.wikipedia.org/wiki/%C3%93scar_Sevilla
# Óscar_Freire              https://en.wikipedia.org/wiki/%C3%93scar_Freire
# Óscar_Vargas_(cyclist)  https://en.wikipedia.org/wiki/%C3%93scar_Varga...
# Íñigo_Chaurreau         https://en.wikipedia.org/wiki/%C3%8D%C3%B1igo_...
#
#                                                                   places1  \
# Ad_Wijnands                                                            []
# Abraham_Olano           [1992 Prueba Villafranca de Ordizia, 1994 Road...
# Aad_van_den_Hoek                    [1978 leg Part B Tour of Netherlands]
# Abelardo_Rondón                                                        []
# Abelardo_Ríos                                                          []
# ...                                                                   ...
# Étienne_De_Beule                                                       []
# Óscar_Sevilla           [2000 Trofeo Luis Ocaña, 2000 Memorial Manuel ...
# Óscar_Freire            [1999 Road race, 2000 Points classification, 2...
# Óscar_Vargas_(cyclist)  [1986 in Subida Urkiola, 1989 in Mountains Cla...
# Íñigo_Chaurreau         [2000 Mountains classification Vuelta a La Rio...
#
#                                                                   places2  \
# Ad_Wijnands                                                            []
# Abraham_Olano           [1995 Time trial, 1995 Vuelta a España, 1996 T...
# Aad_van_den_Hoek                                                       []
# Abelardo_Rondón                                                        []
# Abelardo_Ríos                                                          []
# ...                                                                   ...
# Étienne_De_Beule                                                       []
# Óscar_Sevilla           [2000 Volta a Catalunya, 2000 Vuelta a Burgos,...
# Óscar_Freire            [1997 Road race, 2001 Paris-Tours, 2007 Vatten...
# Óscar_Vargas_(cyclist)        [1990 in   Colombia National Championships]
# Íñigo_Chaurreau                                                        []
#
#                                                                   places3
# Ad_Wijnands                                                            []
# Abraham_Olano           [1992 Clasica de Almeria, 1996 Giro d, 1996 To...
# Aad_van_den_Hoek                                                       []
# Abelardo_Rondón                                                        []
# Abelardo_Ríos                                                          []
# ...                                                                   ...
# Étienne_De_Beule                                                       []
# Óscar_Sevilla           [2001 Escalada a Montjuïc, 2001 Clásica a los ...
# Óscar_Freire            [1998 Road race, 2000 Road race, 2000 Milan-Sa...
# Óscar_Vargas_(cyclist)  [1986 in Clasica de Sabiñanigo, 1989 in Genera...
# Íñigo_Chaurreau                                  [1994 Circuito Montañés]
#
# [2492 rows x 6 columns]

# %%
measure_qaulity(dbpedia_all_cyclists_df, wikipedia_tdf_cyclists_df)
# Out:
# {'overall': 0.9214897120693029,
#  'rider_type': 0.8949036918138032,
#  'places1': 0.9462253518824005,
#  'places2': 0.9227438915641166,
#  'places3': 0.9220859130168911}

# %% [markdown]
# ## Висновки
#
# Виявилося, що на dbpedia дуже мало даних. З wikipedia можна набагато більше стягти, це і дані про велику кількість змагань, і дані про команди з хронологією, і дані про теперішню команду, навіть якщо гонщик вже на пенсії. Тим не менш результат можна покращити, адже мої регекспи трохи не впоруються з деякими ситуаціями.
#
# Результат на всій групі велосипедистів був кращий, тому що багато полів на dbpedia просто незаповнені.
