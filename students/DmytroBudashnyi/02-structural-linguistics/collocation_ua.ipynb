# %%
from collections import defaultdict

import tokenize_uk
import pymorphy2

# %%
morph = pymorphy2.MorphAnalyzer(lang='uk')

# %%
with open('../../../tasks/02-structural-linguistics/data/tyhrolovy.txt') as f:
    book_lines = [l.strip() for l in f.readlines() if l.strip() != '']

# %%
len(book_lines)
# Out:
# 2665

# %%
book_lines[153]
# Out:
# 'Повз нього пливе цей — конкретний, напружений і намагнетизовапий, осяяний блакитним, рожевим, зеленим сяйвом вибагливих абажурів, заслонений газовими фіранками, наснажений коханням і поривами, озвучений патефонними фокстротами і румбами... А над усім — Арсеньєв! Ах-х, Арсеньєв!..'

# %%
tokens = tokenize_uk.tokenize_words(book_lines[153])

# %%
[(word, morph.parse(word)[0].tag.POS) for word in tokens]
# Out:
# [('Повз', 'VERB'),
#  ('нього', 'NPRO'),
#  ('пливе', 'VERB'),
#  ('цей', 'NPRO'),
#  ('—', None),
#  ('конкретний', 'ADJF'),
#  (',', None),
#  ('напружений', 'ADJF'),
#  ('і', 'CONJ'),
#  ('намагнетизовапий', 'ADJF'),
#  (',', None),
#  ('осяяний', 'ADJF'),
#  ('блакитним', 'ADJF'),
#  (',', None),
#  ('рожевим', 'ADJF'),
#  (',', None),
#  ('зеленим', 'VERB'),
#  ('сяйвом', 'NOUN'),
#  ('вибагливих', 'ADJF'),
#  ('абажурів', 'NOUN'),
#  (',', None),
#  ('заслонений', 'ADJF'),
#  ('газовими', 'ADJF'),
#  ('фіранками', 'NOUN'),
#  (',', None),
#  ('наснажений', 'ADJF'),
#  ('коханням', 'NOUN'),
#  ('і', 'CONJ'),
#  ('поривами', 'NOUN'),
#  (',', None),
#  ('озвучений', 'ADJF'),
#  ('патефонними', 'ADJF'),
#  ('фокстротами', 'NOUN'),
#  ('і', 'CONJ'),
#  ('румбами', 'NOUN'),
#  ('...', None),
#  ('А', 'CONJ'),
#  ('над', 'PREP'),
#  ('усім', 'NPRO'),
#  ('—', None),
#  ('Арсеньєв', 'NOUN'),
#  ('!', None),
#  ('Ах', 'INTJ'),
#  ('-', None),
#  ('х', None),
#  (',', None),
#  ('Арсеньєв', 'NOUN'),
#  ('!..', None)]

# %%
def is_adjective(token):
    return token.tag.POS in ('ADJF', 'ADJS')

def is_being(token):
    return token.tag.POS == 'NOUN' and token.tag.animacy == 'anim'

stats = defaultdict(int)

for line in book_lines:
    tokens = tokenize_uk.tokenize_words(line)
    morph_tokens = [morph.parse(t)[0] for t in tokens]
    for i, token in enumerate(morph_tokens):
        if is_being(token) and i > 0 and is_adjective(morph_tokens[i-1]):
            adj_token = morph_tokens[i-1]
            stats['{} {}'.format(adj_token.normal_form, token.normal_form)] += 1

# %%
[(k, v) for k, v in sorted(stats.items(), reverse=True, key=lambda item: item[1])]
# Out:
# [('старий сірко', 84),
#  ('великий начальник', 5),
#  ('сонячний зайчик', 4),
#  ('цибатий зять', 4),
#  ('малий дитина', 3),
#  ('якутський пес', 3),
#  ('вражий мама', 3),
#  ('безумний сміливець', 2),
#  ('державний злочинець', 2),
#  ('земний кулі', 2),
#  ('владивостоцький турок', 2),
#  ('дивний бог', 2),
#  ('змучений мандрівник', 2),
#  ('вражий дівчина', 2),
#  ('знаменитий мисливець', 2),
#  ('бісовий віра', 2),
#  ("нав'ючений кінь", 2),
#  ('природний солон', 2),
#  ('рясний дуб', 2),
#  ('старий мороз', 2),
#  ('григоріїв куреник', 2),
#  ('великий пан', 2),
#  ('чорний ожуга', 2),
#  ('булий дівчина', 2),
#  ('справжній мисливець', 2),
#  ('рясний піт', 2),
#  ('дурний начальник', 2),
#  ('малий дитя', 2),
#  ('хутряний звір', 2),
#  ('гордий тварина', 2),
#  ('собачий хутрянка', 2),
#  ('живий тигр', 2),
#  ('вірний друг', 2),
#  ('вірний пес', 2),
#  ('вогненноокий хробак', 1),
#  ('пекельний потвора', 1),
#  ('фіктивний потвора', 1),
#  ('двоокий циклоп', 1),
#  ('проглинений жертва', 1),
#  ('живий мертвяк', 1),
#  ('метушливий тіна', 1),
#  ('новий арештант', 1),
#  ('випадковий люди', 1),
#  ('арештантський дружба', 1),
#  ('знеосіблений люди', 1),
#  ('гордий сокол', 1),
#  ('гордий нащадок', 1),
#  ('перший каторжанин', 1),
#  ('екзальтований пасажир', 1),
#  ('горластий мешканець', 1),
#  ('радгоспний бюрократ', 1),
#  ('індустріальний авантюрник', 1),
#  ('потенціальний злодій', 1),
#  ('імпотентний фарисей', 1),
#  ('безвідповідальний рвач', 1),
#  ('експансивний відкриватель', 1),
#  ('зухвалий рекордсмен', 1),
#  ('передбачений к', 1),
#  ('напівсконкретизований химера', 1),
#  ('переступлений влада', 1),
#  ('хоробрий шукач', 1),
#  ('смугастий кішечка', 1),
#  ('четвертий коханець', 1),
#  ('похідний коханець', 1),
#  ("сп'янілий шукач", 1),
#  ('дурний кішка', 1),
#  ('старий кавалер', 1),
#  ('ревматичний кость', 1),
#  ('прекрасноокий панянка', 1),
#  ('одчайдушний шибайголова', 1),
#  ('гемороїдальний кооператор', 1),
#  ('субтропічний барс', 1),
#  ('гімалайський ведмідь', 1),
#  ('тендітний єнот', 1),
#  ('екзальтований конкістадор', 1),
#  ('вятський кустпром', 1),
#  ('рідний дунаєвський', 1),
#  ('станційний диспетчер', 1),
#  ('легендарний омуль', 1),
#  ('екзотичний омуль', 1),
#  ('останній пасажир', 1),
#  ('здезорієнтований пасажир', 1),
#  ('екзотичний тубілець', 1),
#  ('червоношкірий бурят', 1),
#  ('бронзовий якут', 1),
#  ('джеклондонівський індієць', 1),
#  ('убраний якутка', 1),
#  ('гостровухий пес', 1),
#  ('найперший каторжник', 1),
#  ('політичний засланець', 1),
#  ('безіменний каторжник', 1),
#  ('національний герой', 1),
#  ('справжній професор', 1),
#  ('каторжанський патріарх', 1),
#  ('безконечний тичбой', 1),
#  ('запопадливий кельнер', 1),
#  ('бравий майор', 1),
#  ('безжурний шибайголова', 1),
#  ('молодий люди', 1),
#  ('кваліфікований інженер', 1),
#  ('кваліфікований літун', 1),
#  ('розгублений кельнер', 1),
#  ('правовірний безвірник', 1),
#  ('переляканий кельнер', 1),
#  ('бравий гульвіса', 1),
#  ('синьоокий пройдисвіт', 1),
#  ('міцний дружба', 1),
#  ('зоологічний націоналіст', 1),
#  ('зайвий хмель', 1),
#  ('переможений жертва', 1),
#  ('екзальтований шукач', 1),
#  ('листатий гігант', 1),
#  ('учений дослідник', 1),
#  ('занепокоєний бурундук', 1),
#  ('волохатий ведмідь', 1),
#  ('дурний вепер', 1),
#  ('двоногий істота', 1),
#  ('страшний привид', 1),
#  ('страхітний звір', 1),
#  ('живий істота', 1),
#  ('двоногий розбійник', 1),
#  ('пожовклий кость', 1),
#  ('противний піт', 1),
#  ('набряклий жила', 1),
#  ('молодий юнак', 1),
#  ('далекий чужинець', 1),
#  ('синій волошка', 1),
#  ('волохатий бог', 1),
#  ('чорний ведмідь', 1),
#  ('грізний бог', 1),
#  ('новий ворог', 1),
#  ('великий дух', 1),
#  ('китайський тіна', 1),
#  ('давній запорожець', 1),
#  ('гірський дух', 1),
#  ('бистроокий дівчина', 1),
#  ('кремезний парубок', 1),
#  ('припертий ведмідь', 1),
#  ('близький люди', 1),
#  ('рідний люди', 1),
#  ('малий ласун', 1),
#  ('чесний людина', 1),
#  ('дурний маля', 1),
#  ('гостровухий собака', 1),
#  ('мисливський собака', 1),
#  ('уссурійський козак', 1),
#  ('козацький осавул', 1),
#  ('амурський козак', 1),
#  ('старий мисливець', 1),
#  ('різний козак', 1),
#  ('другий ведмідь', 1),
#  ('звичайний фотограф', 1),
#  ('найменший ганжа', 1),
#  ('дикий кінь', 1),
#  ('вправний спортсмен', 1),
#  ('недоторканний панна', 1),
#  ('дурний мати', 1),
#  ('полтавський жінка', 1),
#  ('новий переселенка', 1),
#  ('ясний люди', 1),
#  ('простий люди', 1),
#  ('манюнький комашинка', 1),
#  ('подурілий собака', 1),
#  ('вусатий дідуган', 1),
#  ('передній кінь', 1),
#  ('дебелий красень', 1),
#  ('булий новесенько', 1),
#  ('найбільший генерал', 1),
#  ('старий ветеран', 1),
#  ('досвідчений вояк', 1),
#  ('вражий тобі', 1),
#  ('бідний дитина', 1),
#  ('перший наталка', 1),
#  ("п'ятий кулі", 1),
#  ('знающий стрілець', 1),
#  ('потрібний пантівник', 1),
#  ('добрий кінь', 1),
#  ('гарячий борщ', 1),
#  ('невидний мати', 1),
#  ('мрійноголосий пташка', 1),
#  ('тутешній соловей', 1),
#  ('знайомий григорій', 1),
#  ('широкогрудий якут', 1),
#  ('німецький вівчарка', 1),
#  ('наталчин дружка', 1),
#  ('геніальний маляр', 1),
#  ('цінний ізюбр', 1),
#  ('здивований грицько', 1),
#  ('єдиний друг', 1),
#  ('граційний тварина', 1),
#  ('химерний тварина', 1),
#  ('буланий наталка', 1),
#  ('живий тварина', 1),
#  ('степовий куріпка', 1),
#  ('змучений люди', 1),
#  ('ставний дівчина', 1),
#  ("молодий чолов'яга", 1),
#  ('гостроязикий дівчина', 1),
#  ('батьків кум', 1),
#  ('хрещений батько', 1),
#  ('веселий русявка', 1),
#  ('спантеличений гриць', 1),
#  ('мовчазний зять', 1),
#  ('старий друзь', 1),
#  ('старий приятель', 1),
#  ('втомлений люди', 1),
#  ('цибатий співбесідник', 1),
#  ('добрий пес', 1),
#  ('страшний вовчура', 1),
#  ('безжалісний стрілець', 1),
#  ('безпощадний звіролов', 1),
#  ('мускулястий диктатор', 1),
#  ('гордий завойовник', 1),
#  ('виснажений арештант', 1),
#  ('напівбосий люди', 1),
#  ('чесний трудар', 1),
#  ('державний злодій', 1),
#  ('бородатий юнак', 1),
#  ('здичавілий собака', 1),
#  ('холодний піт', 1),
#  ('столітній дуб', 1),
#  ('великий гадюка', 1),
#  ('замріяний дівчина', 1),
#  ('яскравий дикунка', 1),
#  ('страшний заливаєва', 1),
#  ('підходящий панти', 1),
#  ('здоровенний звірюка', 1),
#  ('нерухомий жертва', 1),
#  ('світлий грицько', 1),
#  ('прекрасний пантач', 1),
#  ('великий тварина', 1),
#  ('прегарний тварина', 1),
#  ('рівненький панти', 1),
#  ('старий дід', 1),
#  ('великий панти', 1),
#  ('здоровенний таймень', 1),
#  ('химерний дівчина', 1),
#  ('сміхотливий зайчик', 1),
#  ('чотиримоторовий велетень', 1),
#  ('приголомшений григорій', 1),
#  ('нахмурений григорій', 1),
#  ('несподіваний гість', 1),
#  ('перший мисливець', 1),
#  ('добрий гість', 1),
#  ('сердитий начальник', 1),
#  ('придуркуватий начальник', 1),
#  ('лісовий чоловічок', 1),
#  ('золотий чоловік', 1),
#  ('вражий дочка', 1),
#  ('найперший красуня', 1),
#  ('бідолашний чоловік', 1),
#  ('озвучений гомон', 1),
#  ('гарячий робот', 1),
#  ('новий лада', 1),
#  ('лихий ворог', 1),
#  ('лагідний тенор', 1),
#  ('вродливий дівчина', 1),
#  ("п'яний радівон", 1),
#  ('лісовий дівчина', 1),
#  ('всесвітній залицяльник', 1),
#  ('малий козенятко', 1),
#  ('гарний дівчина', 1),
#  ('велетенський гадюка', 1),
#  ('співучий пташка', 1),
#  ('останній хлопець', 1),
#  ('вусатий дядько', 1),
#  ('путній людина', 1),
#  ('літній жінка', 1),
#  ('чорнявий дівчина', 1),
#  ('цікавий тип', 1),
#  ('здоровенний амурець', 1),
#  ('здивований пес', 1),
#  ('мрійноокий самиця', 1),
#  ('вогненнозорий коханка', 1),
#  ('граційний самиця', 1),
#  ('отруйний гадюка', 1),
#  ('пухлий далі', 1),
#  ('глибокий віра', 1),
#  ('далекий ізюбр', 1),
#  ('рогатий лицар', 1),
#  ('розпалений самець', 1),
#  ('другий ізюбр', 1),
#  ('гордий демон', 1),
#  ('поранений тварина', 1),
#  ('ударений гром', 1),
#  ('вражий кішка', 1),
#  ('невеликий підсвинок', 1),
#  ('великий вепер', 1),
#  ('страшний потвора', 1),
#  ('бузиновий пукавка', 1),
#  ('вимучений дівчина', 1),
#  ('сонний дитина', 1),
#  ('засоромлений григорій', 1),
#  ('чистий дівчина', 1),
#  ('незрозумілий дівчина', 1),
#  ('вівсяний кулі', 1),
#  ("пам'ятний григорій", 1),
#  ('виряджений віршовник', 1),
#  ('зіркий ясненька', 1),
#  ('маленький діти', 1),
#  ('диявольський гайдамак', 1),
#  ('пишний королевич', 1),
#  ('вправний майстер', 1),
#  ('молодий королевич', 1),
#  ('російський імператор', 1),
#  ('пишнобарвний півень', 1),
#  ('бажаний гість', 1),
#  ('добрий кім', 1),
#  ('дикий азіат', 1),
#  ('наївний кім', 1),
#  ('відповідальний відрядженець', 1),
#  ('многонаціональний родіна', 1),
#  ('натоптаний пасажир', 1),
#  ('тяжкий бой', 1),
#  ('набитий люди', 1),
#  ('добровільний ентузіаст', 1),
#  ('манюнький дітки', 1),
#  ('сучий син', 1),
#  ('вбраний представник', 1),
#  ('відповідальний особа', 1),
#  ('невиспаний людина', 1),
#  ('вимучений люди', 1),
#  ('північний олень', 1),
#  ('миршавий олена', 1),
#  ('миршавий пес', 1),
#  ('низенький гольдячок', 1),
#  ('екзотичний олена', 1),
#  ('балакучий дівчина', 1),
#  ('різний люди', 1),
#  ('елегантний пані', 1),
#  ('скажений пес', 1),
#  ('добрий приятель', 1),
#  ('другий роза', 1),
#  ('енергійний хлопець', 1),
#  ('різний звіря', 1),
#  ('енергійний охотінспектор', 1),
#  ('прекрасний хлопець', 1),
#  ('катерининський дама', 1),
#  ('простолінійний хлопчина', 1),
#  ('дикий хлопчисько', 1),
#  ('хижий звір', 1),
#  ('дорогий гриць', 1),
#  ('чортовий син', 1),
#  ('чортовий віслюк', 1),
#  ('основний мешканець', 1),
#  ('найбідніший старовір', 1),
#  ('косоокий японець', 1),
#  ('вражий син', 1),
#  ('дохлий кішка', 1),
#  ('запопадливий збігця', 1),
#  ('новітній муравйов', 1),
#  ('розцяцькований начальник', 1),
#  ('незнаний цар', 1),
#  ('спантеличений клієнт', 1),
#  ('сухозадий кавалер', 1),
#  ('роздрочений вепр', 1),
#  ('захмелілий гриць', 1),
#  ('напівголий дівча', 1),
#  ('личкований командир', 1),
#  ('злий дівча', 1),
#  ('селянський дівча', 1),
#  ('дебелий хлопець', 1),
#  ('здивований дівча', 1),
#  ('дідовий морозов', 1),
#  ('невдалий пінкертон', 1),
#  ('розмальований дівча', 1),
#  ('пришелепкуватий городянин', 1),
#  ('добрий хлопець', 1),
#  ('стрілецький нікола', 1),
#  ('бистрий улітко', 1),
#  ('чистий тобі', 1),
#  ('колишній кат', 1),
#  ('молодий хлопець', 1),
#  ('старий удегеєць', 1),
#  ('безбородий дідусик', 1),
#  ('цупкий ремуза', 1),
#  ('хитрий тварина', 1),
#  ('сталий дуб', 1),
#  ('велетенський кішка', 1),
#  ('велетенський потвора', 1),
#  ('розумний пес', 1),
#  ('нерухомий кішка', 1),
#  ('великий хижак', 1),
#  ('забитий кішка', 1),
#  ('здоровенний самиця', 1),
#  ('уссурійський тигр', 1),
#  ('убитий тигр', 1),
#  ('битий кішка', 1),
#  ("зв'язаний кішка", 1),
#  ('старий дідуган', 1),
#  ('живий кішка', 1),
#  ('сизий становик', 1),
#  ('бравий герой', 1),
#  ('грізний суддя', 1),
#  ('плюгавий злодюжка', 1),
#  ('сопливий боягуз', 1),
#  ('великий собака', 1),
#  ('скажений собака', 1),
#  ('надзвичайний наталка', 1),
#  ('гірський бог', 1),
#  ('пійманий кішка', 1),
#  ('живучий тварина', 1),
#  ('бідолашний дівчина', 1),
#  ('давній мешканка', 1),
#  ('великий пес', 1),
#  ('товстий бревняк', 1),
#  ('японський прикордонник', 1),
#  ('одинокий пес', 1),
#  ('чотириногий товариш', 1),
#  ('суворий тигролов', 1),
#  ('чорний рамець', 1),
#  ('упертий бой', 1),
#  ('доблесний чекіст', 1),
#  ('героїчний бой', 1),
#  ('героїчний начальник', 1),
#  ('гігантський пес', 1),
#  ('грізний енкаведпст', 1),
#  ('старий вовк', 1),
#  ('головний винуватець', 1),
#  ('божий мати', 1)]
