# %%
import json
import os
import re

import langid
import pandas as pd
from pandas_profiling import ProfileReport
import pymorphy2
import tokenize_uk

from sklearn.feature_extraction.text import CountVectorizer
from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.naive_bayes import MultinomialNB

# %%
langid.set_languages(['ru','uk'])
morph = pymorphy2.MorphAnalyzer(lang='uk')

# %%
data = {}
data_dirname = '/Users/dmytrobudashnyi/usr/projects/mine/twitter_scraper/rozetka_goods.json_tmp/'
for filename in os.listdir(data_dirname):
    with open(data_dirname + filename) as f:
        data.update(json.load(f))

len(data)
# Out:
# 136047

# %%
data['0ef244fbcb9c7acb421dbf03a8f4e2e4']
# Out:
# {'user_id': 'Ваня Цитрус',
#  'rating': 'Рейтинг товара 5 из 5',
#  'content': 'Суперр розетки спасибо Недоліки: Нет'}

# %%
rating_pattern = re.compile(r"^Рейтинг товара (\d) из 5$")


def get_rating_digit(comment):
    groups = rating_pattern.search(comment['rating']).groups()
    if groups:
        return groups[0]

def get_lang(comment):
    return langid.classify(comment['content'].replace('Недоліки:', '').replace('Переваги:', ''))[0]

uk_comments = {}
for key, comment in data.items():
    lang = get_lang(comment)
    if lang == 'uk':
        rating = get_rating_digit(comment)
        if rating in ('1', '2', '3', '4', '5'):
            digit_rating = int(rating)
            text = comment['content'].strip()
            uk_comments[key] = {
                'user_id': comment['user_id'],
                'text': text,
                'rating': digit_rating,
                '_ends_with_?': text.endswith('?'),
            }

# %%
len(uk_comments)/len(data), len(uk_comments)
# Out:
# (0.15959190573845802, 21712)

# %% [markdown]
# ![16%](./ua_16.png)

# %%
for key in list(uk_comments.keys())[:20]:
    print(uk_comments[key])
# Out:
# {'user_id': 'Влад.', 'text': "Топова пам'ять за свої гроші класно виглядає в корпусі Переваги: Частота скорость дезайн наклейка карл 60 місяців гарантії це однозначно великий плюс Недоліки: Ніяких!!!)", 'rating': 5, '_ends_with_?': False}
# {'user_id': 'Денис Єгоров', 'text': 'Поставив дві планки у MSI Tomahawk Max - у біосі просто обрав частоту 3200 і все працює без проблем. Я задоволений, що сказати)', 'rating': 5, '_ends_with_?': False}
# {'user_id': 'Максим Скориков', 'text': 'модем на перший погляд непоганий. При швидкості по кабелю 85Мб/с по вай фай роздає від 45 до 50Мб/с., що доволі непогано порівняно з іншими, які ріжуть швидкість втричі. Налаштування важкі - відрізняються від інших роутерів. В службі підтримки киевстар сидять жахливі консультанти, які навіть не знають яка в них МАС адреса та який вони використовують протокол. При швидкому налаштуванні підключити роутер не вийде - треба переходити в ручне керування і головне це виставити МАС адресу за замовчуванням та протокол:"немає" ( у всіх інших роутерах це динамічна IP і вона виставлена автоматично) і тоді все запрацює, але до цього треба було докумекати. Для тих, хто не дуже в цих питаннях розбирається - це було б не можливо без професійних спеціалістів. Поки користуюсь кілька днів. Побачимо як буде далі - гарантія тут не маленька - 3 роки. Там ще є багато функцій, але їх не перевіряв - немає поки що необхідності в них. Переваги: потужний вай фай Недоліки: важкі налаштування', 'rating': 4, '_ends_with_?': False}
# {'user_id': 'Роман Гавриленко', 'text': 'Дуже чітке зображення та хороша передача кольору (для пересічного користувача).  Комфортна швидкість матриці. Розривів чи підлагувань не спостерігається. Грається в динамічні ігри - чудово. Перегляд фільмів, так само. Навіть в 1080 чи 720, цілком нормально дивиться. Ігри в 1080, трохи помітно змазання картинки тому, бажана відповідна відеокарта для 4к. Пікселів не помітно, хіба впертись носом в екран. Хороший звук, як для вбудованих динаміків. Відстань з якої бажано працювати 0,8-1м. Якщо сісти ближче (витягнута рука), то часто доведеться крутити головою і доволі не комфортно спостерігати за подіями на екрані. Тому подбайте за вільний простір перед встановленням. Якісне заводське калібрування кольору, але можна підлаштувати під себе різними режимами, або гнучким налаштуванням (особливо чорний колір, білий - шикарний). Переваги: Діагональ/Ціна. Чітка та приємна картинка. Пульт ДУ. Недоліки: Є незначне "затінення" по периметру, при певних кутах огляду. Не регулюється висота ніжки, тільки нахил.', 'rating': 5, '_ends_with_?': False}
# {'user_id': 'Іван Бірковський', 'text': "А можно до монітора подключіть комп'ютер? Переваги: Пока не знаю.Куплю,увіжу Недоліки: Цена в край большая", 'rating': 5, '_ends_with_?': False}
# {'user_id': 'Маркуш Юрій', 'text': 'Доброго дня!\nСкажіть, будь ласка, які приблизні строки початку продажу цієї моделі?', 'rating': 5, '_ends_with_?': True}
# {'user_id': 'Роман Новачу', 'text': '#моєрозпакування\nПлата однозначно варта кожної витраченої на неї гривні. Якісна підсистема живлення і її охолодження. Брав для Ryzen 3700x все стало і завелося відразу. В налаштування BIOS є абсолютно все що треба. Память 32 гб на частоті 3200.\nПередивився перед покупкою всіх конкурентів, але цей варіант найкращий по співвідношенню ціна-якість. Хто вагається можу запевнити беріть - не прогадаєте.\nЗамовив і на наступний день вже була в мене. За пункти видачі в обласних центрах магазину окремий респект! Переваги: Якісна плата, MSI Недоліки: -', 'rating': 5, '_ends_with_?': False}
# {'user_id': 'Олександр Кашуба', 'text': 'Пів року назад взяв. І зараз тільки руки дійшли біос оновити. І тут проблема. Чорний экран і нічого не допомогає. У мене теж довго грузилась вінда, дістало, і вирішив оновити, і тут халепа. Що мені робити?Чи по гарантії її здати? Переваги: Добротна Недоліки: Біос', 'rating': 1, '_ends_with_?': False}
# {'user_id': 'Алекс Величко', 'text': 'Добрий день, питання до виробника... Тут пише що відеокарти не будуть працювати, якщо процесор не має вбудованого графічного ядра... Тобто Ryzen 7 2700x і будь - яка відеокарта робити не буде? Чи просто треба в саму відеокарту кабель до монітора підключати', 'rating': 5, '_ends_with_?': False}
# {'user_id': 'Рудківський Богда', 'text': 'Купував для R3 1200 з прицілом на апгрейд до 6-8 ядерних r5/r7.\nДовго обирав з усього парку B450х. Остаточно вирішував між MSI A-Pro Max/A-Plus Max та ASUS TUF. З плюсів - виглядає шикарно, непогана підсистема живлення з радіаторами, зручний функціональний інтерфейс UEFI, достатньо портів розширення і конекторів кулерів. В іншому - просто якісний продукт за свої кошти Переваги: Якісні компоненти і ергономіка плати, система живлення, зручний UEFI Недоліки: Відсутні', 'rating': 5, '_ends_with_?': False}
# {'user_id': 'Олег Кравчик', 'text': 'Тут в комплекті є сата кабелі ?', 'rating': 5, '_ends_with_?': True}
# {'user_id': 'Кузик Андрій', 'text': 'Купував в другом месте не МАХ, через місяць пропав звук. Наремонті була 2 рази, нарешті звук робить.\nВиникли проблеми в розгоні озу. Мав 2плашки по 4ГБ team elite 2400 які розігнав до 3200мгц. Докупив ще таких самих 2 шт. Тепер заводиться лише на 2400 якщо вставлені 4шт в платі.\nMSI не купив би більше, Переваги: радіатори Недоліки: якість', 'rating': 2, '_ends_with_?': False}
# {'user_id': 'Дмитр', 'text': 'коробка приїхала відкритою, в середині ні інструкцій  ні ніяких додаткових  книжечок не було,  ні поролону ні чого,   упаковка, як від дешевого взуття. Недоліки: приїхала розпакованою', 'rating': 3, '_ends_with_?': False}
# {'user_id': 'Ирина Цисельска', 'text': 'Коли тримаєш в руках Самсунг стає відразу видно різницю з іншою технікою. Цей планшет купила мамі. Для спілкування та перегляду відео. З задачами справляється на 5 + ,передача кольорів і звук чудові. Мама дуже задоволена. До нього купила протиударний чохол бампер з підставкою, а також захисне скло. Переваги: Зображення, звук Недоліки: Поки що не помітили', 'rating': 5, '_ends_with_?': False}
# {'user_id': 'Богдан Корнівський', 'text': 'Придбав планшет 4 місяці тому . За період користування знайшов як плюси так і мінуси .\n\nПлюси\nПланшет швидко реагує на дотик без лагів і затримок під час натискування .\nЕкран сочний , фільми дивитися саме задоволення . \nЗвук басистий , чистий , два динаміки з функцією Dolby справляються з музикою та фільмами на ура .\nЧитання книг , робота з документами це все за замовчуванням .\nМеталева задня кришка ,  яка наділяє планшет статусним виглядом . \nІгри як на диво йдуть теж на ура , хоча з 2 гб Оп не все так як хотілось б . \nБатерея бомба , тиждень без зарядки при помірному використанні , 3-4 дні середнє використання , 1 день активне використання . \n9 андройд\nКамера хоч і 8 мп але якість що фронтальної що основної вражає . \n\nМінуси \nЗамало ОП , 2гб  не дають планшету  видавати повну потужність процесора . Ігри йдуть без лагів спочатку , потім нагрівається , задня металева кришка не справляється з цим адже нагрівається саме та частина де розміщенна пластмасова вставка для мережової антени і wifi . 1 хв гри по wifi  і вже нагрівається . Звичайні ігри норм .\nЦарапається на ура , так званий gorilla glas нічого не допоміг .\nПачкається моментально , витерти екран та ще мука , просто так не витреш .\nЗатримка при роботі з файлами і фото коли їх є багато .  Останнє відкрите  вікно взагалі стирається і при новому відкритті ще раз прогружає . Важкий , тримати в руках при перегляді фільма справжнє випробовування, руки так і терпнуть , а з чехлом ще важчий став . Переваги: Для сімейного мультимедійного планшета підходить 100% Недоліки: Нема вібро. Не раджу використовувати для ігор . Скоріше за все продуктивність знизиться .', 'rating': 4, '_ends_with_?': False}
# {'user_id': 'Тетяна Човга', 'text': 'Користуємося 3 дні. За цей час недоліків не зауважили Переваги: хороший екран, зручний у користуванні Недоліки: час покаже :)', 'rating': 4, '_ends_with_?': False}
# {'user_id': 'supper Games', 'text': 'Класний пристрій', 'rating': 5, '_ends_with_?': False}
# {'user_id': 'Дмитро Кульчицький', 'text': "Отримав своє замовлення. Justin доставили швидко і без проблем. Карта встановлена в корпусі зі слабкою вентиляцією, в 100% навантаженні карта гріється близько 72С. При таких температурах шум від вентиляторів посилюється але не надокучає. В деяких іграх слабким місцем є ГП, а не об'єм пам'яті, тому, як мені здається, 5500хт з 8гб не завжди врятує. Цей бюджетній варіант добре підійде для сучасних ігор в FHD для високих-ультра налаштувань. Якщо бажаєте всі ігри на ультра налаштуваннях краще розгляньте карти середнього і вище цінових діапазонів. Переваги: 3 роки гарантії. Система охолодження. Тихо працює. GDDR6. Сучасна. Недоліки: Ціна. Думав написати в недоліки об'єм пам'яті, але у всих бюджетних картах він такий (1650, 1650супер)", 'rating': 4, '_ends_with_?': False}
# {'user_id': 'Виктор', 'text': "Через тиждень використання (все працювало добре, прошивка не змінювалась, не розганялась) при завантаженні Windows висла на етапі відеодрайвера. Перевстановив Windows - висне при спробі встановити відеодрайвер, гасне екран, потім самостійно ребут. Далі Windows завантажується зі стандартним драйвером. Поки віддав в сервіс на перевірку. По відгукам в інтернеті - багато проблем саме з відеопам'яттю.", 'rating': 3, '_ends_with_?': False}
# {'user_id': 'Игорь Охрименко', 'text': 'Якщо запускати ігри в FullHD - тягне все на ультрах з величезним запасом, не шумить і не гріється. В 4к тестував лише "Black Desert" - геть без проблем  60 фпс - не шумить, не гріється.\n\nАле є один недолік - потріскування під час автоматичного запуску кулерів (витратив досить часу щоб ідентифікувати що це саме вони шумлять). Хотілось би отримати офіційний коментар щодо цієї проблеми. Переваги: Потужна, тиха, холодна Недоліки: Потріскування при запуску кулерів', 'rating': 4, '_ends_with_?': False}

# %%
all_comments_df = pd.DataFrame(uk_comments).T
all_comments_df
# Out:
#                                            user_id  \
# 20029cc45769724050352ed544f396c7             Влад.
# ae7f8bafe762b6d64a7ddf2071991d6d      Денис Єгоров
# 1de61284cc3bc7224b857e723c1bec7a   Максим Скориков
# 145d013d3b7252487964796f8652ebeb  Роман Гавриленко
# 2a1a4963ab1e9b71534b15e8436257b2  Іван Бірковський
# ...                                            ...
# 297bce6ec938accdc5ea6772df789814      Олег Великий
# fad6a5be690a1b3f99595babf6fb5110   Денис Гордиенко
# 007e0638ff0284c80e684351a30e06fb         Matrix TV
# 13fb2ab8b08798ca9f3e3ef088a36963           Max Bro
# e6fc9061c5cec97147a305b744b416a7        ykrop4ik29
#
#                                                                                text  \
# 20029cc45769724050352ed544f396c7  Топова пам'ять за свої гроші класно виглядає в...
# ae7f8bafe762b6d64a7ddf2071991d6d  Поставив дві планки у MSI Tomahawk Max - у біо...
# 1de61284cc3bc7224b857e723c1bec7a  модем на перший погляд непоганий. При швидкост...
# 145d013d3b7252487964796f8652ebeb  Дуже чітке зображення та хороша передача кольо...
# 2a1a4963ab1e9b71534b15e8436257b2  А можно до монітора подключіть комп'ютер? Пере...
# ...                                                                             ...
# 297bce6ec938accdc5ea6772df789814        Які ігри на ньму підуть і наяких настройках
# fad6a5be690a1b3f99595babf6fb5110      Можно установить видеокарту Asus 1050 Ti ROG?
# 007e0638ff0284c80e684351a30e06fb  Якщо я підключу ПК до vga-монітора картинка бу...
# 13fb2ab8b08798ca9f3e3ef088a36963      Чи можна доставити операційній. Системі на 16
# e6fc9061c5cec97147a305b744b416a7  Комп'ютер прийшов швидко,все добре упаковано і...
#
#                                  rating _ends_with_?
# 20029cc45769724050352ed544f396c7      5        False
# ae7f8bafe762b6d64a7ddf2071991d6d      5        False
# 1de61284cc3bc7224b857e723c1bec7a      4        False
# 145d013d3b7252487964796f8652ebeb      5        False
# 2a1a4963ab1e9b71534b15e8436257b2      5        False
# ...                                 ...          ...
# 297bce6ec938accdc5ea6772df789814      5        False
# fad6a5be690a1b3f99595babf6fb5110      5         True
# 007e0638ff0284c80e684351a30e06fb      5        False
# 13fb2ab8b08798ca9f3e3ef088a36963      4        False
# e6fc9061c5cec97147a305b744b416a7      4        False
#
# [21712 rows x 4 columns]

# %%
#cleaned_comments_df = all_comments_df[all_comments_df['_ends_with_?'] == False].drop(['_ends_with_?'], axis=1)
skip_indexes = all_comments_df[all_comments_df['_ends_with_?']][all_comments_df['rating'] == 5].index
cleaned_comments_df = all_comments_df.drop(skip_indexes, axis=0)
cleaned_comments_df.drop(['_ends_with_?'], axis=1, inplace=True)
cleaned_comments_df
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: UserWarning: Boolean Series key will be reindexed to match DataFrame index.
#                                            user_id  \
# 20029cc45769724050352ed544f396c7             Влад.
# ae7f8bafe762b6d64a7ddf2071991d6d      Денис Єгоров
# 1de61284cc3bc7224b857e723c1bec7a   Максим Скориков
# 145d013d3b7252487964796f8652ebeb  Роман Гавриленко
# 2a1a4963ab1e9b71534b15e8436257b2  Іван Бірковський
# ...                                            ...
# 9e55df94ad5c6568eb5fc307efb13496           Віталій
# 297bce6ec938accdc5ea6772df789814      Олег Великий
# 007e0638ff0284c80e684351a30e06fb         Matrix TV
# 13fb2ab8b08798ca9f3e3ef088a36963           Max Bro
# e6fc9061c5cec97147a305b744b416a7        ykrop4ik29
#
#                                                                                text  \
# 20029cc45769724050352ed544f396c7  Топова пам'ять за свої гроші класно виглядає в...
# ae7f8bafe762b6d64a7ddf2071991d6d  Поставив дві планки у MSI Tomahawk Max - у біо...
# 1de61284cc3bc7224b857e723c1bec7a  модем на перший погляд непоганий. При швидкост...
# 145d013d3b7252487964796f8652ebeb  Дуже чітке зображення та хороша передача кольо...
# 2a1a4963ab1e9b71534b15e8436257b2  А можно до монітора подключіть комп'ютер? Пере...
# ...                                                                             ...
# 9e55df94ad5c6568eb5fc307efb13496  Прийшов досить таки швидко. Відправили в день ...
# 297bce6ec938accdc5ea6772df789814        Які ігри на ньму підуть і наяких настройках
# 007e0638ff0284c80e684351a30e06fb  Якщо я підключу ПК до vga-монітора картинка бу...
# 13fb2ab8b08798ca9f3e3ef088a36963      Чи можна доставити операційній. Системі на 16
# e6fc9061c5cec97147a305b744b416a7  Комп'ютер прийшов швидко,все добре упаковано і...
#
#                                  rating
# 20029cc45769724050352ed544f396c7      5
# ae7f8bafe762b6d64a7ddf2071991d6d      5
# 1de61284cc3bc7224b857e723c1bec7a      4
# 145d013d3b7252487964796f8652ebeb      5
# 2a1a4963ab1e9b71534b15e8436257b2      5
# ...                                 ...
# 9e55df94ad5c6568eb5fc307efb13496      5
# 297bce6ec938accdc5ea6772df789814      5
# 007e0638ff0284c80e684351a30e06fb      5
# 13fb2ab8b08798ca9f3e3ef088a36963      4
# e6fc9061c5cec97147a305b744b416a7      4
#
# [20680 rows x 3 columns]

# %%
for index, row in cleaned_comments_df.iterrows():
    text = row['text']
    sentences = tokenize_uk.tokenize_sents(text)
    lemma_sentences = []
    for sentence in sentences:
        tokens = tokenize_uk.tokenize_words(sentence)
        lemma_sentences.append(' '.join([morph.parse(word)[0].normal_form for word in tokens]))

    if row['rating'] == 5:
        new_rating = 'positive'
    elif row['rating'] == 4:
        new_rating = 'neutral'
    else:
        new_rating = 'negative'

    cleaned_comments_df.loc[index, 'new_rating'] = new_rating
    cleaned_comments_df.loc[index, 'lemmatized_text'] = ' '.join(lemma_sentences)

# %%
cleaned_comments_df
# Out:
#                                            user_id  \
# 20029cc45769724050352ed544f396c7             Влад.
# ae7f8bafe762b6d64a7ddf2071991d6d      Денис Єгоров
# 1de61284cc3bc7224b857e723c1bec7a   Максим Скориков
# 145d013d3b7252487964796f8652ebeb  Роман Гавриленко
# 2a1a4963ab1e9b71534b15e8436257b2  Іван Бірковський
# ...                                            ...
# 9e55df94ad5c6568eb5fc307efb13496           Віталій
# 297bce6ec938accdc5ea6772df789814      Олег Великий
# 007e0638ff0284c80e684351a30e06fb         Matrix TV
# 13fb2ab8b08798ca9f3e3ef088a36963           Max Bro
# e6fc9061c5cec97147a305b744b416a7        ykrop4ik29
#
#                                                                                text  \
# 20029cc45769724050352ed544f396c7  Топова пам'ять за свої гроші класно виглядає в...
# ae7f8bafe762b6d64a7ddf2071991d6d  Поставив дві планки у MSI Tomahawk Max - у біо...
# 1de61284cc3bc7224b857e723c1bec7a  модем на перший погляд непоганий. При швидкост...
# 145d013d3b7252487964796f8652ebeb  Дуже чітке зображення та хороша передача кольо...
# 2a1a4963ab1e9b71534b15e8436257b2  А можно до монітора подключіть комп'ютер? Пере...
# ...                                                                             ...
# 9e55df94ad5c6568eb5fc307efb13496  Прийшов досить таки швидко. Відправили в день ...
# 297bce6ec938accdc5ea6772df789814        Які ігри на ньму підуть і наяких настройках
# 007e0638ff0284c80e684351a30e06fb  Якщо я підключу ПК до vga-монітора картинка бу...
# 13fb2ab8b08798ca9f3e3ef088a36963      Чи можна доставити операційній. Системі на 16
# e6fc9061c5cec97147a305b744b416a7  Комп'ютер прийшов швидко,все добре упаковано і...
#
#                                  rating new_rating  \
# 20029cc45769724050352ed544f396c7      5   positive
# ae7f8bafe762b6d64a7ddf2071991d6d      5   positive
# 1de61284cc3bc7224b857e723c1bec7a      4    neutral
# 145d013d3b7252487964796f8652ebeb      5   positive
# 2a1a4963ab1e9b71534b15e8436257b2      5   positive
# ...                                 ...        ...
# 9e55df94ad5c6568eb5fc307efb13496      5   positive
# 297bce6ec938accdc5ea6772df789814      5   positive
# 007e0638ff0284c80e684351a30e06fb      5   positive
# 13fb2ab8b08798ca9f3e3ef088a36963      4    neutral
# e6fc9061c5cec97147a305b744b416a7      4    neutral
#
#                                                                     lemmatized_text
# 20029cc45769724050352ed544f396c7  топовий пам'ять за свій гріш класно виглядати ...
# ae7f8bafe762b6d64a7ddf2071991d6d  поставити два планка у msi tomahawk max - у бі...
# 1de61284cc3bc7224b857e723c1bec7a  модем на перший погляд непоганий . перти швидк...
# 145d013d3b7252487964796f8652ebeb  дуже чіткий зображення та хороший передача кол...
# 2a1a4963ab1e9b71534b15e8436257b2  а можно до монітор подключити комп'ютер ? пере...
# ...                                                                             ...
# 9e55df94ad5c6568eb5fc307efb13496  прийти досить таки швидко . відправити в день ...
# 297bce6ec938accdc5ea6772df789814            який гра на ньм піти і наякий настройка
# 007e0638ff0284c80e684351a30e06fb  якщо я підключити пк до vga - монітор картинка...
# 13fb2ab8b08798ca9f3e3ef088a36963     чи можна доставити операційний . система на 16
# e6fc9061c5cec97147a305b744b416a7  комп'ютер прийти швидко , весь добре упакувати...
#
# [20680 rows x 5 columns]

# %%
cleaned_comments_df.groupby(['new_rating']).count() / len(cleaned_comments_df) * 100
# Out:
#               user_id       text     rating  lemmatized_text
# new_rating
# negative    12.940039  12.940039  12.940039        12.940039
# neutral     17.577369  17.577369  17.577369        17.577369
# positive    69.482592  69.482592  69.482592        69.482592

# %%
df = cleaned_comments_df.copy(deep=True)
y = df['new_rating']
df.drop(['new_rating'], axis=1, inplace=True)
df
# Out:
#                                            user_id  \
# 20029cc45769724050352ed544f396c7             Влад.
# ae7f8bafe762b6d64a7ddf2071991d6d      Денис Єгоров
# 1de61284cc3bc7224b857e723c1bec7a   Максим Скориков
# 145d013d3b7252487964796f8652ebeb  Роман Гавриленко
# 2a1a4963ab1e9b71534b15e8436257b2  Іван Бірковський
# ...                                            ...
# 9e55df94ad5c6568eb5fc307efb13496           Віталій
# 297bce6ec938accdc5ea6772df789814      Олег Великий
# 007e0638ff0284c80e684351a30e06fb         Matrix TV
# 13fb2ab8b08798ca9f3e3ef088a36963           Max Bro
# e6fc9061c5cec97147a305b744b416a7        ykrop4ik29
#
#                                                                                text  \
# 20029cc45769724050352ed544f396c7  Топова пам'ять за свої гроші класно виглядає в...
# ae7f8bafe762b6d64a7ddf2071991d6d  Поставив дві планки у MSI Tomahawk Max - у біо...
# 1de61284cc3bc7224b857e723c1bec7a  модем на перший погляд непоганий. При швидкост...
# 145d013d3b7252487964796f8652ebeb  Дуже чітке зображення та хороша передача кольо...
# 2a1a4963ab1e9b71534b15e8436257b2  А можно до монітора подключіть комп'ютер? Пере...
# ...                                                                             ...
# 9e55df94ad5c6568eb5fc307efb13496  Прийшов досить таки швидко. Відправили в день ...
# 297bce6ec938accdc5ea6772df789814        Які ігри на ньму підуть і наяких настройках
# 007e0638ff0284c80e684351a30e06fb  Якщо я підключу ПК до vga-монітора картинка бу...
# 13fb2ab8b08798ca9f3e3ef088a36963      Чи можна доставити операційній. Системі на 16
# e6fc9061c5cec97147a305b744b416a7  Комп'ютер прийшов швидко,все добре упаковано і...
#
#                                  rating  \
# 20029cc45769724050352ed544f396c7      5
# ae7f8bafe762b6d64a7ddf2071991d6d      5
# 1de61284cc3bc7224b857e723c1bec7a      4
# 145d013d3b7252487964796f8652ebeb      5
# 2a1a4963ab1e9b71534b15e8436257b2      5
# ...                                 ...
# 9e55df94ad5c6568eb5fc307efb13496      5
# 297bce6ec938accdc5ea6772df789814      5
# 007e0638ff0284c80e684351a30e06fb      5
# 13fb2ab8b08798ca9f3e3ef088a36963      4
# e6fc9061c5cec97147a305b744b416a7      4
#
#                                                                     lemmatized_text
# 20029cc45769724050352ed544f396c7  топовий пам'ять за свій гріш класно виглядати ...
# ae7f8bafe762b6d64a7ddf2071991d6d  поставити два планка у msi tomahawk max - у бі...
# 1de61284cc3bc7224b857e723c1bec7a  модем на перший погляд непоганий . перти швидк...
# 145d013d3b7252487964796f8652ebeb  дуже чіткий зображення та хороший передача кол...
# 2a1a4963ab1e9b71534b15e8436257b2  а можно до монітор подключити комп'ютер ? пере...
# ...                                                                             ...
# 9e55df94ad5c6568eb5fc307efb13496  прийти досить таки швидко . відправити в день ...
# 297bce6ec938accdc5ea6772df789814            який гра на ньм піти і наякий настройка
# 007e0638ff0284c80e684351a30e06fb  якщо я підключити пк до vga - монітор картинка...
# 13fb2ab8b08798ca9f3e3ef088a36963     чи можна доставити операційний . система на 16
# e6fc9061c5cec97147a305b744b416a7  комп'ютер прийти швидко , весь добре упакувати...
#
# [20680 rows x 4 columns]

# %%
X_train, X_test, y_train, y_test = train_test_split(
    df, y, train_size=0.8, test_size=0.2, random_state=0, shuffle=True, stratify=y
)
train_data = X_train.join(y_train)
test_data = X_test.join(y_test)
train_data
# Out:
#                                               user_id  \
# 0c811a8fc0497f8a6de3f254dc24e5a8  Богдан Городенський
# 4870dd047a08460d0240ccdcb89e58e0       Олег Логвиненк
# 005d6ac9a642474c1162c9671e6bae99                Тарас
# ab08664888c4105e2d3a56da076b8a01          Роман Гевко
# 652eb8f8e00837a9913726e55e17c07c         Юрій Колодій
# ...                                               ...
# 27304de29a0701607b6c3cdce449c332               Сергій
# cd3bca92571e792eaab13f24038534a5        Володимир Туз
# 1885029ccc9cadcbb9f8da11962787bc                  Ксе
# 5dbec104c03d1011356c62d6635f810c               Godrik
# e318cd4339d61b20113dadefec8e1ee8       Галина Дьякова
#
#                                                                                text  \
# 0c811a8fc0497f8a6de3f254dc24e5a8  rozetka прислали жорсткий диск в куску картонк...
# 4870dd047a08460d0240ccdcb89e58e0  Використовую вже 7 місяців, все влаштовує. Пер...
# 005d6ac9a642474c1162c9671e6bae99  Досвід користування невеликий, та перше вражен...
# ab08664888c4105e2d3a56da076b8a01                              дуже тихий вентилятор
# 652eb8f8e00837a9913726e55e17c07c  Клавіатура просто супер, ставлю 10/10 рекоменд...
# ...                                                                             ...
# 27304de29a0701607b6c3cdce449c332                   Память як память, працю і добре!
# cd3bca92571e792eaab13f24038534a5  Купував менше року тому. Спочатку - наче все н...
# 1885029ccc9cadcbb9f8da11962787bc  брала на подарок мужу. Ему очень понравились. ...
# 5dbec104c03d1011356c62d6635f810c  Гарно виглядає, чітко працює. IPS матриця роби...
# e318cd4339d61b20113dadefec8e1ee8                 Переваги: Дуже зручно і не дорого.
#
#                                  rating  \
# 0c811a8fc0497f8a6de3f254dc24e5a8      1
# 4870dd047a08460d0240ccdcb89e58e0      5
# 005d6ac9a642474c1162c9671e6bae99      4
# ab08664888c4105e2d3a56da076b8a01      4
# 652eb8f8e00837a9913726e55e17c07c      5
# ...                                 ...
# 27304de29a0701607b6c3cdce449c332      5
# cd3bca92571e792eaab13f24038534a5      1
# 1885029ccc9cadcbb9f8da11962787bc      5
# 5dbec104c03d1011356c62d6635f810c      5
# e318cd4339d61b20113dadefec8e1ee8      5
#
#                                                                     lemmatized_text  \
# 0c811a8fc0497f8a6de3f254dc24e5a8  rozetka прислати жорсткий диск в кусок картонк...
# 4870dd047a08460d0240ccdcb89e58e0  використовувати вже 7 місяць , весь влаштовува...
# 005d6ac9a642474c1162c9671e6bae99  досвід користування невеликий , та перший враж...
# ab08664888c4105e2d3a56da076b8a01                              дуже тихий вентилятор
# 652eb8f8e00837a9913726e55e17c07c  клавіатура просто супер , ставити 10 / 10 реко...
# ...                                                                             ...
# 27304de29a0701607b6c3cdce449c332                 память як память , праця і добре !
# cd3bca92571e792eaab13f24038534a5  купувати менше рок том . спочатку - наче весь ...
# 1885029ccc9cadcbb9f8da11962787bc  брати на подарка муж . ему очення понравитися ...
# 5dbec104c03d1011356c62d6635f810c  гарно виглядати , чітко працювати . ips матриц...
# e318cd4339d61b20113dadefec8e1ee8               перевага : дуже зручно і не дорого .
#
#                                  new_rating
# 0c811a8fc0497f8a6de3f254dc24e5a8   negative
# 4870dd047a08460d0240ccdcb89e58e0   positive
# 005d6ac9a642474c1162c9671e6bae99    neutral
# ab08664888c4105e2d3a56da076b8a01    neutral
# 652eb8f8e00837a9913726e55e17c07c   positive
# ...                                     ...
# 27304de29a0701607b6c3cdce449c332   positive
# cd3bca92571e792eaab13f24038534a5   negative
# 1885029ccc9cadcbb9f8da11962787bc   positive
# 5dbec104c03d1011356c62d6635f810c   positive
# e318cd4339d61b20113dadefec8e1ee8   positive
#
# [16544 rows x 5 columns]

# %%
train_profile = ProfileReport(train_data)
train_profile.to_file('train_profile_report.html')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas_profiling/base.py:319: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)

# %%
test_profile = ProfileReport(test_data)
test_profile.to_file('test_profile_report.html')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/pandas_profiling/base.py:319: FutureWarning: The join_axes-keyword is deprecated. Use .reindex or .reindex_like on the result to achieve the same functionality.
#   variable_stats = pd.concat(ldesc, join_axes=pd.Index([names]), axis=1)

# %% [markdown]
# # Baseline FTW

# %%
baseline = ['positive'] * len(test_data)
print(classification_report(test_data.new_rating.to_list(), baseline))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.00      0.00      0.00       535
#      neutral       0.00      0.00      0.00       727
#     positive       0.69      1.00      0.82      2874
#
#     accuracy                           0.69      4136
#    macro avg       0.23      0.33      0.27      4136
# weighted avg       0.48      0.69      0.57      4136
# /opt/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# # Tokens + CountVectorizer + MultinomialNB

# %%
count_vect = CountVectorizer()

clf = MultinomialNB()
scores = cross_val_score(clf, train_counts, train_data.new_rating.to_list(), cv=5, scoring='f1_macro')
print('[cross_val] F1:', sum(scores)/5)

train_counts = count_vect.fit_transform(train_data.text)
print(train_counts.shape)
count_vect.get_feature_names()[5000:5020]
# Out:
# [cross_val] F1: 0.526215580296729
# (16544, 46933)
# ['rainbow',
#  'rainmetter',
#  'rally',
#  'ram',
#  'ramaxel',
#  'ramdisk',
#  'random',
#  'rapid',
#  'rapoo',
#  'rapoo_3100p_black',
#  'rappo',
#  'rar',
#  'ras',
#  'rasman',
#  'rast',
#  'rate',
#  'ratio',
#  'raw',
#  'ray',
#  'rayzen']

# %%
from sklearn.naive_bayes import MultinomialNB
clf = MultinomialNB().fit(train_counts, train_data.new_rating.to_list())

# %%
test_counts = count_vect.transform(test_data.text)
y_pred = clf.predict(test_counts)

# %%
from sklearn.metrics import classification_report
print(classification_report(test_data.new_rating.to_list(), y_pred))
# Out:
#               precision    recall  f1-score   support
#
#     negative       0.76      0.38      0.51       535
#      neutral       0.42      0.07      0.12       727
#     positive       0.75      0.98      0.85      2874
#
#     accuracy                           0.74      4136
#    macro avg       0.64      0.48      0.49      4136
# weighted avg       0.69      0.74      0.68      4136

# %% [markdown]
# # Lemma + CountVectorizer + Multinomial NB

# %%
count_vect = CountVectorizer()
train_counts = count_vect.fit_transform(train_data.lemmatized_text)
print('Train counts shape:', train_counts.shape)

clf = MultinomialNB()
scores = cross_val_score(clf, train_counts, train_data.new_rating.to_list(), cv=5, scoring='f1_macro')
print('[cross_val] F1:', sum(scores)/5)

clf.fit(train_counts, train_data.new_rating.to_list())

test_counts = count_vect.transform(test_data.lemmatized_text)
print('Test counts shape:', test_counts.shape)
y_pred = clf.predict(test_counts)
test_data['predicted'] = y_pred

print(classification_report(test_data.new_rating.to_list(), y_pred))
# Out:
# Train counts shape: (16544, 27656)
# [cross_val] F1: 0.5298869072370327
# Test counts shape: (4136, 27656)
#               precision    recall  f1-score   support
#
#     negative       0.72      0.46      0.56       535
#      neutral       0.39      0.11      0.17       727
#     positive       0.77      0.96      0.86      2874
#
#     accuracy                           0.75      4136
#    macro avg       0.62      0.51      0.53      4136
# weighted avg       0.70      0.75      0.70      4136

# %% [markdown]
# # Undersampling

# %%
negative_df = train_data.loc[train_data['new_rating'] == 'negative']
n = len(negative_df)
print('Predicted number of records:', n * 3)
neutral_df = train_data.loc[train_data['new_rating'] == 'neutral'].sample(n=n,random_state=0)
positive_df = train_data.loc[train_data['new_rating'] == 'positive'].sample(n=n,random_state=0)
normalized_df = pd.concat([negative_df, neutral_df, positive_df])
normalized_df
# Out:
# Predicted number of records: 6423
#                                               user_id  \
# 0c811a8fc0497f8a6de3f254dc24e5a8  Богдан Городенський
# e189a52c092accb7ec4d157ef72e8d57                  Юра
# 484885177a0825a7ad30791461fefd52         Сергей Олыва
# 77bde83134cf22bf5c7e308ed2910e4a         Грицько Тара
# b746cfae94bcaa22d35e4bb42f83dc32      Елена Алиманска
# ...                                               ...
# 5bb65ced39000189c2ec14a73124ff00          Павел Осоки
# 413091665d0922ed2ead7722670c738a      Микола покупець
# 74306170ae1cb107d463111592be25da              Gotarus
# dacd0f23d4755ac4d2bc31065fad131f  Анатолій Дощанський
# cc75ad37e016981fd0291aa8dc424c3e       Хоцик Олександ
#
#                                                                                text  \
# 0c811a8fc0497f8a6de3f254dc24e5a8  rozetka прислали жорсткий диск в куску картонк...
# e189a52c092accb7ec4d157ef72e8d57  Ноутбук не загружається з цією оперативкою. Ск...
# 484885177a0825a7ad30791461fefd52  Загалом нормальний дешевий роутер, але сигнал ...
# 77bde83134cf22bf5c7e308ed2910e4a  Абсолютно не рекомендую Недоліки: якість жахли...
# b746cfae94bcaa22d35e4bb42f83dc32  на роботі така сама мишка і працює відмінно,мя...
# ...                                                                             ...
# 5bb65ced39000189c2ec14a73124ff00  2 місяці ще не показник, але взагалом всім зад...
# 413091665d0922ed2ead7722670c738a  Поки все норм! Переваги: Дизайн Недоліки: Несу...
# 74306170ae1cb107d463111592be25da  Чудова "оперативка" встановив у ноутбук близьк...
# dacd0f23d4755ac4d2bc31065fad131f  Купував для 3-4gмодема(Н.е3372-607),сімпара ві...
# cc75ad37e016981fd0291aa8dc424c3e  Купив маршала в чехії, грає бомбезно, а думав ...
#
#                                  rating  \
# 0c811a8fc0497f8a6de3f254dc24e5a8      1
# e189a52c092accb7ec4d157ef72e8d57      1
# 484885177a0825a7ad30791461fefd52      3
# 77bde83134cf22bf5c7e308ed2910e4a      1
# b746cfae94bcaa22d35e4bb42f83dc32      1
# ...                                 ...
# 5bb65ced39000189c2ec14a73124ff00      5
# 413091665d0922ed2ead7722670c738a      5
# 74306170ae1cb107d463111592be25da      5
# dacd0f23d4755ac4d2bc31065fad131f      5
# cc75ad37e016981fd0291aa8dc424c3e      5
#
#                                                                     lemmatized_text  \
# 0c811a8fc0497f8a6de3f254dc24e5a8  rozetka прислати жорсткий диск в кусок картонк...
# e189a52c092accb7ec4d157ef72e8d57  ноутбук не загружаватися з цей оперативка . ск...
# 484885177a0825a7ad30791461fefd52  загал нормальний дешевий роутерти , але сигнал...
# 77bde83134cf22bf5c7e308ed2910e4a  абсолютно не рекомендувати недолік : якість жа...
# b746cfae94bcaa22d35e4bb42f83dc32  на робот такий самий мишка і працювати відмінн...
# ...                                                                             ...
# 5bb65ced39000189c2ec14a73124ff00  2 місяць ще не показник , але взагал весь задо...
# 413091665d0922ed2ead7722670c738a  поки весь норма ! перевага : дизайн недолік : ...
# 74306170ae1cb107d463111592be25da  чудовий " оперативка " встановити у ноутбук бл...
# dacd0f23d4755ac4d2bc31065fad131f  купувати для 3-4 gмодем ( н . е3372 -607 ) , с...
# cc75ad37e016981fd0291aa8dc424c3e  купити маршал в чехія , грати бомбезно , а дум...
#
#                                  new_rating
# 0c811a8fc0497f8a6de3f254dc24e5a8   negative
# e189a52c092accb7ec4d157ef72e8d57   negative
# 484885177a0825a7ad30791461fefd52   negative
# 77bde83134cf22bf5c7e308ed2910e4a   negative
# b746cfae94bcaa22d35e4bb42f83dc32   negative
# ...                                     ...
# 5bb65ced39000189c2ec14a73124ff00   positive
# 413091665d0922ed2ead7722670c738a   positive
# 74306170ae1cb107d463111592be25da   positive
# dacd0f23d4755ac4d2bc31065fad131f   positive
# cc75ad37e016981fd0291aa8dc424c3e   positive
#
# [6423 rows x 5 columns]

# %%
count_vect = CountVectorizer()
train_counts = count_vect.fit_transform(normalized_df.lemmatized_text)
print('Train counts shape:', train_counts.shape)

clf = MultinomialNB()
scores = cross_val_score(clf, train_counts, normalized_df.new_rating.to_list(), cv=5, scoring='f1_macro')
print('[cross_val] F1:', sum(scores)/5)

clf.fit(train_counts, normalized_df.new_rating.to_list())

test_counts = count_vect.transform(test_data.lemmatized_text)
print('Test counts shape:', test_counts.shape)
y_pred = clf.predict(test_counts)
test_data['predicted'] = y_pred

print(classification_report(test_data.new_rating.to_list(), y_pred))
# Out:
# Train counts shape: (26642, 27656)
# [cross_val] F1: 0.7546246212892258
# Test counts shape: (4136, 27656)
#               precision    recall  f1-score   support
#
#     negative       0.59      0.58      0.59       535
#      neutral       0.34      0.35      0.34       727
#     positive       0.84      0.83      0.83      2874
#
#     accuracy                           0.71      4136
#    macro avg       0.59      0.59      0.59      4136
# weighted avg       0.72      0.71      0.71      4136

# %% [markdown]
# -----------------------
# Щось пішло не так :|
# Очікування були вищими

# %% [markdown]
# # Bigrams

# %%
count_vect = CountVectorizer(ngram_range=(2,2))
train_counts = count_vect.fit_transform(train_data.lemmatized_text)
print('Train counts shape:', train_counts.shape)

clf = MultinomialNB()
scores = cross_val_score(clf, train_counts, train_data.new_rating.to_list(), cv=5, scoring='f1_macro')
print('[cross_val] F1:', sum(scores)/5)

clf.fit(train_counts, train_data.new_rating.to_list())

test_counts = count_vect.transform(test_data.lemmatized_text)
print('Test counts shape:', test_counts.shape)
y_pred = clf.predict(test_counts)
test_data['predicted'] = y_pred

print(classification_report(test_data.new_rating.to_list(), y_pred))
# Out:
# Train counts shape: (16544, 253395)
# [cross_val] F1: 0.5633846972406789
# Test counts shape: (4136, 253395)
#               precision    recall  f1-score   support
#
#     negative       0.84      0.33      0.48       535
#      neutral       0.39      0.04      0.07       727
#     positive       0.74      0.99      0.85      2874
#
#     accuracy                           0.74      4136
#    macro avg       0.65      0.45      0.46      4136
# weighted avg       0.69      0.74      0.66      4136

# %%
count_vect = CountVectorizer(ngram_range=(1,2))
train_counts = count_vect.fit_transform(train_data.lemmatized_text)
print('Train counts shape:', train_counts.shape)

clf = MultinomialNB()
scores = cross_val_score(clf, train_counts, train_data.new_rating.to_list(), cv=5, scoring='f1_macro')
print('[cross_val] F1:', sum(scores)/5)

clf.fit(train_counts, train_data.new_rating.to_list())

test_counts = count_vect.transform(test_data.lemmatized_text)
print('Test counts shape:', test_counts.shape)
y_pred = clf.predict(test_counts)
test_data['predicted'] = y_pred

print(classification_report(test_data.new_rating.to_list(), y_pred))
# Out:
# Train counts shape: (16544, 281051)
# [cross_val] F1: 0.4827222225741963
# Test counts shape: (4136, 281051)
#               precision    recall  f1-score   support
#
#     negative       0.85      0.22      0.35       535
#      neutral       0.47      0.01      0.02       727
#     positive       0.72      1.00      0.84      2874
#
#     accuracy                           0.72      4136
#    macro avg       0.68      0.41      0.40      4136
# weighted avg       0.69      0.72      0.63      4136

# %% [markdown]
# # Stopwords

# %%
stopwords = [
    'авжеж', 'адже', 'але', 'б', 'без', 'був', 'була', 'були', 'було', 'бути', 'більш', 'вам', 'вас', 'весь', 'вздовж', 'ви',
    'вниз', 'внизу', 'вона', 'вони', 'воно', 'все', 'всередині', 'всіх', 'від', 'він', 'да', 'давай', 'давати', 'де', 'дещо',
    'для', 'до', 'з', 'завжди', 'замість', 'й', 'коли', 'ледве', 'майже', 'ми', 'навколо', 'навіть', 'нам', 'от', 'отже', 'отож',
    'поза', 'про', 'під', 'та', 'так', 'такий', 'також', 'те', 'ти', 'тобто', 'тож', 'тощо', 'хоча', 'це', 'цей', 'чи', 'чого',
    'що', 'як', 'який', 'якої', 'є', 'із', 'інших', 'їх', 'її', 'само',
]
count_vect = CountVectorizer(stop_words=stopwords)
train_counts = count_vect.fit_transform(train_data.lemmatized_text)
print('Train counts shape:', train_counts.shape)

clf = MultinomialNB()
scores = cross_val_score(clf, train_counts, train_data.new_rating.to_list(), cv=5, scoring='f1_macro')
print('[cross_val] F1:', sum(scores)/5)

clf.fit(train_counts, train_data.new_rating.to_list())

test_counts = count_vect.transform(test_data.lemmatized_text)
print('Test counts shape:', test_counts.shape)
y_pred = clf.predict(test_counts)
test_data['predicted'] = y_pred

print(classification_report(test_data.new_rating.to_list(), y_pred))
# Out:
# Train counts shape: (16544, 27603)
# [cross_val] F1: 0.526215580296729
# Test counts shape: (4136, 27603)
#               precision    recall  f1-score   support
#
#     negative       0.72      0.46      0.56       535
#      neutral       0.40      0.11      0.17       727
#     positive       0.77      0.96      0.86      2874
#
#     accuracy                           0.75      4136
#    macro avg       0.63      0.51      0.53      4136
# weighted avg       0.70      0.75      0.70      4136

# %% [markdown]
# # Oversampling

# %%
negative_df = train_data.loc[train_data['new_rating'] == 'negative']
n_neg = len(negative_df)
print('Number of negative records:', n_neg)
neutral_df = train_data.loc[train_data['new_rating'] == 'neutral'] #.sample(n=,random_state=0)
n_neu = len(neutral_df)
print('Number of neutral records:', n_neu)
positive_df = train_data.loc[train_data['new_rating'] == 'positive'] #.sample(n=n,random_state=0)
n_pos = len(positive_df)
print('Number of positive records:', n_pos)
normalized_df = pd.concat([negative_df, neutral_df, negative_df, neutral_df, positive_df, negative_df, neutral_df])
normalized_df
# Out:
# Number of negative records: 2141
# Number of neutral records: 2908
# Number of positive records: 11495
#                                               user_id  \
# 0c811a8fc0497f8a6de3f254dc24e5a8  Богдан Городенський
# e189a52c092accb7ec4d157ef72e8d57                  Юра
# 484885177a0825a7ad30791461fefd52         Сергей Олыва
# 77bde83134cf22bf5c7e308ed2910e4a         Грицько Тара
# b746cfae94bcaa22d35e4bb42f83dc32      Елена Алиманска
# ...                                               ...
# 6a8929b43ed7960ebe9b5a0c2e1070eb       Лыженко Любовь
# ebed3ca9d826094d98cbb7e07caf4138         Misha Petrov
# e3ac736d45eef6d295403ed0a7290a7f             Артем Де
# 0375e8174cbd45b2e1df6890fae20a44   Yura Chamber Beats
# 4d54b6856560c0ddd3661a195ee1688b         Марко Міщенк
#
#                                                                                text  \
# 0c811a8fc0497f8a6de3f254dc24e5a8  rozetka прислали жорсткий диск в куску картонк...
# e189a52c092accb7ec4d157ef72e8d57  Ноутбук не загружається з цією оперативкою. Ск...
# 484885177a0825a7ad30791461fefd52  Загалом нормальний дешевий роутер, але сигнал ...
# 77bde83134cf22bf5c7e308ed2910e4a  Абсолютно не рекомендую Недоліки: якість жахли...
# b746cfae94bcaa22d35e4bb42f83dc32  на роботі така сама мишка і працює відмінно,мя...
# ...                                                                             ...
# 6a8929b43ed7960ebe9b5a0c2e1070eb  купил не давно доволен тих в работе можно за т...
# ebed3ca9d826094d98cbb7e07caf4138  Тиждень в користуванні. Перших 2 дні я кайфува...
# e3ac736d45eef6d295403ed0a7290a7f  Брав малій на подарунок на 11-річчя. Вона задо...
# 0375e8174cbd45b2e1df6890fae20a44     дуже гарно все Переваги: круто Недоліки: немає
# 4d54b6856560c0ddd3661a195ee1688b  Купив цю материнку до ryzen 5 2600 і відяхи 10...
#
#                                  rating  \
# 0c811a8fc0497f8a6de3f254dc24e5a8      1
# e189a52c092accb7ec4d157ef72e8d57      1
# 484885177a0825a7ad30791461fefd52      3
# 77bde83134cf22bf5c7e308ed2910e4a      1
# b746cfae94bcaa22d35e4bb42f83dc32      1
# ...                                 ...
# 6a8929b43ed7960ebe9b5a0c2e1070eb      4
# ebed3ca9d826094d98cbb7e07caf4138      4
# e3ac736d45eef6d295403ed0a7290a7f      4
# 0375e8174cbd45b2e1df6890fae20a44      4
# 4d54b6856560c0ddd3661a195ee1688b      4
#
#                                                                     lemmatized_text  \
# 0c811a8fc0497f8a6de3f254dc24e5a8  rozetka прислати жорсткий диск в кусок картонк...
# e189a52c092accb7ec4d157ef72e8d57  ноутбук не загружаватися з цей оперативка . ск...
# 484885177a0825a7ad30791461fefd52  загал нормальний дешевий роутерти , але сигнал...
# 77bde83134cf22bf5c7e308ed2910e4a  абсолютно не рекомендувати недолік : якість жа...
# b746cfae94bcaa22d35e4bb42f83dc32  на робот такий самий мишка і працювати відмінн...
# ...                                                                             ...
# 6a8929b43ed7960ebe9b5a0c2e1070eb  купил не давно доволен той в работ можно за та...
# ebed3ca9d826094d98cbb7e07caf4138  тиждень в користування . перший 2 дно я кайфув...
# e3ac736d45eef6d295403ed0a7290a7f  брати малий на подарунок на 11-річчя . вона за...
# 0375e8174cbd45b2e1df6890fae20a44   дуже гарно весь перевага : круто недолік : немає
# 4d54b6856560c0ddd3661a195ee1688b  купити цей материнка до ryzen 5 2600 і відях 1...
#
#                                  new_rating
# 0c811a8fc0497f8a6de3f254dc24e5a8   negative
# e189a52c092accb7ec4d157ef72e8d57   negative
# 484885177a0825a7ad30791461fefd52   negative
# 77bde83134cf22bf5c7e308ed2910e4a   negative
# b746cfae94bcaa22d35e4bb42f83dc32   negative
# ...                                     ...
# 6a8929b43ed7960ebe9b5a0c2e1070eb    neutral
# ebed3ca9d826094d98cbb7e07caf4138    neutral
# e3ac736d45eef6d295403ed0a7290a7f    neutral
# 0375e8174cbd45b2e1df6890fae20a44    neutral
# 4d54b6856560c0ddd3661a195ee1688b    neutral
#
# [26642 rows x 5 columns]

# %%
count_vect = CountVectorizer(stop_words=stopwords)
train_counts = count_vect.fit_transform(normalized_df.lemmatized_text)
print('Train counts shape:', train_counts.shape)

clf = MultinomialNB()
scores = cross_val_score(clf, train_counts, normalized_df.new_rating.to_list(), cv=5, scoring='f1_macro')
print('[cross_val] F1:', sum(scores)/5)

clf.fit(train_counts, normalized_df.new_rating.to_list())

test_counts = count_vect.transform(test_data.lemmatized_text)
print('Test counts shape:', test_counts.shape)
y_pred = clf.predict(test_counts)
test_data['predicted'] = y_pred

print(classification_report(test_data.new_rating.to_list(), y_pred))
# Out:
# Train counts shape: (26642, 27603)
# [cross_val] F1: 0.7551692699208357
# Test counts shape: (4136, 27603)
#               precision    recall  f1-score   support
#
#     negative       0.60      0.59      0.59       535
#      neutral       0.33      0.34      0.33       727
#     positive       0.83      0.83      0.83      2874
#
#     accuracy                           0.71      4136
#    macro avg       0.59      0.58      0.59      4136
# weighted avg       0.71      0.71      0.71      4136

# %% [markdown]
# # Думки
#
# 1. Мені здається не всі слова треба включати в підрахунок, наприклад, навіщо нам знати чи зустрічається в тексті слово 'rayzen' та багато инших.
# 2. Можна було підключити ще тональності і спробувати з ними, тільки мені це вже здається варто рахувати і додавати як окрему feature, так само і ваги класів, що генерує NB. Потім підрахувати ще якісь инші властивості, і вже це використати, наприклад, для бустінгу.
#
# Взагалі, хотілося б трохи більше зануритися в тему, щоб почати більше розуміти
# ![more_practice](./more_practice.png)
