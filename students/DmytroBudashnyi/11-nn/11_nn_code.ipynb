# %%
import os
import gzip
import json
from collections import defaultdict, OrderedDict

import numpy as np
import pandas as pd
import spacy

from sklearn.metrics import classification_report
from sklearn.model_selection import train_test_split

# %%
nlp_uk = spacy.load('/mnt/slow_drive/dmytro/uk_vectors')

# %%
base_dir = './1551.gov.ua/raw/'

file_list = []
for letter in os.listdir(base_dir):
    for filename in os.listdir(base_dir + letter):
        file_list.append(base_dir + letter + '/' + filename)

call_data = []

for filename in file_list:
    with gzip.open(filename, 'r') as zipfile:
        call_info = json.load(zipfile)
        call_data.append((call_info[0]['CallZText'], call_info[0]['CallZType']))

'Кількість даних і приклад', len(call_data), call_data[0]
# Out:
# ('Кількість даних і приклад',
#  127329,
#  ('Досі не має теплозабезпечення по нашій адресі.На всі запити нам ЖКХ відповідае,що це не їх проблема,щоб ми зверталися в Київенерго.В нас маленька дитина хворіе ніяк не можимо вилікувати,а батареї холодні і температура в приміщені 14 градусїв.Велике прохання допомогти в рішені проблеми ,так як отоплювальний сезон вже розпочався.',
#   'Відсутність опалення'))

# %%
categories = set([c[1] for c in call_data])
'Кількість унікальних категорій {}'.format(len(categories))
# Out:
# 'Кількість унікальних категорій 920'

# %%
from category_changes import clean_call_data

cleaned_call_data = clean_call_data(call_data)
cleaned_categories = set([c[2] for c in cleaned_call_data])
print('Кількість унікальних категорій: {}'.format(len(cleaned_categories)))
call_df = pd.DataFrame(cleaned_call_data)
call_df.columns = ['text', 'category', 'new_category']
call_df
# Out:
# Кількість унікальних категорій: 758
#                                                      text  \
# 0       Досі не має теплозабезпечення по нашій адресі....
# 1       Ініціативною групою мешканців нашого будинку б...
# 2       Жахливий стан дорожнього покриття на підїзді д...
# 3       Не получил ответа от Жуковой Ларисы Петровны п...
# 4       Подъездная дорога с ул.Белорусская к домам #5,...
# ...                                                   ...
# 127210                               Остатки велодорожек.
# 127211  В доме № 33 на улице Новопироговской не включе...
# 127212  Навпроти нашого будинку (вул. Сортувальна, 4) ...
# 127213  Трафареты готовы !!! Помогите краской ! И мы с...
# 127214  Уберите мусорки с велодорожки.станция метро По...
#
#                                                  category  \
# 0                                    Відсутність опалення
# 1       Відсутність освітлення у під’їзді за відсутнос...
# 2                Укладання та ремонт асфальтного покриття
# 3       Пропозиції, зауваження, щодо роботи web-сторін...
# 4                Укладання та ремонт асфальтного покриття
# ...                                                   ...
# 127210                  Облаштування велосипедних доріжок
# 127211                               Відсутність опалення
# 127212        Облаштування наземного пішохідного переходу
# 127213                  Облаштування велосипедних доріжок
# 127214  Незадовільне розташування сміттєвих контейнері...
#
#                                              new_category
# 0                                    Відсутність опалення
# 1       Відсутність освітлення у під’їзді за відсутнос...
# 2                Укладання та ремонт асфальтного покриття
# 3       Пропозиції, зауваження, щодо роботи web-сторін...
# 4                Укладання та ремонт асфальтного покриття
# ...                                                   ...
# 127210                  Облаштування велосипедних доріжок
# 127211                               Відсутність опалення
# 127212        Облаштування наземного пішохідного переходу
# 127213                  Облаштування велосипедних доріжок
# 127214  Незадовільне розташування сміттєвих контейнері...
#
# [127215 rows x 3 columns]

# %%
digit_to_cat = {i: category for i, category in enumerate(cleaned_categories)}
cat_to_digit = {category: i for i, category in digit_to_cat.items()}

call_data = []
for row in cleaned_call_data:
    call_data.append((row[0], cat_to_digit.get(row[2])))

call_df = pd.DataFrame(call_data)
call_df.columns = ['text', 'digit']
call_df
# Out:
#                                                      text  digit
# 0       Досі не має теплозабезпечення по нашій адресі....    261
# 1       Ініціативною групою мешканців нашого будинку б...    110
# 2       Жахливий стан дорожнього покриття на підїзді д...    255
# 3       Не получил ответа от Жуковой Ларисы Петровны п...     50
# 4       Подъездная дорога с ул.Белорусская к домам #5,...    255
# ...                                                   ...    ...
# 127210                               Остатки велодорожек.    364
# 127211  В доме № 33 на улице Новопироговской не включе...    261
# 127212  Навпроти нашого будинку (вул. Сортувальна, 4) ...    325
# 127213  Трафареты готовы !!! Помогите краской ! И мы с...    364
# 127214  Уберите мусорки с велодорожки.станция метро По...    372
#
# [127215 rows x 2 columns]

# %%
y_column = 'digit'
copy_df = call_df.copy()
y = list(copy_df.loc[:, y_column])
copy_df.drop([y_column], axis=1, inplace=True)

X = [v['text'] for v in copy_df.T.to_dict().values()]

X_train, X_test, y_train, y_test = train_test_split(
    X, y,
    train_size=0.8, test_size=0.2, random_state=0, shuffle=True, stratify=y
)

# %%
X_train2, X_val2, y_train2, y_val2 = train_test_split(
    X_train, y_train,
    train_size=0.8, test_size=0.2, random_state=0, shuffle=True, stratify=y_train
)

# %%
len(X_train), len(X_test), len(X_train2), len(X_val2)
# Out:
# (101772, 25443, 81417, 20355)

# %%
X_test[0], y_test[0]
# Out:
# ('Вы что там ? Что делить  в ”зверненні” ? Каждую бумажку, что ли отдельно расписывать? Повторяю в ТРЕТИЙ РАЗ !!!!!!!!!! Жалоба не неубранный подъезд : нет ни влажной уборки, ни теперь уже не подметается неделю,  в лифте очень грязный пол! Перед мусоросборниками грязь и вонь , тараканы!!!!!!!! Что здесь разделять???????????  Это , что не услуги одной категории?  Квитанции так присылаете, а оказывать услуги,  не хотим, а теперь еще отфутболивать научились? в СУД  ХОТИТЕ?',
#  63)

# %%
import tensorflow as tf
from tensorflow.keras.layers.experimental.preprocessing import TextVectorization

vectorizer = TextVectorization(max_tokens=20000, output_sequence_length=200)
# Let's make a text-only dataset (no labels):
#text_ds = raw_train_ds.map(lambda x, y: x)
text_ds = tf.data.Dataset.from_tensor_slices(X_train2).batch(32)
vectorizer.adapt(text_ds)

# %%
vectorizer.get_vocabulary()[:10]
# Out:
# ['', '[OOV]', 'в', 'на', 'не', 'и', 'та', 'по', 'за', 'з']

# %%
output = vectorizer(np.array([["У попа була собака."]]))
output.numpy()[0, :6]
# Out:
# array([  46,    1,  209, 8043,    0,    0])

# %%
voc = vectorizer.get_vocabulary()
word_index = dict(zip(voc, range(2, len(voc))))

# %%
embeddings_index = {}
with open('./news.cased.tokenized.word2vec.300d') as f:
    for line in f:
        word, coefs = line.split(maxsplit=1)
        coefs = np.fromstring(coefs, "f", sep=" ")
        embeddings_index[word] = coefs

print("Found %s word vectors." % len(embeddings_index))
# Out:
# Found 365320 word vectors.

# %%
num_tokens = len(voc) + 2
embedding_dim = 300
hits = 0
misses = 0

# Prepare embedding matrix
embedding_matrix = np.zeros((num_tokens, embedding_dim))
for word, i in word_index.items():
    embedding_vector = embeddings_index.get(word)
    if embedding_vector is not None:
        embedding_matrix[i] = embedding_vector
        hits += 1
    else:
        misses += 1
print("Converted %d words (%d misses)" % (hits, misses))
# Out:
# Converted 15348 words (4650 misses)

# %%
from tensorflow import keras
from tensorflow.keras.layers import Embedding

embedding_layer = Embedding(
    num_tokens,
    embedding_dim,
    embeddings_initializer=keras.initializers.Constant(embedding_matrix),
    trainable=False,
)

# %%
x_train_ = vectorizer(np.array([[s] for s in X_train2])).numpy()
x_val_ = vectorizer(np.array([[s] for s in X_val2])).numpy()
x_test_ = vectorizer(np.array([[s] for s in X_test])).numpy()

y_train_ = np.array(y_train2)
y_val_ = np.array(y_val2)
y_test_ = np.array(y_test)

# %%
int_sequences_input = keras.Input(shape=(None,), dtype="int64")
x = embedding_layer(int_sequences_input)
x = layers.LSTM(128, return_sequences=True, activation='relu')(x)
#x = layers.Conv1D(128, 5, activation="relu")(x)
#x = layers.MaxPooling1D(5)(x)
#x = layers.Conv1D(128, 5, activation="relu")(x)
#x = layers.MaxPooling1D(5)(x)
#x = layers.Conv1D(128, 5, activation="relu")(x)
x = layers.GlobalMaxPooling1D()(x)
#x = layers.Dense(128, activation="relu")(x)
#x = layers.Dropout(0.5)(x)
preds = layers.Dense(n_classes, activation="softmax")(x)
model2 = keras.Model(int_sequences_input, preds)
print(model2.summary())
model2.output_shape
# Out:
# Model: "functional_63"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# input_38 (InputLayer)        [(None, None)]            0
# _________________________________________________________________
# embedding (Embedding)        multiple                  6000600
# _________________________________________________________________
# lstm_8 (LSTM)                (None, None, 128)         219648
# _________________________________________________________________
# global_max_pooling1d_9 (Glob (None, 128)               0
# _________________________________________________________________
# dense_73 (Dense)             (None, 758)               97782
# =================================================================
# Total params: 6,318,030
# Trainable params: 317,430
# Non-trainable params: 6,000,600
# _________________________________________________________________
# None
# (None, 758)

# %%
model2.compile(loss="sparse_categorical_crossentropy", optimizer="adam", metrics=['accuracy'])
epochs = 10

# Fit the model using the train and test datasets.
model2.fit(x_train_, y_train_, batch_size=32, epochs=epochs, validation_data=(x_val_, y_val_))
# Out:
# Epoch 1/10
# 2545/2545 [==============================] - 365s 143ms/step - loss: 3.0208 - accuracy: 0.3780 - val_loss: 2.8376 - val_accuracy: 0.4108
# Epoch 2/10
# 2545/2545 [==============================] - 368s 144ms/step - loss: 2.4768 - accuracy: 0.4464 - val_loss: 2.6820 - val_accuracy: 0.4315
# Epoch 3/10
# 2545/2545 [==============================] - 366s 144ms/step - loss: 2.1931 - accuracy: 0.4839 - val_loss: 2.6489 - val_accuracy: 0.4506
# Epoch 4/10
# 2545/2545 [==============================] - 367s 144ms/step - loss: 2.0481 - accuracy: 0.5091 - val_loss: 3.1807 - val_accuracy: 0.3944
# Epoch 5/10
# 2545/2545 [==============================] - 363s 142ms/step - loss: 2.0003 - accuracy: 0.5148 - val_loss: 2.7574 - val_accuracy: 0.4486
# Epoch 6/10
# 2545/2545 [==============================] - 363s 143ms/step - loss: 1.7413 - accuracy: 0.5612 - val_loss: 2.8141 - val_accuracy: 0.4528
# Epoch 7/10
# 2545/2545 [==============================] - 361s 142ms/step - loss: 1.6291 - accuracy: 0.5836 - val_loss: 2.8572 - val_accuracy: 0.4504
# Epoch 8/10
# 1190/2545 [=============>................] - ETA: 2:51 - loss: 1.4684 - accuracy: 0.6166

# %%
model2.fit(x_train_, y_train_, batch_size=32, epochs=1, validation_data=(x_val_, y_val_))
# Out:
# 2545/2545 [==============================] - 358s 141ms/step - loss: 1.3399 - accuracy: 0.6404 - val_loss: 3.2006 - val_accuracy: 0.4596

# %%
# ^ Дотренував 11-й раз, бо відвалився VPN і ноутбук не показав, що там відбулося

y_pred = predict(model2, x_test_)
print(classification_report(y_pred, y_test_))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.00      0.00      0.00         0
#            1       0.00      0.00      0.00         0
#            2       1.00      1.00      1.00         1
#            3       0.09      1.00      0.17         1
#            4       0.14      0.30      0.20        53
#            5       0.00      0.00      0.00         1
#            7       0.00      0.00      0.00         0
#            8       0.04      0.10      0.05        10
#            9       0.02      0.09      0.03        11
#           10       0.00      0.00      0.00         0
#           12       0.25      1.00      0.40         2
#           13       0.20      0.13      0.16        47
#           14       0.00      0.00      0.00         1
#           15       1.00      1.00      1.00         1
#           16       0.00      0.00      0.00         0
#           17       0.00      0.00      0.00         1
#           18       0.00      0.00      0.00         2
#           19       0.00      0.00      0.00         1
#           20       0.00      0.00      0.00         0
#           21       0.10      0.25      0.14         4
#           22       0.00      0.00      0.00         0
#           23       0.00      0.00      0.00         0
#           24       0.41      0.69      0.51        45
#           25       0.06      0.09      0.07        11
#           26       0.00      0.00      0.00         2
#           27       0.49      0.33      0.39       214
#           28       0.00      0.00      0.00         2
#           29       0.00      0.00      0.00         0
#           30       0.00      0.00      0.00         0
#           31       0.00      0.00      0.00         0
#           32       0.00      0.00      0.00         1
#           33       0.12      0.15      0.13        34
#           34       0.14      0.46      0.21        13
#           35       0.00      0.00      0.00         0
#           36       0.33      1.00      0.50         1
#           37       0.00      0.00      0.00         2
#           38       0.50      0.50      0.50         2
#           39       0.00      0.00      0.00         4
#           40       0.00      0.00      0.00         4
#           41       0.00      0.00      0.00         9
#           43       0.18      0.25      0.21         8
#           44       0.00      0.00      0.00         5
#           45       0.24      0.50      0.32        10
#           46       1.00      1.00      1.00         1
#           47       0.00      0.00      0.00         0
#           48       0.00      0.00      0.00         0
#           50       0.32      0.41      0.36        17
#           51       0.04      0.10      0.06        10
#           52       0.00      0.00      0.00         0
#           53       0.00      0.00      0.00         0
#           54       0.52      0.55      0.53        49
#           55       0.00      0.00      0.00         1
#           56       0.10      0.25      0.14         4
#           57       0.10      0.50      0.16         4
#           59       0.00      0.00      0.00         0
#           60       0.00      0.00      0.00         2
#           61       0.00      0.00      0.00         0
#           62       0.40      0.50      0.44         4
#           63       0.44      0.62      0.51       105
#           64       0.16      0.24      0.19        21
#           65       0.20      0.11      0.14         9
#           66       1.00      1.00      1.00         1
#           67       0.00      0.00      0.00         3
#           68       0.47      0.43      0.45       136
#           69       0.00      0.00      0.00         5
#           70       0.00      0.00      0.00         1
#           72       0.50      0.25      0.33         4
#           73       0.00      0.00      0.00         1
#           74       0.38      0.38      0.38         8
#           76       1.00      1.00      1.00         1
#           77       0.25      0.11      0.15         9
#           78       0.00      0.00      0.00         0
#           79       0.25      0.21      0.23        14
#           80       0.14      0.14      0.14         7
#           81       0.31      0.50      0.38        70
#           83       0.00      0.00      0.00         0
#           84       0.52      0.66      0.58       140
#           86       0.30      0.41      0.34       237
#           87       0.29      0.42      0.34        48
#           88       0.00      0.00      0.00         0
#           89       0.25      1.00      0.40         1
#           90       0.00      0.00      0.00         2
#           91       0.00      0.00      0.00         0
#           92       0.11      0.20      0.14        10
#           93       0.00      0.00      0.00         3
#           94       0.00      0.00      0.00         1
#           95       0.51      0.61      0.55        92
#           96       0.00      0.00      0.00         1
#           97       0.00      0.00      0.00         0
#           98       0.00      0.00      0.00         0
#           99       0.42      0.56      0.48        18
#          100       0.50      0.10      0.17        40
#          101       0.00      0.00      0.00         1
#          102       0.00      0.00      0.00         0
#          104       0.00      0.00      0.00         1
#          105       0.00      0.00      0.00         0
#          106       0.15      0.14      0.14        29
#          107       0.00      0.00      0.00         0
#          108       0.00      0.00      0.00         0
#          109       0.20      0.23      0.21        43
#          110       0.61      0.48      0.54       669
#          111       0.23      0.14      0.17        36
#          112       0.22      0.25      0.24         8
#          113       0.00      0.00      0.00         0
#          114       0.00      0.00      0.00         0
#          115       0.00      0.00      0.00         2
#          117       0.00      0.00      0.00         0
#          118       0.00      0.00      0.00         0
#          119       0.11      0.24      0.15        54
#          120       0.00      0.00      0.00         0
#          121       0.00      0.00      0.00         0
#          122       0.00      0.00      0.00         0
#          123       0.00      0.00      0.00         0
#          124       0.21      0.28      0.24        32
#          125       0.00      0.00      0.00         3
#          126       0.00      0.00      0.00         1
#          127       0.00      0.00      0.00         3
#          128       0.00      0.00      0.00         4
#          129       0.00      0.00      0.00         1
#          130       0.00      0.00      0.00         1
#          131       0.00      0.00      0.00         0
#          132       0.50      0.50      0.50         8
#          133       0.66      0.61      0.63       173
#          134       0.00      0.00      0.00         0
#          135       0.00      0.00      0.00         0
#          136       0.15      0.28      0.20        40
#          137       0.24      0.58      0.34        12
#          138       0.00      0.00      0.00         2
#          139       0.17      0.21      0.19        24
#          140       0.54      0.63      0.59       230
#          141       0.00      0.00      0.00         0
#          142       0.15      0.21      0.18        14
#          143       1.00      1.00      1.00         1
#          144       0.11      0.17      0.13         6
#          145       0.12      0.08      0.10        13
#          146       0.00      0.00      0.00        15
#          147       0.00      0.00      0.00         0
#          148       0.00      0.00      0.00         0
#          149       0.00      0.00      0.00         1
#          150       0.12      0.10      0.11        21
#          151       0.32      0.32      0.32        63
#          152       0.67      1.00      0.80         2
#          153       0.00      0.00      0.00         1
#          154       0.00      0.00      0.00         1
#          155       0.00      0.00      0.00         0
#          156       0.00      0.00      0.00         0
#          157       0.15      0.26      0.19        19
#          158       0.00      0.00      0.00         1
#          159       0.18      0.20      0.19        20
#          160       0.00      0.00      0.00         0
#          161       0.00      0.00      0.00         4
#          162       0.10      0.06      0.07       104
#          163       0.00      0.00      0.00         0
#          164       0.50      1.00      0.67         1
#          166       0.00      0.00      0.00         0
#          167       0.29      0.24      0.26        50
#          168       0.00      0.00      0.00         0
#          169       0.18      0.18      0.18        11
#          170       0.03      0.08      0.05        12
#          171       0.05      0.11      0.07         9
#          172       0.24      0.28      0.26        40
#          173       0.00      0.00      0.00         1
#          174       0.00      0.00      0.00         1
#          175       0.11      0.25      0.15        12
#          176       0.00      0.00      0.00         2
#          177       0.00      0.00      0.00         2
#          178       0.00      0.00      0.00         0
#          179       0.33      0.47      0.39       135
#          180       0.00      0.00      0.00         0
#          181       0.25      0.14      0.18         7
#          182       0.00      0.00      0.00         0
#          183       0.12      0.17      0.14        12
#          184       0.15      0.25      0.19         8
#          185       0.12      0.11      0.12         9
#          186       0.62      0.45      0.52       577
#          187       0.29      0.20      0.24        10
#          188       0.20      0.25      0.22         4
#          189       0.03      0.04      0.03        28
#          190       0.65      0.74      0.69        27
#          191       0.00      0.00      0.00         1
#          192       0.25      0.38      0.30         8
#          194       0.00      0.00      0.00         0
#          195       0.07      0.33      0.11         3
#          196       0.07      0.08      0.07        13
#          197       0.20      0.21      0.21       179
#          198       0.15      0.50      0.23         6
#          199       0.31      0.35      0.33        72
#          200       0.68      0.33      0.45        57
#          201       0.12      1.00      0.22         1
#          202       0.14      0.17      0.15        18
#          203       0.00      0.00      0.00         0
#          205       0.33      1.00      0.50         1
#          206       0.50      1.00      0.67         1
#          207       0.16      0.15      0.16       332
#          208       0.00      0.00      0.00         0
#          209       0.00      0.00      0.00         0
#          210       0.00      0.00      0.00         4
#          211       0.00      0.00      0.00         0
#          212       0.09      0.21      0.13        14
#          213       0.17      0.25      0.20         4
#          214       0.00      0.00      0.00         2
#          215       0.00      0.00      0.00         3
#          217       0.50      0.67      0.57         3
#          218       0.00      0.00      0.00         1
#          219       0.17      0.08      0.11       100
#          220       0.50      1.00      0.67         1
#          221       0.08      0.05      0.06        19
#          222       0.19      0.14      0.16        86
#          223       0.00      0.00      0.00         1
#          224       0.50      0.40      0.44       480
#          225       0.35      0.55      0.43        11
#          226       0.00      0.00      0.00         0
#          227       0.00      0.00      0.00         0
#          228       0.00      0.00      0.00        10
#          229       0.00      0.00      0.00         1
#          230       0.50      0.50      0.50         2
#          231       0.00      0.00      0.00         0
#          232       0.00      0.00      0.00         2
#          233       0.00      0.00      0.00         0
#          234       0.08      0.07      0.07        14
#          235       0.67      1.00      0.80         2
#          236       0.00      0.00      0.00         0
#          237       0.00      0.00      0.00         1
#          238       0.00      0.00      0.00         0
#          239       0.33      1.00      0.50         1
#          240       0.46      0.76      0.57        95
#          242       0.12      0.18      0.14        39
#          243       0.27      0.55      0.36        11
#          244       0.00      0.00      0.00         0
#          245       0.00      0.00      0.00         0
#          246       0.00      0.00      0.00         0
#          248       0.00      0.00      0.00         0
#          249       0.13      0.25      0.17        16
#          250       0.00      0.00      0.00         1
#          251       0.12      0.09      0.10        23
#          253       0.00      0.00      0.00         0
#          254       0.00      0.00      0.00         0
#          255       0.71      0.55      0.62      1700
#          256       0.00      0.00      0.00         1
#          257       0.00      0.00      0.00         0
#          258       1.00      0.50      0.67         2
#          260       0.19      0.25      0.21        12
#          261       0.80      0.63      0.71      1524
#          262       0.00      0.00      0.00         0
#          264       0.00      0.00      0.00         0
#          265       0.00      0.00      0.00         1
#          266       0.00      0.00      0.00         1
#          267       0.00      0.00      0.00         0
#          268       0.00      0.00      0.00         7
#          269       0.28      0.56      0.37        48
#          270       0.00      0.00      0.00         0
#          271       0.38      0.43      0.40        14
#          272       0.00      0.00      0.00         0
#          273       0.00      0.00      0.00         2
#          274       0.00      0.00      0.00         5
#          275       0.41      0.21      0.28       138
#          276       0.00      0.00      0.00         1
#          277       0.00      0.00      0.00         2
#          278       0.17      0.25      0.20         4
#          279       0.43      0.27      0.33        11
#          280       0.00      0.00      0.00         5
#          281       0.00      0.00      0.00         0
#          283       0.00      0.00      0.00         0
#          284       0.27      0.29      0.28        52
#          285       0.07      0.08      0.08        50
#          286       0.52      0.73      0.61       102
#          287       0.00      0.00      0.00         3
#          288       0.33      1.00      0.50         1
#          289       0.25      0.14      0.18         7
#          290       0.12      0.07      0.09        15
#          291       0.00      0.00      0.00         0
#          292       0.36      0.31      0.33       120
#          293       0.00      0.00      0.00         3
#          294       0.70      0.52      0.60        94
#          295       0.00      0.00      0.00         0
#          296       0.46      0.48      0.47       453
#          297       0.32      0.29      0.30        21
#          298       0.56      0.57      0.57       455
#          299       0.10      0.12      0.11         8
#          300       0.00      0.00      0.00         0
#          301       0.00      0.00      0.00         0
#          302       0.00      0.00      0.00         0
#          303       0.33      0.50      0.40         2
#          304       0.06      0.10      0.08        20
#          305       0.26      0.29      0.27       219
#          306       0.00      0.00      0.00         0
#          308       0.33      1.00      0.50         2
#          309       0.66      0.77      0.71       115
#          310       0.00      0.00      0.00         0
#          311       0.36      0.61      0.45        31
#          312       0.00      0.00      0.00         2
#          313       0.63      0.51      0.56       143
#          314       0.00      0.00      0.00         0
#          315       0.36      0.49      0.41       316
#          316       0.00      0.00      0.00         0
#          317       0.17      0.23      0.20        39
#          318       0.80      0.44      0.57         9
#          319       0.00      0.00      0.00         0
#          320       0.47      0.48      0.48        64
#          321       0.33      0.67      0.44         3
#          322       0.00      0.00      0.00         6
#          323       0.40      0.29      0.34        75
#          324       0.31      0.26      0.28        74
#          325       0.17      0.23      0.20        39
#          326       0.01      0.11      0.02         9
#          327       0.00      0.00      0.00         1
#          328       0.00      0.00      0.00         0
#          329       0.00      0.00      0.00         1
#          330       0.59      0.34      0.43       370
#          332       0.25      0.24      0.25        29
#          333       0.14      0.50      0.22         4
#          334       1.00      1.00      1.00         1
#          335       0.00      0.00      0.00         0
#          336       0.00      0.00      0.00         0
#          337       0.00      0.00      0.00         2
#          338       0.23      0.32      0.27        22
#          339       0.85      0.77      0.81      2946
#          340       0.12      0.25      0.17         4
#          342       0.40      0.10      0.16        20
#          344       0.25      1.00      0.40         1
#          345       0.27      0.15      0.19        41
#          346       0.00      0.00      0.00         4
#          347       0.00      0.00      0.00         0
#          348       0.21      0.31      0.25        13
#          349       0.50      0.50      0.50         4
#          350       0.00      0.00      0.00         0
#          351       0.14      0.33      0.20         3
#          352       0.00      0.00      0.00         0
#          353       0.13      0.08      0.10        99
#          354       0.33      0.14      0.20         7
#          355       0.21      0.33      0.26        12
#          356       0.00      0.00      0.00        12
#          357       0.11      0.12      0.12         8
#          358       0.00      0.00      0.00         0
#          359       0.09      0.14      0.11         7
#          360       0.11      0.25      0.15         4
#          361       0.47      0.33      0.38        46
#          362       0.19      0.14      0.16        49
#          363       0.21      0.13      0.16        53
#          364       0.09      0.17      0.12         6
#          365       0.11      0.38      0.18        53
#          366       0.20      0.67      0.31         3
#          367       0.56      0.38      0.46       455
#          368       0.00      0.00      0.00         3
#          370       0.12      0.03      0.05        30
#          371       0.60      0.60      0.60         5
#          372       0.37      0.47      0.42        57
#          373       0.33      0.33      0.33         3
#          374       0.17      0.14      0.15        36
#          375       0.28      0.38      0.32        84
#          376       0.00      0.00      0.00         0
#          377       0.30      0.56      0.39        34
#          378       0.00      0.00      0.00         0
#          379       0.00      0.00      0.00         0
#          380       0.00      0.00      0.00         2
#          381       0.32      0.50      0.39        54
#          382       0.00      0.00      0.00         0
#          383       0.00      0.00      0.00        13
#          384       0.00      0.00      0.00         2
#          385       0.00      0.00      0.00         0
#          386       0.69      0.46      0.55      1099
#          387       0.14      0.25      0.18        16
#          388       0.00      0.00      0.00         2
#          389       0.20      0.33      0.25         9
#          391       0.11      0.20      0.14        10
#          392       0.12      0.12      0.12         8
#          393       0.00      0.00      0.00         1
#          394       0.14      0.25      0.18         8
#          395       0.38      0.20      0.26        15
#          396       0.00      0.00      0.00         1
#          398       0.51      0.36      0.43        55
#          399       0.14      0.18      0.16        45
#          400       0.00      0.00      0.00         0
#          401       0.00      0.00      0.00         0
#          402       0.00      0.00      0.00         0
#          403       0.00      0.00      0.00         0
#          404       0.17      0.50      0.25         2
#          405       0.00      0.00      0.00         2
#          408       0.00      0.00      0.00         0
#          409       0.11      0.25      0.15         4
#          411       0.22      0.22      0.22        23
#          412       0.62      0.56      0.59         9
#          413       0.75      0.64      0.69        14
#          415       0.14      0.33      0.20         3
#          416       0.00      0.00      0.00         1
#          417       0.00      0.00      0.00         0
#          418       0.00      0.00      0.00         1
#          419       0.32      0.50      0.39        28
#          420       0.50      1.00      0.67         1
#          421       0.00      0.00      0.00         0
#          422       0.00      0.00      0.00         1
#          423       0.00      0.00      0.00         0
#          424       0.00      0.00      0.00         0
#          425       0.33      0.20      0.25         5
#          426       0.03      0.04      0.03        54
#          427       0.00      0.00      0.00         0
#          428       0.19      0.23      0.21        13
#          429       0.17      0.14      0.15         7
#          430       0.00      0.00      0.00         1
#          431       0.00      0.00      0.00         0
#          432       0.00      0.00      0.00         1
#          433       0.25      0.32      0.28        44
#          434       0.00      0.00      0.00         0
#          435       0.00      0.00      0.00         1
#          436       0.00      0.00      0.00         5
#          437       0.62      0.46      0.53        54
#          438       0.64      0.78      0.70        32
#          439       0.10      0.33      0.15         3
#          440       0.00      0.00      0.00         0
#          441       0.42      0.31      0.35        36
#          442       0.00      0.00      0.00         3
#          443       0.00      0.00      0.00         0
#          444       0.00      0.00      0.00         0
#          445       0.15      0.33      0.21        30
#          446       0.46      0.48      0.47        61
#          447       0.15      0.50      0.23         8
#          448       0.00      0.00      0.00         0
#          450       0.00      0.00      0.00         1
#          451       0.47      0.44      0.46       309
#          452       0.00      0.00      0.00         1
#          453       0.00      0.00      0.00         1
#          454       0.00      0.00      0.00        11
#          455       0.50      0.51      0.50       260
#          456       0.00      0.00      0.00         0
#          457       0.00      0.00      0.00         6
#          458       0.00      0.00      0.00         0
#          459       0.00      0.00      0.00         1
#          460       0.49      0.45      0.47        88
#          461       0.00      0.00      0.00         0
#          462       0.00      0.00      0.00         0
#          463       0.00      0.00      0.00         0
#          464       0.50      0.50      0.50         2
#          465       0.38      0.43      0.40         7
#          466       0.40      0.44      0.42       144
#          467       0.00      0.00      0.00         5
#          468       0.17      0.33      0.23        12
#          469       0.00      0.00      0.00         0
#          470       0.30      0.30      0.30        43
#          471       0.00      0.00      0.00         1
#          472       0.00      0.00      0.00         0
#          473       0.00      0.00      0.00         3
#          474       0.50      1.00      0.67         1
#          475       0.29      0.50      0.36         4
#          476       0.00      0.00      0.00         3
#          477       0.00      0.00      0.00         0
#          479       0.00      0.00      0.00         4
#          480       0.00      0.00      0.00         1
#          481       0.00      0.00      0.00         4
#          482       0.05      0.03      0.04        59
#          483       0.13      0.27      0.18        44
#          484       0.00      0.00      0.00         0
#          485       0.00      0.00      0.00         2
#          486       0.00      0.00      0.00         1
#          487       0.00      0.00      0.00         2
#          488       0.25      0.05      0.09        19
#          489       0.00      0.00      0.00         0
#          490       0.00      0.00      0.00         0
#          491       0.04      0.06      0.05        18
#          492       0.17      0.38      0.23         8
#          493       0.00      0.00      0.00         0
#          494       0.53      0.59      0.56       105
#          495       0.11      0.11      0.11        18
#          496       0.00      0.00      0.00         0
#          497       1.00      0.33      0.50         3
#          498       0.00      0.00      0.00         0
#          499       0.18      0.32      0.23        19
#          500       0.00      0.00      0.00         0
#          501       0.00      0.00      0.00         1
#          502       0.48      0.32      0.38       168
#          503       0.00      0.00      0.00         0
#          504       0.00      0.00      0.00         0
#          505       0.00      0.00      0.00         0
#          506       0.33      0.33      0.33         3
#          507       0.00      0.00      0.00         2
#          508       0.00      0.00      0.00         1
#          510       0.31      0.35      0.33        69
#          511       0.17      0.34      0.23        35
#          512       0.41      0.42      0.42        88
#          513       0.25      1.00      0.40         1
#          514       0.20      1.00      0.33         1
#          515       0.00      0.00      0.00         1
#          516       0.00      0.00      0.00         0
#          517       0.00      0.00      0.00         8
#          518       0.60      0.78      0.68        55
#          519       0.17      0.14      0.15         7
#          521       0.20      0.11      0.14         9
#          522       0.00      0.00      0.00         1
#          523       0.00      0.00      0.00         3
#          524       1.00      0.50      0.67         2
#          525       0.00      0.00      0.00         0
#          526       0.00      0.00      0.00         2
#          527       0.00      0.00      0.00         2
#          528       0.00      0.00      0.00         0
#          529       0.00      0.00      0.00         3
#          530       0.33      0.50      0.40         2
#          532       0.00      0.00      0.00         0
#          533       0.65      0.46      0.54       125
#          534       0.00      0.00      0.00         0
#          535       0.54      0.47      0.50       331
#          536       0.60      1.00      0.75         3
#          537       0.12      0.11      0.11        45
#          538       0.00      0.00      0.00        12
#          540       0.00      0.00      0.00         1
#          541       0.00      0.00      0.00         3
#          543       0.10      0.21      0.14        14
#          544       0.00      0.00      0.00         6
#          545       0.27      0.50      0.35         6
#          546       0.00      0.00      0.00         0
#          547       0.00      0.00      0.00         1
#          548       0.36      0.46      0.40        46
#          551       0.28      0.13      0.18        38
#          552       0.00      0.00      0.00         6
#          553       0.00      0.00      0.00         0
#          555       1.00      1.00      1.00         1
#          556       0.00      0.00      0.00         0
#          557       0.48      0.37      0.42        43
#          558       0.00      0.00      0.00         0
#          559       0.33      0.40      0.36         5
#          560       0.00      0.00      0.00         1
#          561       0.33      0.55      0.42        29
#          562       0.25      0.33      0.29         3
#          563       0.17      0.47      0.25        15
#          564       0.17      0.16      0.16        76
#          565       0.00      0.00      0.00         5
#          566       0.15      0.15      0.15        33
#          567       0.00      0.00      0.00         0
#          568       0.30      0.27      0.28       221
#          569       0.00      0.00      0.00         0
#          570       0.00      0.00      0.00         0
#          572       0.00      0.00      0.00         1
#          573       0.25      0.22      0.24        18
#          574       0.10      0.50      0.17         2
#          575       0.46      0.41      0.43        69
#          576       0.50      1.00      0.67         2
#          577       0.35      0.55      0.43        11
#          578       0.10      0.33      0.15         3
#          579       0.00      0.00      0.00         1
#          580       0.00      0.00      0.00         0
#          581       1.00      1.00      1.00         1
#          582       0.24      0.47      0.32        17
#          583       0.33      0.26      0.29       139
#          584       0.37      0.34      0.35       119
#          585       0.11      0.17      0.13         6
#          586       0.00      0.00      0.00         1
#          587       0.17      0.25      0.20        12
#          588       0.67      0.40      0.50         5
#          589       0.11      0.22      0.14         9
#          591       0.17      0.25      0.20         8
#          592       0.33      0.51      0.40        37
#          593       0.04      0.08      0.05        13
#          594       0.00      0.00      0.00        25
#          595       0.20      0.33      0.25         3
#          596       1.00      1.00      1.00         1
#          597       0.75      0.70      0.73       584
#          598       0.00      0.00      0.00         2
#          599       0.14      0.08      0.10        26
#          600       0.00      0.00      0.00         0
#          602       0.00      0.00      0.00         0
#          603       0.50      1.00      0.67         1
#          604       0.00      0.00      0.00         1
#          606       0.39      0.29      0.33        31
#          607       0.00      0.00      0.00         4
#          608       0.14      0.11      0.12        18
#          609       0.10      0.18      0.13        34
#          610       0.00      0.00      0.00         3
#          611       0.17      0.33      0.22         6
#          612       0.37      0.47      0.41        49
#          613       0.00      0.00      0.00         5
#          614       0.00      0.00      0.00         1
#          615       0.33      0.25      0.29         4
#          616       0.33      1.00      0.50         1
#          617       0.47      0.21      0.29        73
#          618       0.22      0.44      0.29        18
#          619       0.00      0.00      0.00         6
#          620       0.00      0.00      0.00         0
#          621       0.33      0.49      0.39        70
#          622       0.09      0.40      0.15         5
#          623       0.00      0.00      0.00         0
#          624       0.21      0.60      0.32         5
#          625       0.00      0.00      0.00         1
#          626       0.19      0.22      0.20        23
#          627       0.14      0.12      0.13        17
#          628       0.05      0.06      0.06        16
#          629       0.12      0.23      0.15        13
#          630       0.00      0.00      0.00         1
#          631       0.26      0.24      0.25        41
#          632       0.00      0.00      0.00         1
#          633       0.42      0.22      0.29       199
#          634       0.23      0.12      0.16        25
#          635       0.00      0.00      0.00         0
#          636       0.00      0.00      0.00         2
#          637       0.50      0.12      0.19        17
#          638       0.25      0.17      0.20         6
#          639       0.05      0.20      0.08         5
#          640       0.39      0.44      0.42        99
#          641       0.00      0.00      0.00         0
#          643       0.00      0.00      0.00         0
#          644       0.00      0.00      0.00         7
#          645       0.00      0.00      0.00        12
#          646       0.10      0.29      0.15         7
#          647       0.00      0.00      0.00         0
#          649       0.00      0.00      0.00         0
#          650       0.00      0.00      0.00         0
#          651       0.20      0.33      0.25         3
#          652       0.00      0.00      0.00         0
#          653       0.00      0.00      0.00         0
#          654       0.08      0.17      0.11         6
#          656       0.00      0.00      0.00        10
#          657       0.16      0.33      0.22        24
#          658       0.00      0.00      0.00         5
#          659       0.00      0.00      0.00         1
#          660       0.00      0.00      0.00         0
#          661       0.48      0.41      0.44       715
#          662       0.07      0.17      0.10         6
#          664       0.00      0.00      0.00         1
#          665       0.14      0.20      0.17        10
#          666       0.00      0.00      0.00         1
#          667       0.00      0.00      0.00         0
#          668       0.12      0.06      0.08        18
#          669       0.00      0.00      0.00         0
#          670       0.25      0.20      0.22         5
#          671       0.05      0.09      0.06        11
#          673       0.00      0.00      0.00         0
#          675       0.00      0.00      0.00         0
#          676       0.00      0.00      0.00         0
#          677       0.00      0.00      0.00         1
#          678       0.00      0.00      0.00         3
#          679       0.00      0.00      0.00         3
#          680       0.14      1.00      0.25         1
#          681       0.06      0.17      0.09        12
#          682       0.10      0.12      0.11        16
#          683       0.00      0.00      0.00         0
#          684       0.00      0.00      0.00         2
#          686       0.20      0.40      0.27         5
#          687       0.00      0.00      0.00         2
#          688       1.00      0.50      0.67         2
#          689       0.11      0.33      0.17         3
#          690       0.00      0.00      0.00         0
#          691       0.00      0.00      0.00         0
#          692       0.35      0.46      0.40        85
#          693       0.08      0.09      0.09        11
#          694       0.00      0.00      0.00         0
#          695       0.00      0.00      0.00         1
#          696       0.05      0.17      0.07         6
#          697       0.00      0.00      0.00         0
#          698       0.34      0.25      0.29        79
#          699       0.00      0.00      0.00         7
#          700       0.00      0.00      0.00         5
#          701       0.00      0.00      0.00         4
#          702       0.00      0.00      0.00         0
#          704       0.50      0.26      0.34        62
#          705       0.00      0.00      0.00        17
#          706       0.50      1.00      0.67         4
#          707       0.00      0.00      0.00         5
#          708       0.00      0.00      0.00         2
#          709       0.10      0.17      0.13        52
#          710       0.00      0.00      0.00         0
#          711       0.29      0.33      0.31         6
#          712       0.00      0.00      0.00         1
#          713       0.51      0.55      0.53        44
#          714       0.12      0.50      0.20         2
#          715       1.00      0.33      0.50         3
#          716       0.43      0.21      0.28        62
#          717       0.62      0.55      0.58        71
#          718       0.00      0.00      0.00         1
#          720       0.06      0.07      0.06        46
#          721       0.00      0.00      0.00         9
#          722       0.13      0.14      0.13        22
#          723       0.10      0.12      0.11        16
#          724       0.00      0.00      0.00         0
#          725       0.00      0.00      0.00         0
#          726       0.00      0.00      0.00         0
#          727       0.00      0.00      0.00        12
#          728       1.00      1.00      1.00         1
#          730       0.51      0.53      0.52        60
#          731       0.07      0.12      0.09        17
#          732       0.10      0.17      0.12        12
#          733       0.51      0.60      0.55        42
#          734       0.00      0.00      0.00         0
#          736       0.00      0.00      0.00         1
#          738       0.00      0.00      0.00         0
#          739       0.56      0.78      0.65       234
#          740       0.00      0.00      0.00         1
#          741       0.69      0.54      0.61       291
#          743       0.47      0.51      0.49        47
#          744       0.00      0.00      0.00         2
#          745       0.00      0.00      0.00         5
#          746       0.00      0.00      0.00         0
#          747       0.20      0.50      0.29         8
#          748       0.00      0.00      0.00         2
#          749       0.33      0.12      0.18        16
#          750       0.50      1.00      0.67         1
#          751       0.00      0.00      0.00         1
#          752       0.50      0.50      0.50         2
#          753       0.00      0.00      0.00         0
#          754       0.43      0.35      0.38        57
#          755       0.00      0.00      0.00         1
#          756       0.40      0.62      0.49       264
#
#     accuracy                           0.46     25443
#    macro avg       0.16      0.20      0.17     25443
# weighted avg       0.51      0.46      0.48     25443
# /home/dmytro/anaconda3/lib/python3.7/site-packages/sklearn/metrics/_classification.py:1272: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %% [markdown]
# Отримав macro avg 0.17, тут ще можна звичайно покращити модель, але вона так довго тренується, що якщо додам ще різних шарів, то невідомо скільки це займе і чи вкладуся я в суботу.
#
# Отож, тут **0.17**, на моєму baselie було лишень **0.11**, а далі я в 10-й домашній роботі не просунувся.
