# %% [markdown]
# # Collocations

# %%
import spacy
import nltk

# %%
from tqdm.notebook import tqdm

# %%
nlp = spacy.load("en_core_web_md")

# %%
from nltk.corpus import wordnet

# %%
first_set = ['say', 'tell', 'speak', 'claim', 'communicate']

# %%
syn_series = set()
for word in first_set:
    word_synset = wordnet.synsets(word, 'v')[0]
    syn_lemmas = word_synset.lemma_names()
    print(f'{word} --- {syn_lemmas}')
    syn_series.update([word]+syn_lemmas)
print(f'\nResulting series: {syn_series}')
# Out:
# say --- ['state', 'say', 'tell']
# tell --- ['state', 'say', 'tell']
# speak --- ['talk', 'speak', 'utter', 'mouth', 'verbalize', 'verbalise']
# claim --- ['claim']
# communicate --- ['communicate', 'pass_on', 'pass', 'pass_along', 'put_across']
#
# Resulting series: {'state', 'utter', 'tell', 'speak', 'pass_on', 'put_across', 'pass', 'say', 'talk', 'pass_along', 'verbalise', 'claim', 'communicate', 'verbalize', 'mouth'}

# %%
with open('/home/yevhen/prj/prj-nlp-2020/tasks/02-structural-linguistics/data/blog2008.txt', 'r') as f:
    blogs = f.read().splitlines()

# %%
len(blogs)
# Out:
# 303994

# %%
n = 215
blogs[n]
# Out:
# '" We do n\'t mind going to any extent , as nobody is involved from the government or agency side , " he said .'

# %%
def find_adverbs_with_ly(doc, syn_series, stats_dict):
    for token in doc:
        if token.lemma_ in syn_series:
            for child in token.children:
                if child.pos_ == 'ADV' and child.text[-2:] == 'ly':
                    current_num = stats_dict[token.lemma_].get(child.lemma_, 0)
                    stats_dict[token.lemma_][child.lemma_] = current_num + 1
    return stats_dict

# %%
stats_dict = {verb:{} for verb in syn_series}
for blog in tqdm(blogs):
    doc = nlp(blog)
    stats_on_all_blogs = find_adverbs_with_ly(doc, syn_series, stats_dict)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=303994.0), HTML(value='')))

# %%
stats_on_all_blogs
# Out:
# {'state': {'subtly': 1,
#   'suggestively': 1,
#   'only': 5,
#   'calmly': 1,
#   'bluntly': 7,
#   'unequivocally': 12,
#   'exactly': 2,
#   'repeatedly': 5,
#   'merely': 2,
#   'absurdly': 1,
#   'previously': 6,
#   'specifically': 4,
#   'publicly': 22,
#   'briefly': 3,
#   'expressly': 3,
#   'simply': 7,
#   'clearly': 19,
#   'really': 1,
#   'especially': 1,
#   'emphatically': 5,
#   'recently': 6,
#   'obscenely': 1,
#   'forcefully': 2,
#   'plainly': 3,
#   'directly': 1,
#   'formally': 1,
#   'honestly': 1,
#   'accurately': 1,
#   'correctly': 4,
#   'explicitly': 13,
#   'authoritatively': 1,
#   'persistently': 1,
#   'shortly': 1,
#   'famously': 2,
#   'officially': 1,
#   'flatly': 7,
#   'basically': 2,
#   'ludicrously': 1,
#   'generically': 1,
#   'virtually': 2,
#   'properly': 1,
#   'categorically': 2,
#   'rightly': 2,
#   'baldly': 1,
#   'formerly': 1,
#   'finally': 1,
#   'respectively': 1,
#   'essentially': 1,
#   'firmly': 1,
#   'adamantly': 1,
#   'inaccurately': 1,
#   'incorrectly': 3,
#   'uncategorically': 1,
#   'additionally': 1,
#   'naturally': 1,
#   'immediately': 1,
#   'openly': 1,
#   'falsely': 2,
#   'separately': 1,
#   'forwardly': 1,
#   'obviously': 1,
#   'intriguingly': 1,
#   'frequently': 1,
#   'usually': 1},
#  'utter': {'really': 1,
#   'actually': 2,
#   'casually': 1,
#   'pejoratively': 1,
#   'only': 1},
#  'tell': {'continually': 1,
#   'flatly': 2,
#   'realistically': 1,
#   'privately': 12,
#   'glibly': 1,
#   'willingly': 1,
#   'subsequently': 1,
#   'repeatedly': 8,
#   'actually': 8,
#   'bluntly': 5,
#   'probably': 7,
#   'recently': 25,
#   'apparently': 3,
#   'exactly': 4,
#   'habitually': 1,
#   'possibly': 2,
#   'really': 8,
#   'especially': 4,
#   'specifically': 8,
#   'undoubtedly': 1,
#   'faithfully': 1,
#   'unavailingly': 1,
#   'originally': 1,
#   'extremely': 2,
#   'reportedly': 14,
#   'only': 9,
#   'confidently': 3,
#   'basically': 9,
#   'evidently': 1,
#   'sadly': 2,
#   'accidentally': 2,
#   'snidely': 1,
#   'defensively': 1,
#   'solemnly': 1,
#   'consistently': 1,
#   'effectively': 2,
#   'loudly': 1,
#   'certainly': 5,
#   'coincidentally': 1,
#   'usually': 2,
#   'heatedly': 1,
#   'casually': 1,
#   'essentially': 3,
#   'early': 1,
#   'supposedly': 1,
#   'honestly': 3,
#   'finally': 9,
#   'famously': 2,
#   'constantly': 3,
#   'explicitly': 7,
#   'helpfully': 2,
#   'easily': 1,
#   'seriously': 2,
#   'indirectly': 1,
#   'particularly': 2,
#   'falsely': 2,
#   'quickly': 1,
#   'slowly': 2,
#   'likely': 3,
#   'initially': 4,
#   'absolutely': 1,
#   'mindedly': 1,
#   'grimly': 1,
#   'innocently': 1,
#   'relatedly': 1,
#   'guilelessly': 1,
#   'similarly': 4,
#   'reliably': 3,
#   'politely': 1,
#   'personally': 6,
#   'publicly': 2,
#   'immediately': 1,
#   'allegedly': 3,
#   'sternly': 1,
#   'readily': 1,
#   'suddenly': 2,
#   'mostly': 1,
#   'definitively': 2,
#   'dismissively': 2,
#   'plausibly': 1,
#   'unequivocally': 1,
#   'blithely': 1,
#   'condescendingly': 1,
#   'sarcastically': 1,
#   'simply': 8,
#   'sheepishly': 1,
#   'categorically': 1,
#   'fairly': 1,
#   'curiously': 2,
#   'eventually': 2,
#   'gleefully': 1,
#   'subtly': 1,
#   'previously': 1,
#   'frankly': 1,
#   'ultimately': 2,
#   'additionally': 1,
#   'respectfully': 1,
#   'directly': 1,
#   'candidly': 1,
#   'disingenuously': 1,
#   'infamously': 1,
#   'clearly': 1,
#   'forcefully': 1,
#   'necessarily': 1,
#   'optimistically': 1,
#   'expressly': 1,
#   'lovingly': 1,
#   'barely': 2,
#   'dramatically': 1,
#   'kindly': 1},
#  'speak': {'briefly': 9,
#   'overtly': 1,
#   'subsequently': 1,
#   'publicly': 15,
#   'tactically': 1,
#   'directly': 33,
#   'anonymously': 5,
#   'bluntly': 3,
#   'privately': 3,
#   'recently': 8,
#   'exclusively': 1,
#   'infrequently': 1,
#   'only': 11,
#   'fiercely': 12,
#   'eloquently': 5,
#   'technically': 2,
#   'probably': 3,
#   'naturally': 1,
#   'negatively': 2,
#   'movingly': 1,
#   'generally': 9,
#   'previously': 5,
#   'intensely': 1,
#   'fluently': 1,
#   'highly': 3,
#   'certainly': 3,
#   'politically': 7,
#   'willingly': 1,
#   'inadvertently': 1,
#   'emotionally': 1,
#   'haltingly': 2,
#   'constitutionally': 1,
#   'frequently': 4,
#   'earnestly': 1,
#   'despairingly': 1,
#   'really': 4,
#   'brusquely': 1,
#   'loudly': 7,
#   'abusively': 1,
#   'freely': 5,
#   'constantly': 1,
#   'comparatively': 3,
#   'stylistically': 1,
#   'accurately': 1,
#   'derisively': 1,
#   'harshly': 1,
#   'gingerly': 1,
#   'plainly': 3,
#   'broadly': 5,
#   'forcefully': 5,
#   'barely': 1,
#   'occasionally': 1,
#   'glowingly': 2,
#   'rarely': 2,
#   'strictly': 7,
#   'clearly': 5,
#   'traditionally': 1,
#   'extensively': 1,
#   'actually': 6,
#   'figuratively': 5,
#   'statistically': 2,
#   'effectively': 2,
#   'finally': 5,
#   'enthusiastically': 1,
#   'imprecisely': 2,
#   'candidly': 2,
#   'unsurprisingly': 1,
#   'hypothetically': 2,
#   'exactly': 2,
#   'properly': 1,
#   'roughly': 1,
#   'openly': 8,
#   'strongly': 4,
#   'objectively': 2,
#   'disdainfully': 1,
#   'competently': 1,
#   'darkly': 1,
#   'relentlessly': 1,
#   'especially': 1,
#   'specifically': 4,
#   'legally': 1,
#   'usually': 2,
#   'culturally': 1,
#   'historically': 2,
#   'quickly': 1,
#   'inartfully': 2,
#   'facetiously': 1,
#   'extemporaneously': 3,
#   'morally': 1,
#   'correctly': 1,
#   'badly': 1,
#   'softly': 2,
#   'apparently': 1,
#   'hysterically': 1,
#   'unfortunately': 1,
#   'rationally': 1,
#   'conspicuously': 1,
#   'relatively': 1,
#   'practically': 2,
#   'philosophically': 1,
#   'dismissively': 1,
#   'normally': 1,
#   'lately': 1,
#   'personally': 2,
#   'literally': 2,
#   'immensely': 1,
#   'frankly': 3,
#   'competitively': 1,
#   'ethically': 1,
#   'passionately': 1,
#   'truthfully': 2,
#   'metaphorically': 2,
#   'additionally': 1,
#   'aggressively': 1,
#   'consistently': 1,
#   'repeatedly': 1,
#   'presumably': 1,
#   'simply': 1,
#   'regularly': 1,
#   'favorably': 5,
#   'confidentially': 1,
#   'essentially': 1,
#   'reportedly': 1,
#   'officially': 1,
#   'compassionately': 1,
#   'truly': 1,
#   'currently': 1},
#  'pass_on': {},
#  'put_across': {},
#  'pass': {'apparently': 3,
#   'speedily': 1,
#   'certainly': 1,
#   'recently': 5,
#   'hardly': 1,
#   'previously': 1,
#   'automatically': 1,
#   'probably': 8,
#   'unanimously': 11,
#   'only': 9,
#   'thankfully': 1,
#   'quickly': 13,
#   'safely': 1,
#   'successfully': 2,
#   'simply': 2,
#   'hurriedly': 1,
#   'easily': 4,
#   'briefly': 1,
#   'lightly': 1,
#   'overwhelmingly': 5,
#   'finally': 3,
#   'conclusively': 1,
#   'sadly': 1,
#   'narrowly': 4,
#   'federally': 1,
#   'uncritically': 1,
#   'exactly': 1,
#   'blithely': 1,
#   'untimely': 1,
#   'smoothly': 1,
#   'barely': 1,
#   'nearly': 1,
#   'exponentially': 1,
#   'usually': 1,
#   'ironically': 1,
#   'early': 1,
#   'eventually': 4,
#   'unfortunately': 1,
#   'partly': 1,
#   'secondly': 1,
#   'initially': 2,
#   'reportedly': 1,
#   'undoubtedly': 1,
#   'possibly': 1,
#   'merely': 1,
#   'completely': 1,
#   'physically': 1,
#   'immediately': 3,
#   'arbitrarily': 1,
#   'hastily': 2,
#   'really': 1,
#   'quietly': 1,
#   'strongly': 1,
#   'basically': 1,
#   'actually': 1,
#   'sufficiently': 1,
#   'conceivably': 1,
#   'tragically': 1},
#  'say': {'definitively': 6,
#   'recently': 73,
#   'really': 31,
#   'quickly': 4,
#   'daily': 1,
#   'actually': 76,
#   'presumably': 2,
#   'piously': 1,
#   'apparently': 7,
#   'convincingly': 1,
#   'literally': 2,
#   'triumphantly': 2,
#   'ultimately': 1,
#   'interestingly': 4,
#   'probably': 13,
#   'unequivocally': 6,
#   'eventually': 3,
#   'previously': 22,
#   'clearly': 21,
#   'repeatedly': 55,
#   'typically': 1,
#   'famously': 19,
#   'unfortunately': 6,
#   'firmly': 1,
#   'only': 25,
#   'currently': 2,
#   'differently': 4,
#   'directly': 9,
#   'simply': 46,
#   'genially': 1,
#   'obviously': 3,
#   'publicly': 36,
#   'finally': 19,
#   'flatly': 9,
#   'responsibly': 1,
#   'dismissively': 4,
#   'stupidly': 1,
#   'originally': 5,
#   'explicitly': 39,
#   'especially': 2,
#   'simultaneously': 3,
#   'essentially': 12,
#   'graciously': 2,
#   'respectfully': 2,
#   'specifically': 16,
#   'economically': 1,
#   'consistently': 8,
#   'infamously': 1,
#   'eloquently': 1,
#   'nervously': 1,
#   'allegedly': 7,
#   'warmly': 1,
#   'instantly': 1,
#   'mockingly': 3,
#   'honestly': 11,
#   'bluntly': 7,
#   'absolutely': 8,
#   'secondly': 2,
#   'absurdly': 1,
#   'routinely': 2,
#   'constantly': 5,
#   'generally': 1,
#   'certainly': 4,
#   'falsely': 3,
#   'suddenly': 3,
#   'rightly': 3,
#   'reportedly': 10,
#   'confidently': 1,
#   'similarly': 11,
#   'quietly': 5,
#   'correctly': 9,
#   'usually': 1,
#   'substantially': 1,
#   'plainly': 3,
#   'importantly': 1,
#   'purportedly': 1,
#   'smugly': 1,
#   'innocently': 1,
#   'privately': 17,
#   'derisively': 2,
#   'basically': 34,
#   'similiarly': 1,
#   'exactly': 5,
#   'snidely': 1,
#   'defensively': 1,
#   'straightforwardly': 1,
#   'particularly': 1,
#   'properly': 1,
#   'merely': 17,
#   'genteelly': 1,
#   'accidentally': 2,
#   'sadly': 1,
#   'casually': 1,
#   'inevitably': 1,
#   'blindly': 1,
#   'thoughtfully': 1,
#   'euphemistically': 2,
#   'seriously': 3,
#   'coincidentally': 1,
#   'animatedly': 1,
#   'ruefully': 1,
#   'sheepishly': 1,
#   'necessarily': 4,
#   'incorrectly': 1,
#   'early': 4,
#   'surprisingly': 4,
#   'pointedly': 1,
#   'loudly': 2,
#   'hardly': 1,
#   'charitably': 1,
#   'overwhelmingly': 1,
#   'frequently': 2,
#   'likely': 1,
#   'categorically': 3,
#   'initially': 6,
#   'precisely': 2,
#   'sarcastically': 2,
#   'immediately': 3,
#   'supposedly': 3,
#   'notably': 2,
#   'strictly': 1,
#   'incidentally': 3,
#   'neatly': 1,
#   'rightfully': 1,
#   'memorably': 1,
#   'officially': 1,
#   'fundamentally': 1,
#   'surely': 2,
#   'tactfully': 1,
#   'technically': 2,
#   'safely': 2,
#   'unconsciously': 1,
#   'openly': 5,
#   'rarely': 1,
#   'alternately': 1,
#   'acidly': 1,
#   'evidently': 1,
#   'ironically': 4,
#   'easily': 5,
#   'legitimately': 1,
#   'normally': 3,
#   'theoretically': 1,
#   'unbelievably': 1,
#   'hypothetically': 4,
#   'possibly': 1,
#   'lately': 2,
#   'politically': 1,
#   'reluctantly': 2,
#   'financially': 1,
#   'truly': 1,
#   'automatically': 1,
#   'notoriously': 1,
#   'conservatively': 2,
#   'frankly': 1,
#   'additionally': 4,
#   'negligently': 1,
#   'judiciously': 1,
#   'candidly': 1,
#   'effectively': 2,
#   'unfairly': 1,
#   'bitterly': 1,
#   'erroneously': 1,
#   'conversely': 1,
#   'emphatically': 1,
#   'approvingly': 1,
#   'proudly': 1,
#   'personally': 1,
#   'haltingly': 1,
#   'intially': 1,
#   'predictably': 1,
#   'partly': 1,
#   'plausibly': 1,
#   'prophetically': 1,
#   'amazingly': 1,
#   'inadvertently': 1,
#   'wrongly': 2,
#   'dryly': 1,
#   'continuously': 1,
#   'factly': 1,
#   'curtly': 1,
#   'contemporaneously': 2,
#   'unabashedly': 1,
#   'jokingly': 1,
#   'boldly': 1,
#   'sternly': 5,
#   'somberly': 1,
#   'severely': 1,
#   'politely': 1,
#   'hopefully': 1,
#   'strikingly': 1,
#   'grimly': 1,
#   'indignantly': 2,
#   'independently': 1,
#   'forcefully': 1},
#  'talk': {'especially': 1,
#   'consistently': 2,
#   'recently': 4,
#   'forcefully': 1,
#   'actively': 1,
#   'blithely': 1,
#   'directly': 14,
#   'rarely': 2,
#   'really': 11,
#   'frankly': 2,
#   'openly': 7,
#   'only': 12,
#   'unconditionally': 2,
#   'glowingly': 1,
#   'publicly': 6,
#   'mainly': 1,
#   'personally': 5,
#   'softly': 2,
#   'clearly': 5,
#   'firmly': 1,
#   'honestly': 2,
#   'usually': 1,
#   'quickly': 1,
#   'truly': 1,
#   'reasonably': 1,
#   'virtuously': 1,
#   'badly': 1,
#   'routinely': 1,
#   'probably': 2,
#   'explicitly': 1,
#   'nationally': 1,
#   'evidently': 1,
#   'concretely': 1,
#   'beautifully': 1,
#   'gamely': 1,
#   'essentially': 1,
#   'separately': 1,
#   'actually': 7,
#   'constantly': 5,
#   'simply': 2,
#   'repeatedly': 6,
#   'daily': 2,
#   'extensively': 2,
#   'anonymously': 1,
#   'literally': 1,
#   'increasingly': 1,
#   'vaporously': 1,
#   'gravely': 1,
#   'famously': 1,
#   'broadly': 1,
#   'permanently': 2,
#   'brazenly': 1,
#   'exactly': 2,
#   'obviously': 5,
#   'substantively': 1,
#   'presumably': 1,
#   'endlessly': 3,
#   'voluntarily': 1,
#   'suddenly': 1,
#   'incessantly': 1,
#   'mostly': 3,
#   'effectively': 1,
#   'outwardly': 1,
#   'occasionally': 1,
#   'certainly': 1,
#   'interestingly': 1,
#   'approvingly': 1,
#   'rightly': 1,
#   'casually': 1,
#   'memorably': 1,
#   'unfortunately': 2,
#   'particularly': 1,
#   'cordially': 1,
#   'stiffly': 1,
#   'finally': 3,
#   'merely': 2,
#   'regularly': 5,
#   'periodically': 2,
#   'specifically': 6,
#   'exclusively': 1,
#   'uncharacteristically': 1,
#   'nicely': 1,
#   'unilaterally': 1,
#   'passionately': 1,
#   'apparently': 1,
#   'namely': 1,
#   'necessarily': 1,
#   'sensibly': 1,
#   'responsibly': 1},
#  'pass_along': {},
#  'verbalise': {},
#  'claim': {'initially': 3,
#   'brazenly': 1,
#   'surely': 2,
#   'solemnly': 1,
#   'previously': 9,
#   'falsely': 81,
#   'oddly': 1,
#   'apparently': 2,
#   'fiercely': 1,
#   'alternatively': 1,
#   'constantly': 1,
#   'loudly': 1,
#   'annually': 1,
#   'bizarrely': 2,
#   'actually': 3,
#   'piously': 1,
#   'recently': 4,
#   'preposterously': 1,
#   'notably': 1,
#   'widely': 1,
#   'absurdly': 3,
#   'clearly': 1,
#   'probably': 1,
#   'illegally': 1,
#   'righteously': 1,
#   'indignantly': 2,
#   'immediately': 2,
#   'explicitly': 1,
#   'tearfully': 1,
#   'patronizingly': 1,
#   'credibly': 3,
#   'repeatedly': 8,
#   'openly': 1,
#   'incorrectly': 3,
#   'remotely': 1,
#   'erroneously': 2,
#   'publicly': 3,
#   'consistently': 2,
#   'really': 1,
#   'realistically': 1,
#   'truly': 1,
#   'completely': 1,
#   'originally': 2,
#   'merely': 1,
#   'chronologically': 1,
#   'evidently': 2,
#   'inadvertently': 1,
#   'persuasively': 1,
#   'predictably': 1,
#   'likely': 1,
#   'ostensibly': 1,
#   'laughably': 3,
#   'sanctimoniously': 1,
#   'shamelessly': 1,
#   'reportedly': 1,
#   'ironically': 2,
#   'cluelessly': 1,
#   'angrily': 1,
#   'jokingly': 1,
#   'baselessly': 1,
#   'emptively': 1,
#   'disingenuously': 2,
#   'inaccurately': 2,
#   'ludicrously': 3,
#   'audaciously': 1,
#   'frequently': 2,
#   'largely': 1,
#   'dismissively': 1,
#   'vaguely': 2,
#   'unbelievably': 1,
#   'boldly': 1,
#   'finally': 1,
#   'astonishingly': 1,
#   'inexplicably': 1,
#   'incessantly': 1,
#   'similarly': 1,
#   'disturbingly': 1,
#   'emphatically': 1,
#   'improperly': 1,
#   'successfully': 1,
#   'interestingly': 1,
#   'only': 1,
#   'tantalizingly': 1,
#   'mindedly': 1,
#   'formerly': 2,
#   'sweetly': 1,
#   'simultaneously': 1},
#  'communicate': {'freely': 1,
#   'really': 1,
#   'effectively': 3,
#   'directly': 3,
#   'verbally': 1,
#   'apparently': 1,
#   'loudly': 1,
#   'hopefully': 1,
#   'daily': 1,
#   'actually': 1,
#   'regularly': 1,
#   'quickly': 1,
#   'profoundly': 1,
#   'poorly': 1,
#   'finally': 1,
#   'privately': 1},
#  'verbalize': {},
#  'mouth': {'especially': 1, 'robotically': 1, 'merely': 1}}

# %%
sorted_dict  = {}
for verb in stats_on_all_blogs.keys():
    sorted_dict[verb] = {
        key: value 
        for key, value 
        in sorted(stats_on_all_blogs[verb].items(), key=lambda item: item[1], reverse=True)
    }

# %%
sorted_dict
# Out:
# {'state': {'publicly': 22,
#   'clearly': 19,
#   'explicitly': 13,
#   'unequivocally': 12,
#   'bluntly': 7,
#   'simply': 7,
#   'flatly': 7,
#   'previously': 6,
#   'recently': 6,
#   'only': 5,
#   'repeatedly': 5,
#   'emphatically': 5,
#   'specifically': 4,
#   'correctly': 4,
#   'briefly': 3,
#   'expressly': 3,
#   'plainly': 3,
#   'incorrectly': 3,
#   'exactly': 2,
#   'merely': 2,
#   'forcefully': 2,
#   'famously': 2,
#   'basically': 2,
#   'virtually': 2,
#   'categorically': 2,
#   'rightly': 2,
#   'falsely': 2,
#   'subtly': 1,
#   'suggestively': 1,
#   'calmly': 1,
#   'absurdly': 1,
#   'really': 1,
#   'especially': 1,
#   'obscenely': 1,
#   'directly': 1,
#   'formally': 1,
#   'honestly': 1,
#   'accurately': 1,
#   'authoritatively': 1,
#   'persistently': 1,
#   'shortly': 1,
#   'officially': 1,
#   'ludicrously': 1,
#   'generically': 1,
#   'properly': 1,
#   'baldly': 1,
#   'formerly': 1,
#   'finally': 1,
#   'respectively': 1,
#   'essentially': 1,
#   'firmly': 1,
#   'adamantly': 1,
#   'inaccurately': 1,
#   'uncategorically': 1,
#   'additionally': 1,
#   'naturally': 1,
#   'immediately': 1,
#   'openly': 1,
#   'separately': 1,
#   'forwardly': 1,
#   'obviously': 1,
#   'intriguingly': 1,
#   'frequently': 1,
#   'usually': 1},
#  'utter': {'actually': 2,
#   'really': 1,
#   'casually': 1,
#   'pejoratively': 1,
#   'only': 1},
#  'tell': {'recently': 25,
#   'reportedly': 14,
#   'privately': 12,
#   'only': 9,
#   'basically': 9,
#   'finally': 9,
#   'repeatedly': 8,
#   'actually': 8,
#   'really': 8,
#   'specifically': 8,
#   'simply': 8,
#   'probably': 7,
#   'explicitly': 7,
#   'personally': 6,
#   'bluntly': 5,
#   'certainly': 5,
#   'exactly': 4,
#   'especially': 4,
#   'initially': 4,
#   'similarly': 4,
#   'apparently': 3,
#   'confidently': 3,
#   'essentially': 3,
#   'honestly': 3,
#   'constantly': 3,
#   'likely': 3,
#   'reliably': 3,
#   'allegedly': 3,
#   'flatly': 2,
#   'possibly': 2,
#   'extremely': 2,
#   'sadly': 2,
#   'accidentally': 2,
#   'effectively': 2,
#   'usually': 2,
#   'famously': 2,
#   'helpfully': 2,
#   'seriously': 2,
#   'particularly': 2,
#   'falsely': 2,
#   'slowly': 2,
#   'publicly': 2,
#   'suddenly': 2,
#   'definitively': 2,
#   'dismissively': 2,
#   'curiously': 2,
#   'eventually': 2,
#   'ultimately': 2,
#   'barely': 2,
#   'continually': 1,
#   'realistically': 1,
#   'glibly': 1,
#   'willingly': 1,
#   'subsequently': 1,
#   'habitually': 1,
#   'undoubtedly': 1,
#   'faithfully': 1,
#   'unavailingly': 1,
#   'originally': 1,
#   'evidently': 1,
#   'snidely': 1,
#   'defensively': 1,
#   'solemnly': 1,
#   'consistently': 1,
#   'loudly': 1,
#   'coincidentally': 1,
#   'heatedly': 1,
#   'casually': 1,
#   'early': 1,
#   'supposedly': 1,
#   'easily': 1,
#   'indirectly': 1,
#   'quickly': 1,
#   'absolutely': 1,
#   'mindedly': 1,
#   'grimly': 1,
#   'innocently': 1,
#   'relatedly': 1,
#   'guilelessly': 1,
#   'politely': 1,
#   'immediately': 1,
#   'sternly': 1,
#   'readily': 1,
#   'mostly': 1,
#   'plausibly': 1,
#   'unequivocally': 1,
#   'blithely': 1,
#   'condescendingly': 1,
#   'sarcastically': 1,
#   'sheepishly': 1,
#   'categorically': 1,
#   'fairly': 1,
#   'gleefully': 1,
#   'subtly': 1,
#   'previously': 1,
#   'frankly': 1,
#   'additionally': 1,
#   'respectfully': 1,
#   'directly': 1,
#   'candidly': 1,
#   'disingenuously': 1,
#   'infamously': 1,
#   'clearly': 1,
#   'forcefully': 1,
#   'necessarily': 1,
#   'optimistically': 1,
#   'expressly': 1,
#   'lovingly': 1,
#   'dramatically': 1,
#   'kindly': 1},
#  'speak': {'directly': 33,
#   'publicly': 15,
#   'fiercely': 12,
#   'only': 11,
#   'briefly': 9,
#   'generally': 9,
#   'recently': 8,
#   'openly': 8,
#   'politically': 7,
#   'loudly': 7,
#   'strictly': 7,
#   'actually': 6,
#   'anonymously': 5,
#   'eloquently': 5,
#   'previously': 5,
#   'freely': 5,
#   'broadly': 5,
#   'forcefully': 5,
#   'clearly': 5,
#   'figuratively': 5,
#   'finally': 5,
#   'favorably': 5,
#   'frequently': 4,
#   'really': 4,
#   'strongly': 4,
#   'specifically': 4,
#   'bluntly': 3,
#   'privately': 3,
#   'probably': 3,
#   'highly': 3,
#   'certainly': 3,
#   'comparatively': 3,
#   'plainly': 3,
#   'extemporaneously': 3,
#   'frankly': 3,
#   'technically': 2,
#   'negatively': 2,
#   'haltingly': 2,
#   'glowingly': 2,
#   'rarely': 2,
#   'statistically': 2,
#   'effectively': 2,
#   'imprecisely': 2,
#   'candidly': 2,
#   'hypothetically': 2,
#   'exactly': 2,
#   'objectively': 2,
#   'usually': 2,
#   'historically': 2,
#   'inartfully': 2,
#   'softly': 2,
#   'practically': 2,
#   'personally': 2,
#   'literally': 2,
#   'truthfully': 2,
#   'metaphorically': 2,
#   'overtly': 1,
#   'subsequently': 1,
#   'tactically': 1,
#   'exclusively': 1,
#   'infrequently': 1,
#   'naturally': 1,
#   'movingly': 1,
#   'intensely': 1,
#   'fluently': 1,
#   'willingly': 1,
#   'inadvertently': 1,
#   'emotionally': 1,
#   'constitutionally': 1,
#   'earnestly': 1,
#   'despairingly': 1,
#   'brusquely': 1,
#   'abusively': 1,
#   'constantly': 1,
#   'stylistically': 1,
#   'accurately': 1,
#   'derisively': 1,
#   'harshly': 1,
#   'gingerly': 1,
#   'barely': 1,
#   'occasionally': 1,
#   'traditionally': 1,
#   'extensively': 1,
#   'enthusiastically': 1,
#   'unsurprisingly': 1,
#   'properly': 1,
#   'roughly': 1,
#   'disdainfully': 1,
#   'competently': 1,
#   'darkly': 1,
#   'relentlessly': 1,
#   'especially': 1,
#   'legally': 1,
#   'culturally': 1,
#   'quickly': 1,
#   'facetiously': 1,
#   'morally': 1,
#   'correctly': 1,
#   'badly': 1,
#   'apparently': 1,
#   'hysterically': 1,
#   'unfortunately': 1,
#   'rationally': 1,
#   'conspicuously': 1,
#   'relatively': 1,
#   'philosophically': 1,
#   'dismissively': 1,
#   'normally': 1,
#   'lately': 1,
#   'immensely': 1,
#   'competitively': 1,
#   'ethically': 1,
#   'passionately': 1,
#   'additionally': 1,
#   'aggressively': 1,
#   'consistently': 1,
#   'repeatedly': 1,
#   'presumably': 1,
#   'simply': 1,
#   'regularly': 1,
#   'confidentially': 1,
#   'essentially': 1,
#   'reportedly': 1,
#   'officially': 1,
#   'compassionately': 1,
#   'truly': 1,
#   'currently': 1},
#  'pass_on': {},
#  'put_across': {},
#  'pass': {'quickly': 13,
#   'unanimously': 11,
#   'only': 9,
#   'probably': 8,
#   'recently': 5,
#   'overwhelmingly': 5,
#   'easily': 4,
#   'narrowly': 4,
#   'eventually': 4,
#   'apparently': 3,
#   'finally': 3,
#   'immediately': 3,
#   'successfully': 2,
#   'simply': 2,
#   'initially': 2,
#   'hastily': 2,
#   'speedily': 1,
#   'certainly': 1,
#   'hardly': 1,
#   'previously': 1,
#   'automatically': 1,
#   'thankfully': 1,
#   'safely': 1,
#   'hurriedly': 1,
#   'briefly': 1,
#   'lightly': 1,
#   'conclusively': 1,
#   'sadly': 1,
#   'federally': 1,
#   'uncritically': 1,
#   'exactly': 1,
#   'blithely': 1,
#   'untimely': 1,
#   'smoothly': 1,
#   'barely': 1,
#   'nearly': 1,
#   'exponentially': 1,
#   'usually': 1,
#   'ironically': 1,
#   'early': 1,
#   'unfortunately': 1,
#   'partly': 1,
#   'secondly': 1,
#   'reportedly': 1,
#   'undoubtedly': 1,
#   'possibly': 1,
#   'merely': 1,
#   'completely': 1,
#   'physically': 1,
#   'arbitrarily': 1,
#   'really': 1,
#   'quietly': 1,
#   'strongly': 1,
#   'basically': 1,
#   'actually': 1,
#   'sufficiently': 1,
#   'conceivably': 1,
#   'tragically': 1},
#  'say': {'actually': 76,
#   'recently': 73,
#   'repeatedly': 55,
#   'simply': 46,
#   'explicitly': 39,
#   'publicly': 36,
#   'basically': 34,
#   'really': 31,
#   'only': 25,
#   'previously': 22,
#   'clearly': 21,
#   'famously': 19,
#   'finally': 19,
#   'privately': 17,
#   'merely': 17,
#   'specifically': 16,
#   'probably': 13,
#   'essentially': 12,
#   'honestly': 11,
#   'similarly': 11,
#   'reportedly': 10,
#   'directly': 9,
#   'flatly': 9,
#   'correctly': 9,
#   'consistently': 8,
#   'absolutely': 8,
#   'apparently': 7,
#   'allegedly': 7,
#   'bluntly': 7,
#   'definitively': 6,
#   'unequivocally': 6,
#   'unfortunately': 6,
#   'initially': 6,
#   'originally': 5,
#   'constantly': 5,
#   'quietly': 5,
#   'exactly': 5,
#   'openly': 5,
#   'easily': 5,
#   'sternly': 5,
#   'quickly': 4,
#   'interestingly': 4,
#   'differently': 4,
#   'dismissively': 4,
#   'certainly': 4,
#   'necessarily': 4,
#   'early': 4,
#   'surprisingly': 4,
#   'ironically': 4,
#   'hypothetically': 4,
#   'additionally': 4,
#   'eventually': 3,
#   'obviously': 3,
#   'simultaneously': 3,
#   'mockingly': 3,
#   'falsely': 3,
#   'suddenly': 3,
#   'rightly': 3,
#   'plainly': 3,
#   'seriously': 3,
#   'categorically': 3,
#   'immediately': 3,
#   'supposedly': 3,
#   'incidentally': 3,
#   'normally': 3,
#   'presumably': 2,
#   'literally': 2,
#   'triumphantly': 2,
#   'currently': 2,
#   'especially': 2,
#   'graciously': 2,
#   'respectfully': 2,
#   'secondly': 2,
#   'routinely': 2,
#   'derisively': 2,
#   'accidentally': 2,
#   'euphemistically': 2,
#   'loudly': 2,
#   'frequently': 2,
#   'precisely': 2,
#   'sarcastically': 2,
#   'notably': 2,
#   'surely': 2,
#   'technically': 2,
#   'safely': 2,
#   'lately': 2,
#   'reluctantly': 2,
#   'conservatively': 2,
#   'effectively': 2,
#   'wrongly': 2,
#   'contemporaneously': 2,
#   'indignantly': 2,
#   'daily': 1,
#   'piously': 1,
#   'convincingly': 1,
#   'ultimately': 1,
#   'typically': 1,
#   'firmly': 1,
#   'genially': 1,
#   'responsibly': 1,
#   'stupidly': 1,
#   'economically': 1,
#   'infamously': 1,
#   'eloquently': 1,
#   'nervously': 1,
#   'warmly': 1,
#   'instantly': 1,
#   'absurdly': 1,
#   'generally': 1,
#   'confidently': 1,
#   'usually': 1,
#   'substantially': 1,
#   'importantly': 1,
#   'purportedly': 1,
#   'smugly': 1,
#   'innocently': 1,
#   'similiarly': 1,
#   'snidely': 1,
#   'defensively': 1,
#   'straightforwardly': 1,
#   'particularly': 1,
#   'properly': 1,
#   'genteelly': 1,
#   'sadly': 1,
#   'casually': 1,
#   'inevitably': 1,
#   'blindly': 1,
#   'thoughtfully': 1,
#   'coincidentally': 1,
#   'animatedly': 1,
#   'ruefully': 1,
#   'sheepishly': 1,
#   'incorrectly': 1,
#   'pointedly': 1,
#   'hardly': 1,
#   'charitably': 1,
#   'overwhelmingly': 1,
#   'likely': 1,
#   'strictly': 1,
#   'neatly': 1,
#   'rightfully': 1,
#   'memorably': 1,
#   'officially': 1,
#   'fundamentally': 1,
#   'tactfully': 1,
#   'unconsciously': 1,
#   'rarely': 1,
#   'alternately': 1,
#   'acidly': 1,
#   'evidently': 1,
#   'legitimately': 1,
#   'theoretically': 1,
#   'unbelievably': 1,
#   'possibly': 1,
#   'politically': 1,
#   'financially': 1,
#   'truly': 1,
#   'automatically': 1,
#   'notoriously': 1,
#   'frankly': 1,
#   'negligently': 1,
#   'judiciously': 1,
#   'candidly': 1,
#   'unfairly': 1,
#   'bitterly': 1,
#   'erroneously': 1,
#   'conversely': 1,
#   'emphatically': 1,
#   'approvingly': 1,
#   'proudly': 1,
#   'personally': 1,
#   'haltingly': 1,
#   'intially': 1,
#   'predictably': 1,
#   'partly': 1,
#   'plausibly': 1,
#   'prophetically': 1,
#   'amazingly': 1,
#   'inadvertently': 1,
#   'dryly': 1,
#   'continuously': 1,
#   'factly': 1,
#   'curtly': 1,
#   'unabashedly': 1,
#   'jokingly': 1,
#   'boldly': 1,
#   'somberly': 1,
#   'severely': 1,
#   'politely': 1,
#   'hopefully': 1,
#   'strikingly': 1,
#   'grimly': 1,
#   'independently': 1,
#   'forcefully': 1},
#  'talk': {'directly': 14,
#   'only': 12,
#   'really': 11,
#   'openly': 7,
#   'actually': 7,
#   'publicly': 6,
#   'repeatedly': 6,
#   'specifically': 6,
#   'personally': 5,
#   'clearly': 5,
#   'constantly': 5,
#   'obviously': 5,
#   'regularly': 5,
#   'recently': 4,
#   'endlessly': 3,
#   'mostly': 3,
#   'finally': 3,
#   'consistently': 2,
#   'rarely': 2,
#   'frankly': 2,
#   'unconditionally': 2,
#   'softly': 2,
#   'honestly': 2,
#   'probably': 2,
#   'simply': 2,
#   'daily': 2,
#   'extensively': 2,
#   'permanently': 2,
#   'exactly': 2,
#   'unfortunately': 2,
#   'merely': 2,
#   'periodically': 2,
#   'especially': 1,
#   'forcefully': 1,
#   'actively': 1,
#   'blithely': 1,
#   'glowingly': 1,
#   'mainly': 1,
#   'firmly': 1,
#   'usually': 1,
#   'quickly': 1,
#   'truly': 1,
#   'reasonably': 1,
#   'virtuously': 1,
#   'badly': 1,
#   'routinely': 1,
#   'explicitly': 1,
#   'nationally': 1,
#   'evidently': 1,
#   'concretely': 1,
#   'beautifully': 1,
#   'gamely': 1,
#   'essentially': 1,
#   'separately': 1,
#   'anonymously': 1,
#   'literally': 1,
#   'increasingly': 1,
#   'vaporously': 1,
#   'gravely': 1,
#   'famously': 1,
#   'broadly': 1,
#   'brazenly': 1,
#   'substantively': 1,
#   'presumably': 1,
#   'voluntarily': 1,
#   'suddenly': 1,
#   'incessantly': 1,
#   'effectively': 1,
#   'outwardly': 1,
#   'occasionally': 1,
#   'certainly': 1,
#   'interestingly': 1,
#   'approvingly': 1,
#   'rightly': 1,
#   'casually': 1,
#   'memorably': 1,
#   'particularly': 1,
#   'cordially': 1,
#   'stiffly': 1,
#   'exclusively': 1,
#   'uncharacteristically': 1,
#   'nicely': 1,
#   'unilaterally': 1,
#   'passionately': 1,
#   'apparently': 1,
#   'namely': 1,
#   'necessarily': 1,
#   'sensibly': 1,
#   'responsibly': 1},
#  'pass_along': {},
#  'verbalise': {},
#  'claim': {'falsely': 81,
#   'previously': 9,
#   'repeatedly': 8,
#   'recently': 4,
#   'initially': 3,
#   'actually': 3,
#   'absurdly': 3,
#   'credibly': 3,
#   'incorrectly': 3,
#   'publicly': 3,
#   'laughably': 3,
#   'ludicrously': 3,
#   'surely': 2,
#   'apparently': 2,
#   'bizarrely': 2,
#   'indignantly': 2,
#   'immediately': 2,
#   'erroneously': 2,
#   'consistently': 2,
#   'originally': 2,
#   'evidently': 2,
#   'ironically': 2,
#   'disingenuously': 2,
#   'inaccurately': 2,
#   'frequently': 2,
#   'vaguely': 2,
#   'formerly': 2,
#   'brazenly': 1,
#   'solemnly': 1,
#   'oddly': 1,
#   'fiercely': 1,
#   'alternatively': 1,
#   'constantly': 1,
#   'loudly': 1,
#   'annually': 1,
#   'piously': 1,
#   'preposterously': 1,
#   'notably': 1,
#   'widely': 1,
#   'clearly': 1,
#   'probably': 1,
#   'illegally': 1,
#   'righteously': 1,
#   'explicitly': 1,
#   'tearfully': 1,
#   'patronizingly': 1,
#   'openly': 1,
#   'remotely': 1,
#   'really': 1,
#   'realistically': 1,
#   'truly': 1,
#   'completely': 1,
#   'merely': 1,
#   'chronologically': 1,
#   'inadvertently': 1,
#   'persuasively': 1,
#   'predictably': 1,
#   'likely': 1,
#   'ostensibly': 1,
#   'sanctimoniously': 1,
#   'shamelessly': 1,
#   'reportedly': 1,
#   'cluelessly': 1,
#   'angrily': 1,
#   'jokingly': 1,
#   'baselessly': 1,
#   'emptively': 1,
#   'audaciously': 1,
#   'largely': 1,
#   'dismissively': 1,
#   'unbelievably': 1,
#   'boldly': 1,
#   'finally': 1,
#   'astonishingly': 1,
#   'inexplicably': 1,
#   'incessantly': 1,
#   'similarly': 1,
#   'disturbingly': 1,
#   'emphatically': 1,
#   'improperly': 1,
#   'successfully': 1,
#   'interestingly': 1,
#   'only': 1,
#   'tantalizingly': 1,
#   'mindedly': 1,
#   'sweetly': 1,
#   'simultaneously': 1},
#  'communicate': {'effectively': 3,
#   'directly': 3,
#   'freely': 1,
#   'really': 1,
#   'verbally': 1,
#   'apparently': 1,
#   'loudly': 1,
#   'hopefully': 1,
#   'daily': 1,
#   'actually': 1,
#   'regularly': 1,
#   'quickly': 1,
#   'profoundly': 1,
#   'poorly': 1,
#   'finally': 1,
#   'privately': 1},
#  'verbalize': {},
#  'mouth': {'especially': 1, 'robotically': 1, 'merely': 1}}

# %%
for verb, adverbs in sorted_dict.items():
    print(verb, list(adverbs.items())[:10], '\n')
# Out:
# state [('publicly', 22), ('clearly', 19), ('explicitly', 13), ('unequivocally', 12), ('bluntly', 7), ('simply', 7), ('flatly', 7), ('previously', 6), ('recently', 6), ('only', 5)]
#
# utter [('actually', 2), ('really', 1), ('casually', 1), ('pejoratively', 1), ('only', 1)]
#
# tell [('recently', 25), ('reportedly', 14), ('privately', 12), ('only', 9), ('basically', 9), ('finally', 9), ('repeatedly', 8), ('actually', 8), ('really', 8), ('specifically', 8)]
#
# speak [('directly', 33), ('publicly', 15), ('fiercely', 12), ('only', 11), ('briefly', 9), ('generally', 9), ('recently', 8), ('openly', 8), ('politically', 7), ('loudly', 7)]
#
# pass_on []
#
# put_across []
#
# pass [('quickly', 13), ('unanimously', 11), ('only', 9), ('probably', 8), ('recently', 5), ('overwhelmingly', 5), ('easily', 4), ('narrowly', 4), ('eventually', 4), ('apparently', 3)]
#
# say [('actually', 76), ('recently', 73), ('repeatedly', 55), ('simply', 46), ('explicitly', 39), ('publicly', 36), ('basically', 34), ('really', 31), ('only', 25), ('previously', 22)]
#
# talk [('directly', 14), ('only', 12), ('really', 11), ('openly', 7), ('actually', 7), ('publicly', 6), ('repeatedly', 6), ('specifically', 6), ('personally', 5), ('clearly', 5)]
#
# pass_along []
#
# verbalise []
#
# claim [('falsely', 81), ('previously', 9), ('repeatedly', 8), ('recently', 4), ('initially', 3), ('actually', 3), ('absurdly', 3), ('credibly', 3), ('incorrectly', 3), ('publicly', 3)]
#
# communicate [('effectively', 3), ('directly', 3), ('freely', 1), ('really', 1), ('verbally', 1), ('apparently', 1), ('loudly', 1), ('hopefully', 1), ('daily', 1), ('actually', 1)]
#
# verbalize []
#
# mouth [('especially', 1), ('robotically', 1), ('merely', 1)]

# %% [markdown]
# ## Про Тигроловів

# %%
with open('/home/yevhen/prj/prj-nlp-2020/tasks/02-structural-linguistics/data/tyhrolovy.txt', 'r') as f:
    tigers = f.read().splitlines()
    tigers = [item for ]

# %%
import stanza #former StanfordNLP

# %%
stanza.download('uk')
# Out:
# Downloading https://raw.githubusercontent.com/stanfordnlp/stanza-resources/master/resources_1.0.0.json: 116kB [00:00, 3.79MB/s]
# 2020-03-21 00:59:36 INFO: Downloading default packages for language: uk (Ukrainian)...
# Downloading http://nlp.stanford.edu/software/stanza/1.0.0/uk/default.zip: 100%|██████████| 239M/239M [01:52<00:00, 2.13MB/s]
# 2020-03-21 01:01:34 INFO: Finished downloading models and saved to /home/yevhen/stanza_resources.

# %%
stanza_nlp = stanza.Pipeline('uk')
# Out:
# 2020-03-21 01:02:45 INFO: Loading these models for language: uk (Ukrainian):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | iu      |
# | mwt       | iu      |
# | pos       | iu      |
# | lemma     | iu      |
# | depparse  | iu      |
# =======================
#
# 2020-03-21 01:02:45 INFO: Use device: cpu
# 2020-03-21 01:02:45 INFO: Loading: tokenize
# 2020-03-21 01:02:45 INFO: Loading: mwt
# 2020-03-21 01:02:45 INFO: Loading: pos
# 2020-03-21 01:02:46 INFO: Loading: lemma
# 2020-03-21 01:02:46 INFO: Loading: depparse
# 2020-03-21 01:02:47 INFO: Done loading processors!

# %%
def get_anim_amod(doc, stats_dict):
    for sent in doc.sentences:
        for word in sent.words:
            if word.upos == 'ADJ' and word.deprel in ('conj', 'amod'):
                if word.deprel == 'conj':
                    head_noun_index = sent.words[word.head-1].head
                elif word.deprel == 'amod': 
                    head_noun_index = word.head
                parent_word = sent.words[head_noun_index-1]
                if parent_word.upos == 'NOUN' and 'Animacy=Anim' in parent_word.feats:
                    phrase = ' '.join([word.lemma,parent_word.lemma])
                    current_num = stats_dict.get(phrase, 0)
                    stats_dict[phrase] = current_num + 1
    return stats_dict

# %%
tigers_stats_dict = {}
for tiger in tqdm(tigers2):
    doc = stanza_nlp(tiger)
    stats_on_all_tigers = get_anim_amod(doc, tigers_stats_dict)
# Out:
# HBox(children=(FloatProgress(value=0.0, max=2665.0), HTML(value='')))

# %%
stats_on_all_tigers
# Out:
# {'вогненноокий хробак': 1,
#  'пекельний потвора': 1,
#  'фіктивний потвора': 1,
#  'наївний казок': 1,
#  'китайський казок': 1,
#  'легендарний дракон': 1,
#  'справжній дракон': 1,
#  'найбільший дракон': 1,
#  'найстрашніший дракон': 1,
#  'велетенський циклоп': 1,
#  'двоокий циклоп': 1,
#  'живий мертвяк': 1,
#  'приречений безнадійний': 1,
#  'змордований безнадійний': 1,
#  'великий начальник': 5,
#  'рідний товариш': 1,
#  'обірваний людина': 1,
#  'брудний людина': 1,
#  'зарослий людина': 1,
#  'випадковий людина': 1,
#  'змарнований людина': 1,
#  'знеосіблений людина': 1,
#  'гордий сокола': 1,
#  'відомий нащадка': 1,
#  'гордий нащадка': 1,
#  'перший каторжанина': 1,
#  'страшний злочинця': 1,
#  'державний злочинця': 1,
#  'русявий Юнак': 1,
#  'екзальтований пасажир': 1,
#  'безперервний мандрівка': 1,
#  'десятиденний мандрівка': 1,
#  'різнокольоровий абажур': 1,
#  'експансивний мешканець': 1,
#  'горластий мешканець': 1,
#  'колгоспний колективізатор': 1,
#  'радгоспний бюрократ': 1,
#  'індустріальний авантюрник': 1,
#  'потенціальний злодій': 1,
#  'імпотентний фариса': 1,
#  'експансивний відкриватель': 1,
#  'вибагливий абажур': 1,
#  'хоробрий шукач': 1,
#  'смугастий кішечко': 1,
#  'четвертий коханець': 1,
#  'похідний коханець': 1,
#  'сп’янілий шукач': 1,
#  'дурний кішка': 1,
#  'могутній талісман': 1,
#  'старий кавалер': 1,
#  'прекрасноокий панянок': 1,
#  'старий кооператор': 1,
#  'гемороїдальний кооператор': 1,
#  'гімалайський ведмідь': 1,
#  'шляхетний олень': 1,
#  'сніжний горал': 1,
#  'тендітний єнота': 1,
#  'екзальтований конкістадор': 1,
#  'станційний диспетчер': 1,
#  'священний риба': 1,
#  'здезорієнтований пасажир': 1,
#  'екзотичний тубілець': 1,
#  'червоношкірий бурят': 1,
#  'гордий тубілець': 1,
#  'засмалений якуть': 1,
#  'бронзовий якуть': 1,
#  'подібний якуть': 1,
#  'джеклондонівський індієць': 1,
#  'бронзовий індієць': 1,
#  'гостровухий пес': 2,
#  'перший каторжник': 2,
#  'найперший каторжник': 1,
#  'найперший засланець': 1,
#  'політичний засланець': 1,
#  'навіжений протопоп': 1,
#  'малоросійський гетьман': 1,
#  'більший каторжник': 1,
#  'менший каторжник': 1,
#  'відомий каторжник': 1,
#  'безіменний каторжник': 1,
#  'національний герой': 1,
#  'справжній професор': 1,
#  'перший піонер': 1,
#  'химерний гетьман': 1,
#  'підходящий гетьман': 1,
#  'каторжанський патріарха': 1,
#  'каторжанський патріар': 1,
#  'списаний людина': 1,
#  'розполоханий голуб': 1,
#  'бравий майор': 1,
#  'чорнобривий майор': 1,
#  'виголошений вождя': 1,
#  'таємничий міна': 1,
#  'придуркуватий дерс': 1,
#  'молодий людина': 1,
#  'кваліфікований інженер': 1,
#  'засмалений гуляйпілець': 1,
#  'розгублений кельнер': 1,
#  'гарячий професор': 1,
#  'веселий професор': 1,
#  'владивостоцький турок': 2,
#  'правовірний безвірник': 1,
#  'переляканий кельнер': 1,
#  'обірваний пас': 1,
#  'зоологічний націоналіст': 1,
#  'окатий змія': 1,
#  'гримучий змія': 1,
#  'екзальтований шукач': 1,
#  'нетерплячий пасажир': 1,
#  'листатий гігант': 1,
#  'маленький звірок': 1,
#  'смугастий звірок': 3,
#  'учений дослідник': 1,
#  'дивний бог': 2,
#  'сонячний зайчик': 4,
#  'занепокоєний бурундук': 1,
#  'волохатий ведмідь': 1,
#  'туй рись': 2,
#  'двоногий істота': 1,
#  'молодий олень': 2,
#  'гордий олень': 1,
#  'страшний привид': 1,
#  'пережитий привид': 1,
#  'страшніший привид': 1,
#  'цькований звір': 1,
#  'страхітний звір': 1,
#  'живий істота': 1,
#  'хижий звірка': 1,
#  'запалений звірка': 1,
#  'дебелоговий сука': 1,
#  'замашний сука': 1,
#  'двоногий розбійник': 1,
#  'противний піт': 1,
#  'білий дідусь': 1,
#  'різний мошкар': 1,
#  'змучений мандрівник': 2,
#  'молодий юнак': 1,
#  'далекий чужинець': 1,
#  'тутешній бог': 1,
#  'волохатий бог': 1,
#  'лютий бог': 1,
#  'скупий бог': 1,
#  'ненажерливий бог': 1,
#  'величезний ведмідь': 1,
#  'чорний ведмідь': 1,
#  'безжалісний бог': 1,
#  'грізний бог': 1,
#  'новий ворог': 1,
#  'тай людина': 1,
#  'великий дух': 1,
#  'давній запорожець': 1,
#  'сідланий кінь': 2,
#  'гейбий привид': 1,
#  'спросонній глухар': 1,
#  'нечутій сова': 1,
#  'рудий пес': 1,
#  'партійний пес': 1,
#  'чужий дівчина': 1,
#  'бистроокий дівчина': 2,
#  'густобровий парубок': 1,
#  'кремезний парубок': 1,
#  'припертий ведмідь': 1,
#  'лук’янівський в’язниця': 1,
#  'рідний людина': 2,
#  'близький людина': 2,
#  'тай риба': 1,
#  'білий риба': 1,
#  'чудний риба': 1,
#  'малий ласун': 1,
#  'чесний людина': 1,
#  'чорний сатан': 1,
#  'здоровенний сатан': 1,
#  'дурний маля': 1,
#  'оточений чоловік': 1,
#  'здоровенний собака': 1,
#  'гостровухий собака': 1,
#  'мисливський собака': 1,
#  'уссурійський козак': 2,
#  'козацький осавула': 1,
#  'амурський козак': 1,
#  'здоровенний тигр': 1,
#  'старий мисливець': 1,
#  'різний козак': 1,
#  'другий ведмідь': 1,
#  'звичайний фотограф': 1,
#  'відомий фотограф': 1,
#  'домашній кішка': 1,
#  'незвичайний людина': 1,
#  'дикий кінь': 1,
#  'сонячний комаха': 1,
#  'критий наличник': 1,
#  'вправний спортсмен': 1,
#  'дикий коза': 4,
#  'дурний мати': 1,
#  'полтавський жінка': 1,
#  'хороший дитина': 1,
#  'новий дитина': 1,
#  'новий переселенець': 1,
#  'простий людина': 1,
#  'вражий дівчина': 1,
#  'подурілий собака': 1,
#  'якутський пес': 3,
#  'нав’ючений кінь': 3,
#  'вусатий дідуган': 1,
#  'дебелий дідуган': 1,
#  'високий дідуган': 1,
#  'червоновидий дідуган': 1,
#  'передній кінь': 1,
#  'високий красня': 1,
#  'дебелий красня': 1,
#  'буйний чуб': 1,
#  'однаковий зріст': 2,
#  'найбільший генерал': 1,
#  'старий ветеран': 1,
#  'знаменитий мисливець': 2,
#  'вражий мама': 3,
#  'досвідчений вояк': 1,
#  'боєвий патрон': 1,
#  'бідний дитино': 1,
#  'очікуючій людина': 1,
#  'намальований олени': 1,
#  'старий бубон': 1,
#  'знающий стрілець': 1,
#  'різний коник': 1,
#  'стрілецький коник': 1,
#  'добрий кінь': 1,
#  'сірий кінь': 1,
#  'буланий кінь': 1,
#  'вороний кінь': 1,
#  'гнідий кінь': 1,
#  'здоровенний пес': 1,
#  'звіровий пес': 1,
#  'невидний мати': 1,
#  'мрійноголосий пташка': 1,
#  'тутешній солове': 1,
#  'рудий нерпа': 1,
#  'звіровий собака': 2,
#  'страшний якут': 1,
#  'широкогрудий якут': 1,
#  'буйний ріс': 1,
#  'геніальний маляр': 1,
#  'плямистий оленя': 2,
#  'плямистий олень': 1,
#  'ізюбри самець': 1,
#  'хитрий звір': 1,
#  'єдиний друг': 1,
#  'менший пташка': 1,
#  'летючий сестра': 1,
#  'середній сестра': 1,
#  'високий тварина': 1,
#  'граційний тварина': 1,
#  'химерний тварина': 1,
#  'обережній збіс': 1,
#  'чуйний збіс': 1,
#  'подібний комаха': 1,
#  'дикий тварина': 1,
#  'бідолашний тварина': 1,
#  'живий тварина': 1,
#  'степовий куріпка': 1,
#  'перший рябок': 1,
#  'змучений людина': 1,
#  'ставний дівчина': 1,
#  'білявий дівчина': 1,
#  'цибатий чолов’я': 1,
#  'чорновусий чолов’я': 1,
#  'молодий чолов’я': 1,
#  'замурзаний дівчина': 1,
#  'гостроязикий дівчина': 1,
#  'хрещений батько': 1,
#  'розмальований дівчина': 2,
#  'потомий дівчина': 1,
#  'спритний дівчина': 1,
#  'цибатий зять': 5,
#  'мовчазний зять': 1,
#  'старий друг': 2,
#  'старий приятель': 1,
#  'тай мадонна': 1,
#  'дикий нетрище': 1,
#  'старий мороз': 1,
#  'чорнявий мати': 1,
#  'збайдужілий людина': 1,
#  'втомлений людина': 1,
#  'цибатий співбесідник': 1,
#  'старий мороза': 2,
#  'добрий пес': 1,
#  'гостровухий вовчура': 1,
#  'страшний вовчура': 1,
#  'безжалісний стрілець': 1,
#  'веселий звіролова': 1,
#  'безпощадний звіролова': 1,
#  'мускулястий диктатор': 1,
#  'гордий завойовник': 1,
#  'рідний син': 1,
#  'виснажений арештант': 1,
#  'напівголий людина': 1,
#  'напівбосий людина': 1,
#  'чесний трудар': 1,
#  'полтавський трудар': 1,
#  'катеринославський трудар': 1,
#  'херсонський куркул': 1,
#  'державний злодій': 1,
#  'суджений злодій': 1,
#  'бородатий дід': 1,
#  'бородатий юнак': 1,
#  'здичавілий собака': 1,
#  'закинений нащадок': 1,
#  'останній гадюча': 1,
#  'клятий гнус': 1,
#  'великий пан': 3,
#  'григорієвий куреник': 1,
#  'замріяний дівчина': 1,
#  'хвостатий звірок': 1,
#  'добрий кішка': 1,
#  'задоволений собака': 1,
#  'непроханий сторожа': 1,
#  'справжній господа': 1,
#  'здоровенний звірюка': 1,
#  'нерухомий жертва': 1,
#  'лихий личина': 1,
#  'нормальний дівоче': 1,
#  'строгий дівоче': 1,
#  'воднораз дівоче': 1,
#  'ніжний дівоче': 1,
#  'рудуватий тварина': 1,
#  'великий тварина': 2,
#  'прегарний тварина': 1,
#  'молодший самець': 1,
#  'старий дід': 1,
#  'збісий хитро': 1,
#  'здоровенний тайменя': 1,
#  'дивовижний дівчина': 1,
#  'химерний дівчина': 3,
#  'здоровенний таймень': 1,
#  'сміхотливий зайчик': 1,
#  'надзвичайний зайчик': 1,
#  'чотиримоторовий велетень': 1,
#  'невиданий птиць': 1,
#  'несподіваний гість': 1,
#  'добрий друг': 1,
#  'перший мисливець': 1,
#  'добрий гість': 1,
#  'больший начальник': 1,
#  'шибкий начальник': 1,
#  'сердитий начальник': 1,
#  'придуркуватий начальник': 1,
#  'наївний чоловічок': 1,
#  'лісовий чоловічок': 1,
#  'золотий чоловік': 1,
#  'гарний дочка': 1,
#  'вражий дочка': 1,
#  'тай красуня': 1,
#  'найперший красуня': 1,
#  'бідолашний чоловік': 1,
#  'мальований краль': 1,
#  'лихий ворог': 1,
#  'лагідний тенор': 1,
#  'дивний красуня': 1,
#  'вродливий дівчина': 1,
#  'лісовий дівчина': 1,
#  'дурний шматок': 1,
#  'всесвітній залицяльник': 1,
#  'смішний горностай': 1,
#  'бурий горностай': 1,
#  'гарний дівчина': 1,
#  'малий дитя': 2,
#  'межий гілляч': 1,
#  'лісовий мавка': 1,
#  'співучий пташок': 1,
#  'останній хлопець': 1,
#  'рудий дядько': 1,
#  'вусатий дядько': 1,
#  'турецький султан': 1,
#  'путній людина': 1,
#  'привітний людина': 1,
#  'літній жінка': 1,
#  'привітний жінка': 1,
#  'веселий жінка': 1,
#  'низенький судаков': 1,
#  'здоровенний амурець': 1,
#  'щирий приятель': 1,
#  'добрий людина': 2,
#  'здивований пес': 1,
#  'межий людина': 1,
#  'японський качка': 1,
#  'дивний качка': 1,
#  'дрібний звір': 1,
#  'цінний звір': 1,
#  'хутряний звір': 2,
#  'могутній бог': 2,
#  'мрійноокий самиця': 1,
#  'вогненнозорий коханець': 1,
#  'граційний самиця': 1,
#  'шалений переможець': 1,
#  'страшний гадюка': 1,
#  'отруйний гадюка': 1,
#  'розпалений бик': 1,
#  'стихійний інстинкт': 1,
#  'сліпий інстинкт': 1,
#  'розпалений лицар': 1,
#  'рогатий лицар': 1,
#  'другий бик': 1,
#  'розпалений самце': 1,
#  'красений демон': 1,
#  'гордий демон': 1,
#  'гордий тварина': 3,
#  'зацькований тварина': 1,
#  'поранений тварина': 1,
#  'ударений тварина': 1,
#  'ходовий вивірка': 2,
#  'здобуваючій мисливець': 1,
#  'тай кішка': 1,
#  'вражий кішка': 1,
#  'тріскотнявий шелест': 1,
#  'підозрілий шелест': 1,
#  'великий вепра': 1,
#  'вепрячий отаман': 1,
#  'страшний потвора': 1,
#  'вимучений дівчина': 1,
#  'сонний дитина': 1,
#  'гордий дівчина': 1,
#  'чистий дівчина': 1,
#  'виряджений віршовник': 1,
#  'ясненький зірка': 1,
#  'гарний зірка': 1,
#  'кругленький зірка': 1,
#  'чудній янгола': 1,
#  'лепський янгола': 1,
#  'старенький іцько': 1,
#  'маленький дитина': 1,
#  'диявольський гайдамак': 1,
#  'вправний майстер': 1,
#  'наснажений майстер': 1,
#  'молодий королевич': 1,
#  'російський імператор': 1,
#  'пишнобарвний півень': 1,
#  'пишноперий півень': 1,
#  'збитий півень': 1,
#  'сірковий мандз': 1,
#  'знайомий мандз': 1,
#  'бажаний гість': 1,
#  'далекий азіат': 1,
#  'дикий азіат': 1,
#  'різний відрядженець': 1,
#  'відповідальний відрядженець': 1,
#  'примусовий ентузіаст': 1,
#  'добровільний ентузіаст': 1,
#  'слізний материна': 1,
#  'розпучливий ластівочка': 1,
#  'сучий син': 1,
#  'відповідальний представник': 1,
#  'вбраний представник': 1,
#  'великий особа': 1,
#  'відповідальний особа': 1,
#  'вимучений людина': 2,
#  'невиспаний людина': 1,
#  'смішний походенька': 1,
#  'печальний походенька': 1,
#  "п'ятдесятиступневий мороз": 1,
#  'рогатий олені': 1,
#  'миршавий олені': 1,
#  'миршавий пес': 1,
#  'вбраний гольдячка': 1,
#  'низенький гольдячка': 1,
#  'змінний старожилець': 1,
#  'творчий геній': 1,
#  'екзотичний олені': 1,
#  'старший панна': 1,
#  'чудний хабаровка': 1,
#  'балакучий дівчина': 1,
#  'різний людина': 1,
#  'елегантний пані': 1,
#  'елегантніший дівчина': 1,
#  'опанований дівчина': 1,
#  'хоробрий дівчина': 1,
#  'скажений пес': 1,
#  'добрий приятель': 1,
#  'низенький хлопець': 1,
#  'енергійний хлопець': 1,
#  'гостроносий хлопець': 1,
#  'закоханий хлопець': 1,
#  'різний звіря': 1,
#  'енергійний охотінспектор': 1,
#  'прекрасний хлопець': 1,
#  'катерининський дама': 1,
#  'примітивний хлопчина': 1,
#  'простолінійний хлопчина': 1,
#  'дикий горал': 1,
#  'гордий горал': 1,
#  'свободолюбивий горал': 1,
#  'справжній мисливець': 1,
#  'хижий звір': 1,
#  'знаменитий охотник': 1,
#  'чортовий син': 1,
#  'чортовий віслюк': 1,
#  'основний мешканець': 1,
#  'косоокий японець': 1,
#  'вражий син': 1,
#  'дохлий кішка': 1,
#  'запопадливий збігець': 1,
#  'розцяцькований начальник': 1,
#  'більший начальник': 1,
#  'оспіваний нетрів': 1,
#  'невідомий нетрів': 1,
#  'уссурійський нетрів': 1,
#  'голоспинний баб': 1,
#  'голий лікоть': 1,
#  'спантеличений клієнт': 1,
#  'сухозадий кавалер': 1,
#  'роздрочений вепр': 1,
#  'смішний городянин': 1,
#  'напівоголений дівчина': 1,
#  'небачений дівчина': 1,
#  'напівголий дівчина': 1,
#  'згальванізований імпотент': 1,
#  'кралий командир': 1,
#  'личкований командир': 1,
#  'претензійний суб’єкт': 1,
#  'заслинений панна': 1,
#  'заялозений панна': 1,
#  'селянський дівчина': 1,
#  'розкуркулений батьки': 1,
#  'розкиданий батьки': 1,
#  'дебелий хлопець': 1,
#  'суворий контролер': 2,
#  'мальований панянок': 1,
#  'пришелепкуватий городянин': 1,
#  'старий сірно': 1,
#  'добрий хлопець': 1,
#  'дебелий лосина': 1,
#  'кований кінь': 1,
#  'добрий жовтяк': 1,
#  'чистий красуня': 1,
#  'колишній ката': 1,
#  'злий дух': 1,
#  'тайговий хлопець': 1,
#  'молодий хлопець': 1,
#  'повний господар': 1,
#  'малий дитина': 1,
#  'старенький дідусик': 1,
#  'зморщений дідусик': 1,
#  'безбородий дідусик': 1,
#  'дурніший зріст': 1,
#  'зрадливий твар': 1,
#  'старий мати': 1,
#  'кінський дух': 1,
#  'пишний соболь': 1,
#  'велетенський кішка': 1,
#  'спущений рушай': 1,
#  'велетенський потвір': 1,
#  'розумний пес': 1,
#  'нерухомий кішка': 1,
#  'великий хижак': 1,
#  'забитий кішка': 1,
#  'здоровенний самиця': 1,
#  'старий тигра': 1,
#  'уссурійський тигра': 1,
#  'убитий тигра': 1,
#  'битий кішка': 1,
#  'зв’язаний кішка': 1,
#  'оцей кішка': 1,
#  'старий дідуган': 1,
#  'живий кішка': 1,
#  'мертвий тигра': 1,
#  'живий тигра': 2,
#  'бравий герой': 1,
#  'грізний судде': 1,
#  'душий людець': 1,
#  'плюгавий злодюжка': 1,
#  'бідолашний кінь': 1,
#  'великий собака': 1,
#  'скажений собака': 1,
#  'білий голуб': 1,
#  'гірський бог': 1,
#  'рідний мати': 1,
#  'пійманий кішка': 1,
#  'живучий тварина': 1,
#  'нещасливий соколе': 1,
#  'старий ну-на': 1,
#  'бідолашний дівчина': 1,
#  'вражений батьки': 1,
#  'великий пес': 3,
#  'колишній козача': 1,
#  'перетворений козача': 1,
#  'давній мешканець': 1,
#  'бердичівський патріот': 1,
#  'тульський патріот': 1,
#  'орловський патріот': 1,
#  'товстий бревняк': 1,
#  'пристібаючий любка': 1,
#  'японський прикордонник': 1,
#  'поставлений прикордонник': 1,
#  'вилий пес': 1,
#  'дикий тія': 1,
#  'дикий козуля': 1,
#  'милий друг': 1,
#  'вірний друг': 2,
#  'одинокий пес': 1,
#  'вірний пес': 3,
#  'чотириногий товариш': 1,
#  'великий БАНДА': 1,
#  'озброєний БАНДА': 1,
#  'крупний злочинець': 1,
#  'державний злочинець': 1,
#  'славний чекіст': 1,
#  'доблесний чекіст': 1,
#  'страхітливий отамана': 1,
#  'героїчний начальник': 1,
#  'гігантський пес': 1,
#  'великий банда': 2,
#  'старий вовк': 1,
#  'гігантскій пес': 1,
#  'дурний начальник': 1,
#  'сірковий донька': 1,
#  'головний винуватець': 1,
#  'озброєний банда': 1,
#  'туй депеша': 1,
#  'старенький мати': 1,
#  'божий мати': 1,
#  'веселий господиня': 1,
#  'вірний товаришка': 1,
#  'одчайдушний пес': 1}

# %%
stats_on_all_tigers['сонячний зайчик']
# Out:
# 4

# %%
the_most_value = 0
the_most_key = ""
for key, value in stats_on_all_tigers.items():
    if value > the_most_value:
        the_most_key, the_most_value =key, value
print(the_most_key, the_most_value)
# Out:
# великий начальник 5
