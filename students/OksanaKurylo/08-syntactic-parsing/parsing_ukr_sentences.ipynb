# %%
from collections import OrderedDict
from conllu import parse
from enum import Enum
import stanza
import os

# %%
stanza_nlp = stanza.Pipeline(lang='uk')
# Out:
# 2020-05-03 18:20:54 INFO: Loading these models for language: uk (Ukrainian):
# =======================
# | Processor | Package |
# -----------------------
# | tokenize  | iu      |
# | mwt       | iu      |
# | pos       | iu      |
# | lemma     | iu      |
# | depparse  | iu      |
# =======================
#
# 2020-05-03 18:20:54 INFO: Use device: cpu
# 2020-05-03 18:20:54 INFO: Loading: tokenize
# 2020-05-03 18:20:54 INFO: Loading: mwt
# 2020-05-03 18:20:54 INFO: Loading: pos
# 2020-05-03 18:20:56 INFO: Loading: lemma
# 2020-05-03 18:20:56 INFO: Loading: depparse
# 2020-05-03 18:20:57 INFO: Done loading processors!

# %%
script_path = os.path.abspath('__file__') 
path_list = script_path.split(os.sep)
script_directory = path_list[0:len(path_list)-5]
rel_path = "UD_Ukrainian-IU"
PATH = "/".join(script_directory[:4]) + "/" + rel_path
 
with open(PATH + "/uk_iu-ud-train.conllu", "r") as f:
    train_trees = parse(f.read())

with open(PATH + "/uk_iu-ud-dev.conllu", "r") as f:
    test_trees = parse(f.read())

# %%
corpus = ["Цінова лихоманка у царині енергоресурсів засвідчує, що світова економіка переживає не найкращі часи.", 
          "Проте усвідомлення цього факту не завадило верховному представнику ЄС у закордонних справах та політиці безпеки Жозепу Боррелю під час спілкування з Дмитром Кулебою наголосити на зацікавленості Європейського Союзу у співпраці з Україною та готовності здійснити відкладений візит до України тільки-но для цього з’явиться можливість.",
          "Нагадаю, що пан Боррель мав намір відвідати Донбас, що протягом останніх років стало ледь не обов’язковою частиною для перебування в Україні поважних іноземних гостей.",
          "Міністри закордонних справ країн ЄС також продемонстрували готовність до розвитку співпраці з Україною, а Європейська Комісія оголосила про готовність виділити для України 1,2 мільярди для боротьби з наслідками коронавірусу.",  
          "Російська Федерація також демонструє активність щодо України, проте дещо іншого порядку.", 
          "У Москві свідомо ігнорують очевидне: словосполучення «російський гуманітарний конвой» з 2014 року стало синонімом незаконного втручання та підтримки бойовиків."]

# %%
def transform_sent(sentence):
    transformed_tree = []
    doc = stanza_nlp(sentence)
    for sent in doc.sentences:
        for word in sent.words:
            transformed_tree.append(OrderedDict([('id', int(word.id)), ('form',  word.text), ('lemma',word.lemma),
                                     ('upostag', word.upos), ('xpostag', None),
                                     ('feats', word.feats), ('head', int(word.head)), ('deprel', None),
                                     ('deps', None), ('misc', None)]))
    return transformed_tree

# %%
class Actions(str, Enum):
    SHIFT = "shift"
    REDUCE = "reduce"
    RIGHT = "right"
    LEFT = "left"
    
def oracle(stack, top_queue, relations):
    """
    Make a decision on the right action to do.
    """
    top_stack = stack[-1]
    # check if both stack and queue are non-empty
    if top_stack and not top_queue:
        return Actions.REDUCE
    # check if there are any clear dependencies
    elif top_queue["head"] == top_stack["id"]:
        return Actions.RIGHT
    elif top_stack["head"] == top_queue["id"]:
        return Actions.LEFT
    # check if we can reduce the top of the stack
    elif top_stack["id"] in [i[0] for i in relations] and \
         (top_queue["head"] < top_stack["id"] or \
          [s for s in stack if s["head"] == top_queue["id"]]):
        return Actions.REDUCE
    # default option
    else:
        return Actions.SHIFT

# %%
def extract_features(stack, queue):
    features = dict()

    if len(stack) > 0:
        stack_top = stack[-1]
        features["s0-word"] = stack_top["form"]
        features["s0-lemma"] = stack_top["lemma"]
        features["s0-tag"] = stack_top["upostag"]
         # фічі для ост-го слова в стеці
        if stack_top["feats"] != None:
            features["s0-feats"] = str(stack_top["feats"])
        else:
            features["s0-feats"] = False
    if len(stack) > 1:
        features["s1-tag"] = stack[-2]["upostag"]
        if stack[-2]["feats"] != None:
            features["s1-feats"] = str(stack[-2]["feats"])
        else:
            features["s1-feats"] = False
    if queue:
        queue_top = queue[0]
        features["q0-word"] = queue_top["form"]
        features["q0-lemma"] = queue_top["lemma"]
        features["q0-tag"] = queue_top["upostag"]
        # фічі для 1-го слова в черзі
        if queue_top["feats"] != None:
            features["q0-feats"] = str(queue_top["feats"])
        else:
            features["q0-feats"] = False
    if len(queue) > 1:
        queue_next = queue[1]
        features["q1-word"] = queue_next["form"]
        features["q1-tag"] = queue_next["upostag"]
        # фічі для 2-го слова в черзі
        if queue_next["feats"] != None:
            features["q1-feats"] = str(queue_next["feats"])
        else:
            features["q1-feats"] = False
    if len(queue) > 2:
        features["q2-tag"] = queue[2]["upostag"]
    if len(queue) > 3:
        features["q3-tag"] = queue[3]["upostag"]
    return features

# %%
ROOT = OrderedDict([('id', 0), ('form', 'ROOT'), ('lemma', 'ROOT'), ('upostag', 'ROOT'),
                    ('xpostag', None), ('feats', None), ('head', None), ('deprel', None),
                    ('deps', None), ('misc', None)])

# %%
def get_data(tree):
    features, labels = [], []
    stack, queue, relations = [ROOT], tree[:], []
    
    while queue or stack:
        action = oracle(stack if len(stack) > 0 else None,
                       queue[0] if len(queue) > 0 else None,
                       relations)
        features.append(extract_features(stack, queue))
        labels.append(action.value)
        if action == Actions.SHIFT:
            stack.append(queue.pop(0))
        elif action == Actions.REDUCE:
            stack.pop()
        elif action == Actions.LEFT:
            relations.append((stack[-1]["id"], queue[0]["id"]))
            stack.pop()
        elif action == Actions.RIGHT:
            relations.append((queue[0]["id"], stack[-1]["id"]))
            stack.append(queue.pop(0))
        else:
            print("Unknown action.")
    return features, labels

# %%
for sentence in corpus:
    tree = transform_sent(sentence)
    tree_features, tree_labels = get_data([t for t in tree if type(t["id"])==int])

    print("Number of words:", len(tree))
    print("Number of actions:", len(tree_labels))
    print("List of actions taken:", tree_labels)
    print("Features:")
    for word in tree_features:
        print(word) 
    print("---------------------------------------")
# Out:
# Number of words: 15
# Number of actions: 31
# List of actions taken: ['shift', 'left', 'shift', 'shift', 'left', 'right', 'right', 'reduce', 'reduce', 'left', 'right', 'shift', 'shift', 'shift', 'left', 'shift', 'left', 'left', 'left', 'right', 'shift', 'left', 'shift', 'left', 'right', 'reduce', 'reduce', 'right', 'reduce', 'reduce', 'reduce']
# Features:
# {'s0-word': 'ROOT', 's0-lemma': 'ROOT', 's0-tag': 'ROOT', 's0-feats': False, 'q0-word': 'Цінова', 'q0-lemma': 'ціновий', 'q0-tag': 'ADJ', 'q0-feats': 'Case=Nom|Gender=Fem|Number=Sing', 'q1-word': 'лихоманка', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q2-tag': 'ADP', 'q3-tag': 'NOUN'}
# {'s0-word': 'Цінова', 's0-lemma': 'ціновий', 's0-tag': 'ADJ', 's0-feats': 'Case=Nom|Gender=Fem|Number=Sing', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': 'лихоманка', 'q0-lemma': 'лихоманка', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q1-word': 'у', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'ROOT', 's0-lemma': 'ROOT', 's0-tag': 'ROOT', 's0-feats': False, 'q0-word': 'лихоманка', 'q0-lemma': 'лихоманка', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q1-word': 'у', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'лихоманка', 's0-lemma': 'лихоманка', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': 'у', 'q0-lemma': 'у', 'q0-tag': 'ADP', 'q0-feats': 'Case=Loc', 'q1-word': 'царині', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'VERB'}
# {'s0-word': 'у', 's0-lemma': 'у', 's0-tag': 'ADP', 's0-feats': 'Case=Loc', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q0-word': 'царині', 'q0-lemma': 'царина', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q1-word': 'енергоресурсів', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur', 'q2-tag': 'VERB', 'q3-tag': 'PUNCT'}
# {'s0-word': 'лихоманка', 's0-lemma': 'лихоманка', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': 'царині', 'q0-lemma': 'царина', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q1-word': 'енергоресурсів', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur', 'q2-tag': 'VERB', 'q3-tag': 'PUNCT'}
# {'s0-word': 'царині', 's0-lemma': 'царина', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q0-word': 'енергоресурсів', 'q0-lemma': 'енергоресурс', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur', 'q1-word': 'засвідчує', 'q1-tag': 'VERB', 'q1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q2-tag': 'PUNCT', 'q3-tag': 'SCONJ'}
# {'s0-word': 'енергоресурсів', 's0-lemma': 'енергоресурс', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Plur', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q0-word': 'засвідчує', 'q0-lemma': 'засвідчувати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q1-word': ',', 'q1-tag': 'PUNCT', 'q1-feats': False, 'q2-tag': 'SCONJ', 'q3-tag': 'ADJ'}
# {'s0-word': 'царині', 's0-lemma': 'царина', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q0-word': 'засвідчує', 'q0-lemma': 'засвідчувати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q1-word': ',', 'q1-tag': 'PUNCT', 'q1-feats': False, 'q2-tag': 'SCONJ', 'q3-tag': 'ADJ'}
# {'s0-word': 'лихоманка', 's0-lemma': 'лихоманка', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': 'засвідчує', 'q0-lemma': 'засвідчувати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q1-word': ',', 'q1-tag': 'PUNCT', 'q1-feats': False, 'q2-tag': 'SCONJ', 'q3-tag': 'ADJ'}
# {'s0-word': 'ROOT', 's0-lemma': 'ROOT', 's0-tag': 'ROOT', 's0-feats': False, 'q0-word': 'засвідчує', 'q0-lemma': 'засвідчувати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q1-word': ',', 'q1-tag': 'PUNCT', 'q1-feats': False, 'q2-tag': 'SCONJ', 'q3-tag': 'ADJ'}
# {'s0-word': 'засвідчує', 's0-lemma': 'засвідчувати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': ',', 'q0-lemma': ',', 'q0-tag': 'PUNCT', 'q0-feats': False, 'q1-word': 'що', 'q1-tag': 'SCONJ', 'q1-feats': False, 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': ',', 's0-lemma': ',', 's0-tag': 'PUNCT', 's0-feats': False, 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': 'що', 'q0-lemma': 'що', 'q0-tag': 'SCONJ', 'q0-feats': False, 'q1-word': 'світова', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Nom|Gender=Fem|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'VERB'}
# {'s0-word': 'що', 's0-lemma': 'що', 's0-tag': 'SCONJ', 's0-feats': False, 's1-tag': 'PUNCT', 's1-feats': False, 'q0-word': 'світова', 'q0-lemma': 'світовий', 'q0-tag': 'ADJ', 'q0-feats': 'Case=Nom|Gender=Fem|Number=Sing', 'q1-word': 'економіка', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q2-tag': 'VERB', 'q3-tag': 'PART'}
# {'s0-word': 'світова', 's0-lemma': 'світовий', 's0-tag': 'ADJ', 's0-feats': 'Case=Nom|Gender=Fem|Number=Sing', 's1-tag': 'SCONJ', 's1-feats': False, 'q0-word': 'економіка', 'q0-lemma': 'економіка', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q1-word': 'переживає', 'q1-tag': 'VERB', 'q1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q2-tag': 'PART', 'q3-tag': 'ADJ'}
# {'s0-word': 'що', 's0-lemma': 'що', 's0-tag': 'SCONJ', 's0-feats': False, 's1-tag': 'PUNCT', 's1-feats': False, 'q0-word': 'економіка', 'q0-lemma': 'економіка', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q1-word': 'переживає', 'q1-tag': 'VERB', 'q1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q2-tag': 'PART', 'q3-tag': 'ADJ'}
# {'s0-word': 'економіка', 's0-lemma': 'економіка', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 's1-tag': 'SCONJ', 's1-feats': False, 'q0-word': 'переживає', 'q0-lemma': 'переживати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q1-word': 'не', 'q1-tag': 'PART', 'q1-feats': 'Polarity=Neg', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'що', 's0-lemma': 'що', 's0-tag': 'SCONJ', 's0-feats': False, 's1-tag': 'PUNCT', 's1-feats': False, 'q0-word': 'переживає', 'q0-lemma': 'переживати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q1-word': 'не', 'q1-tag': 'PART', 'q1-feats': 'Polarity=Neg', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': ',', 's0-lemma': ',', 's0-tag': 'PUNCT', 's0-feats': False, 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': 'переживає', 'q0-lemma': 'переживати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q1-word': 'не', 'q1-tag': 'PART', 'q1-feats': 'Polarity=Neg', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'засвідчує', 's0-lemma': 'засвідчувати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': 'переживає', 'q0-lemma': 'переживати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q1-word': 'не', 'q1-tag': 'PART', 'q1-feats': 'Polarity=Neg', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'переживає', 's0-lemma': 'переживати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': 'не', 'q0-lemma': 'не', 'q0-tag': 'PART', 'q0-feats': 'Polarity=Neg', 'q1-word': 'найкращі', 'q1-tag': 'ADJ', 'q1-feats': 'Animacy=Inan|Case=Acc|Degree=Sup|Number=Plur', 'q2-tag': 'NOUN', 'q3-tag': 'PUNCT'}
# {'s0-word': 'не', 's0-lemma': 'не', 's0-tag': 'PART', 's0-feats': 'Polarity=Neg', 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': 'найкращі', 'q0-lemma': 'найкращий', 'q0-tag': 'ADJ', 'q0-feats': 'Animacy=Inan|Case=Acc|Degree=Sup|Number=Plur', 'q1-word': 'часи', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur', 'q2-tag': 'PUNCT'}
# {'s0-word': 'переживає', 's0-lemma': 'переживати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': 'найкращі', 'q0-lemma': 'найкращий', 'q0-tag': 'ADJ', 'q0-feats': 'Animacy=Inan|Case=Acc|Degree=Sup|Number=Plur', 'q1-word': 'часи', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur', 'q2-tag': 'PUNCT'}
# {'s0-word': 'найкращі', 's0-lemma': 'найкращий', 's0-tag': 'ADJ', 's0-feats': 'Animacy=Inan|Case=Acc|Degree=Sup|Number=Plur', 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': 'часи', 'q0-lemma': 'час', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur', 'q1-word': '.', 'q1-tag': 'PUNCT', 'q1-feats': False}
# {'s0-word': 'переживає', 's0-lemma': 'переживати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': 'часи', 'q0-lemma': 'час', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur', 'q1-word': '.', 'q1-tag': 'PUNCT', 'q1-feats': False}
# {'s0-word': 'часи', 's0-lemma': 'час', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Plur', 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': '.', 'q0-lemma': '.', 'q0-tag': 'PUNCT', 'q0-feats': False}
# {'s0-word': 'переживає', 's0-lemma': 'переживати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': '.', 'q0-lemma': '.', 'q0-tag': 'PUNCT', 'q0-feats': False}
# {'s0-word': 'засвідчує', 's0-lemma': 'засвідчувати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': '.', 'q0-lemma': '.', 'q0-tag': 'PUNCT', 'q0-feats': False}
# {'s0-word': '.', 's0-lemma': '.', 's0-tag': 'PUNCT', 's0-feats': False, 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin'}
# {'s0-word': 'засвідчує', 's0-lemma': 'засвідчувати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Imp|Mood=Ind|Number=Sing|Person=3|Tense=Pres|VerbForm=Fin', 's1-tag': 'ROOT', 's1-feats': False}
# {'s0-word': 'ROOT', 's0-lemma': 'ROOT', 's0-tag': 'ROOT', 's0-feats': False}
# ---------------------------------------
# Number of words: 47
# Number of actions: 95
# List of actions taken: ['shift', 'shift', 'shift', 'left', 'right', 'shift', 'left', 'reduce', 'left', 'left', 'right', 'shift', 'left', 'right', 'right', 'shift', 'shift', 'left', 'left', 'reduce', 'right', 'shift', 'left', 'right', 'right', 'right', 'right', 'shift', 'left', 'shift', 'right', 'shift', 'left', 'right', 'right', 'reduce', 'reduce', 'reduce', 'left', 'reduce', 'reduce', 'reduce', 'reduce', 'reduce', 'reduce', 'right', 'shift', 'left', 'right', 'shift', 'left', 'right', 'shift', 'left', 'reduce', 'right', 'shift', 'left', 'right', 'shift', 'left', 'right', 'right', 'shift', 'left', 'right', 'shift', 'left', 'right', 'shift', 'shift', 'shift', 'shift', 'left', 'shift', 'left', 'left', 'left', 'left', 'reduce', 'reduce', 'reduce', 'reduce', 'reduce', 'reduce', 'reduce', 'reduce', 'right', 'right', 'reduce', 'right', 'reduce', 'reduce', 'reduce', 'reduce']
# Features:
# {'s0-word': 'ROOT', 's0-lemma': 'ROOT', 's0-tag': 'ROOT', 's0-feats': False, 'q0-word': 'Проте', 'q0-lemma': 'проте', 'q0-tag': 'CCONJ', 'q0-feats': False, 'q1-word': 'усвідомлення', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 'q2-tag': 'DET', 'q3-tag': 'NOUN'}
# {'s0-word': 'Проте', 's0-lemma': 'проте', 's0-tag': 'CCONJ', 's0-feats': False, 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': 'усвідомлення', 'q0-lemma': 'усвідомлення', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 'q1-word': 'цього', 'q1-tag': 'DET', 'q1-feats': 'Case=Gen|Gender=Masc|Number=Sing|PronType=Dem', 'q2-tag': 'NOUN', 'q3-tag': 'PART'}
# {'s0-word': 'усвідомлення', 's0-lemma': 'усвідомлення', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 's1-tag': 'CCONJ', 's1-feats': False, 'q0-word': 'цього', 'q0-lemma': 'цей', 'q0-tag': 'DET', 'q0-feats': 'Case=Gen|Gender=Masc|Number=Sing|PronType=Dem', 'q1-word': 'факту', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q2-tag': 'PART', 'q3-tag': 'VERB'}
# {'s0-word': 'цього', 's0-lemma': 'цей', 's0-tag': 'DET', 's0-feats': 'Case=Gen|Gender=Masc|Number=Sing|PronType=Dem', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 'q0-word': 'факту', 'q0-lemma': 'факт', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q1-word': 'не', 'q1-tag': 'PART', 'q1-feats': 'Polarity=Neg', 'q2-tag': 'VERB', 'q3-tag': 'ADJ'}
# {'s0-word': 'усвідомлення', 's0-lemma': 'усвідомлення', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 's1-tag': 'CCONJ', 's1-feats': False, 'q0-word': 'факту', 'q0-lemma': 'факт', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q1-word': 'не', 'q1-tag': 'PART', 'q1-feats': 'Polarity=Neg', 'q2-tag': 'VERB', 'q3-tag': 'ADJ'}
# {'s0-word': 'факту', 's0-lemma': 'факт', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 'q0-word': 'не', 'q0-lemma': 'не', 'q0-tag': 'PART', 'q0-feats': 'Polarity=Neg', 'q1-word': 'завадило', 'q1-tag': 'VERB', 'q1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'не', 's0-lemma': 'не', 's0-tag': 'PART', 's0-feats': 'Polarity=Neg', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q0-word': 'завадило', 'q0-lemma': 'завадити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q1-word': 'верховному', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Dat|Gender=Masc|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'факту', 's0-lemma': 'факт', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 'q0-word': 'завадило', 'q0-lemma': 'завадити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q1-word': 'верховному', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Dat|Gender=Masc|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'усвідомлення', 's0-lemma': 'усвідомлення', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 's1-tag': 'CCONJ', 's1-feats': False, 'q0-word': 'завадило', 'q0-lemma': 'завадити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q1-word': 'верховному', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Dat|Gender=Masc|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'Проте', 's0-lemma': 'проте', 's0-tag': 'CCONJ', 's0-feats': False, 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': 'завадило', 'q0-lemma': 'завадити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q1-word': 'верховному', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Dat|Gender=Masc|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'ROOT', 's0-lemma': 'ROOT', 's0-tag': 'ROOT', 's0-feats': False, 'q0-word': 'завадило', 'q0-lemma': 'завадити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q1-word': 'верховному', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Dat|Gender=Masc|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'завадило', 's0-lemma': 'завадити', 's0-tag': 'VERB', 's0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': 'верховному', 'q0-lemma': 'верховний', 'q0-tag': 'ADJ', 'q0-feats': 'Case=Dat|Gender=Masc|Number=Sing', 'q1-word': 'представнику', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'ADP'}
# {'s0-word': 'верховному', 's0-lemma': 'верховний', 's0-tag': 'ADJ', 's0-feats': 'Case=Dat|Gender=Masc|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q0-word': 'представнику', 'q0-lemma': 'представник', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing', 'q1-word': 'ЄС', 'q1-tag': 'NOUN', 'q1-feats': 'Abbr=Yes|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing|Uninflect=Yes', 'q2-tag': 'ADP', 'q3-tag': 'ADJ'}
# {'s0-word': 'завадило', 's0-lemma': 'завадити', 's0-tag': 'VERB', 's0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': 'представнику', 'q0-lemma': 'представник', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing', 'q1-word': 'ЄС', 'q1-tag': 'NOUN', 'q1-feats': 'Abbr=Yes|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing|Uninflect=Yes', 'q2-tag': 'ADP', 'q3-tag': 'ADJ'}
# {'s0-word': 'представнику', 's0-lemma': 'представник', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q0-word': 'ЄС', 'q0-lemma': 'ЄС', 'q0-tag': 'NOUN', 'q0-feats': 'Abbr=Yes|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing|Uninflect=Yes', 'q1-word': 'у', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'ЄС', 's0-lemma': 'ЄС', 's0-tag': 'NOUN', 's0-feats': 'Abbr=Yes|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing|Uninflect=Yes', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing', 'q0-word': 'у', 'q0-lemma': 'у', 'q0-tag': 'ADP', 'q0-feats': 'Case=Loc', 'q1-word': 'закордонних', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Loc|Number=Plur', 'q2-tag': 'NOUN', 'q3-tag': 'CCONJ'}
# {'s0-word': 'у', 's0-lemma': 'у', 's0-tag': 'ADP', 's0-feats': 'Case=Loc', 's1-tag': 'NOUN', 's1-feats': 'Abbr=Yes|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing|Uninflect=Yes', 'q0-word': 'закордонних', 'q0-lemma': 'закордонний', 'q0-tag': 'ADJ', 'q0-feats': 'Case=Loc|Number=Plur', 'q1-word': 'справах', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur', 'q2-tag': 'CCONJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'закордонних', 's0-lemma': 'закордонний', 's0-tag': 'ADJ', 's0-feats': 'Case=Loc|Number=Plur', 's1-tag': 'ADP', 's1-feats': 'Case=Loc', 'q0-word': 'справах', 'q0-lemma': 'справа', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur', 'q1-word': 'та', 'q1-tag': 'CCONJ', 'q1-feats': False, 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'у', 's0-lemma': 'у', 's0-tag': 'ADP', 's0-feats': 'Case=Loc', 's1-tag': 'NOUN', 's1-feats': 'Abbr=Yes|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing|Uninflect=Yes', 'q0-word': 'справах', 'q0-lemma': 'справа', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur', 'q1-word': 'та', 'q1-tag': 'CCONJ', 'q1-feats': False, 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'ЄС', 's0-lemma': 'ЄС', 's0-tag': 'NOUN', 's0-feats': 'Abbr=Yes|Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing|Uninflect=Yes', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing', 'q0-word': 'справах', 'q0-lemma': 'справа', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur', 'q1-word': 'та', 'q1-tag': 'CCONJ', 'q1-feats': False, 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'представнику', 's0-lemma': 'представник', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q0-word': 'справах', 'q0-lemma': 'справа', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur', 'q1-word': 'та', 'q1-tag': 'CCONJ', 'q1-feats': False, 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'справах', 's0-lemma': 'справа', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing', 'q0-word': 'та', 'q0-lemma': 'та', 'q0-tag': 'CCONJ', 'q0-feats': False, 'q1-word': 'політиці', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'PROPN'}
# {'s0-word': 'та', 's0-lemma': 'та', 's0-tag': 'CCONJ', 's0-feats': False, 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur', 'q0-word': 'політиці', 'q0-lemma': 'політика', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q1-word': 'безпеки', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q2-tag': 'PROPN', 'q3-tag': 'PROPN'}
# {'s0-word': 'справах', 's0-lemma': 'справа', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing', 'q0-word': 'політиці', 'q0-lemma': 'політика', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q1-word': 'безпеки', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q2-tag': 'PROPN', 'q3-tag': 'PROPN'}
# {'s0-word': 'політиці', 's0-lemma': 'політика', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur', 'q0-word': 'безпеки', 'q0-lemma': 'безпека', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q1-word': 'Жозепу', 'q1-tag': 'PROPN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q2-tag': 'PROPN', 'q3-tag': 'ADP'}
# {'s0-word': 'безпеки', 's0-lemma': 'безпека', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q0-word': 'Жозепу', 'q0-lemma': 'Жозепа', 'q0-tag': 'PROPN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q1-word': 'Боррелю', 'q1-tag': 'PROPN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q2-tag': 'ADP', 'q3-tag': 'NOUN'}
# {'s0-word': 'Жозепу', 's0-lemma': 'Жозепа', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q0-word': 'Боррелю', 'q0-lemma': 'Боррель', 'q0-tag': 'PROPN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q1-word': 'під', 'q1-tag': 'ADP', 'q1-feats': 'Case=Acc', 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'Боррелю', 's0-lemma': 'Боррель', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 's1-tag': 'PROPN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q0-word': 'під', 'q0-lemma': 'під', 'q0-tag': 'ADP', 'q0-feats': 'Case=Acc', 'q1-word': 'час', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'ADP'}
# {'s0-word': 'під', 's0-lemma': 'під', 's0-tag': 'ADP', 's0-feats': 'Case=Acc', 's1-tag': 'PROPN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q0-word': 'час', 'q0-lemma': 'час', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 'q1-word': 'спілкування', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 'q2-tag': 'ADP', 'q3-tag': 'PROPN'}
# {'s0-word': 'Боррелю', 's0-lemma': 'Боррель', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 's1-tag': 'PROPN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q0-word': 'час', 'q0-lemma': 'час', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 'q1-word': 'спілкування', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 'q2-tag': 'ADP', 'q3-tag': 'PROPN'}
# {'s0-word': 'час', 's0-lemma': 'час', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 's1-tag': 'PROPN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q0-word': 'спілкування', 'q0-lemma': 'спілкування', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 'q1-word': 'з', 'q1-tag': 'ADP', 'q1-feats': 'Case=Ins', 'q2-tag': 'PROPN', 'q3-tag': 'PROPN'}
# {'s0-word': 'спілкування', 's0-lemma': 'спілкування', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 'q0-word': 'з', 'q0-lemma': 'з', 'q0-tag': 'ADP', 'q0-feats': 'Case=Ins', 'q1-word': 'Дмитром', 'q1-tag': 'PROPN', 'q1-feats': 'Animacy=Anim|Case=Ins|Gender=Masc|NameType=Giv|Number=Sing', 'q2-tag': 'PROPN', 'q3-tag': 'VERB'}
# {'s0-word': 'з', 's0-lemma': 'з', 's0-tag': 'ADP', 's0-feats': 'Case=Ins', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 'q0-word': 'Дмитром', 'q0-lemma': 'Дмитро', 'q0-tag': 'PROPN', 'q0-feats': 'Animacy=Anim|Case=Ins|Gender=Masc|NameType=Giv|Number=Sing', 'q1-word': 'Кулебою', 'q1-tag': 'PROPN', 'q1-feats': 'Animacy=Anim|Case=Ins|Gender=Masc|NameType=Sur|Number=Sing', 'q2-tag': 'VERB', 'q3-tag': 'ADP'}
# {'s0-word': 'спілкування', 's0-lemma': 'спілкування', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 'q0-word': 'Дмитром', 'q0-lemma': 'Дмитро', 'q0-tag': 'PROPN', 'q0-feats': 'Animacy=Anim|Case=Ins|Gender=Masc|NameType=Giv|Number=Sing', 'q1-word': 'Кулебою', 'q1-tag': 'PROPN', 'q1-feats': 'Animacy=Anim|Case=Ins|Gender=Masc|NameType=Sur|Number=Sing', 'q2-tag': 'VERB', 'q3-tag': 'ADP'}
# {'s0-word': 'Дмитром', 's0-lemma': 'Дмитро', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Anim|Case=Ins|Gender=Masc|NameType=Giv|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 'q0-word': 'Кулебою', 'q0-lemma': 'Кулеба', 'q0-tag': 'PROPN', 'q0-feats': 'Animacy=Anim|Case=Ins|Gender=Masc|NameType=Sur|Number=Sing', 'q1-word': 'наголосити', 'q1-tag': 'VERB', 'q1-feats': 'Aspect=Perf|VerbForm=Inf', 'q2-tag': 'ADP', 'q3-tag': 'NOUN'}
# {'s0-word': 'Кулебою', 's0-lemma': 'Кулеба', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Anim|Case=Ins|Gender=Masc|NameType=Sur|Number=Sing', 's1-tag': 'PROPN', 's1-feats': 'Animacy=Anim|Case=Ins|Gender=Masc|NameType=Giv|Number=Sing', 'q0-word': 'наголосити', 'q0-lemma': 'наголосити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|VerbForm=Inf', 'q1-word': 'на', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'Дмитром', 's0-lemma': 'Дмитро', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Anim|Case=Ins|Gender=Masc|NameType=Giv|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 'q0-word': 'наголосити', 'q0-lemma': 'наголосити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|VerbForm=Inf', 'q1-word': 'на', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'спілкування', 's0-lemma': 'спілкування', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 'q0-word': 'наголосити', 'q0-lemma': 'наголосити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|VerbForm=Inf', 'q1-word': 'на', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'час', 's0-lemma': 'час', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 's1-tag': 'PROPN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q0-word': 'наголосити', 'q0-lemma': 'наголосити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|VerbForm=Inf', 'q1-word': 'на', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'Боррелю', 's0-lemma': 'Боррель', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 's1-tag': 'PROPN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q0-word': 'наголосити', 'q0-lemma': 'наголосити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|VerbForm=Inf', 'q1-word': 'на', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'Жозепу', 's0-lemma': 'Жозепа', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q0-word': 'наголосити', 'q0-lemma': 'наголосити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|VerbForm=Inf', 'q1-word': 'на', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'безпеки', 's0-lemma': 'безпека', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q0-word': 'наголосити', 'q0-lemma': 'наголосити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|VerbForm=Inf', 'q1-word': 'на', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'політиці', 's0-lemma': 'політика', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur', 'q0-word': 'наголосити', 'q0-lemma': 'наголосити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|VerbForm=Inf', 'q1-word': 'на', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'справах', 's0-lemma': 'справа', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Plur', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing', 'q0-word': 'наголосити', 'q0-lemma': 'наголосити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|VerbForm=Inf', 'q1-word': 'на', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'представнику', 's0-lemma': 'представник', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Anim|Case=Dat|Gender=Masc|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q0-word': 'наголосити', 'q0-lemma': 'наголосити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|VerbForm=Inf', 'q1-word': 'на', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'завадило', 's0-lemma': 'завадити', 's0-tag': 'VERB', 's0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': 'наголосити', 'q0-lemma': 'наголосити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|VerbForm=Inf', 'q1-word': 'на', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'наголосити', 's0-lemma': 'наголосити', 's0-tag': 'VERB', 's0-feats': 'Aspect=Perf|VerbForm=Inf', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q0-word': 'на', 'q0-lemma': 'на', 'q0-tag': 'ADP', 'q0-feats': 'Case=Loc', 'q1-word': 'зацікавленості', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'на', 's0-lemma': 'на', 's0-tag': 'ADP', 's0-feats': 'Case=Loc', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|VerbForm=Inf', 'q0-word': 'зацікавленості', 'q0-lemma': 'зацікавленість', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q1-word': 'Європейського', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Gen|Gender=Masc|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'ADP'}
# {'s0-word': 'наголосити', 's0-lemma': 'наголосити', 's0-tag': 'VERB', 's0-feats': 'Aspect=Perf|VerbForm=Inf', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q0-word': 'зацікавленості', 'q0-lemma': 'зацікавленість', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q1-word': 'Європейського', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Gen|Gender=Masc|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'ADP'}
# {'s0-word': 'зацікавленості', 's0-lemma': 'зацікавленість', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|VerbForm=Inf', 'q0-word': 'Європейського', 'q0-lemma': 'європейський', 'q0-tag': 'ADJ', 'q0-feats': 'Case=Gen|Gender=Masc|Number=Sing', 'q1-word': 'Союзу', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q2-tag': 'ADP', 'q3-tag': 'NOUN'}
# {'s0-word': 'Європейського', 's0-lemma': 'європейський', 's0-tag': 'ADJ', 's0-feats': 'Case=Gen|Gender=Masc|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q0-word': 'Союзу', 'q0-lemma': 'союз', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q1-word': 'у', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADP'}
# {'s0-word': 'зацікавленості', 's0-lemma': 'зацікавленість', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|VerbForm=Inf', 'q0-word': 'Союзу', 'q0-lemma': 'союз', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q1-word': 'у', 'q1-tag': 'ADP', 'q1-feats': 'Case=Loc', 'q2-tag': 'NOUN', 'q3-tag': 'ADP'}
# {'s0-word': 'Союзу', 's0-lemma': 'союз', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q0-word': 'у', 'q0-lemma': 'у', 'q0-tag': 'ADP', 'q0-feats': 'Case=Loc', 'q1-word': 'співпраці', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q2-tag': 'ADP', 'q3-tag': 'PROPN'}
# {'s0-word': 'у', 's0-lemma': 'у', 's0-tag': 'ADP', 's0-feats': 'Case=Loc', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q0-word': 'співпраці', 'q0-lemma': 'співпраця', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q1-word': 'з', 'q1-tag': 'ADP', 'q1-feats': 'Case=Ins', 'q2-tag': 'PROPN', 'q3-tag': 'CCONJ'}
# {'s0-word': 'Союзу', 's0-lemma': 'союз', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q0-word': 'співпраці', 'q0-lemma': 'співпраця', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q1-word': 'з', 'q1-tag': 'ADP', 'q1-feats': 'Case=Ins', 'q2-tag': 'PROPN', 'q3-tag': 'CCONJ'}
# {'s0-word': 'зацікавленості', 's0-lemma': 'зацікавленість', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|VerbForm=Inf', 'q0-word': 'співпраці', 'q0-lemma': 'співпраця', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q1-word': 'з', 'q1-tag': 'ADP', 'q1-feats': 'Case=Ins', 'q2-tag': 'PROPN', 'q3-tag': 'CCONJ'}
# {'s0-word': 'співпраці', 's0-lemma': 'співпраця', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q0-word': 'з', 'q0-lemma': 'з', 'q0-tag': 'ADP', 'q0-feats': 'Case=Ins', 'q1-word': 'Україною', 'q1-tag': 'PROPN', 'q1-feats': 'Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing', 'q2-tag': 'CCONJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'з', 's0-lemma': 'з', 's0-tag': 'ADP', 's0-feats': 'Case=Ins', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q0-word': 'Україною', 'q0-lemma': 'Україна', 'q0-tag': 'PROPN', 'q0-feats': 'Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing', 'q1-word': 'та', 'q1-tag': 'CCONJ', 'q1-feats': False, 'q2-tag': 'NOUN', 'q3-tag': 'VERB'}
# {'s0-word': 'співпраці', 's0-lemma': 'співпраця', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q0-word': 'Україною', 'q0-lemma': 'Україна', 'q0-tag': 'PROPN', 'q0-feats': 'Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing', 'q1-word': 'та', 'q1-tag': 'CCONJ', 'q1-feats': False, 'q2-tag': 'NOUN', 'q3-tag': 'VERB'}
# {'s0-word': 'Україною', 's0-lemma': 'Україна', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q0-word': 'та', 'q0-lemma': 'та', 'q0-tag': 'CCONJ', 'q0-feats': False, 'q1-word': 'готовності', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q2-tag': 'VERB', 'q3-tag': 'ADJ'}
# {'s0-word': 'та', 's0-lemma': 'та', 's0-tag': 'CCONJ', 's0-feats': False, 's1-tag': 'PROPN', 's1-feats': 'Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing', 'q0-word': 'готовності', 'q0-lemma': 'готовність', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q1-word': 'здійснити', 'q1-tag': 'VERB', 'q1-feats': 'Aspect=Perf|VerbForm=Inf', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'Україною', 's0-lemma': 'Україна', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q0-word': 'готовності', 'q0-lemma': 'готовність', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q1-word': 'здійснити', 'q1-tag': 'VERB', 'q1-feats': 'Aspect=Perf|VerbForm=Inf', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'готовності', 's0-lemma': 'готовність', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 's1-tag': 'PROPN', 's1-feats': 'Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing', 'q0-word': 'здійснити', 'q0-lemma': 'здійснити', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|VerbForm=Inf', 'q1-word': 'відкладений', 'q1-tag': 'ADJ', 'q1-feats': 'Animacy=Inan|Aspect=Perf|Case=Acc|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass', 'q2-tag': 'NOUN', 'q3-tag': 'ADP'}
# {'s0-word': 'здійснити', 's0-lemma': 'здійснити', 's0-tag': 'VERB', 's0-feats': 'Aspect=Perf|VerbForm=Inf', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q0-word': 'відкладений', 'q0-lemma': 'відкладений', 'q0-tag': 'ADJ', 'q0-feats': 'Animacy=Inan|Aspect=Perf|Case=Acc|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass', 'q1-word': 'візит', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 'q2-tag': 'ADP', 'q3-tag': 'PROPN'}
# {'s0-word': 'відкладений', 's0-lemma': 'відкладений', 's0-tag': 'ADJ', 's0-feats': 'Animacy=Inan|Aspect=Perf|Case=Acc|Gender=Masc|Number=Sing|VerbForm=Part|Voice=Pass', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|VerbForm=Inf', 'q0-word': 'візит', 'q0-lemma': 'візит', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 'q1-word': 'до', 'q1-tag': 'ADP', 'q1-feats': 'Case=Gen', 'q2-tag': 'PROPN', 'q3-tag': 'PART'}
# {'s0-word': 'здійснити', 's0-lemma': 'здійснити', 's0-tag': 'VERB', 's0-feats': 'Aspect=Perf|VerbForm=Inf', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q0-word': 'візит', 'q0-lemma': 'візит', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 'q1-word': 'до', 'q1-tag': 'ADP', 'q1-feats': 'Case=Gen', 'q2-tag': 'PROPN', 'q3-tag': 'PART'}
# {'s0-word': 'візит', 's0-lemma': 'візит', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|VerbForm=Inf', 'q0-word': 'до', 'q0-lemma': 'до', 'q0-tag': 'ADP', 'q0-feats': 'Case=Gen', 'q1-word': 'України', 'q1-tag': 'PROPN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q2-tag': 'PART', 'q3-tag': 'PUNCT'}
# {'s0-word': 'до', 's0-lemma': 'до', 's0-tag': 'ADP', 's0-feats': 'Case=Gen', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 'q0-word': 'України', 'q0-lemma': 'Україна', 'q0-tag': 'PROPN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q1-word': 'тільки', 'q1-tag': 'PART', 'q1-feats': False, 'q2-tag': 'PUNCT', 'q3-tag': 'PART'}
# {'s0-word': 'візит', 's0-lemma': 'візит', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|VerbForm=Inf', 'q0-word': 'України', 'q0-lemma': 'Україна', 'q0-tag': 'PROPN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q1-word': 'тільки', 'q1-tag': 'PART', 'q1-feats': False, 'q2-tag': 'PUNCT', 'q3-tag': 'PART'}
# {'s0-word': 'України', 's0-lemma': 'Україна', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 'q0-word': 'тільки', 'q0-lemma': 'тільки', 'q0-tag': 'PART', 'q0-feats': False, 'q1-word': '-', 'q1-tag': 'PUNCT', 'q1-feats': 'PunctType=Dash', 'q2-tag': 'PART', 'q3-tag': 'ADP'}
# {'s0-word': 'тільки', 's0-lemma': 'тільки', 's0-tag': 'PART', 's0-feats': False, 's1-tag': 'PROPN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q0-word': '-', 'q0-lemma': '-', 'q0-tag': 'PUNCT', 'q0-feats': 'PunctType=Dash', 'q1-word': 'но', 'q1-tag': 'PART', 'q1-feats': False, 'q2-tag': 'ADP', 'q3-tag': 'PRON'}
# {'s0-word': '-', 's0-lemma': '-', 's0-tag': 'PUNCT', 's0-feats': 'PunctType=Dash', 's1-tag': 'PART', 's1-feats': False, 'q0-word': 'но', 'q0-lemma': 'но', 'q0-tag': 'PART', 'q0-feats': False, 'q1-word': 'для', 'q1-tag': 'ADP', 'q1-feats': 'Case=Gen', 'q2-tag': 'PRON', 'q3-tag': 'VERB'}
# {'s0-word': 'но', 's0-lemma': 'но', 's0-tag': 'PART', 's0-feats': False, 's1-tag': 'PUNCT', 's1-feats': 'PunctType=Dash', 'q0-word': 'для', 'q0-lemma': 'для', 'q0-tag': 'ADP', 'q0-feats': 'Case=Gen', 'q1-word': 'цього', 'q1-tag': 'PRON', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing|PronType=Dem', 'q2-tag': 'VERB', 'q3-tag': 'NOUN'}
# {'s0-word': 'для', 's0-lemma': 'для', 's0-tag': 'ADP', 's0-feats': 'Case=Gen', 's1-tag': 'PART', 's1-feats': False, 'q0-word': 'цього', 'q0-lemma': 'це', 'q0-tag': 'PRON', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing|PronType=Dem', 'q1-word': 'з’явиться', 'q1-tag': 'VERB', 'q1-feats': 'Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin', 'q2-tag': 'NOUN', 'q3-tag': 'PUNCT'}
# {'s0-word': 'но', 's0-lemma': 'но', 's0-tag': 'PART', 's0-feats': False, 's1-tag': 'PUNCT', 's1-feats': 'PunctType=Dash', 'q0-word': 'цього', 'q0-lemma': 'це', 'q0-tag': 'PRON', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing|PronType=Dem', 'q1-word': 'з’явиться', 'q1-tag': 'VERB', 'q1-feats': 'Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin', 'q2-tag': 'NOUN', 'q3-tag': 'PUNCT'}
# {'s0-word': 'цього', 's0-lemma': 'це', 's0-tag': 'PRON', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing|PronType=Dem', 's1-tag': 'PART', 's1-feats': False, 'q0-word': 'з’явиться', 'q0-lemma': 'з’явитися', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin', 'q1-word': 'можливість', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q2-tag': 'PUNCT'}
# {'s0-word': 'но', 's0-lemma': 'но', 's0-tag': 'PART', 's0-feats': False, 's1-tag': 'PUNCT', 's1-feats': 'PunctType=Dash', 'q0-word': 'з’явиться', 'q0-lemma': 'з’явитися', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin', 'q1-word': 'можливість', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q2-tag': 'PUNCT'}
# {'s0-word': '-', 's0-lemma': '-', 's0-tag': 'PUNCT', 's0-feats': 'PunctType=Dash', 's1-tag': 'PART', 's1-feats': False, 'q0-word': 'з’явиться', 'q0-lemma': 'з’явитися', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin', 'q1-word': 'можливість', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q2-tag': 'PUNCT'}
# {'s0-word': 'тільки', 's0-lemma': 'тільки', 's0-tag': 'PART', 's0-feats': False, 's1-tag': 'PROPN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q0-word': 'з’явиться', 'q0-lemma': 'з’явитися', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin', 'q1-word': 'можливість', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q2-tag': 'PUNCT'}
# {'s0-word': 'України', 's0-lemma': 'Україна', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 'q0-word': 'з’явиться', 'q0-lemma': 'з’явитися', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin', 'q1-word': 'можливість', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q2-tag': 'PUNCT'}
# {'s0-word': 'візит', 's0-lemma': 'візит', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Acc|Gender=Masc|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|VerbForm=Inf', 'q0-word': 'з’явиться', 'q0-lemma': 'з’явитися', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin', 'q1-word': 'можливість', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q2-tag': 'PUNCT'}
# {'s0-word': 'здійснити', 's0-lemma': 'здійснити', 's0-tag': 'VERB', 's0-feats': 'Aspect=Perf|VerbForm=Inf', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q0-word': 'з’явиться', 'q0-lemma': 'з’явитися', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin', 'q1-word': 'можливість', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q2-tag': 'PUNCT'}
# {'s0-word': 'готовності', 's0-lemma': 'готовність', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 's1-tag': 'PROPN', 's1-feats': 'Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing', 'q0-word': 'з’явиться', 'q0-lemma': 'з’явитися', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin', 'q1-word': 'можливість', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q2-tag': 'PUNCT'}
# {'s0-word': 'Україною', 's0-lemma': 'Україна', 's0-tag': 'PROPN', 's0-feats': 'Animacy=Inan|Case=Ins|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Loc|Gender=Fem|Number=Sing', 'q0-word': 'з’явиться', 'q0-lemma': 'з’явитися', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Mood=Ind|Number=Sing|Person=3|Tense=Fut|VerbForm=Fin', 'q1-word': 'можливість', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Nom|Gender=Fem|Number=Sing', 'q2-tag': 'PUNCT'}
# ...
# {'s0-word': 'ROOT', 's0-lemma': 'ROOT', 's0-tag': 'ROOT', 's0-feats': False, 'q0-word': 'ігнорують', 'q0-lemma': 'ігнорувати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin', 'q1-word': 'очевидне', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Acc|Degree=Pos|Gender=Neut|Number=Sing', 'q2-tag': 'PUNCT', 'q3-tag': 'NOUN'}
# {'s0-word': 'ігнорують', 's0-lemma': 'ігнорувати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': 'очевидне', 'q0-lemma': 'очевидний', 'q0-tag': 'ADJ', 'q0-feats': 'Case=Acc|Degree=Pos|Gender=Neut|Number=Sing', 'q1-word': ':', 'q1-tag': 'PUNCT', 'q1-feats': False, 'q2-tag': 'NOUN', 'q3-tag': 'PUNCT'}
# {'s0-word': 'очевидне', 's0-lemma': 'очевидний', 's0-tag': 'ADJ', 's0-feats': 'Case=Acc|Degree=Pos|Gender=Neut|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': ':', 'q0-lemma': ':', 'q0-tag': 'PUNCT', 'q0-feats': False, 'q1-word': 'словосполучення', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 'q2-tag': 'PUNCT', 'q3-tag': 'ADJ'}
# {'s0-word': ':', 's0-lemma': ':', 's0-tag': 'PUNCT', 's0-feats': False, 's1-tag': 'ADJ', 's1-feats': 'Case=Acc|Degree=Pos|Gender=Neut|Number=Sing', 'q0-word': 'словосполучення', 'q0-lemma': 'словосполучення', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 'q1-word': '«', 'q1-tag': 'PUNCT', 'q1-feats': 'PunctType=Quot', 'q2-tag': 'ADJ', 'q3-tag': 'ADJ'}
# {'s0-word': 'словосполучення', 's0-lemma': 'словосполучення', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 's1-tag': 'PUNCT', 's1-feats': False, 'q0-word': '«', 'q0-lemma': '«', 'q0-tag': 'PUNCT', 'q0-feats': 'PunctType=Quot', 'q1-word': 'російський', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Nom|Gender=Masc|Number=Sing', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': '«', 's0-lemma': '«', 's0-tag': 'PUNCT', 's0-feats': 'PunctType=Quot', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 'q0-word': 'російський', 'q0-lemma': 'російський', 'q0-tag': 'ADJ', 'q0-feats': 'Case=Nom|Gender=Masc|Number=Sing', 'q1-word': 'гуманітарний', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Nom|Gender=Masc|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'PUNCT'}
# {'s0-word': 'російський', 's0-lemma': 'російський', 's0-tag': 'ADJ', 's0-feats': 'Case=Nom|Gender=Masc|Number=Sing', 's1-tag': 'PUNCT', 's1-feats': 'PunctType=Quot', 'q0-word': 'гуманітарний', 'q0-lemma': 'гуманітарний', 'q0-tag': 'ADJ', 'q0-feats': 'Case=Nom|Gender=Masc|Number=Sing', 'q1-word': 'конвой', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 'q2-tag': 'PUNCT', 'q3-tag': 'ADP'}
# {'s0-word': 'гуманітарний', 's0-lemma': 'гуманітарний', 's0-tag': 'ADJ', 's0-feats': 'Case=Nom|Gender=Masc|Number=Sing', 's1-tag': 'ADJ', 's1-feats': 'Case=Nom|Gender=Masc|Number=Sing', 'q0-word': 'конвой', 'q0-lemma': 'конвой', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 'q1-word': '»', 'q1-tag': 'PUNCT', 'q1-feats': 'PunctType=Quot', 'q2-tag': 'ADP', 'q3-tag': 'ADJ'}
# {'s0-word': 'російський', 's0-lemma': 'російський', 's0-tag': 'ADJ', 's0-feats': 'Case=Nom|Gender=Masc|Number=Sing', 's1-tag': 'PUNCT', 's1-feats': 'PunctType=Quot', 'q0-word': 'конвой', 'q0-lemma': 'конвой', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 'q1-word': '»', 'q1-tag': 'PUNCT', 'q1-feats': 'PunctType=Quot', 'q2-tag': 'ADP', 'q3-tag': 'ADJ'}
# {'s0-word': '«', 's0-lemma': '«', 's0-tag': 'PUNCT', 's0-feats': 'PunctType=Quot', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 'q0-word': 'конвой', 'q0-lemma': 'конвой', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 'q1-word': '»', 'q1-tag': 'PUNCT', 'q1-feats': 'PunctType=Quot', 'q2-tag': 'ADP', 'q3-tag': 'ADJ'}
# {'s0-word': 'словосполучення', 's0-lemma': 'словосполучення', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 's1-tag': 'PUNCT', 's1-feats': False, 'q0-word': 'конвой', 'q0-lemma': 'конвой', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 'q1-word': '»', 'q1-tag': 'PUNCT', 'q1-feats': 'PunctType=Quot', 'q2-tag': 'ADP', 'q3-tag': 'ADJ'}
# {'s0-word': 'конвой', 's0-lemma': 'конвой', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 'q0-word': '»', 'q0-lemma': '»', 'q0-tag': 'PUNCT', 'q0-feats': 'PunctType=Quot', 'q1-word': 'з', 'q1-tag': 'ADP', 'q1-feats': 'Case=Gen', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': '»', 's0-lemma': '»', 's0-tag': 'PUNCT', 's0-feats': 'PunctType=Quot', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 'q0-word': 'з', 'q0-lemma': 'з', 'q0-tag': 'ADP', 'q0-feats': 'Case=Gen', 'q1-word': '2014', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Gen|Gender=Masc|NumType=Ord|Number=Sing|Uninflect=Yes', 'q2-tag': 'NOUN', 'q3-tag': 'VERB'}
# {'s0-word': 'з', 's0-lemma': 'з', 's0-tag': 'ADP', 's0-feats': 'Case=Gen', 's1-tag': 'PUNCT', 's1-feats': 'PunctType=Quot', 'q0-word': '2014', 'q0-lemma': '2014', 'q0-tag': 'ADJ', 'q0-feats': 'Case=Gen|Gender=Masc|NumType=Ord|Number=Sing|Uninflect=Yes', 'q1-word': 'року', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q2-tag': 'VERB', 'q3-tag': 'NOUN'}
# {'s0-word': '2014', 's0-lemma': '2014', 's0-tag': 'ADJ', 's0-feats': 'Case=Gen|Gender=Masc|NumType=Ord|Number=Sing|Uninflect=Yes', 's1-tag': 'ADP', 's1-feats': 'Case=Gen', 'q0-word': 'року', 'q0-lemma': 'рік', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q1-word': 'стало', 'q1-tag': 'VERB', 'q1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'з', 's0-lemma': 'з', 's0-tag': 'ADP', 's0-feats': 'Case=Gen', 's1-tag': 'PUNCT', 's1-feats': 'PunctType=Quot', 'q0-word': 'року', 'q0-lemma': 'рік', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q1-word': 'стало', 'q1-tag': 'VERB', 'q1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': '»', 's0-lemma': '»', 's0-tag': 'PUNCT', 's0-feats': 'PunctType=Quot', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 'q0-word': 'року', 'q0-lemma': 'рік', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 'q1-word': 'стало', 'q1-tag': 'VERB', 'q1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q2-tag': 'NOUN', 'q3-tag': 'ADJ'}
# {'s0-word': 'року', 's0-lemma': 'рік', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Masc|Number=Sing', 's1-tag': 'PUNCT', 's1-feats': 'PunctType=Quot', 'q0-word': 'стало', 'q0-lemma': 'стати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q1-word': 'синонімом', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': '»', 's0-lemma': '»', 's0-tag': 'PUNCT', 's0-feats': 'PunctType=Quot', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 'q0-word': 'стало', 'q0-lemma': 'стати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q1-word': 'синонімом', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'конвой', 's0-lemma': 'конвой', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Nom|Gender=Masc|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 'q0-word': 'стало', 'q0-lemma': 'стати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q1-word': 'синонімом', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'словосполучення', 's0-lemma': 'словосполучення', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Acc|Gender=Neut|Number=Sing', 's1-tag': 'PUNCT', 's1-feats': False, 'q0-word': 'стало', 'q0-lemma': 'стати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q1-word': 'синонімом', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': ':', 's0-lemma': ':', 's0-tag': 'PUNCT', 's0-feats': False, 's1-tag': 'ADJ', 's1-feats': 'Case=Acc|Degree=Pos|Gender=Neut|Number=Sing', 'q0-word': 'стало', 'q0-lemma': 'стати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q1-word': 'синонімом', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'очевидне', 's0-lemma': 'очевидний', 's0-tag': 'ADJ', 's0-feats': 'Case=Acc|Degree=Pos|Gender=Neut|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': 'стало', 'q0-lemma': 'стати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q1-word': 'синонімом', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'ігнорують', 's0-lemma': 'ігнорувати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': 'стало', 'q0-lemma': 'стати', 'q0-tag': 'VERB', 'q0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q1-word': 'синонімом', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 'q2-tag': 'ADJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'стало', 's0-lemma': 'стати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': 'синонімом', 'q0-lemma': 'синонім', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 'q1-word': 'незаконного', 'q1-tag': 'ADJ', 'q1-feats': 'Case=Gen|Gender=Neut|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'CCONJ'}
# {'s0-word': 'синонімом', 's0-lemma': 'синонім', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q0-word': 'незаконного', 'q0-lemma': 'незаконний', 'q0-tag': 'ADJ', 'q0-feats': 'Case=Gen|Gender=Neut|Number=Sing', 'q1-word': 'втручання', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 'q2-tag': 'CCONJ', 'q3-tag': 'NOUN'}
# {'s0-word': 'незаконного', 's0-lemma': 'незаконний', 's0-tag': 'ADJ', 's0-feats': 'Case=Gen|Gender=Neut|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 'q0-word': 'втручання', 'q0-lemma': 'втручання', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 'q1-word': 'та', 'q1-tag': 'CCONJ', 'q1-feats': False, 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'синонімом', 's0-lemma': 'синонім', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q0-word': 'втручання', 'q0-lemma': 'втручання', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 'q1-word': 'та', 'q1-tag': 'CCONJ', 'q1-feats': False, 'q2-tag': 'NOUN', 'q3-tag': 'NOUN'}
# {'s0-word': 'втручання', 's0-lemma': 'втручання', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 'q0-word': 'та', 'q0-lemma': 'та', 'q0-tag': 'CCONJ', 'q0-feats': False, 'q1-word': 'підтримки', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q2-tag': 'NOUN', 'q3-tag': 'PUNCT'}
# {'s0-word': 'та', 's0-lemma': 'та', 's0-tag': 'CCONJ', 's0-feats': False, 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 'q0-word': 'підтримки', 'q0-lemma': 'підтримка', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q1-word': 'бойовиків', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur', 'q2-tag': 'PUNCT'}
# {'s0-word': 'втручання', 's0-lemma': 'втручання', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 'q0-word': 'підтримки', 'q0-lemma': 'підтримка', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q1-word': 'бойовиків', 'q1-tag': 'NOUN', 'q1-feats': 'Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur', 'q2-tag': 'PUNCT'}
# {'s0-word': 'підтримки', 's0-lemma': 'підтримка', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 'q0-word': 'бойовиків', 'q0-lemma': 'бойовик', 'q0-tag': 'NOUN', 'q0-feats': 'Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur', 'q1-word': '.', 'q1-tag': 'PUNCT', 'q1-feats': False}
# {'s0-word': 'бойовиків', 's0-lemma': 'бойовик', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Anim|Case=Gen|Gender=Masc|Number=Plur', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 'q0-word': '.', 'q0-lemma': '.', 'q0-tag': 'PUNCT', 'q0-feats': False}
# {'s0-word': 'підтримки', 's0-lemma': 'підтримка', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Fem|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 'q0-word': '.', 'q0-lemma': '.', 'q0-tag': 'PUNCT', 'q0-feats': False}
# {'s0-word': 'втручання', 's0-lemma': 'втручання', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Gen|Gender=Neut|Number=Sing', 's1-tag': 'NOUN', 's1-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 'q0-word': '.', 'q0-lemma': '.', 'q0-tag': 'PUNCT', 'q0-feats': False}
# {'s0-word': 'синонімом', 's0-lemma': 'синонім', 's0-tag': 'NOUN', 's0-feats': 'Animacy=Inan|Case=Ins|Gender=Masc|Number=Sing', 's1-tag': 'VERB', 's1-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 'q0-word': '.', 'q0-lemma': '.', 'q0-tag': 'PUNCT', 'q0-feats': False}
# {'s0-word': 'стало', 's0-lemma': 'стати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Perf|Gender=Neut|Mood=Ind|Number=Sing|Tense=Past|VerbForm=Fin', 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin', 'q0-word': '.', 'q0-lemma': '.', 'q0-tag': 'PUNCT', 'q0-feats': False}
# {'s0-word': 'ігнорують', 's0-lemma': 'ігнорувати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin', 's1-tag': 'ROOT', 's1-feats': False, 'q0-word': '.', 'q0-lemma': '.', 'q0-tag': 'PUNCT', 'q0-feats': False}
# {'s0-word': '.', 's0-lemma': '.', 's0-tag': 'PUNCT', 's0-feats': False, 's1-tag': 'VERB', 's1-feats': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin'}
# {'s0-word': 'ігнорують', 's0-lemma': 'ігнорувати', 's0-tag': 'VERB', 's0-feats': 'Aspect=Imp|Mood=Ind|Number=Plur|Person=3|Tense=Pres|VerbForm=Fin', 's1-tag': 'ROOT', 's1-feats': False}
# {'s0-word': 'ROOT', 's0-lemma': 'ROOT', 's0-tag': 'ROOT', 's0-feats': False}
# ---------------------------------------

# %%
train_features, train_labels = [], []
for tree in train_trees:
    tree_features, tree_labels = get_data([t for t in tree if type(t["id"])==int])
    train_features += tree_features
    train_labels += tree_labels

print(len(train_features), len(train_labels))
# Out:
# 190298 190298

# %%
test_features, test_labels = [], []
for sentence in corpus:
    tree = transform_sent(sentence)
    tree_features, tree_labels = get_data([t for t in tree if type(t["id"])==int])
    test_features += tree_features
    test_labels += tree_labels

print(len(test_features), len(test_labels))
# Out:
# 322 322

# %%
from sklearn.feature_extraction import DictVectorizer 
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report

# %%
vectorizer = DictVectorizer()
vec = vectorizer.fit(train_features)
print("\nTotal number of features:", len(vec.get_feature_names()))
# Out:
# Total number of features: 115315

# %%
train_features_vectorized = vec.transform(train_features)
test_features_vectorized = vec.transform(test_features)
print(len(train_features_vectorized.toarray()), len(test_features_vectorized.toarray()))
# Out:
# 190298 322

# %%
lrc = LogisticRegression(random_state=42, solver="saga", multi_class="multinomial", max_iter=1000, verbose=1)
lrc.fit(train_features_vectorized, train_labels)
# Out:
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# convergence after 646 epochs took 161 seconds
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:  2.7min finished
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#                    intercept_scaling=1, l1_ratio=None, max_iter=1000,
#                    multi_class='multinomial', n_jobs=None, penalty='l2',
#                    random_state=42, solver='saga', tol=0.0001, verbose=1,
#                    warm_start=False)

# %%
predicted = lrc.predict(test_features_vectorized)
print(classification_report(test_labels, predicted))
# Out:
#               precision    recall  f1-score   support
#
#         left       0.96      0.83      0.89        83
#       reduce       0.82      0.95      0.88        81
#        right       0.82      0.84      0.83        75
#        shift       0.92      0.88      0.90        83
#
#     accuracy                           0.88       322
#    macro avg       0.88      0.88      0.88       322
# weighted avg       0.88      0.88      0.88       322
